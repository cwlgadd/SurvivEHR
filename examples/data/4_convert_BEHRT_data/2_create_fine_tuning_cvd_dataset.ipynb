# %% [markdown]
# # BEHRT dataset for cardiovascular disease outcomes in patients with Type 2 Diabete Mellitus
#
# In this workbook we demonstrate the workflow of adding the BEHRT adapter to FastEHR

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# !pwd

# %load_ext autoreload
# %autoreload 2
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# /rds/homes/g/gaddcz/Projects/CPRD/examples/data/4_convert_BEHRT_data

# %%
import torch
from hydra import compose, initialize
from omegaconf import OmegaConf
import logging
import time
import pickle as pkl
from tqdm import tqdm
import pandas as pd

from FastEHR.dataloader import FoundationalDataModule
from CPRD.examples.data.study_criteria import t2d_inclusion_method

logging.disable(logging.CRITICAL)
torch.manual_seed(1337)

logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")
# Out:
# Using device: cuda.

# %%
# load the configuration file, override any settings 
with initialize(version_base=None, config_path="../../modelling/SurvivEHR/confs", job_name="dataset_creation_notebook"):
    cfg = compose(config_name="config_CompetingRisk11M", overrides=[])

# Create new dataset 
cfg.data.path_to_ds = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/"
# Removing windowing applied to SurvivEHR by default so BEHRT can set it's own windowing
cfg.transformer.block_size = 1e6

print(OmegaConf.to_yaml(cfg))
# Out:
# is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: SurvivEHR
#   run_id: ${head.SurvLayer}PreTrain_small_${experiment.seed}
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: true
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
# fine_tuning:
#   fine_tune_outcomes: null
#   custom_outcome_method:
#     _target_: null
#   custom_stratification_method:
#     _target_: null
#   use_callbacks:
#     hidden_embedding:
#       num_batches: 1
#       mask_static: false
#       mask_value: false
#     performance_metrics: true
#     rmst: false
#   head:
#     surv_weight: 1
#     value_weight: 0
#     learning_rate: 0.0005
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: null
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 1000000.0
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression: None
#   value_weight: 0.1

# %% [markdown]
# # Adding an adapter
#
# Using FastEHR we can add an adapter to an existing dataloader which will be called inside the collator. This adapter will format the data to what is needed by the downstream task - in this case BEHRT.
#
# In doing this we still retain the PyTorch dataloader style, but in the case of BEHRT - the downstream model requires all of the data to instead be stored in a single dataframe.

# %%
# Build 
dm = FoundationalDataModule(
    path_to_db=cfg.data.path_to_db,
    path_to_ds=cfg.data.path_to_ds,
    load=True,
    overwrite_practice_ids = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/practice_id_splits.pickle",
    overwrite_meta_information=cfg.data.meta_information_path,
    num_threads=6,
    supervised=True,
    adapter="BEHRT",
)

vocab_size = dm.train_set.tokenizer.vocab_size

print(f"{len(dm.train_set)} training patients")
print(f"{len(dm.val_set)} validation patients")
print(f"{len(dm.test_set)} test patients")
print(f"{vocab_size} vocab elements")

# If we were to view the sample, this would be before collation and so we would see the original format.
# dm.train_set.view_sample(1, max_dynamic_events=None, report_time=True)
# Out:
# 572096 training patients
# 33280 validation patients
# 35758 test patients
# 265 vocab elements

# %% [markdown]
# ## Adapter tokeniser
#
# Our adapter also provides the new tokeniser which would be compatible with BEHRT, including the new special tokens "SEP", "CLS", and "MASK".

# %%
display(dm.adapter.tokenizer)
# Out:
# {'PAD': 0,
#  'UNK': 1,
#  'SEP': 2,
#  'CLS': 3,
#  'MASK': 4,
#  'ADDISONS_DISEASE': 5,
#  'CYSTICFIBROSIS': 6,
#  'SYSTEMIC_SCLEROSIS': 7,
#  'SICKLE_CELL_DISEASE_V2': 8,
#  'ADDISON_DISEASE': 9,
#  'DOWNSSYNDROME': 10,
#  'HAEMOCHROMATOSIS_V2': 11,
#  'PLASMACELL_NEOPLASM_V2': 12,
#  'SJOGRENSSYNDROME': 13,
#  'SYSTEMIC_LUPUS_ERYTHEMATOSUS': 14,
#  'HIVAIDS': 15,
#  'PSORIATICARTHRITIS2021': 16,
#  'MS': 17,
#  'Plasma_N_terminal_pro_B_type_natriuretic_peptide_conc_70': 18,
#  'LEUKAEMIA_PREVALENCEV2': 19,
#  'N_terminal_pro_brain_natriuretic_peptide_level_67': 20,
#  'ILD_SH': 21,
#  'CHRONIC_LIVER_DISEASE_ALCOHOL': 22,
#  'PERNICIOUSANAEMIA': 23,
#  'MENIERESDISEASE': 24,
#  'LYMPHOMA_PREVALENCE_V2': 25,
#  'CROHNS_DISEASE': 26,
#  'AllHIVdrugs_HIV': 27,
#  'Plasma_B_natriuretic_peptide_level_69': 28,
#  'CHRONICFATIGUESYNDROMEMM_V2': 29,
#  'Plasma_pro_brain_natriuretic_peptide_level_64': 30,
#  'STROKE_HAEMRGIC': 31,
#  'PARKINSONS': 32,
#  'AORTICANEURYSM_V2': 33,
#  'BIPOLAR': 34,
#  'BRONCHIECTASIS': 35,
#  'ULCERATIVE_COLITIS': 36,
#  'SCHIZOPHRENIAMM_V2': 37,
#  'PTSDDIAGNOSIS': 38,
#  'TYPE1DM': 39,
#  'FIBROMYALGIA': 40,
#  'VISUAL_IMPAIRMENT': 41,
#  'AUTISM': 42,
#  'NAFLD_V2': 43,
#  'ISCHAEMICSTROKE_V2': 44,
#  'Albumin___creatinine_ratio_37': 45,
#  'PVD_V3': 46,
#  'EATINGDISORDERS': 47,
#  'PMRANDGCA': 48,
#  'RHEUMATOIDARTHRITIS': 49,
#  'Urine_microalbumin_creatinine_ratio_36': 50,
#  'ENDOMETRIOSIS_ADENOMYOSIS_V2': 51,
#  'HYPERTHYROIDISM_V2': 52,
#  'Plasma_ferritin_level_62': 53,
#  'Brain_natriuretic_peptide_level_66': 54,
#  'OSA': 55,
#  'Monoamine_Oxidase_Inhibitors_OPTIMAL': 56,
#  'Serum_pro_brain_natriuretic_peptide_level_65': 57,
#  'Serum_vitamin_D2_level_89': 58,
#  'PAD_STRICT': 59,
#  'OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL': 60,
#  'POLYCYSTIC_OVARIAN_SYNDROME_PCOS_V2': 61,
#  'Total_25_hydroxyvitamin_D_level_91': 62,
#  'EPILEPSY': 63,
#  'Serum_N_terminal_pro_B_type_natriuretic_peptide_conc_68': 64,
#  'VALVULARDISEASES_V2': 65,
#  'Blood_calcium_level_38': 66,
#  'INR___international_normalised_ratio_81': 67,
#  'STROKEUNSPECIFIED_V2': 68,
#  'Combined_total_vitamin_D2_and_D3_level_93': 69,
#  'MINFARCTION': 70,
#  'Amantadine': 71,
#  'Meglitinides_Aurum': 72,
#  'SUBSTANCEMISUSE': 73,
#  'TSH_level_74': 74,
#  'Acarbose_AURUM': 75,
#  'Serum_T4_level_78': 76,
#  'HF_V3': 77,
#  'ALL_DEMENTIA': 78,
#  'LeflunomideAURUM_Zhaonan': 79,
#  'Plasma_cholesterol_HDL_ratio_96': 80,
#  'OSTEOPOROSIS': 81,
#  'GOUT': 82,
#  'Plasma_free_T4_level_77': 83,
#  'AF': 84,
#  'PSORIASIS': 85,
#  'COPD': 86,
#  '25_Hydroxyvitamin_D2_level_92': 87,
#  'Blood_urea_28': 88,
#  '25_Hydroxyvitamin_D3_level_90': 89,
#  'MAO_B_Optimal': 90,
#  'Galantamine_NEW': 91,
#  'PERIPHERAL_NEUROPATHY': 92,
#  'COMT_Optimal': 93,
#  'HYPOTHYROIDISM_DRAFT_V1': 94,
#  'Rivastigmine': 95,
#  'CKDSTAGE3TO5': 96,
#  'ALCOHOLMISUSE_V2': 97,
#  'IHDINCLUDINGMI_OPTIMALV2': 98,
#  'Plasma_corrected_calcium_level_43': 99,
#  'PREVALENT_IBS_V2': 100,
#  'Serum_25_Hydroxy_vitamin_D3_level_88': 101,
#  'Plasma_calcium_level_40': 102,
#  'TYPE2DIABETES': 103,
#  'Free_T4_level_76': 104,
#  'Plasma_LDL_cholesterol_level_104': 105,
#  'Calcium_adjusted_level_41': 106,
#  'ALLCANCER_NOHAEM_NOBCC': 107,
#  'Plasma_triglyceride_level_106': 108,
#  'DEATH': 109,
#  'AST___aspartate_transam_SGOT__46': 110,
#  'Plasma_gamma_glutamyl_transferase_level_58': 111,
#  'Plasma_urea_level_30': 112,
#  'Plasma_TSH_level_73': 113,
#  'Plasma_HDL_cholesterol_level_101': 114,
#  'Serum_total_25_hydroxy_vitamin_D_level_87': 115,
#  'Total_bilirubin_55': 116,
#  'ANY_DEAFNESS_HEARING_LOSS_V2': 117,
#  'Fibrate_FenofibrateOnly': 118,
#  'AMD_DH_Memantine': 119,
#  'Plasma_total_cholesterol_level_99': 120,
#  'Non_HDL_cholesterol_level_108': 121,
#  'Serum_vitamin_D_86': 122,
#  'OSTEOARTHRITIS': 123,
#  'GLP_1Aurum': 124,
#  'Plasma_alkaline_phosphatase_level_49': 125,
#  'ALLERGICRHINITISCONJ': 126,
#  'HydroxychloroquineAURUM_Zhaonan': 127,
#  'Plasma_total_bilirubin_level_54': 128,
#  'ANXIETY': 129,
#  'TSH___thyroid_stim_hormone_72': 130,
#  'Plasma_albumin_level_52': 131,
#  'HYPERTENSION': 132,
#  'Plasma_alanine_aminotransferase_level_44': 133,
#  'SGLT2inhibitors_Optimal': 134,
#  'SulfasalazineAURUM_Zhaonan': 135,
#  'DEPRESSION': 136,
#  'ASTHMA_PUSHASTHMA': 137,
#  'Haematocrit___PCV_16': 138,
#  'ATOPICECZEMA': 139,
#  'Lithium_OPTIMAL': 140,
#  'Plasma_potassium_level_27': 141,
#  'Plasma_sodium_level_25': 142,
#  'Plasma_creatinine_level_32': 143,
#  'Serum_total_cholesterol_level_98': 144,
#  'AMD_DH_Donepezil': 145,
#  'Thiazolidinediones_Aurum_JC': 146,
#  'Total_alkaline_phosphatase_48': 147,
#  'Haemoglobin_A1c_level_8': 148,
#  'Calculated_LDL_cholesterol_level_103': 149,
#  'MethotrexateAURUM_Zhaonan': 150,
#  'levodopa_Optimal': 151,
#  'LKA_PUSHAsthma': 152,
#  'Plasma_C_reactive_protein_60': 153,
#  'Dementia': 154,
#  'Current_smoker_83': 155,
#  'Serum_non_high_density_lipoprotein_cholesterol_level_107': 156,
#  'AST_serum_level_47': 157,
#  'AldosteroneAntagonist_D2T': 158,
#  'DPP4inhibitors_OPTIMAL': 159,
#  'POP_reg_contraceptive': 160,
#  'Carbamazepine_Optimal': 161,
#  'eGFR_using_creatinine_CKD_EPI_per_1_73_square_metres_33': 162,
#  'PropranololAnxiety_mumpredict': 163,
#  'ValproateMigraine': 164,
#  'Pregabalin_Optimal': 165,
#  'Serum_folate_80': 166,
#  'Direct_Acting_Oral_Anticoagulants_DOAC': 167,
#  'HbA1c_level__DCCT_aligned__7': 168,
#  'LABA_PUSH_Asthma': 169,
#  'phosphodiesterasetype5inhibitor_OPTIMAL': 170,
#  'Urine_albumin_creatinine_ratio_35': 171,
#  'LAMA_PUSHAsthma': 172,
#  'Total_cholesterol_HDL_ratio_95': 173,
#  'First_gen_H1_antihistamines': 174,
#  'Corrected_serum_calcium_level_42': 175,
#  'Serum_vitamin_B12_79': 176,
#  'Digoxin_': 177,
#  'Gabapentin_Oral_OPTIMAL': 178,
#  'Serum_C_reactive_protein_level_59': 179,
#  'UricAcid_LoweringDrugs_optimal': 180,
#  'SNRIs_OPTIMAL': 181,
#  'Serum_ferritin_63': 182,
#  'Serum_free_T4_level_75': 183,
#  'Serum_gamma_glutamyl_transferase_level_57': 184,
#  'Mirtazapine': 185,
#  'Serum_bilirubin_level_53': 186,
#  'Ex_smoker_84': 187,
#  'International_normalised_ratio_82': 188,
#  'Serum_calcium_39': 189,
#  'Serum_cholesterol_HDL_ratio_94': 190,
#  'Insulin_Aurum_v2': 191,
#  'Nasal_steroids_optimal': 192,
#  'asthma_combined_inhalers': 193,
#  'All_AntiArrhythmics_D2T': 194,
#  'OCS_PUSHAsthma2': 195,
#  'Erythrocyte_sedimentation_rate_61': 196,
#  'Serum_LDL_cholesterol_level_102': 197,
#  'Bisphosphonates_osteoporosis': 198,
#  'Antipsychotics_OPTIMAL': 199,
#  'Strong_Opioids_2022_Final': 200,
#  'Anxiolytics_mumpredict': 201,
#  'Systemic_oral_corticosteroids_optimal': 202,
#  'Sulphonylureas_Aurum': 203,
#  'COCP_reg_contraception': 204,
#  'Haemoglobin_A1c_level___IFCC_standardised_6': 205,
#  'Warfarin_': 206,
#  'Serum_triglycerides_105': 207,
#  'Amitriptyline_optimal': 208,
#  'Serum_alanine_aminotransferase_level_45': 209,
#  'Antihistamines_second_generation_H1_antagonists': 210,
#  'Red_blood_cell_distribution_width_17': 211,
#  'Serum_HDL_cholesterol_level_100': 212,
#  'AlphaBlocker': 213,
#  'all_contraceptive': 214,
#  'Serum_total_bilirubin_level_56': 215,
#  'Benzodiazepines': 216,
#  'Serum_TSH_level_71': 217,
#  'Serum_cholesterol_97': 218,
#  'Calcium_supplements_Optimal': 219,
#  'Never_smoked_tobacco_85': 220,
#  'Tricyclic_Antidepressants_final': 221,
#  'O_E___height_1': 222,
#  'Mean_corpusc_Hb_conc__MCHC__14': 223,
#  'ARBs_Luyuan': 224,
#  'Vitamin_D': 225,
#  'GFR_calculated_abbreviated_MDRD_34': 226,
#  'Metformin_612_A10BD2': 227,
#  'Serum_alkaline_phosphatase_50': 228,
#  'Haematocrit_15': 229,
#  'Serum_urea_level_29': 230,
#  'BetaBlockers_OPTIMAL': 231,
#  'Serum_albumin_51': 232,
#  'Paracetamol_OPTIMAL': 233,
#  'Basophil_count_22': 234,
#  'Mean_corpusc_haemoglobin_MCH__13': 235,
#  'Anticonvulsants_OPTIMAL': 236,
#  'SABA_PUSHAsthma': 237,
#  'Eosinophil_count_21': 238,
#  'Red_blood_cell__RBC__count_10': 239,
#  'Monocyte_count_23': 240,
#  'Lymphocyte_count_20': 241,
#  'Neutrophil_count_19': 242,
#  'Mean_corpuscular_volume__MCV__11': 243,
#  'Total_white_cell_count_18': 244,
#  'ICS_PUSHAsthma': 245,
#  'Platelet_count_12': 246,
#  'Haemoglobin_estimation_9': 247,
#  'Serum_potassium_26': 248,
#  'Serum_sodium_24': 249,
#  'Body_mass_index_3': 250,
#  'Serum_creatinine_31': 251,
#  'Thiazide_Diuretics_v2': 252,
#  'CalciumChannelBlck_D2T': 253,
#  'O_E___weight_2': 254,
#  'Levothyroxine_': 255,
#  'Aspirin_OPTIMAL': 256,
#  'SSRIs_Optimal': 257,
#  'Weak_Opioids_Final': 258,
#  'All_Antiplatelets': 259,
#  'All_Diuretics_D2T': 260,
#  'All_Diuretics_ExclLactones_D2T': 261,
#  'ACE_Inhibitors_D2T': 262,
#  'NSAIDS_oral_OPTIMAL_final': 263,
#  'Diastolic_blood_pressure_5': 264,
#  'Systolic_blood_pressure_4': 265,
#  'Statins': 266,
#  'Lipid_lowering_drugs_Optimal': 267}

# %% [markdown]
# ## Loading with an adapter
#
# Now when we load data into memory we get the correct form. We additionally retain values - despite now being used in BEHRT.
#
# We do not retain static baseline covariates, as these are not used in BEHRT. However it is simple to modify the existing adapter, or create new adapters to include this information.

# %%
for batch in dm.train_dataloader():
    break

def print_row(tkn, age, value):
    
    itostr = {tkn_str: tkn_idx for tkn_idx, tkn_str in dm.adapter.tokenizer.items()}
    
    print(f"{itostr[tkn.item()]}".ljust(50) + \
          f"{age.item() * dm.train_set.time_scale / 365:.1f}".ljust(10) + \
          f"{value.item():.1f}"
          )

# First patient of batch
atn_mask = batch["attention_mask"][0, :]
events = batch["tokens"][0, atn_mask==1]
ages = batch["ages"][0, atn_mask==1]
values = batch["values"][0, atn_mask==1]

print("Event".ljust(50) + "Age".ljust(10) + "Value".ljust(10) + "\n" + "="*70)
for event, age, value in zip(events, ages, values):
    print_row(event, age, value)


print("="*70)
print_row(batch['target_token'][0],
          batch['target_age_delta'][0] * dm.collate_fn.supervised_time_scale,
          batch['target_value'][0]
         )
# Out:
# Event                                             Age       Value
# ======================================================================
# CLS                                               33.9      nan
# Body_mass_index_3                                 33.9      -0.3
# Diastolic_blood_pressure_5                        33.9      -0.3
# O_E___height_1                                    33.9      0.1
# O_E___weight_2                                    33.9      -0.4
# Systolic_blood_pressure_4                         33.9      -0.3
# SEP                                               33.9      nan
# Serum_cholesterol_97                              33.9      -0.4
# Serum_triglycerides_105                           33.9      -0.4
# SEP                                               33.9      nan
# Serum_cholesterol_97                              34.9      -0.4
# Serum_triglycerides_105                           34.9      -0.5
# SEP                                               34.9      nan
# NSAIDS_oral_OPTIMAL_final                         36.9      nan
# SEP                                               36.9      nan
# NSAIDS_oral_OPTIMAL_final                         38.4      nan
# SEP                                               38.4      nan
# NSAIDS_oral_OPTIMAL_final                         38.4      nan
# SEP                                               38.4      nan
# NSAIDS_oral_OPTIMAL_final                         39.9      nan
# SEP                                               39.9      nan
# NSAIDS_oral_OPTIMAL_final                         46.1      nan
# GOUT                                              46.1      nan
# SEP                                               46.1      nan
# Serum_creatinine_31                               46.1      -0.5
# Serum_gamma_glutamyl_transferase_level_57         46.1      -0.0
# Serum_potassium_26                                46.1      -0.0
# Serum_sodium_24                                   46.1      -0.0
# Serum_urea_level_29                               46.1      0.1
# SEP                                               46.1      nan
# Never_smoked_tobacco_85                           48.6      nan
# SEP                                               48.6      nan
# Diastolic_blood_pressure_5                        50.1      -0.3
# Never_smoked_tobacco_85                           50.1      nan
# Systolic_blood_pressure_4                         50.1      -0.2
# SEP                                               50.1      nan
# Basophil_count_22                                 50.6      -0.5
# Diastolic_blood_pressure_5                        50.6      -0.3
# Eosinophil_count_21                               50.6      -0.5
# GFR_calculated_abbreviated_MDRD_34                50.6      -0.2
# Haematocrit_15                                    50.6      -0.0
# Haemoglobin_A1c_level___IFCC_standardised_6       50.6      -0.2
# Haemoglobin_estimation_9                          50.6      -0.5
# HbA1c_level__DCCT_aligned__7                      50.6      -0.5
# Lymphocyte_count_20                               50.6      -0.5
# Mean_corpusc_haemoglobin_MCH__13                  50.6      -0.2
# Mean_corpuscular_volume__MCV__11                  50.6      -0.2
# Monocyte_count_23                                 50.6      -0.5
# Neutrophil_count_19                               50.6      -0.4
# Platelet_count_12                                 50.6      -0.5
# Red_blood_cell__RBC__count_10                     50.6      -0.5
# Serum_HDL_cholesterol_level_100                   50.6      -0.2
# Serum_TSH_level_71                                50.6      -0.5
# Serum_albumin_51                                  50.6      -0.3
# Serum_cholesterol_97                              50.6      -0.4
# Serum_creatinine_31                               50.6      -0.5
# Serum_free_T4_level_75                            50.6      -0.5
# Serum_gamma_glutamyl_transferase_level_57         50.6      -0.1
# Serum_potassium_26                                50.6      -0.1
# Serum_sodium_24                                   50.6      -0.0
# Serum_total_bilirubin_level_56                    50.6      -0.5
# Serum_triglycerides_105                           50.6      -0.5
# Serum_urea_level_29                               50.6      0.0
# Systolic_blood_pressure_4                         50.6      -0.2
# Total_alkaline_phosphatase_48                     50.6      0.0
# Total_white_cell_count_18                         50.6      -0.5
# SEP                                               50.6      nan
# Body_mass_index_3                                 50.6      -0.3
# Diastolic_blood_pressure_5                        50.6      -0.3
# Diastolic_blood_pressure_5                        50.6      -0.3
# Never_smoked_tobacco_85                           50.6      nan
# O_E___height_1                                    50.6      0.1
# O_E___weight_2                                    50.6      -0.4
# Systolic_blood_pressure_4                         50.6      -0.2
# Systolic_blood_pressure_4                         50.6      -0.2
# Urine_albumin_creatinine_ratio_35                 50.6      -0.5
# Lipid_lowering_drugs_Optimal                      50.6      nan
# Statins                                           50.6      nan
# TYPE2DIABETES                                     50.6      nan
# SEP                                               50.6      nan
# ======================================================================
# phosphodiesterasetype5inhibitor_OPTIMAL           9.8       nan

# %% [markdown]
# # The BEHRT pandas dataset
#
# We now have a usable dataloader for a BEHRT model. However, the original code requires all data be saved in a single dataframe. This is done in the ``build_cvd_BEHRT_dataset.py`` file found in this directory.
#
# Here, we inspect what is produced.

# %% [markdown]
# ### Tokeniser
#
# The tokeniser (already shown above as an attribute of the datamodule class), was saved to file to be loaded into the BEHRT model framework

# %%
with open(cfg.data.path_to_ds + "BEHRT/token2idx.pkl", "rb") as f:
    bert_vocab = pkl.load(f)
    
display(bert_vocab)
# Out:
# {'token2idx': {'PAD': 0,
#   'UNK': 1,
#   'SEP': 2,
#   'CLS': 3,
#   'MASK': 4,
#   'ADDISONS_DISEASE': 5,
#   'CYSTICFIBROSIS': 6,
#   'SYSTEMIC_SCLEROSIS': 7,
#   'SICKLE_CELL_DISEASE_V2': 8,
#   'ADDISON_DISEASE': 9,
#   'DOWNSSYNDROME': 10,
#   'HAEMOCHROMATOSIS_V2': 11,
#   'PLASMACELL_NEOPLASM_V2': 12,
#   'SJOGRENSSYNDROME': 13,
#   'SYSTEMIC_LUPUS_ERYTHEMATOSUS': 14,
#   'HIVAIDS': 15,
#   'PSORIATICARTHRITIS2021': 16,
#   'MS': 17,
#   'Plasma_N_terminal_pro_B_type_natriuretic_peptide_conc_70': 18,
#   'LEUKAEMIA_PREVALENCEV2': 19,
#   'N_terminal_pro_brain_natriuretic_peptide_level_67': 20,
#   'ILD_SH': 21,
#   'CHRONIC_LIVER_DISEASE_ALCOHOL': 22,
#   'PERNICIOUSANAEMIA': 23,
#   'MENIERESDISEASE': 24,
#   'LYMPHOMA_PREVALENCE_V2': 25,
#   'CROHNS_DISEASE': 26,
#   'AllHIVdrugs_HIV': 27,
#   'Plasma_B_natriuretic_peptide_level_69': 28,
#   'CHRONICFATIGUESYNDROMEMM_V2': 29,
#   'Plasma_pro_brain_natriuretic_peptide_level_64': 30,
#   'STROKE_HAEMRGIC': 31,
#   'PARKINSONS': 32,
#   'AORTICANEURYSM_V2': 33,
#   'BIPOLAR': 34,
#   'BRONCHIECTASIS': 35,
#   'ULCERATIVE_COLITIS': 36,
#   'SCHIZOPHRENIAMM_V2': 37,
#   'PTSDDIAGNOSIS': 38,
#   'TYPE1DM': 39,
#   'FIBROMYALGIA': 40,
#   'VISUAL_IMPAIRMENT': 41,
#   'AUTISM': 42,
#   'NAFLD_V2': 43,
#   'ISCHAEMICSTROKE_V2': 44,
#   'Albumin___creatinine_ratio_37': 45,
#   'PVD_V3': 46,
#   'EATINGDISORDERS': 47,
#   'PMRANDGCA': 48,
#   'RHEUMATOIDARTHRITIS': 49,
#   'Urine_microalbumin_creatinine_ratio_36': 50,
#   'ENDOMETRIOSIS_ADENOMYOSIS_V2': 51,
#   'HYPERTHYROIDISM_V2': 52,
#   'Plasma_ferritin_level_62': 53,
#   'Brain_natriuretic_peptide_level_66': 54,
#   'OSA': 55,
#   'Monoamine_Oxidase_Inhibitors_OPTIMAL': 56,
#   'Serum_pro_brain_natriuretic_peptide_level_65': 57,
#   'Serum_vitamin_D2_level_89': 58,
#   'PAD_STRICT': 59,
#   'OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL': 60,
#   'POLYCYSTIC_OVARIAN_SYNDROME_PCOS_V2': 61,
#   'Total_25_hydroxyvitamin_D_level_91': 62,
#   'EPILEPSY': 63,
#   'Serum_N_terminal_pro_B_type_natriuretic_peptide_conc_68': 64,
#   'VALVULARDISEASES_V2': 65,
#   'Blood_calcium_level_38': 66,
#   'INR___international_normalised_ratio_81': 67,
#   'STROKEUNSPECIFIED_V2': 68,
#   'Combined_total_vitamin_D2_and_D3_level_93': 69,
#   'MINFARCTION': 70,
#   'Amantadine': 71,
#   'Meglitinides_Aurum': 72,
#   'SUBSTANCEMISUSE': 73,
#   'TSH_level_74': 74,
#   'Acarbose_AURUM': 75,
#   'Serum_T4_level_78': 76,
#   'HF_V3': 77,
#   'ALL_DEMENTIA': 78,
#   'LeflunomideAURUM_Zhaonan': 79,
#   'Plasma_cholesterol_HDL_ratio_96': 80,
#   'OSTEOPOROSIS': 81,
#   'GOUT': 82,
#   'Plasma_free_T4_level_77': 83,
#   'AF': 84,
#   'PSORIASIS': 85,
#   'COPD': 86,
#   '25_Hydroxyvitamin_D2_level_92': 87,
#   'Blood_urea_28': 88,
#   '25_Hydroxyvitamin_D3_level_90': 89,
#   'MAO_B_Optimal': 90,
#   'Galantamine_NEW': 91,
#   'PERIPHERAL_NEUROPATHY': 92,
#   'COMT_Optimal': 93,
#   'HYPOTHYROIDISM_DRAFT_V1': 94,
#   'Rivastigmine': 95,
#   'CKDSTAGE3TO5': 96,
#   'ALCOHOLMISUSE_V2': 97,
#   'IHDINCLUDINGMI_OPTIMALV2': 98,
#   'Plasma_corrected_calcium_level_43': 99,
#   'PREVALENT_IBS_V2': 100,
#   'Serum_25_Hydroxy_vitamin_D3_level_88': 101,
#   'Plasma_calcium_level_40': 102,
#   'TYPE2DIABETES': 103,
#   'Free_T4_level_76': 104,
#   'Plasma_LDL_cholesterol_level_104': 105,
#   'Calcium_adjusted_level_41': 106,
#   'ALLCANCER_NOHAEM_NOBCC': 107,
#   'Plasma_triglyceride_level_106': 108,
#   'DEATH': 109,
#   'AST___aspartate_transam_SGOT__46': 110,
#   'Plasma_gamma_glutamyl_transferase_level_58': 111,
#   'Plasma_urea_level_30': 112,
#   'Plasma_TSH_level_73': 113,
#   'Plasma_HDL_cholesterol_level_101': 114,
#   'Serum_total_25_hydroxy_vitamin_D_level_87': 115,
#   'Total_bilirubin_55': 116,
#   'ANY_DEAFNESS_HEARING_LOSS_V2': 117,
#   'Fibrate_FenofibrateOnly': 118,
#   'AMD_DH_Memantine': 119,
#   'Plasma_total_cholesterol_level_99': 120,
#   'Non_HDL_cholesterol_level_108': 121,
#   'Serum_vitamin_D_86': 122,
#   'OSTEOARTHRITIS': 123,
#   'GLP_1Aurum': 124,
#   'Plasma_alkaline_phosphatase_level_49': 125,
#   'ALLERGICRHINITISCONJ': 126,
#   'HydroxychloroquineAURUM_Zhaonan': 127,
#   'Plasma_total_bilirubin_level_54': 128,
#   'ANXIETY': 129,
#   'TSH___thyroid_stim_hormone_72': 130,
#   'Plasma_albumin_level_52': 131,
#   'HYPERTENSION': 132,
#   'Plasma_alanine_aminotransferase_level_44': 133,
#   'SGLT2inhibitors_Optimal': 134,
#   'SulfasalazineAURUM_Zhaonan': 135,
#   'DEPRESSION': 136,
#   'ASTHMA_PUSHASTHMA': 137,
#   'Haematocrit___PCV_16': 138,
#   'ATOPICECZEMA': 139,
#   'Lithium_OPTIMAL': 140,
#   'Plasma_potassium_level_27': 141,
#   'Plasma_sodium_level_25': 142,
#   'Plasma_creatinine_level_32': 143,
#   'Serum_total_cholesterol_level_98': 144,
#   'AMD_DH_Donepezil': 145,
#   'Thiazolidinediones_Aurum_JC': 146,
#   'Total_alkaline_phosphatase_48': 147,
#   'Haemoglobin_A1c_level_8': 148,
#   'Calculated_LDL_cholesterol_level_103': 149,
#   'MethotrexateAURUM_Zhaonan': 150,
#   'levodopa_Optimal': 151,
#   'LKA_PUSHAsthma': 152,
#   'Plasma_C_reactive_protein_60': 153,
#   'Dementia': 154,
#   'Current_smoker_83': 155,
#   'Serum_non_high_density_lipoprotein_cholesterol_level_107': 156,
#   'AST_serum_level_47': 157,
#   'AldosteroneAntagonist_D2T': 158,
#   'DPP4inhibitors_OPTIMAL': 159,
#   'POP_reg_contraceptive': 160,
#   'Carbamazepine_Optimal': 161,
#   'eGFR_using_creatinine_CKD_EPI_per_1_73_square_metres_33': 162,
#   'PropranololAnxiety_mumpredict': 163,
#   'ValproateMigraine': 164,
#   'Pregabalin_Optimal': 165,
#   'Serum_folate_80': 166,
#   'Direct_Acting_Oral_Anticoagulants_DOAC': 167,
#   'HbA1c_level__DCCT_aligned__7': 168,
#   'LABA_PUSH_Asthma': 169,
#   'phosphodiesterasetype5inhibitor_OPTIMAL': 170,
#   'Urine_albumin_creatinine_ratio_35': 171,
#   'LAMA_PUSHAsthma': 172,
#   'Total_cholesterol_HDL_ratio_95': 173,
#   'First_gen_H1_antihistamines': 174,
#   'Corrected_serum_calcium_level_42': 175,
#   'Serum_vitamin_B12_79': 176,
#   'Digoxin_': 177,
#   'Gabapentin_Oral_OPTIMAL': 178,
#   'Serum_C_reactive_protein_level_59': 179,
#   'UricAcid_LoweringDrugs_optimal': 180,
#   'SNRIs_OPTIMAL': 181,
#   'Serum_ferritin_63': 182,
#   'Serum_free_T4_level_75': 183,
#   'Serum_gamma_glutamyl_transferase_level_57': 184,
#   'Mirtazapine': 185,
#   'Serum_bilirubin_level_53': 186,
#   'Ex_smoker_84': 187,
#   'International_normalised_ratio_82': 188,
#   'Serum_calcium_39': 189,
#   'Serum_cholesterol_HDL_ratio_94': 190,
#   'Insulin_Aurum_v2': 191,
#   'Nasal_steroids_optimal': 192,
#   'asthma_combined_inhalers': 193,
#   'All_AntiArrhythmics_D2T': 194,
#   'OCS_PUSHAsthma2': 195,
#   'Erythrocyte_sedimentation_rate_61': 196,
#   'Serum_LDL_cholesterol_level_102': 197,
#   'Bisphosphonates_osteoporosis': 198,
#   'Antipsychotics_OPTIMAL': 199,
#   'Strong_Opioids_2022_Final': 200,
#   'Anxiolytics_mumpredict': 201,
#   'Systemic_oral_corticosteroids_optimal': 202,
#   'Sulphonylureas_Aurum': 203,
#   'COCP_reg_contraception': 204,
#   'Haemoglobin_A1c_level___IFCC_standardised_6': 205,
#   'Warfarin_': 206,
#   'Serum_triglycerides_105': 207,
#   'Amitriptyline_optimal': 208,
#   'Serum_alanine_aminotransferase_level_45': 209,
#   'Antihistamines_second_generation_H1_antagonists': 210,
#   'Red_blood_cell_distribution_width_17': 211,
#   'Serum_HDL_cholesterol_level_100': 212,
#   'AlphaBlocker': 213,
#   'all_contraceptive': 214,
#   'Serum_total_bilirubin_level_56': 215,
#   'Benzodiazepines': 216,
#   'Serum_TSH_level_71': 217,
#   'Serum_cholesterol_97': 218,
#   'Calcium_supplements_Optimal': 219,
#   'Never_smoked_tobacco_85': 220,
#   'Tricyclic_Antidepressants_final': 221,
#   'O_E___height_1': 222,
#   'Mean_corpusc_Hb_conc__MCHC__14': 223,
#   'ARBs_Luyuan': 224,
#   'Vitamin_D': 225,
#   'GFR_calculated_abbreviated_MDRD_34': 226,
#   'Metformin_612_A10BD2': 227,
#   'Serum_alkaline_phosphatase_50': 228,
#   'Haematocrit_15': 229,
#   'Serum_urea_level_29': 230,
#   'BetaBlockers_OPTIMAL': 231,
#   'Serum_albumin_51': 232,
#   'Paracetamol_OPTIMAL': 233,
#   'Basophil_count_22': 234,
#   'Mean_corpusc_haemoglobin_MCH__13': 235,
#   'Anticonvulsants_OPTIMAL': 236,
#   'SABA_PUSHAsthma': 237,
#   'Eosinophil_count_21': 238,
#   'Red_blood_cell__RBC__count_10': 239,
#   'Monocyte_count_23': 240,
#   'Lymphocyte_count_20': 241,
#   'Neutrophil_count_19': 242,
#   'Mean_corpuscular_volume__MCV__11': 243,
#   'Total_white_cell_count_18': 244,
#   'ICS_PUSHAsthma': 245,
#   'Platelet_count_12': 246,
#   'Haemoglobin_estimation_9': 247,
#   'Serum_potassium_26': 248,
#   'Serum_sodium_24': 249,
#   'Body_mass_index_3': 250,
#   'Serum_creatinine_31': 251,
#   'Thiazide_Diuretics_v2': 252,
#   'CalciumChannelBlck_D2T': 253,
#   'O_E___weight_2': 254,
#   'Levothyroxine_': 255,
#   'Aspirin_OPTIMAL': 256,
#   'SSRIs_Optimal': 257,
#   'Weak_Opioids_Final': 258,
#   'All_Antiplatelets': 259,
#   'All_Diuretics_D2T': 260,
#   'All_Diuretics_ExclLactones_D2T': 261,
#   'ACE_Inhibitors_D2T': 262,
#   'NSAIDS_oral_OPTIMAL_final': 263,
#   'Diastolic_blood_pressure_5': 264,
#   'Systolic_blood_pressure_4': 265,
#   'Statins': 266,
#   'Lipid_lowering_drugs_Optimal': 267}}

# %% [markdown]
# ### DataFrame
#
# Similarly, the pandas DataFrame was also saved to file

# %%
df = pd.read_parquet(cfg.data.path_to_ds + "BEHRT/dataset.parquet")

print(f"Dataframe with {len(df)} samples")
# Out:
# Dataframe with 572096 samples

# %%
display(df.head())
# Out:
#       patid                                         caliber_id  \
# 0  P0000001  [CLS, Body_mass_index_3, Diastolic_blood_press...
# 1  P0000002  [CLS, HYPERTENSION, SEP, OSTEOARTHRITIS, PREVA...
# 2  P0000003  [CLS, O_E___height_1, O_E___weight_2, SEP, AST...
# 3  P0000004  [CLS, Erythrocyte_sedimentation_rate_61, Eryth...
# 4  P0000005  [CLS, Body_mass_index_3, Diastolic_blood_press...
#
#                                                  age
# 0  [6.778630256652832, 6.778630256652832, 6.77863...
# 1  [11.300822257995605, 11.300822257995605, 11.30...
# 2  [4.4553422927856445, 4.4553422927856445, 4.455...
# 3  [5.9572601318359375, 5.9572601318359375, 5.957...
# 4  [6.888767242431641, 6.888767242431641, 6.88876...
