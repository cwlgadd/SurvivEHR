# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# !pwd

# %load_ext autoreload
# %autoreload 2
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# /rds/homes/g/gaddcz/Projects/CPRD/examples/data

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import logging
from tqdm import tqdm
import pickle
from hydra import compose, initialize
from omegaconf import OmegaConf
from CPRD.examples.modelling.SurvStreamGPT.experiment import run
from CPRD.data.foundational_loader import FoundationalDataModule
from CPRD.src.models.survival.task_heads.causal import SurvStreamGPTForCausalModelling

import time
import pyarrow.dataset as ds
import pyarrow.parquet as pq
import os
import polars as pl
pl.Config.set_tbl_rows(10000)
import pandas as pd
pd.options.display.max_rows = 10000

torch.manual_seed(1337)
torch.set_float32_matmul_precision('medium')

logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")
# Out:
# Using device: cuda.

# %% [markdown]
# ## Build configurations

# %%
# load the configuration file, override any settings 
with initialize(version_base=None, config_path="../modelling/SurvStreamGPT/confs", job_name="testing_notebook"):
    cfg = compose(config_name="config_SingleRisk11M", overrides=[])


# cfg.data.batch_size = 16
# cfg.transformer.block_size = 32
# # cfg.transformer.n_layer = 10

# %%
print(OmegaConf.to_yaml(cfg))
# Out:
# is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 20
#   global_diagnoses: false
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information.pickle
# experiment:
#   project_name: SurvStreamGPT_${head.SurvLayer}
#   run_id: PreTrain_${head.SurvLayer}_11M_${experiment.seed}
#   train: true
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
# optim:
#   num_epochs: 1
#   learning_rate: 0.0001
#   scheduler: CAWarmRestarts
#   scheduler_periods: 5000
#   scheduler_warmup: true
#   lr_cosine_decay_period: 10000000.0
#   val_check_interval: 1000
#   early_stop: false
#   early_stop_patience: 5
#   log_every_n_steps: 20
#   limit_val_batches: 0.05
#   limit_test_batches: 0.05
# transformer:
#   block_type: Neo
#   block_size: 128
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
# head:
#   SurvLayer: sr
#   surv_weight: 0.5
#   tokens_for_univariate_regression: None
#   value_weight: 0.5

# %%
# Build 
dm = FoundationalDataModule(path_to_db=cfg.data.path_to_db,
                            path_to_ds=cfg.data.path_to_ds,
                            load=True,
                            tokenizer="tabular",
                            batch_size=cfg.data.batch_size,
                            max_seq_length=cfg.transformer.block_size,
                            freq_threshold=cfg.data.unk_freq_threshold,
                            min_workers=cfg.data.min_workers,
                            inclusion_conditions=["COUNTRY = 'E'"],
                           )

vocab_size = dm.train_set.tokenizer.vocab_size
print(f"{vocab_size} vocab elements")

# list of univariate measurements to model with Normal distribution
# Extract the measurements, using the fact that the diagnoses are all up upper case.
measurements_for_univariate_regression = [record for record in dm.tokenizer._event_counts["EVENT"] if record.upper() != record]
cfg.head.tokens_for_univariate_regression = dm.encode(measurements_for_univariate_regression) 
# display(measurements_for_univariate_regression)
# Out:
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=train/ dataset, with 23,613,894 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=test/ dataset, with 1,508,320 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=val/ dataset, with 1,426,714 samples
# 265 vocab elements

# %%
start = time.time()   # starting time
for batch in dm.train_dataloader():
    break
print(f"batch loaded in {time.time()-start} seconds")    
    
# for key in batch.keys():
#     print(f"{key}".ljust(20) + f"{batch[key].shape}")

# tokens = batch["tokens"][0].tolist()    
# sentence = dm.decode(tokens).split(" ")
# for token, value in zip(sentence, batch["values"][0].tolist()):
#     print(f"{token}:".ljust(40) + f"{value}")

# %% [markdown]
# # View an example sample

# %%
dm.train_set.view_sample(12348, max_dynamic_events=120, report_time=True)
# Out:
# Time to retrieve sample index 12348 was 0.03458809852600098 seconds
#
# SEX                 | F
# IMD                 | 1.0
# ETHNICITY           | WHITE
# birth_year          | 1965.0
# Sequence of 99 events
#
# Token                                                                      | Age               | Standardised value
# ===================================================================================================================
# Diastolic_blood_pressure_5                                                 | 11137             | -0.04
# Systolic_blood_pressure_4                                                  | 11137             | -0.03
# Diastolic_blood_pressure_5                                                 | 11554             | 0.04
# Systolic_blood_pressure_4                                                  | 11554             | -0.03
# Anxiolytics_mumpredict                                                     | 12157             | nan
# Benzodiazepines                                                            | 12157             | nan
# Diastolic_blood_pressure_5                                                 | 12965             | 0.04
# Systolic_blood_pressure_4                                                  | 12965             | 0.17
# POP_reg_contraceptive                                                      | 13111             | nan
# all_contraceptive                                                          | 13111             | nan
# NSAIDS_oral_OPTIMAL_final                                                  | 13202             | nan
# Diastolic_blood_pressure_5                                                 | 13276             | 0.22
# Systolic_blood_pressure_4                                                  | 13276             | 0.46
# POP_reg_contraceptive                                                      | 13293             | nan
# all_contraceptive                                                          | 13293             | nan
# Diastolic_blood_pressure_5                                                 | 13371             | 0.22
# Systolic_blood_pressure_4                                                  | 13371             | 0.36
# POP_reg_contraceptive                                                      | 13371             | nan
# all_contraceptive                                                          | 13371             | nan
# Body_mass_index_3                                                          | 13475             | -0.21
# Diastolic_blood_pressure_5                                                 | 13475             | 0.39
# O_E___height_1                                                             | 13475             | 0.07
# O_E___weight_2                                                             | 13475             | -0.13
# Systolic_blood_pressure_4                                                  | 13475             | 0.44
# POP_reg_contraceptive                                                      | 13475             | nan
# all_contraceptive                                                          | 13475             | nan
# POP_reg_contraceptive                                                      | 13557             | nan
# all_contraceptive                                                          | 13557             | nan
# POP_reg_contraceptive                                                      | 13641             | nan
# all_contraceptive                                                          | 13641             | nan
# POP_reg_contraceptive                                                      | 13710             | nan
# all_contraceptive                                                          | 13710             | nan
# Diastolic_blood_pressure_5                                                 | 13768             | 0.22
# Systolic_blood_pressure_4                                                  | 13768             | 0.36
# Diastolic_blood_pressure_5                                                 | 13956             | 0.04
# O_E___weight_2                                                             | 13956             | -0.13
# Systolic_blood_pressure_4                                                  | 13956             | 0.07
# POP_reg_contraceptive                                                      | 13956             | nan
# all_contraceptive                                                          | 13956             | nan
# Basophil_count_22                                                          | 14001             | -0.05
# Eosinophil_count_21                                                        | 14001             | -0.18
# Haematocrit___PCV_16                                                       | 14001             | -0.06
# Haemoglobin_estimation_9                                                   | 14001             | nan
# Lymphocyte_count_20                                                        | 14001             | -0.23
# Mean_corpusc_Hb_conc__MCHC__14                                             | 14001             | nan
# Mean_corpusc_haemoglobin_MCH__13                                           | 14001             | 0.25
# Mean_corpuscular_volume__MCV__11                                           | 14001             | 0.20
# Monocyte_count_23                                                          | 14001             | 0.09
# Neutrophil_count_19                                                        | 14001             | nan
# Platelet_count_12                                                          | 14001             | 0.17
# Red_blood_cell__RBC__count_10                                              | 14001             | -0.19
# Serum_ferritin_63                                                          | 14001             | -0.19
# Serum_ferritin_63                                                          | 14001             | -0.19
# Serum_ferritin_63                                                          | 14001             | -0.19
# Serum_ferritin_63                                                          | 14001             | -0.19
# Serum_ferritin_63                                                          | 14001             | -0.18
# Serum_ferritin_63                                                          | 14001             | -0.18
# Serum_ferritin_63                                                          | 14001             | -0.18
# Serum_ferritin_63                                                          | 14001             | -0.16
# Serum_ferritin_63                                                          | 14001             | -0.16
# Serum_ferritin_63                                                          | 14001             | -0.16
# Serum_ferritin_63                                                          | 14001             | -0.15
# Serum_ferritin_63                                                          | 14001             | -0.15
# Serum_ferritin_63                                                          | 14001             | -0.10
# Serum_ferritin_63                                                          | 14001             | -0.09
# Serum_ferritin_63                                                          | 14001             | -0.09
# Serum_ferritin_63                                                          | 14001             | 0.08
# Serum_ferritin_63                                                          | 14001             | nan
# Total_white_cell_count_18                                                  | 14001             | 0.50
# Diastolic_blood_pressure_5                                                 | 14088             | 0.04
# Systolic_blood_pressure_4                                                  | 14088             | 0.26
# Body_mass_index_3                                                          | 14561             | -0.19
# O_E___height_1                                                             | 14561             | -0.01
# O_E___weight_2                                                             | 14561             | -0.15
# Body_mass_index_3                                                          | 14956             | -0.22
# O_E___height_1                                                             | 14956             | -0.01
# O_E___weight_2                                                             | 14956             | -0.17
# Body_mass_index_3                                                          | 15371             | -0.20
# Diastolic_blood_pressure_5                                                 | 15371             | 0.22
# O_E___height_1                                                             | 15371             | -0.01
# O_E___weight_2                                                             | 15371             | -0.16
# Systolic_blood_pressure_4                                                  | 15371             | 0.26
# Body_mass_index_3                                                          | 15790             | -0.20
# O_E___height_1                                                             | 15790             | -0.01
# O_E___weight_2                                                             | 15790             | -0.16
# NSAIDS_oral_OPTIMAL_final                                                  | 15834             | nan
# Paracetamol_OPTIMAL                                                        | 15834             | nan
# Body_mass_index_3                                                          | 16217             | -0.19
# Diastolic_blood_pressure_5                                                 | 16217             | 0.22
# O_E___height_1                                                             | 16217             | -0.01
# O_E___weight_2                                                             | 16217             | -0.15
# Systolic_blood_pressure_4                                                  | 16217             | 0.26
# Body_mass_index_3                                                          | 16617             | -0.18
# Diastolic_blood_pressure_5                                                 | 16617             | 0.31
# O_E___weight_2                                                             | 16617             | -0.14
# Systolic_blood_pressure_4                                                  | 16617             | nan
# PropranololAnxiety_mumpredict                                              | 20011             | nan
# PropranololAnxiety_mumpredict                                              | 20032             | nan
# DEATH                                                                      | 20062             | nan

# %%
times = []
start_time = time.time()
for _idx, row in enumerate(tqdm(dm.train_dataloader())):
    times.append(time.time() - start_time)
    start_time = time.time()
    if _idx > 10:
        break
print(np.mean(times))
# Out:
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch/2.0.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 20 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 11/359580 [00:16<146:46:04,  1.47s/it]
# 0.8016159335772196

# %%
print(np.mean(times))
# Out:
# 0.8016159335772196

# %% [markdown]
# ## View counts and frequency of each event

# %%
print(dm.tokenizer._event_counts)
# Out:
# shape: (264, 3)
# ┌───────────────────────────────────┬───────────┬───────────┐
# │ EVENT                             ┆ COUNT     ┆ FREQUENCY │
# │ ---                               ┆ ---       ┆ ---       │
# │ str                               ┆ u32       ┆ f64       │
# ╞═══════════════════════════════════╪═══════════╪═══════════╡
# │ UNK                               ┆ 0         ┆ 0.0       │
# │ ADDISONS_DISEASE                  ┆ 6691      ┆ 8.8559e-7 │
# │ CYSTICFIBROSIS                    ┆ 7053      ┆ 9.3350e-7 │
# │ SYSTEMIC_SCLEROSIS                ┆ 8772      ┆ 0.000001  │
# │ SICKLE_CELL_DISEASE_V2            ┆ 11159     ┆ 0.000001  │
# │ ADDISON_DISEASE                   ┆ 11794     ┆ 0.000002  │
# │ DOWNSSYNDROME                     ┆ 17006     ┆ 0.000002  │
# │ HAEMOCHROMATOSIS_V2               ┆ 18631     ┆ 0.000002  │
# │ PLASMACELL_NEOPLASM_V2            ┆ 20301     ┆ 0.000003  │
# │ SJOGRENSSYNDROME                  ┆ 23326     ┆ 0.000003  │
# │ SYSTEMIC_LUPUS_ERYTHEMATOSUS      ┆ 26820     ┆ 0.000004  │
# │ HIVAIDS                           ┆ 41951     ┆ 0.000006  │
# │ PSORIATICARTHRITIS2021            ┆ 51273     ┆ 0.000007  │
# │ MS                                ┆ 53204     ┆ 0.000007  │
# │ Plasma_N_terminal_pro_B_type_nat… ┆ 53534     ┆ 0.000007  │
# │ LEUKAEMIA_PREVALENCEV2            ┆ 54438     ┆ 0.000007  │
# │ N_terminal_pro_brain_natriuretic… ┆ 57470     ┆ 0.000008  │
# │ ILD_SH                            ┆ 58104     ┆ 0.000008  │
# │ CHRONIC_LIVER_DISEASE_ALCOHOL     ┆ 63405     ┆ 0.000008  │
# │ PERNICIOUSANAEMIA                 ┆ 73331     ┆ 0.00001   │
# │ MENIERESDISEASE                   ┆ 73688     ┆ 0.00001   │
# │ LYMPHOMA_PREVALENCE_V2            ┆ 80511     ┆ 0.000011  │
# │ CROHNS_DISEASE                    ┆ 81250     ┆ 0.000011  │
# │ AllHIVdrugs_HIV                   ┆ 82262     ┆ 0.000011  │
# │ Plasma_B_natriuretic_peptide_lev… ┆ 82488     ┆ 0.000011  │
# │ CHRONICFATIGUESYNDROMEMM_V2       ┆ 82799     ┆ 0.000011  │
# │ Plasma_pro_brain_natriuretic_pep… ┆ 83343     ┆ 0.000011  │
# │ STROKE_HAEMRGIC                   ┆ 83609     ┆ 0.000011  │
# │ PARKINSONS                        ┆ 91718     ┆ 0.000012  │
# │ AORTICANEURYSM_V2                 ┆ 101134    ┆ 0.000013  │
# │ BIPOLAR                           ┆ 108852    ┆ 0.000014  │
# │ BRONCHIECTASIS                    ┆ 112618    ┆ 0.000015  │
# │ ULCERATIVE_COLITIS                ┆ 120361    ┆ 0.000016  │
# │ SCHIZOPHRENIAMM_V2                ┆ 125141    ┆ 0.000017  │
# │ PTSDDIAGNOSIS                     ┆ 126269    ┆ 0.000017  │
# │ TYPE1DM                           ┆ 145143    ┆ 0.000019  │
# │ FIBROMYALGIA                      ┆ 153213    ┆ 0.00002   │
# │ VISUAL_IMPAIRMENT                 ┆ 155707    ┆ 0.000021  │
# │ AUTISM                            ┆ 156860    ┆ 0.000021  │
# │ NAFLD_V2                          ┆ 158688    ┆ 0.000021  │
# │ ISCHAEMICSTROKE_V2                ┆ 178437    ┆ 0.000024  │
# │ Albumin___creatinine_ratio_37     ┆ 180911    ┆ 0.000024  │
# │ PVD_V3                            ┆ 185904    ┆ 0.000025  │
# │ EATINGDISORDERS                   ┆ 191873    ┆ 0.000025  │
# │ PMRANDGCA                         ┆ 195907    ┆ 0.000026  │
# │ RHEUMATOIDARTHRITIS               ┆ 197253    ┆ 0.000026  │
# │ Urine_microalbumin_creatinine_ra… ┆ 201318    ┆ 0.000027  │
# │ ENDOMETRIOSIS_ADENOMYOSIS_V2      ┆ 209157    ┆ 0.000028  │
# │ HYPERTHYROIDISM_V2                ┆ 217964    ┆ 0.000029  │
# │ Plasma_ferritin_level_62          ┆ 220380    ┆ 0.000029  │
# │ Brain_natriuretic_peptide_level_… ┆ 229202    ┆ 0.00003   │
# │ OSA                               ┆ 234938    ┆ 0.000031  │
# │ Monoamine_Oxidase_Inhibitors_OPT… ┆ 236966    ┆ 0.000031  │
# │ Serum_pro_brain_natriuretic_pept… ┆ 243565    ┆ 0.000032  │
# │ Serum_vitamin_D2_level_89         ┆ 249092    ┆ 0.000033  │
# │ PAD_STRICT                        ┆ 254632    ┆ 0.000034  │
# │ OTHER_CHRONIC_LIVER_DISEASE_OPTI… ┆ 289252    ┆ 0.000038  │
# │ POLYCYSTIC_OVARIAN_SYNDROME_PCOS… ┆ 332297    ┆ 0.000044  │
# │ Total_25_hydroxyvitamin_D_level_… ┆ 333324    ┆ 0.000044  │
# │ EPILEPSY                          ┆ 377341    ┆ 0.00005   │
# │ Serum_N_terminal_pro_B_type_natr… ┆ 383790    ┆ 0.000051  │
# │ VALVULARDISEASES_V2               ┆ 401061    ┆ 0.000053  │
# │ Blood_calcium_level_38            ┆ 415717    ┆ 0.000055  │
# │ INR___international_normalised_r… ┆ 426165    ┆ 0.000056  │
# │ STROKEUNSPECIFIED_V2              ┆ 446046    ┆ 0.000059  │
# │ Combined_total_vitamin_D2_and_D3… ┆ 452984    ┆ 0.00006   │
# │ MINFARCTION                       ┆ 477556    ┆ 0.000063  │
# │ Amantadine                        ┆ 479791    ┆ 0.000064  │
# │ Meglitinides_Aurum                ┆ 486644    ┆ 0.000064  │
# │ SUBSTANCEMISUSE                   ┆ 502552    ┆ 0.000067  │
# │ TSH_level_74                      ┆ 507085    ┆ 0.000067  │
# │ Acarbose_AURUM                    ┆ 507434    ┆ 0.000067  │
# │ Serum_T4_level_78                 ┆ 524777    ┆ 0.000069  │
# │ HF_V3                             ┆ 524982    ┆ 0.000069  │
# │ ALL_DEMENTIA                      ┆ 528602    ┆ 0.00007   │
# │ LeflunomideAURUM_Zhaonan          ┆ 586799    ┆ 0.000078  │
# │ Plasma_cholesterol_HDL_ratio_96   ┆ 587483    ┆ 0.000078  │
# │ OSTEOPOROSIS                      ┆ 628118    ┆ 0.000083  │
# │ GOUT                              ┆ 632089    ┆ 0.000084  │
# │ Plasma_free_T4_level_77           ┆ 724108    ┆ 0.000096  │
# │ AF                                ┆ 731332    ┆ 0.000097  │
# │ PSORIASIS                         ┆ 743897    ┆ 0.000098  │
# │ COPD                              ┆ 751320    ┆ 0.000099  │
# │ 25_Hydroxyvitamin_D2_level_92     ┆ 782791    ┆ 0.000104  │
# │ Blood_urea_28                     ┆ 785766    ┆ 0.000104  │
# │ 25_Hydroxyvitamin_D3_level_90     ┆ 809104    ┆ 0.000107  │
# │ MAO_B_Optimal                     ┆ 829174    ┆ 0.00011   │
# │ Galantamine_NEW                   ┆ 830429    ┆ 0.00011   │
# │ PERIPHERAL_NEUROPATHY             ┆ 840638    ┆ 0.000111  │
# │ COMT_Optimal                      ┆ 886259    ┆ 0.000117  │
# │ HYPOTHYROIDISM_DRAFT_V1           ┆ 932079    ┆ 0.000123  │
# │ Rivastigmine                      ┆ 963471    ┆ 0.000128  │
# │ CKDSTAGE3TO5                      ┆ 1088754   ┆ 0.000144  │
# │ ALCOHOLMISUSE_V2                  ┆ 1125212   ┆ 0.000149  │
# │ IHDINCLUDINGMI_OPTIMALV2          ┆ 1162843   ┆ 0.000154  │
# │ Plasma_corrected_calcium_level_4… ┆ 1168224   ┆ 0.000155  │
# │ PREVALENT_IBS_V2                  ┆ 1210229   ┆ 0.00016   │
# │ Serum_25_Hydroxy_vitamin_D3_leve… ┆ 1211141   ┆ 0.00016   │
# │ Plasma_calcium_level_40           ┆ 1294409   ┆ 0.000171  │
# │ TYPE2DIABETES                     ┆ 1404325   ┆ 0.000186  │
# │ Free_T4_level_76                  ┆ 1405341   ┆ 0.000186  │
# │ Plasma_LDL_cholesterol_level_104  ┆ 1434461   ┆ 0.00019   │
# │ Calcium_adjusted_level_41         ┆ 1464226   ┆ 0.000194  │
# │ ALLCANCER_NOHAEM_NOBCC            ┆ 1496973   ┆ 0.000198  │
# │ Plasma_triglyceride_level_106     ┆ 1573268   ┆ 0.000208  │
# │ DEATH                             ┆ 1629100   ┆ 0.000216  │
# │ AST___aspartate_transam_SGOT__46  ┆ 1738489   ┆ 0.00023   │
# │ Plasma_gamma_glutamyl_transferas… ┆ 1762750   ┆ 0.000233  │
# │ Plasma_urea_level_30              ┆ 1991274   ┆ 0.000264  │
# │ Plasma_TSH_level_73               ┆ 2049380   ┆ 0.000271  │
# │ Plasma_HDL_cholesterol_level_101  ┆ 2173456   ┆ 0.000288  │
# │ Serum_total_25_hydroxy_vitamin_D… ┆ 2178432   ┆ 0.000288  │
# │ Total_bilirubin_55                ┆ 2193031   ┆ 0.00029   │
# │ ANY_DEAFNESS_HEARING_LOSS_V2      ┆ 2282766   ┆ 0.000302  │
# │ Fibrate_FenofibrateOnly           ┆ 2305308   ┆ 0.000305  │
# │ AMD_DH_Memantine                  ┆ 2309471   ┆ 0.000306  │
# │ Plasma_total_cholesterol_level_9… ┆ 2331589   ┆ 0.000309  │
# │ Non_HDL_cholesterol_level_108     ┆ 2408310   ┆ 0.000319  │
# │ Serum_vitamin_D_86                ┆ 2478806   ┆ 0.000328  │
# │ OSTEOARTHRITIS                    ┆ 2653242   ┆ 0.000351  │
# │ GLP_1Aurum                        ┆ 2676211   ┆ 0.000354  │
# │ Plasma_alkaline_phosphatase_leve… ┆ 3290802   ┆ 0.000436  │
# │ ALLERGICRHINITISCONJ              ┆ 3291165   ┆ 0.000436  │
# │ HydroxychloroquineAURUM_Zhaonan   ┆ 3312310   ┆ 0.000438  │
# │ Plasma_total_bilirubin_level_54   ┆ 3443114   ┆ 0.000456  │
# │ ANXIETY                           ┆ 3560978   ┆ 0.000471  │
# │ TSH___thyroid_stim_hormone_72     ┆ 3568579   ┆ 0.000472  │
# │ Plasma_albumin_level_52           ┆ 3719377   ┆ 0.000492  │
# │ HYPERTENSION                      ┆ 3934473   ┆ 0.000521  │
# │ Plasma_alanine_aminotransferase_… ┆ 4012790   ┆ 0.000531  │
# │ SGLT2inhibitors_Optimal           ┆ 4059940   ┆ 0.000537  │
# │ SulfasalazineAURUM_Zhaonan        ┆ 4084855   ┆ 0.000541  │
# │ DEPRESSION                        ┆ 4109336   ┆ 0.000544  │
# │ ASTHMA_PUSHASTHMA                 ┆ 4175115   ┆ 0.000553  │
# │ Haematocrit___PCV_16              ┆ 4346108   ┆ 0.000575  │
# │ ATOPICECZEMA                      ┆ 4369082   ┆ 0.000578  │
# │ Lithium_OPTIMAL                   ┆ 4395155   ┆ 0.000582  │
# │ Plasma_potassium_level_27         ┆ 4445152   ┆ 0.000588  │
# │ Plasma_sodium_level_25            ┆ 4458632   ┆ 0.00059   │
# │ Plasma_creatinine_level_32        ┆ 4513054   ┆ 0.000597  │
# │ Serum_total_cholesterol_level_98  ┆ 5185017   ┆ 0.000686  │
# │ AMD_DH_Donepezil                  ┆ 5635153   ┆ 0.000746  │
# │ Thiazolidinediones_Aurum_JC       ┆ 6191596   ┆ 0.000819  │
# │ Total_alkaline_phosphatase_48     ┆ 6461505   ┆ 0.000855  │
# │ Haemoglobin_A1c_level_8           ┆ 6516701   ┆ 0.000863  │
# │ Calculated_LDL_cholesterol_level… ┆ 6967780   ┆ 0.000922  │
# │ MethotrexateAURUM_Zhaonan         ┆ 7884622   ┆ 0.001044  │
# │ levodopa_Optimal                  ┆ 8483033   ┆ 0.001123  │
# │ LKA_PUSHAsthma                    ┆ 8537907   ┆ 0.00113   │
# │ Plasma_C_reactive_protein_60      ┆ 9155551   ┆ 0.001212  │
# │ Dementia                          ┆ 9738544   ┆ 0.001289  │
# │ Current_smoker_83                 ┆ 10592787  ┆ 0.001402  │
# │ Serum_non_high_density_lipoprote… ┆ 10648096  ┆ 0.001409  │
# │ AST_serum_level_47                ┆ 10837982  ┆ 0.001434  │
# │ AldosteroneAntagonist_D2T         ┆ 11182704  ┆ 0.00148   │
# │ DPP4inhibitors_OPTIMAL            ┆ 12000147  ┆ 0.001588  │
# │ POP_reg_contraceptive             ┆ 12186107  ┆ 0.001613  │
# │ Carbamazepine_Optimal             ┆ 12812897  ┆ 0.001696  │
# │ eGFR_using_creatinine_CKD_EPI_pe… ┆ 12869245  ┆ 0.001703  │
# │ PropranololAnxiety_mumpredict     ┆ 12924874  ┆ 0.001711  │
# │ ValproateMigraine                 ┆ 13594697  ┆ 0.001799  │
# │ Pregabalin_Optimal                ┆ 14497547  ┆ 0.001919  │
# │ Serum_folate_80                   ┆ 14643748  ┆ 0.001938  │
# │ Direct_Acting_Oral_Anticoagulant… ┆ 14815747  ┆ 0.001961  │
# │ HbA1c_level__DCCT_aligned__7      ┆ 14948615  ┆ 0.001979  │
# │ LABA_PUSH_Asthma                  ┆ 14958767  ┆ 0.00198   │
# │ phosphodiesterasetype5inhibitor_… ┆ 15057609  ┆ 0.001993  │
# │ Urine_albumin_creatinine_ratio_3… ┆ 15107807  ┆ 0.002     │
# │ LAMA_PUSHAsthma                   ┆ 15239995  ┆ 0.002017  │
# │ Total_cholesterol_HDL_ratio_95    ┆ 15760772  ┆ 0.002086  │
# │ First_gen_H1_antihistamines       ┆ 16181607  ┆ 0.002142  │
# │ Corrected_serum_calcium_level_42  ┆ 16683796  ┆ 0.002208  │
# │ Serum_vitamin_B12_79              ┆ 16797696  ┆ 0.002223  │
# │ Digoxin_                          ┆ 17497910  ┆ 0.002316  │
# │ Gabapentin_Oral_OPTIMAL           ┆ 17508445  ┆ 0.002317  │
# │ Serum_C_reactive_protein_level_5… ┆ 19234068  ┆ 0.002546  │
# │ UricAcid_LoweringDrugs_optimal    ┆ 20559558  ┆ 0.002721  │
# │ SNRIs_OPTIMAL                     ┆ 21379065  ┆ 0.00283   │
# │ Serum_ferritin_63                 ┆ 21412371  ┆ 0.002834  │
# │ Serum_free_T4_level_75            ┆ 22579062  ┆ 0.002988  │
# │ Serum_gamma_glutamyl_transferase… ┆ 22592131  ┆ 0.00299   │
# │ Mirtazapine                       ┆ 23524446  ┆ 0.003114  │
# │ Serum_bilirubin_level_53          ┆ 24090337  ┆ 0.003188  │
# │ Ex_smoker_84                      ┆ 24891632  ┆ 0.003295  │
# │ International_normalised_ratio_8… ┆ 27966697  ┆ 0.003702  │
# │ Serum_calcium_39                  ┆ 28049902  ┆ 0.003713  │
# │ Serum_cholesterol_HDL_ratio_94    ┆ 28586515  ┆ 0.003784  │
# │ Insulin_Aurum_v2                  ┆ 28641496  ┆ 0.003791  │
# │ Nasal_steroids_optimal            ┆ 29010523  ┆ 0.00384   │
# │ asthma_combined_inhalers          ┆ 29469516  ┆ 0.0039    │
# │ All_AntiArrhythmics_D2T           ┆ 29502352  ┆ 0.003905  │
# │ OCS_PUSHAsthma2                   ┆ 29568929  ┆ 0.003914  │
# │ Erythrocyte_sedimentation_rate_6… ┆ 29892785  ┆ 0.003956  │
# │ Serum_LDL_cholesterol_level_102   ┆ 30073152  ┆ 0.00398   │
# │ Bisphosphonates_osteoporosis      ┆ 30294675  ┆ 0.00401   │
# │ Antipsychotics_OPTIMAL            ┆ 31658166  ┆ 0.00419   │
# │ Strong_Opioids_2022_Final         ┆ 31728471  ┆ 0.004199  │
# │ Anxiolytics_mumpredict            ┆ 32874923  ┆ 0.004351  │
# │ Systemic_oral_corticosteroids_op… ┆ 33516650  ┆ 0.004436  │
# │ Sulphonylureas_Aurum              ┆ 34289555  ┆ 0.004538  │
# │ COCP_reg_contraception            ┆ 34316525  ┆ 0.004542  │
# │ Haemoglobin_A1c_level___IFCC_sta… ┆ 35091904  ┆ 0.004645  │
# │ Warfarin_                         ┆ 37353354  ┆ 0.004944  │
# │ Serum_triglycerides_105           ┆ 42415036  ┆ 0.005614  │
# │ Amitriptyline_optimal             ┆ 46415710  ┆ 0.006143  │
# │ Serum_alanine_aminotransferase_l… ┆ 46896239  ┆ 0.006207  │
# │ Antihistamines_second_generation… ┆ 47308115  ┆ 0.006261  │
# │ Red_blood_cell_distribution_widt… ┆ 49751137  ┆ 0.006585  │
# │ Serum_HDL_cholesterol_level_100   ┆ 50953183  ┆ 0.006744  │
# │ AlphaBlocker                      ┆ 51635379  ┆ 0.006834  │
# │ all_contraceptive                 ┆ 53655141  ┆ 0.007102  │
# │ Serum_total_bilirubin_level_56    ┆ 54098383  ┆ 0.00716   │
# │ Benzodiazepines                   ┆ 55608827  ┆ 0.00736   │
# │ Serum_TSH_level_71                ┆ 55655662  ┆ 0.007366  │
# │ Serum_cholesterol_97              ┆ 57393841  ┆ 0.007596  │
# │ Calcium_supplements_Optimal       ┆ 57542223  ┆ 0.007616  │
# │ Never_smoked_tobacco_85           ┆ 60751822  ┆ 0.008041  │
# │ Tricyclic_Antidepressants_final   ┆ 68893019  ┆ 0.009118  │
# │ O_E___height_1                    ┆ 69089436  ┆ 0.009144  │
# │ Mean_corpusc_Hb_conc__MCHC__14    ┆ 70867102  ┆ 0.00938   │
# │ ARBs_Luyuan                       ┆ 72329278  ┆ 0.009573  │
# │ Vitamin_D                         ┆ 72657845  ┆ 0.009617  │
# │ GFR_calculated_abbreviated_MDRD_… ┆ 73709249  ┆ 0.009756  │
# │ Metformin_612_A10BD2              ┆ 74162080  ┆ 0.009816  │
# │ Serum_alkaline_phosphatase_50     ┆ 76052242  ┆ 0.010066  │
# │ Haematocrit_15                    ┆ 76582325  ┆ 0.010136  │
# │ Serum_urea_level_29               ┆ 78670253  ┆ 0.010412  │
# │ BetaBlockers_OPTIMAL              ┆ 79374522  ┆ 0.010506  │
# │ Serum_albumin_51                  ┆ 83105055  ┆ 0.010999  │
# │ Paracetamol_OPTIMAL               ┆ 85242874  ┆ 0.011282  │
# │ Basophil_count_22                 ┆ 86869779  ┆ 0.011498  │
# │ Mean_corpusc_haemoglobin_MCH__13  ┆ 90498376  ┆ 0.011978  │
# │ Anticonvulsants_OPTIMAL           ┆ 90774779  ┆ 0.012015  │
# │ SABA_PUSHAsthma                   ┆ 91182585  ┆ 0.012069  │
# │ Eosinophil_count_21               ┆ 92193433  ┆ 0.012202  │
# │ Red_blood_cell__RBC__count_10     ┆ 92326200  ┆ 0.01222   │
# │ Monocyte_count_23                 ┆ 92489278  ┆ 0.012241  │
# │ Lymphocyte_count_20               ┆ 92896401  ┆ 0.012295  │
# │ Neutrophil_count_19               ┆ 93489124  ┆ 0.012374  │
# │ Mean_corpuscular_volume__MCV__11  ┆ 94723195  ┆ 0.012537  │
# │ Total_white_cell_count_18         ┆ 94827537  ┆ 0.012551  │
# │ ICS_PUSHAsthma                    ┆ 94873269  ┆ 0.012557  │
# │ Platelet_count_12                 ┆ 95904116  ┆ 0.012693  │
# │ Haemoglobin_estimation_9          ┆ 97391693  ┆ 0.01289   │
# │ Serum_potassium_26                ┆ 99036754  ┆ 0.013108  │
# │ Serum_sodium_24                   ┆ 99409745  ┆ 0.013157  │
# │ Body_mass_index_3                 ┆ 99868822  ┆ 0.013218  │
# │ Serum_creatinine_31               ┆ 102915170 ┆ 0.013621  │
# │ Thiazide_Diuretics_v2             ┆ 105228802 ┆ 0.013928  │
# │ CalciumChannelBlck_D2T            ┆ 108721302 ┆ 0.01439   │
# │ O_E___weight_2                    ┆ 117401338 ┆ 0.015539  │
# │ Levothyroxine_                    ┆ 117844926 ┆ 0.015597  │
# │ Aspirin_OPTIMAL                   ┆ 131327634 ┆ 0.017382  │
# │ SSRIs_Optimal                     ┆ 132417423 ┆ 0.017526  │
# │ Weak_Opioids_Final                ┆ 140622354 ┆ 0.018612  │
# │ All_Antiplatelets                 ┆ 162940629 ┆ 0.021566  │
# │ All_Diuretics_D2T                 ┆ 176070847 ┆ 0.023304  │
# │ All_Diuretics_ExclLactones_D2T    ┆ 176070847 ┆ 0.023304  │
# │ ACE_Inhibitors_D2T                ┆ 191462111 ┆ 0.025341  │
# │ NSAIDS_oral_OPTIMAL_final         ┆ 219183349 ┆ 0.02901   │
# │ Diastolic_blood_pressure_5        ┆ 241026671 ┆ 0.031901  │
# │ Systolic_blood_pressure_4         ┆ 241541988 ┆ 0.031969  │
# │ Statins                           ┆ 249911634 ┆ 0.033077  │
# │ Lipid_lowering_drugs_Optimal      ┆ 263876709 ┆ 0.034926  │
# └───────────────────────────────────┴───────────┴───────────┘

# %% [markdown]
# ## View the meta information that was collected during Polars transformation of data into ML friendly parquet files

# %%
import pandas as pd
pd.set_option('display.max_rows', 1000) #replace n with the number of columns you want to see completely
for _key in dm.train_set.meta_information.keys():
    display(dm.train_set.meta_information[_key])
# Out:
# {'SEX':   category     count
#  0        F  14278868
#  1        I       683
#  2        M  13841966,
#  'IMD':    category    count
#  0       NaN  2442913
#  1       1.0  4789813
#  2       2.0  4981882
#  3       3.0  5072397
#  4       4.0  5650727
#  5       5.0  5183785,
#  'ETHNICITY':   category     count
#  0    ASIAN   2267997
#  1    BLACK   1156866
#  2  MISSING   8058247
#  3    MIXED    485838
#  4    OTHER    422374
#  5    WHITE  15730195}
#                                   event    count
# 0                      ADDISONS_DISEASE     6691
# 1                       ADDISON_DISEASE    11794
# 2                                    AF   731332
# 3                      ALCOHOLMISUSE_V2  1125212
# 4                ALLCANCER_NOHAEM_NOBCC  1496973
# 5                  ALLERGICRHINITISCONJ  3291165
# 6                          ALL_DEMENTIA   528602
# 7                               ANXIETY  3560978
# 8          ANY_DEAFNESS_HEARING_LOSS_V2  2282766
# 9                     AORTICANEURYSM_V2   101134
# 10                    ASTHMA_PUSHASTHMA  4175115
# 11                         ATOPICECZEMA  4369082
# 12                               AUTISM   156860
# 13                              BIPOLAR   108852
# 14                       BRONCHIECTASIS   112618
# 15          CHRONICFATIGUESYNDROMEMM_V2    82799
# 16        CHRONIC_LIVER_DISEASE_ALCOHOL    63405
# 17                         CKDSTAGE3TO5  1088754
# 18                                 COPD   751320
# 19                       CROHNS_DISEASE    81250
# 20                       CYSTICFIBROSIS     7053
# 21                                DEATH  1629100
# 22                           DEPRESSION  4109336
# 23                        DOWNSSYNDROME    17006
# 24                      EATINGDISORDERS   191873
# 25         ENDOMETRIOSIS_ADENOMYOSIS_V2   209157
# 26                             EPILEPSY   377341
# 27                         FIBROMYALGIA   153213
# 28                                 GOUT   632089
# 29                  HAEMOCHROMATOSIS_V2    18631
# 30                                HF_V3   524982
# 31                              HIVAIDS    41951
# 32                         HYPERTENSION  3934473
# 33                   HYPERTHYROIDISM_V2   217964
# 34              HYPOTHYROIDISM_DRAFT_V1   932079
# 35             IHDINCLUDINGMI_OPTIMALV2  1162843
# 36                               ILD_SH    58104
# 37                   ISCHAEMICSTROKE_V2   178437
# 38               LEUKAEMIA_PREVALENCEV2    54438
# 39               LYMPHOMA_PREVALENCE_V2    80511
# 40                      MENIERESDISEASE    73688
# 41                          MINFARCTION   477556
# 42                                   MS    53204
# 43                             NAFLD_V2   158688
# 44                                  OSA   234938
# 45                       OSTEOARTHRITIS  2653242
# 46                         OSTEOPOROSIS   628118
# 47  OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL   289252
# 48                           PAD_STRICT   254632
# 49                           PARKINSONS    91718
# 50                PERIPHERAL_NEUROPATHY   840638
# 51                    PERNICIOUSANAEMIA    73331
# 52               PLASMACELL_NEOPLASM_V2    20301
# 53                            PMRANDGCA   195907
# 54  POLYCYSTIC_OVARIAN_SYNDROME_PCOS_V2   332297
# 55                     PREVALENT_IBS_V2  1210229
# 56                            PSORIASIS   743897
# 57               PSORIATICARTHRITIS2021    51273
# 58                        PTSDDIAGNOSIS   126269
# 59                               PVD_V3   185904
# 60                  RHEUMATOIDARTHRITIS   197253
# 61                   SCHIZOPHRENIAMM_V2   125141
# 62               SICKLE_CELL_DISEASE_V2    11159
# 63                     SJOGRENSSYNDROME    23326
# 64                 STROKEUNSPECIFIED_V2   446046
# 65                      STROKE_HAEMRGIC    83609
# 66                      SUBSTANCEMISUSE   502552
# 67         SYSTEMIC_LUPUS_ERYTHEMATOSUS    26820
# 68                   SYSTEMIC_SCLEROSIS     8772
# 69                              TYPE1DM   145143
# 70                        TYPE2DIABETES  1404325
# 71                   ULCERATIVE_COLITIS   120361
# 72                  VALVULARDISEASES_V2   401061
# 73                    VISUAL_IMPAIRMENT   155707
#                                                  event      count  count_obs  \
# 0                        25_Hydroxyvitamin_D2_level_92     782791     693470
# 1                        25_Hydroxyvitamin_D3_level_90     809104     781118
# 2                     AST___aspartate_transam_SGOT__46    1738489    1680613
# 3                                   AST_serum_level_47   10837982   10485351
# 4                        Albumin___creatinine_ratio_37     180911      78420
# 5                                    Basophil_count_22   86869779   85642540
# 6                               Blood_calcium_level_38     415717     385464
# 7                                        Blood_urea_28     785766     671861
# 8                                    Body_mass_index_3   99868822   97759312
# 9                   Brain_natriuretic_peptide_level_66     229202     159318
# 10                           Calcium_adjusted_level_41    1464226    1457911
# 11                Calculated_LDL_cholesterol_level_103    6967780    6719746
# 12           Combined_total_vitamin_D2_and_D3_level_93     452984     424568
# 13                    Corrected_serum_calcium_level_42   16683796   16264645
# 14                                   Current_smoker_83   10592787    2509612
# 15                          Diastolic_blood_pressure_5  241026671  240724855
# 16                                 Eosinophil_count_21   92193433   91608967
# 17                   Erythrocyte_sedimentation_rate_61   29892785   24659777
# 18                                        Ex_smoker_84   24891632    1988555
# 19                                    Free_T4_level_76    1405341    1254654
# 20                  GFR_calculated_abbreviated_MDRD_34   73709249   65832806
# 21                                Haematocrit___PCV_16    4346108    4313923
# 22                                      Haematocrit_15   76582325   76295018
# 23         Haemoglobin_A1c_level___IFCC_standardised_6   35091904   32542190
# 24                             Haemoglobin_A1c_level_8    6516701    2279027
# 25                            Haemoglobin_estimation_9   97391693   96533626
# 26                        HbA1c_level__DCCT_aligned__7   14948615   12120543
# 27             INR___international_normalised_ratio_81     426165     409175
# 28                   International_normalised_ratio_82   27966697   24573431
# 29                                 Lymphocyte_count_20   92896401   92370088
# 30                      Mean_corpusc_Hb_conc__MCHC__14   70867102   70624255
# 31                    Mean_corpusc_haemoglobin_MCH__13   90498376   90220814
# 32                    Mean_corpuscular_volume__MCV__11   94723195   94409919
# 33                                   Monocyte_count_23   92489278   91979180
# 34   N_terminal_pro_brain_natriuretic_peptide_level_67      57470      53401
# 35                                 Neutrophil_count_19   93489124   92851403
# 36                             Never_smoked_tobacco_85   60751822    1538646
# 37                       Non_HDL_cholesterol_level_108    2408310    2393900
# 38                                      O_E___height_1   69089436   68753070
# 39                                      O_E___weight_2  117401338  116811930
# 40               Plasma_B_natriuretic_peptide_level_69      82488      78777
# 41                        Plasma_C_reactive_protein_60    9155551    7401061
# 42                    Plasma_HDL_cholesterol_level_101    2173456    2111774
# 43                    Plasma_LDL_cholesterol_level_104    1434461    1249520
# 44   Plasma_N_terminal_pro_B_type_natriuretic_pepti...      53534      52305
# 45                                 Plasma_TSH_level_73    2049380    2017201
# 46            Plasma_alanine_aminotransferase_level_44    4012790    3989304
# 47                             Plasma_albumin_level_52    3719377    3707409
# 48                Plasma_alkaline_phosphatase_level_49    3290802    3281396
# 49                             Plasma_calcium_level_40    1294409    1286874
# 50                     Plasma_cholesterol_HDL_ratio_96     587483     575593
# 51                   Plasma_corrected_calcium_level_43    1168224     900092
# 52                          Plasma_creatinine_level_32    4513054    4489265
# 53                            Plasma_ferritin_level_62     220380     167898
# 54                             Plasma_free_T4_level_77     724108     681695
# 55          Plasma_gamma_glutamyl_transferase_level_58    1762750    1749440
# 56                           Plasma_potassium_level_27    4445152    4402840
# 57       Plasma_pro_brain_natriuretic_peptide_level_64      83343      70129
# 58                              Plasma_sodium_level_25    4458632    4425530
# 59                     Plasma_total_bilirubin_level_54    3443114    3429483
# 60                   Plasma_total_cholesterol_level_99    2331589    2302691
# 61                       Plasma_triglyceride_level_106    1573268    1548859
# 62                                Plasma_urea_level_30    1991274    1968449
# 63                                   Platelet_count_12   95904116   95382243
# 64                       Red_blood_cell__RBC__count_10   92326200   91855577
# 65                Red_blood_cell_distribution_width_17   49751137   46387000
# 66                Serum_25_Hydroxy_vitamin_D3_level_88    1211141     847628
# 67                   Serum_C_reactive_protein_level_59   19234068   16340825
# 68                     Serum_HDL_cholesterol_level_100   50953183   50016821
# 69                     Serum_LDL_cholesterol_level_102   30073152   29091476
# 70   Serum_N_terminal_pro_B_type_natriuretic_peptid...     383790     335656
# 71                                   Serum_T4_level_78     524777     450988
# 72                                  Serum_TSH_level_71   55655662   52458151
# 73             Serum_alanine_aminotransferase_level_45   46896239   46118828
# 74                                    Serum_albumin_51   83105055   82755894
# 75                       Serum_alkaline_phosphatase_50   76052242   75709587
# 76                            Serum_bilirubin_level_53   24090337   23943058
# 77                                    Serum_calcium_39   28049902   26929397
# 78                                Serum_cholesterol_97   57393841   55137024
# 79                      Serum_cholesterol_HDL_ratio_94   28586515   27949257
# 80                                 Serum_creatinine_31  102915170  101600210
# 81                                   Serum_ferritin_63   21412371   18831052
# 82                                     Serum_folate_80   14643748   13245269
# 83                              Serum_free_T4_level_75   22579062   21978910
# 84           Serum_gamma_glutamyl_transferase_level_57   22592131   21804090
# 85   Serum_non_high_density_lipoprotein_cholesterol...   10648096   10620740
# 86                                  Serum_potassium_26   99036754   97495916
# 87        Serum_pro_brain_natriuretic_peptide_level_65     243565     196058
# 88                                     Serum_sodium_24   99409745   98817250
# 89           Serum_total_25_hydroxy_vitamin_D_level_87    2178432    1882341
# 90                      Serum_total_bilirubin_level_56   54098383   53753453
# 91                    Serum_total_cholesterol_level_98    5185017    5100659
# 92                             Serum_triglycerides_105   42415036   41980818
# 93                                 Serum_urea_level_29   78670253   78276364
# 94                                Serum_vitamin_B12_79   16797696   15132281
# 95                           Serum_vitamin_D2_level_89     249092     204719
# 96                                  Serum_vitamin_D_86    2478806    1741767
# 97                           Systolic_blood_pressure_4  241541988  241223179
# 98                       TSH___thyroid_stim_hormone_72    3568579    3063531
# 99                                        TSH_level_74     507085     272902
# 100                 Total_25_hydroxyvitamin_D_level_91     333324     283455
# 101                      Total_alkaline_phosphatase_48    6461505    6422922
# 102                                 Total_bilirubin_55    2193031    2141609
# 103                     Total_cholesterol_HDL_ratio_95   15760772   15489099
# 104                          Total_white_cell_count_18   94827537   94179010
# 105                  Urine_albumin_creatinine_ratio_35   15107807   10249206
# 106             Urine_microalbumin_creatinine_ratio_36     201318      94009
# 107  eGFR_using_creatinine_CKD_EPI_per_1_73_square_...   12869245   11902149
# 108                                 ACE_Inhibitors_D2T  191462111          0
# 109                                   AMD_DH_Donepezil    5635153          0
# 110                                   AMD_DH_Memantine    2309471          0
# 111                                        ARBs_Luyuan   72329278          0
# 112                                     Acarbose_AURUM     507434          0
# 113                          AldosteroneAntagonist_D2T   11182704          0
# 114                                    AllHIVdrugs_HIV      82262          0
# 115                            All_AntiArrhythmics_D2T   29502352          0
# 116                                  All_Antiplatelets  162940629          0
# 117                                  All_Diuretics_D2T  176070847          0
# 118                     All_Diuretics_ExclLactones_D2T  176070847          0
# 119                                       AlphaBlocker   51635379          0
# 120                                         Amantadine     479791          0
# 121                              Amitriptyline_optimal   46415710          0
# 122                            Anticonvulsants_OPTIMAL   90774779          0
# 123    Antihistamines_second_generation_H1_antagonists   47308115          0
# 124                             Antipsychotics_OPTIMAL   31658166          0
# 125                             Anxiolytics_mumpredict   32874923          0
# 126                                    Aspirin_OPTIMAL  131327634          0
# 127                                    Benzodiazepines   55608827          0
# 128                               BetaBlockers_OPTIMAL   79374522          0
# 129                       Bisphosphonates_osteoporosis   30294675          0
# 130                             COCP_reg_contraception   34316525          0
# 131                                       COMT_Optimal     886259          0
# 132                             CalciumChannelBlck_D2T  108721302          0
# 133                        Calcium_supplements_Optimal   57542223          0
# 134                              Carbamazepine_Optimal   12812897          0
# 135                             DPP4inhibitors_OPTIMAL   12000147          0
# 136                                           Dementia    9738544          0
# 137                                           Digoxin_   17497910          0
# 138             Direct_Acting_Oral_Anticoagulants_DOAC   14815747          0
# 139                            Fibrate_FenofibrateOnly    2305308          0
# 140                        First_gen_H1_antihistamines   16181607          0
# 141                                         GLP_1Aurum    2676211          0
# 142                            Gabapentin_Oral_OPTIMAL   17508445          0
# 143                                    Galantamine_NEW     830429          0
# 144                    HydroxychloroquineAURUM_Zhaonan    3312310          0
# 145                                     ICS_PUSHAsthma   94873269          0
# 146                                   Insulin_Aurum_v2   28641496          0
# 147                                   LABA_PUSH_Asthma   14958767          0
# 148                                    LAMA_PUSHAsthma   15239995          0
# 149                                     LKA_PUSHAsthma    8537907          0
# 150                           LeflunomideAURUM_Zhaonan     586799          0
# 151                                     Levothyroxine_  117844926          0
# 152                       Lipid_lowering_drugs_Optimal  263876709          0
# 153                                    Lithium_OPTIMAL    4395155          0
# 154                                      MAO_B_Optimal     829174          0
# 155                                 Meglitinides_Aurum     486644          0
# 156                               Metformin_612_A10BD2   74162080          0
# 157                          MethotrexateAURUM_Zhaonan    7884622          0
# 158                                        Mirtazapine   23524446          0
# 159               Monoamine_Oxidase_Inhibitors_OPTIMAL     236966          0
# 160                          NSAIDS_oral_OPTIMAL_final  219183349          0
# 161                             Nasal_steroids_optimal   29010523          0
# 162                                    OCS_PUSHAsthma2   29568929          0
# 163                              POP_reg_contraceptive   12186107          0
# 164                                Paracetamol_OPTIMAL   85242874          0
# 165                                 Pregabalin_Optimal   14497547          0
# 166                      PropranololAnxiety_mumpredict   12924874          0
# 167                                       Rivastigmine     963471          0
# 168                                    SABA_PUSHAsthma   91182585          0
# 169                            SGLT2inhibitors_Optimal    4059940          0
# 170                                      SNRIs_OPTIMAL   21379065          0
# 171                                      SSRIs_Optimal  132417423          0
# 172                                            Statins  249911634          0
# 173                          Strong_Opioids_2022_Final   31728471          0
# 174                         SulfasalazineAURUM_Zhaonan    4084855          0
# 175                               Sulphonylureas_Aurum   34289555          0
# 176              Systemic_oral_corticosteroids_optimal   33516650          0
# 177                              Thiazide_Diuretics_v2  105228802          0
# 178                        Thiazolidinediones_Aurum_JC    6191596          0
# 179                    Tricyclic_Antidepressants_final   68893019          0
# 180                     UricAcid_LoweringDrugs_optimal   20559558          0
# 181                                  ValproateMigraine   13594697          0
# 182                                          Vitamin_D   72657845          0
# 183                                          Warfarin_   37353354          0
# 184                                 Weak_Opioids_Final  140622354          0
# 185                                  all_contraceptive   53655141          0
# 186                           asthma_combined_inhalers   29469516          0
# 187                                   levodopa_Optimal    8483033          0
# 188            phosphodiesterasetype5inhibitor_OPTIMAL   15057609          0
#
#                                                 digest           min  \
# 0    ({'m': 0.0, 'c': 9.0}, {'m': 0.1, 'c': 112.0},...  0.000000e+00
# 1    ({'m': 0.1, 'c': 3.0}, {'m': 1.0, 'c': 314.0},...  0.000000e+00
# 2    ({'m': 0.0, 'c': 3901.0}, {'m': 0.770571428571...  0.000000e+00
# 3    ({'m': 0.0, 'c': 53.0}, {'m': 1.8, 'c': 1.0}, ... -5.000000e+00
# 4    ({'m': -1.0, 'c': 1.0}, {'m': 0.0, 'c': 4213.0... -1.000000e+00
# 5    ({'m': 0.0, 'c': 37098.0}, {'m': 0.01, 'c': 28... -1.000000e-01
# 6    ({'m': 0.0, 'c': 33.0}, {'m': 1.0, 'c': 1.0}, ...  0.000000e+00
# 7    ({'m': 0.0, 'c': 2746.0}, {'m': 0.09, 'c': 1.0...  0.000000e+00
# 8    ({'m': 0.0, 'c': 14.0}, {'m': 0.05, 'c': 1.0},... -3.268000e+04
# 9    ({'m': 0.0, 'c': 120.0}, {'m': 0.1, 'c': 1.0},...  0.000000e+00
# 10   ({'m': 0.99, 'c': 1.0}, {'m': 1.04, 'c': 1.0},...  0.000000e+00
# 11   ({'m': 0.0, 'c': 1.0}, {'m': 0.1, 'c': 15.0}, ... -8.400000e+00
# 12   ({'m': 0.0, 'c': 9.0}, {'m': 2.2, 'c': 1.0}, {...  0.000000e+00
# 13   ({'m': 0.0, 'c': 4.0}, {'m': 0.16, 'c': 1.0}, ... -2.580000e+00
# 14   ({'m': 0.0, 'c': 893.0}, {'m': 0.2, 'c': 2.0},... -2.030000e+03
# 15   ({'m': 0.0, 'c': 8.0}, {'m': 5.0, 'c': 1.0}, {... -1.200000e+02
# 16   ({'m': 0.0, 'c': 3017.0}, {'m': 0.01, 'c': 255... -6.000000e-01
# 17   ({'m': -4.0, 'c': 2.0}, {'m': 0.0, 'c': 127.0}... -2.000000e+01
# 18   ({'m': -1.0, 'c': 1.0}, {'m': 0.0, 'c': 3006.0... -2.030000e+03
# 19   ({'m': -9.1, 'c': 1.0}, {'m': -8.8, 'c': 1.0},... -1.340000e+02
# 20   ({'m': 0.0, 'c': 17.0}, {'m': 1.73, 'c': 1.0},... -9.000000e+01
# 21   ({'m': -0.29, 'c': 1.0}, {'m': -0.28, 'c': 5.0... -4.650000e-01
# 22   ({'m': 0.003, 'c': 2.0}, {'m': 0.004, 'c': 1.0...  0.000000e+00
# 23   ({'m': 0.0, 'c': 2.0}, {'m': 3.9, 'c': 1.0}, {... -7.900000e+01
# 24   ({'m': 0.0, 'c': 6.0}, {'m': 0.1, 'c': 1.0}, {...  0.000000e+00
# 25   ({'m': 1.38, 'c': 1.0}, {'m': 6.9, 'c': 1.0}, ... -1.120000e+02
# 26   ({'m': 0.0, 'c': 17.0}, {'m': 0.67, 'c': 1.0},... -4.100000e+01
# 27   ({'m': 0.0, 'c': 22.0}, {'m': 0.1, 'c': 3.0}, ...  0.000000e+00
# 28   ({'m': 0.0, 'c': 36.0}, {'m': 0.2, 'c': 2.0}, ... -3.400000e+01
# 29   ({'m': 0.0, 'c': 3.0}, {'m': 0.03, 'c': 2.0}, ... -3.500000e+01
# 30   ({'m': 0.0, 'c': 1.0}, {'m': 0.36, 'c': 1.0}, ... -2.950000e+02
# 31   ({'m': 10.8, 'c': 1.0}, {'m': 12.7, 'c': 2.0},... -2.890000e+01
# 32   ({'m': 0.3, 'c': 1.0}, {'m': 0.4, 'c': 1.0}, {... -1.004000e+02
# 33   ({'m': 0.0, 'c': 10.0}, {'m': 0.03, 'c': 2.0},... -4.000000e+00
# 34   ({'m': 0.0, 'c': 1.0}, {'m': 1.0, 'c': 8.0}, {...  0.000000e+00
# 35   ({'m': 0.0, 'c': 7.0}, {'m': 0.01, 'c': 1.0}, ... -6.700000e+01
# 36   ({'m': -25.0, 'c': 3.0}, {'m': -1.0, 'c': 2.0}... -2.500000e+01
# 37   ({'m': -1.6, 'c': 1.0}, {'m': -1.2, 'c': 1.0},... -1.600000e+00
# 38   ({'m': 0.0, 'c': 148.0}, {'m': 0.14, 'c': 1.0}... -1.079000e+05
# 39   ({'m': 0.0, 'c': 23.0}, {'m': 0.093, 'c': 1.0}... -1.170000e+04
# 40   ({'m': 0.0, 'c': 51.0}, {'m': 0.58, 'c': 12.0}...  0.000000e+00
# 41   ({'m': 0.0, 'c': 17.0}, {'m': 0.1, 'c': 821.0}... -3.814000e+03
# 42   ({'m': 0.0, 'c': 4.0}, {'m': 0.05, 'c': 1.0}, ...  0.000000e+00
# 43   ({'m': 0.0, 'c': 37.0}, {'m': 0.1, 'c': 3.0}, ...  0.000000e+00
# 44   ({'m': 0.2, 'c': 1.0}, {'m': 1.0, 'c': 31.0}, ...  2.000000e-01
# 45   ({'m': 0.0, 'c': 74.0}, {'m': 0.001, 'c': 1.0}... -7.800000e+00
# 46   ({'m': 0.0, 'c': 13.0}, {'m': 1.0, 'c': 4.0}, ...  0.000000e+00
# 47   ({'m': 0.0, 'c': 3.0}, {'m': 10.0, 'c': 1.0}, ...  0.000000e+00
# 48   ({'m': 0.0, 'c': 6.0}, {'m': 0.69, 'c': 1.0}, ... -2.400000e+01
# 49   ({'m': 0.0, 'c': 2.0}, {'m': 0.13, 'c': 2.0}, ...  0.000000e+00
# 50   ({'m': 0.0, 'c': 6.0}, {'m': 0.16, 'c': 1.0}, ...  0.000000e+00
# 51   ({'m': 0.0, 'c': 13.0}, {'m': 0.12, 'c': 1.0},...  0.000000e+00
# 52   ({'m': 0.0, 'c': 7.0}, {'m': 2.42, 'c': 1.0}, ...  0.000000e+00
# 53   ({'m': 0.0, 'c': 3655.0}, {'m': 0.1, 'c': 1.0}...  0.000000e+00
# 54   ({'m': 0.0, 'c': 547.0}, {'m': 0.0199999999999... -7.720000e+01
# 55   ({'m': 0.0, 'c': 6.0}, {'m': 3.0, 'c': 4.0}, {...  0.000000e+00
# 56   ({'m': 0.0, 'c': 33.0}, {'m': 1.3, 'c': 1.0}, ...  0.000000e+00
# 57   ({'m': 0.0, 'c': 12.0}, {'m': 0.01, 'c': 1.0},...  0.000000e+00
# 58   ({'m': 0.0, 'c': 6.0}, {'m': 4.5, 'c': 1.0}, {...  0.000000e+00
# 59   ({'m': 0.0, 'c': 36.0}, {'m': 0.9, 'c': 1.0}, ...  0.000000e+00
# 60   ({'m': 0.0, 'c': 2073.0}, {'m': 1.01, 'c': 3.0...  0.000000e+00
# 61   ({'m': 0.0, 'c': 8.0}, {'m': 0.1, 'c': 2.0}, {...  0.000000e+00
# 62   ({'m': 0.0, 'c': 5.0}, {'m': 0.3, 'c': 3.0}, {...  0.000000e+00
# 63   ({'m': 0.0, 'c': 4.0}, {'m': 1.44, 'c': 1.0}, ... -5.600000e+02
# 64   ({'m': 0.0, 'c': 3.0}, {'m': 0.81, 'c': 1.0}, ... -4.460000e+00
# 65   ({'m': 0.0, 'c': 2.0}, {'m': 5.2, 'c': 1.0}, {...  0.000000e+00
# 66   ({'m': 0.0, 'c': 18.0}, {'m': 0.5, 'c': 3.0}, ...  0.000000e+00
# 67   ({'m': 0.0, 'c': 21.0}, {'m': 0.1, 'c': 219.0}... -1.150000e+02
# 68   ({'m': 0.0, 'c': 9.0}, {'m': 0.06, 'c': 1.0}, ... -3.900000e+01
# 69   ({'m': -999994.31, 'c': 2.0}, {'m': -1.1, 'c':... -9.999943e+05
# 70   ({'m': 1.0, 'c': 13.0}, {'m': 1.478, 'c': 1.0}...  0.000000e+00
# 71   ({'m': -25.0, 'c': 7.0}, {'m': -20.0, 'c': 1.0... -2.500000e+01
# 72   ({'m': 0.0, 'c': 5.0}, {'m': 0.008, 'c': 12.0}... -2.143000e+01
# 73   ({'m': 2.0, 'c': 2.0}, {'m': 3.0, 'c': 12.0}, ... -4.300000e+01
# 74   ({'m': 2.14, 'c': 1.0}, {'m': 4.0, 'c': 1.0}, ... -4.500000e+01
# 75   ({'m': 0.6, 'c': 1.0}, {'m': 0.77, 'c': 1.0}, ... -1.650000e+02
# 76   ({'m': 0.0, 'c': 17.0}, {'m': 0.66, 'c': 1.0},... -1.912620e+05
# 77   ({'m': 0.0, 'c': 13.0}, {'m': 0.5, 'c': 1.0}, ... -2.120000e+00
# 78   ({'m': 0.0, 'c': 67.0}, {'m': 0.7, 'c': 1.0}, ... -7.500000e+01
# 79   ({'m': 0.0, 'c': 13.0}, {'m': 0.14, 'c': 1.0},... -3.400000e+00
# 80   ({'m': 1.0, 'c': 1.0}, {'m': 1.09, 'c': 1.0}, ... -4.212000e+04
# 81   ({'m': 0.0, 'c': 10.0}, {'m': 0.1, 'c': 1.0}, ... -2.810200e+06
# 82   ({'m': 0.0, 'c': 27.0}, {'m': 0.009, 'c': 1.0}... -2.000000e+01
# 83   ({'m': 0.0, 'c': 2.0}, {'m': 0.3, 'c': 4.0}, {...  0.000000e+00
# 84   ({'m': 0.0, 'c': 4.0}, {'m': 1.0, 'c': 1.0}, {... -4.620000e+02
# 85   ({'m': 0.17, 'c': 2.0}, {'m': 0.4, 'c': 2.0}, ... -2.500000e+00
# 86   ({'m': 1.8, 'c': 1.0}, {'m': 2.0, 'c': 1.0}, {... -2.179000e+03
# 87   ({'m': 0.0, 'c': 44.0}, {'m': 0.05, 'c': 2.0},...  0.000000e+00
# 88   ({'m': 1.18, 'c': 1.0}, {'m': 1.32, 'c': 1.0},... -1.400000e+02
# 89   ({'m': 2.0, 'c': 20.0}, {'m': 5.0, 'c': 15.0},...  0.000000e+00
# 90   ({'m': 1.0, 'c': 15.0}, {'m': 2.0, 'c': 110.0}... -2.000000e+00
# 91   ({'m': 0.0, 'c': 4.0}, {'m': 0.6, 'c': 1.0}, {... -7.600000e+00
# 92   ({'m': 0.0, 'c': 18.0}, {'m': 0.08, 'c': 1.0},... -3.762000e+02
# 93   ({'m': 0.2, 'c': 1.0}, {'m': 0.4, 'c': 1.0}, {... -2.410000e+01
# 94   ({'m': 0.0, 'c': 8.0}, {'m': 1.57, 'c': 1.0}, ... -5.781707e+08
# 95   ({'m': -5.0, 'c': 1.0}, {'m': 0.0, 'c': 1786.0... -5.000000e+00
# 96   ({'m': 0.0, 'c': 26.0}, {'m': 0.1, 'c': 2.0}, ... -3.970000e+01
# 97   ({'m': 0.0, 'c': 8.0}, {'m': 50.0, 'c': 1.0}, ... -2.000000e+02
# 98   ({'m': -0.36, 'c': 1.0}, {'m': -0.1, 'c': 1.0}... -5.000000e+01
# 99   ({'m': 0.0, 'c': 2901.0}, {'m': 0.001, 'c': 1.... -5.000000e-01
# 100  ({'m': 0.0, 'c': 1.0}, {'m': 0.9, 'c': 1.0}, {...  0.000000e+00
# 101  ({'m': 0.96, 'c': 1.0}, {'m': 1.09, 'c': 1.0},...  0.000000e+00
# 102  ({'m': 0.0, 'c': 314.0}, {'m': 0.14, 'c': 1.0}... -7.000000e+00
# 103  ({'m': 0.0, 'c': 21.0}, {'m': 0.001, 'c': 2.0}... -3.100000e+00
# 104  ({'m': -0.3, 'c': 1.0}, {'m': 0.0, 'c': 3.0}, ... -1.470000e+01
# 105  ({'m': 0.0, 'c': 213.0}, {'m': 0.01, 'c': 3.0}... -1.400000e+01
# 106  ({'m': 0.0, 'c': 5691.0}, {'m': 0.001, 'c': 53... -5.803000e+00
# 107  ({'m': 0.0, 'c': 1.0}, {'m': 4.0, 'c': 9.0}, {... -9.000000e+01
# 108                                               None           NaN
# 109                                               None           NaN
# 110                                               None           NaN
# 111                                               None           NaN
# 112                                               None           NaN
# 113                                               None           NaN
# 114                                               None           NaN
# 115                                               None           NaN
# 116                                               None           NaN
# 117                                               None           NaN
# 118                                               None           NaN
# 119                                               None           NaN
# 120                                               None           NaN
# 121                                               None           NaN
# 122                                               None           NaN
# 123                                               None           NaN
# 124                                               None           NaN
# 125                                               None           NaN
# 126                                               None           NaN
# 127                                               None           NaN
# 128                                               None           NaN
# 129                                               None           NaN
# 130                                               None           NaN
# 131                                               None           NaN
# 132                                               None           NaN
# 133                                               None           NaN
# 134                                               None           NaN
# 135                                               None           NaN
# 136                                               None           NaN
# 137                                               None           NaN
# 138                                               None           NaN
# 139                                               None           NaN
# 140                                               None           NaN
# 141                                               None           NaN
# 142                                               None           NaN
# 143                                               None           NaN
# 144                                               None           NaN
# 145                                               None           NaN
# 146                                               None           NaN
# 147                                               None           NaN
# 148                                               None           NaN
# 149                                               None           NaN
# 150                                               None           NaN
# 151                                               None           NaN
# 152                                               None           NaN
# 153                                               None           NaN
# 154                                               None           NaN
# 155                                               None           NaN
# 156                                               None           NaN
# 157                                               None           NaN
# 158                                               None           NaN
# 159                                               None           NaN
# 160                                               None           NaN
# 161                                               None           NaN
# 162                                               None           NaN
# 163                                               None           NaN
# 164                                               None           NaN
# 165                                               None           NaN
# 166                                               None           NaN
# 167                                               None           NaN
# 168                                               None           NaN
# 169                                               None           NaN
# 170                                               None           NaN
# 171                                               None           NaN
# 172                                               None           NaN
# 173                                               None           NaN
# 174                                               None           NaN
# 175                                               None           NaN
# 176                                               None           NaN
# 177                                               None           NaN
# 178                                               None           NaN
# 179                                               None           NaN
# 180                                               None           NaN
# 181                                               None           NaN
# 182                                               None           NaN
# 183                                               None           NaN
# 184                                               None           NaN
# 185                                               None           NaN
# 186                                               None           NaN
# 187                                               None           NaN
# 188                                               None           NaN
#
#               max          mean   approx_lqr   approx_uqr
# 0    6.860000e+02  3.908721e+00    -4.673936    10.857805
# 1    9.518000e+02  4.714889e+01   -36.770239   121.653230
# 2    1.533000e+04  2.661963e+01     3.417134    41.771075
# 3    2.070000e+04  2.725168e+01     4.558863    41.966985
# 4    1.282100e+04  1.067255e+01    -4.318622     8.826145
# 5    1.111110e+05  5.008992e-02    -0.093801     0.160919
# 6    4.400000e+02  2.352980e+00     2.025402     2.622520
# 7    1.265000e+03  6.513018e+00     0.158376    11.063455
# 8    2.100000e+09  2.933050e+02    10.477956    43.319633
# 9    5.001420e+05  4.168786e+02  -245.377936   483.324994
# 10   2.790000e+02  2.365999e+00     2.085297     2.628290
# 11   2.400000e+02  2.819830e+00     0.198232     5.486490
# 12   1.222000e+03  5.235274e+01   -33.925790   127.104584
# 13   1.205201e+07  3.892081e+00     2.049077     2.602211
# 14   1.710202e+07  6.982623e+01   -11.221780    31.898993
# 15   9.066667e+11  3.849124e+03    48.776736   106.184113
# 16   4.444440e+05  2.339810e-01    -0.185129     0.578140
# 17   1.315371e+07  1.843387e+01   -21.361837    49.686055
# 18   2.000000e+08  4.101646e+02 -2954.918220  4925.729435
# 19   9.800000e+10  2.859576e+05     5.337169    24.968620
# 20   1.816032e+07  7.195087e+01    25.945469   111.404559
# 21   9.385000e+03  5.573050e+00     0.275576     0.545245
# 22   2.090678e+05  3.781405e+00     0.291792     0.528275
# 23   6.000952e+12  1.888003e+05    13.039172    74.364252
# 24   9.999990e+05  1.350703e+01     2.967688    11.229089
# 25   1.411201e+07  7.961700e+01    96.395174   177.320646
# 26   3.302112e+07  1.169712e+01     3.021371    11.061291
# 27   3.112000e+04  2.775144e+00     0.625480     4.402399
# 28   3.012201e+07  2.391763e+01     0.424929     4.289624
# 29   3.720369e+09  3.650021e+02     0.106436     3.928900
# 30   3.512660e+05  1.861975e+02   266.315522   388.670121
# 31   3.550000e+07  8.281642e+01    24.965489    35.383949
# 32   2.000000e+12  2.127458e+04    74.595518   105.847735
# 33   3.720369e+09  8.190597e+01    -0.015277     1.094536
# 34   7.501200e+04  7.599375e+02  -609.082298  1182.273239
# 35   3.720369e+09  8.505009e+01    -0.086820     7.896765
# 36   2.004000e+03  5.093185e+00 -1101.151007  1833.906998
# 37   3.407000e+03  3.447365e+00     0.440619     6.406608
# 38   1.980230e+10  6.643426e+02   131.952709   200.122733
# 39   4.000000e+12  5.843027e+04    17.406073   128.152245
# 40   5.711570e+05  2.149659e+02  -179.142854   367.796340
# 41   1.255000e+07  1.373701e+01   -11.163921    22.944272
# 42   3.720369e+09  1.763100e+03     0.342956     2.341945
# 43   5.020000e+02  2.839491e+00    -0.056098     5.725604
# 44   1.012460e+05  8.320501e+02  -634.067509  1243.257728
# 45   2.470000e+04  2.591849e+00    -1.342745     4.966060
# 46   1.096500e+04  2.680884e+01    -6.462309    51.710100
# 47   4.354350e+04  4.083299e+01    31.303738    50.384734
# 48   2.021600e+04  1.284950e+02   -59.841461   281.110518
# 49   3.780000e+02  2.376339e+00     2.066500     2.655478
# 50   9.990000e+02  3.794378e+00     0.594254     6.838489
# 51   2.480000e+02  2.347791e+00     2.070485     2.603971
# 52   3.720369e+09  9.151366e+02    29.784070   139.676969
# 53   2.478000e+04  8.423415e+01   -90.055064   192.463238
# 54   2.530000e+10  5.727122e+05     3.870309    21.266291
# 55   1.215100e+04  5.360479e+01   -26.335878    90.693909
# 56   3.720369e+09  8.491083e+02     2.900553     5.293295
# 57   6.686000e+04  5.495602e+02  -347.007866   670.042405
# 58   3.720369e+09  9.799688e+02   132.452214   146.099184
# 59   1.100000e+04  1.104913e+01    -0.840618    19.866168
# 60   3.720369e+09  1.620601e+03     1.636645     8.138319
# 61   3.720369e+09  2.403661e+03    -0.488123     3.457336
# 62   8.080000e+02  5.956689e+00     0.423108    10.139321
# 63   3.720369e+09  2.535123e+04    75.644755   439.071722
# 64   3.720369e+09  6.149268e+04     3.277186     5.871597
# 65   2.603070e+05  1.398563e+01    10.411794    16.548972
# 66   2.000000e+04  4.997980e+01   -34.636925   124.385015
# 67   2.104936e+08  2.375269e+01    -8.026632    17.386169
# 68   1.762016e+06  1.506581e+00     0.332601     2.370315
# 69   3.720369e+09  3.871861e+02    -0.036738     5.928991
# 70   1.247610e+05  7.859756e+02  -616.021339  1198.091279
# 71   1.550000e+11  5.216837e+06  -117.542229   233.367476
# 72   1.990000e+07  1.537853e+01    -1.159385     4.927815
# 73   2.060000e+05  2.705385e+01    -4.416892    48.131274
# 74   9.000000e+09  7.911712e+02    30.640767    50.902597
# 75   1.523013e+07  8.934480e+01    13.084213   146.109293
# 76   1.232190e+08  1.615846e+01    -0.918125    20.072804
# 77   7.042004e+06  2.638354e+00     2.058337     2.626330
# 78   3.720369e+09  7.465021e+01     1.756148     8.246216
# 79   3.720369e+09  1.368317e+02     0.684423     6.811169
# 80   3.720369e+09  5.354401e+02    23.438298   136.812468
# 81   1.905228e+08  1.202831e+02  -112.607179   246.982225
# 82   2.400000e+04  8.601245e+00    -4.577850    20.450367
# 83   1.000000e+11  5.508446e+05     4.277940    20.917435
# 84   7.022400e+04  5.737895e+01   -29.034568    94.758250
# 85   7.265600e+03  3.402179e+00     0.123684     6.500609
# 86   3.720369e+09  4.322233e+01     3.138815     5.467735
# 87   7.700000e+05  7.009120e+02  -500.380581   931.235804
# 88   6.910678e+07  1.413177e+02   132.031609   146.183544
# 89   9.210000e+02  5.323836e+01   -19.214536   123.717129
# 90   4.300000e+07  3.203331e+01    -0.908074    25.216474
# 91   1.010101e+06  5.174581e+00     1.571161     8.235506
# 92   3.720369e+09  4.449784e+02    -0.531844     3.290011
# 93   2.400000e+10  5.770647e+03     0.411447    10.238402
# 94   3.720369e+09  7.152044e+02   -93.229494   819.178700
# 95   7.280000e+02  1.481123e+01    -7.753651    20.591934
# 96   3.000000e+06  5.367082e+01   -30.550753   119.385740
# 97   1.111111e+11  6.007336e+02    82.366694   183.856668
# 98   8.100000e+06  2.560645e+01    -1.533357     5.129009
# 99   9.780000e+03  4.040092e+00    -1.962186     5.614790
# 100  1.229000e+03  4.803738e+01   -27.638894   120.498093
# 101  9.014000e+03  8.453068e+01    13.392947   138.915685
# 102  1.800000e+07  1.466419e+02    -2.319086    22.560694
# 103  3.720369e+09  9.647043e+02     0.486686     6.881645
# 104  3.720369e+09  2.501895e+02     1.581031    12.079522
# 105  1.000000e+10  9.960699e+02    -3.777828     7.896006
# 106  3.176800e+04  1.077503e+01    -4.119705     8.247756
# 107  8.713000e+04  7.427459e+01    22.686686   129.955590
# 108           NaN           NaN          NaN          NaN
# 109           NaN           NaN          NaN          NaN
# 110           NaN           NaN          NaN          NaN
# 111           NaN           NaN          NaN          NaN
# 112           NaN           NaN          NaN          NaN
# 113           NaN           NaN          NaN          NaN
# 114           NaN           NaN          NaN          NaN
# 115           NaN           NaN          NaN          NaN
# 116           NaN           NaN          NaN          NaN
# 117           NaN           NaN          NaN          NaN
# 118           NaN           NaN          NaN          NaN
# 119           NaN           NaN          NaN          NaN
# 120           NaN           NaN          NaN          NaN
# 121           NaN           NaN          NaN          NaN
# 122           NaN           NaN          NaN          NaN
# 123           NaN           NaN          NaN          NaN
# 124           NaN           NaN          NaN          NaN
# 125           NaN           NaN          NaN          NaN
# 126           NaN           NaN          NaN          NaN
# 127           NaN           NaN          NaN          NaN
# 128           NaN           NaN          NaN          NaN
# 129           NaN           NaN          NaN          NaN
# 130           NaN           NaN          NaN          NaN
# 131           NaN           NaN          NaN          NaN
# 132           NaN           NaN          NaN          NaN
# 133           NaN           NaN          NaN          NaN
# 134           NaN           NaN          NaN          NaN
# 135           NaN           NaN          NaN          NaN
# 136           NaN           NaN          NaN          NaN
# 137           NaN           NaN          NaN          NaN
# 138           NaN           NaN          NaN          NaN
# 139           NaN           NaN          NaN          NaN
# 140           NaN           NaN          NaN          NaN
# 141           NaN           NaN          NaN          NaN
# 142           NaN           NaN          NaN          NaN
# 143           NaN           NaN          NaN          NaN
# 144           NaN           NaN          NaN          NaN
# 145           NaN           NaN          NaN          NaN
# 146           NaN           NaN          NaN          NaN
# 147           NaN           NaN          NaN          NaN
# 148           NaN           NaN          NaN          NaN
# 149           NaN           NaN          NaN          NaN
# 150           NaN           NaN          NaN          NaN
# 151           NaN           NaN          NaN          NaN
# 152           NaN           NaN          NaN          NaN
# 153           NaN           NaN          NaN          NaN
# 154           NaN           NaN          NaN          NaN
# 155           NaN           NaN          NaN          NaN
# 156           NaN           NaN          NaN          NaN
# 157           NaN           NaN          NaN          NaN
# 158           NaN           NaN          NaN          NaN
# 159           NaN           NaN          NaN          NaN
# 160           NaN           NaN          NaN          NaN
# 161           NaN           NaN          NaN          NaN
# 162           NaN           NaN          NaN          NaN
# 163           NaN           NaN          NaN          NaN
# 164           NaN           NaN          NaN          NaN
# 165           NaN           NaN          NaN          NaN
# 166           NaN           NaN          NaN          NaN
# 167           NaN           NaN          NaN          NaN
# 168           NaN           NaN          NaN          NaN
# 169           NaN           NaN          NaN          NaN
# 170           NaN           NaN          NaN          NaN
# 171           NaN           NaN          NaN          NaN
# 172           NaN           NaN          NaN          NaN
# 173           NaN           NaN          NaN          NaN
# 174           NaN           NaN          NaN          NaN
# 175           NaN           NaN          NaN          NaN
# 176           NaN           NaN          NaN          NaN
# 177           NaN           NaN          NaN          NaN
# 178           NaN           NaN          NaN          NaN
# 179           NaN           NaN          NaN          NaN
# 180           NaN           NaN          NaN          NaN
# 181           NaN           NaN          NaN          NaN
# 182           NaN           NaN          NaN          NaN
# 183           NaN           NaN          NaN          NaN
# 184           NaN           NaN          NaN          NaN
# 185           NaN           NaN          NaN          NaN
# 186           NaN           NaN          NaN          NaN
# 187           NaN           NaN          NaN          NaN
# 188           NaN           NaN          NaN          NaN

# %% [markdown]
# # Outlier bounds

# %% [markdown]
# ### Get the pre-processed estimated quantile based upper and lower outlier bounds

# %%
meta_measurement = dm.train_set.meta_information["measurement_tables"]

# Fille with quantile based estimates
measurement_limit_list = {}
for _, _row in meta_measurement.iterrows():
    measurement_limit_list[_row.event] = [_row.approx_lqr, _row.approx_uqr]
display(measurement_limit_list)
# Out:
# {'25_Hydroxyvitamin_D2_level_92': [-4.67393603726698, 10.857804944243398],
#  '25_Hydroxyvitamin_D3_level_90': [-36.770239453029085, 121.65323028859444],
#  'AST___aspartate_transam_SGOT__46': [3.4171338038240116, 41.77107521642682],
#  'AST_serum_level_47': [4.558863141370336, 41.966985461548944],
#  'Albumin___creatinine_ratio_37': [-4.318622277704492, 8.826145270522485],
#  'Basophil_count_22': [-0.09380115366794299, 0.1609191424008079],
#  'Blood_calcium_level_38': [2.025401527575622, 2.6225197728812093],
#  'Blood_urea_28': [0.15837579012681058, 11.063454600066638],
#  'Body_mass_index_3': [10.477955941584963, 43.319632799587666],
#  'Brain_natriuretic_peptide_level_66': [-245.3779363349517,
#   483.32499369786353],
#  'Calcium_adjusted_level_41': [2.0852967482708866, 2.6282899313330343],
#  'Calculated_LDL_cholesterol_level_103': [0.19823248550905048,
#   5.486489620225761],
#  'Combined_total_vitamin_D2_and_D3_level_93': [-33.92579046750491,
#   127.10458377019135],
#  'Corrected_serum_calcium_level_42': [2.049077139786654, 2.6022105321432605],
#  'Current_smoker_83': [-11.221780004827133, 31.898993164778112],
#  'Diastolic_blood_pressure_5': [48.77673642066362, 106.18411294636343],
#  'Eosinophil_count_21': [-0.1851292934652531, 0.5781399506756797],
#  'Erythrocyte_sedimentation_rate_61': [-21.36183685757753, 49.68605484855949],
#  'Ex_smoker_84': [-2954.9182195904395, 4925.7294354423575],
#  'Free_T4_level_76': [5.337168661374699, 24.96861960692869],
#  'GFR_calculated_abbreviated_MDRD_34': [25.945468507045653, 111.4045591937966],
#  'Haematocrit___PCV_16': [0.2755756190528724, 0.5452450627747591],
#  'Haematocrit_15': [0.2917920175967789, 0.5282748223438849],
#  'Haemoglobin_A1c_level___IFCC_standardised_6': [13.039172236320088,
#   74.36425176024876],
#  'Haemoglobin_A1c_level_8': [2.9676883416277944, 11.229088784287736],
#  'Haemoglobin_estimation_9': [96.39517387655162, 177.32064636895888],
#  'HbA1c_level__DCCT_aligned__7': [3.0213707473470905, 11.06129102676905],
#  'INR___international_normalised_ratio_81': [0.6254804690679008,
#   4.402399071269393],
#  'International_normalised_ratio_82': [0.4249291869940268, 4.28962355418008],
#  'Lymphocyte_count_20': [0.10643557699836026, 3.928899717083681],
#  'Mean_corpusc_Hb_conc__MCHC__14': [266.31552208761275, 388.6701210494142],
#  'Mean_corpusc_haemoglobin_MCH__13': [24.96548937304727, 35.38394852409464],
#  'Mean_corpuscular_volume__MCV__11': [74.5955180673202, 105.84773510781173],
#  'Monocyte_count_23': [-0.015276882862519492, 1.0945363719320444],
#  'N_terminal_pro_brain_natriuretic_peptide_level_67': [-609.0822977543723,
#   1182.2732394963996],
#  'Neutrophil_count_19': [-0.08682046729519932, 7.896764799548803],
#  'Never_smoked_tobacco_85': [-1101.1510071503315, 1833.9069977328218],
#  'Non_HDL_cholesterol_level_108': [0.4406189860862635, 6.406607605028538],
#  'O_E___height_1': [131.95270855679385, 200.12273330202973],
#  'O_E___weight_2': [17.406073323098184, 128.15224480073877],
#  'Plasma_B_natriuretic_peptide_level_69': [-179.14285412325177,
#   367.7963396005311],
#  'Plasma_C_reactive_protein_60': [-11.163920887734704, 22.94427177228193],
#  'Plasma_HDL_cholesterol_level_101': [0.34295599297133383, 2.3419445794410776],
#  'Plasma_LDL_cholesterol_level_104': [-0.0560977497769275, 5.725603534274358],
#  'Plasma_N_terminal_pro_B_type_natriuretic_peptide_conc_70': [-634.067508976564,
#   1243.2577276272318],
#  'Plasma_TSH_level_73': [-1.342744984393625, 4.966059605624249],
#  'Plasma_alanine_aminotransferase_level_44': [-6.462308605404846,
#   51.71009983782841],
#  'Plasma_albumin_level_52': [31.303737910576665, 50.38473421994569],
#  'Plasma_alkaline_phosphatase_level_49': [-59.841460829377425,
#   281.11051801954716],
#  'Plasma_calcium_level_40': [2.066499658254852, 2.655478470981521],
#  'Plasma_cholesterol_HDL_ratio_96': [0.5942540880527631, 6.838488999991082],
#  'Plasma_corrected_calcium_level_43': [2.0704853785268815, 2.603971060928516],
#  'Plasma_creatinine_level_32': [29.78406994771627, 139.6769689751822],
#  'Plasma_ferritin_level_62': [-90.05506358044467, 192.46323785449889],
#  'Plasma_free_T4_level_77': [3.87030918674629, 21.266290942245853],
#  'Plasma_gamma_glutamyl_transferase_level_58': [-26.335877811704524,
#   90.69390876241238],
#  'Plasma_potassium_level_27': [2.9005534534588264, 5.2932947754558715],
#  'Plasma_pro_brain_natriuretic_peptide_level_64': [-347.0078663101823,
#   670.0424054862324],
#  'Plasma_sodium_level_25': [132.4522144388257, 146.0991840003532],
#  'Plasma_total_bilirubin_level_54': [-0.8406180418241398, 19.86616822373394],
#  'Plasma_total_cholesterol_level_99': [1.6366451841284895, 8.138318909253126],
#  'Plasma_triglyceride_level_106': [-0.4881226842330719, 3.457335874205304],
#  'Plasma_urea_level_30': [0.4231078467594225, 10.139320887512213],
#  'Platelet_count_12': [75.64475518476311, 439.07172214759623],
#  'Red_blood_cell__RBC__count_10': [3.2771862521066706, 5.871596820164569],
#  'Red_blood_cell_distribution_width_17': [10.41179363867223,
#   16.548971985879973],
#  'Serum_25_Hydroxy_vitamin_D3_level_88': [-34.63692524791125,
#   124.38501506102997],
#  'Serum_C_reactive_protein_level_59': [-8.026631914082296, 17.38616914042155],
#  'Serum_HDL_cholesterol_level_100': [0.3326011632094429, 2.370314600200399],
#  'Serum_LDL_cholesterol_level_102': [-0.03673820671792605, 5.928990639139855],
#  'Serum_N_terminal_pro_B_type_natriuretic_peptide_conc_68': [-616.0213394960826,
#   1198.0912791914993],
#  'Serum_T4_level_78': [-117.54222867107606, 233.3674759003693],
#  'Serum_TSH_level_71': [-1.1593845118829544, 4.927815394478304],
#  'Serum_alanine_aminotransferase_level_45': [-4.416892478441605,
#   48.13127411238318],
#  'Serum_albumin_51': [30.640767367566937, 50.90259693181589],
#  'Serum_alkaline_phosphatase_50': [13.084213334528137, 146.1092926270858],
#  'Serum_bilirubin_level_53': [-0.9181253323207192, 20.072804359812224],
#  'Serum_calcium_39': [2.0583367066129465, 2.626330431595102],
#  'Serum_cholesterol_97': [1.7561481054157881, 8.246215898655288],
#  'Serum_cholesterol_HDL_ratio_94': [0.6844233767167895, 6.811169191140477],
#  'Serum_creatinine_31': [23.4382982516102, 136.81246820350543],
#  'Serum_ferritin_63': [-112.60717910657885, 246.98222468342652],
#  'Serum_folate_80': [-4.577849784284281, 20.450366924424415],
#  'Serum_free_T4_level_75': [4.277940480826725, 20.91743455829791],
#  'Serum_gamma_glutamyl_transferase_level_57': [-29.034568439621957,
#   94.75825038517512],
#  'Serum_non_high_density_lipoprotein_cholesterol_level_107': [0.12368449359571843,
#   6.5006091752297515],
#  'Serum_potassium_26': [3.1388151236439215, 5.4677346090024646],
#  'Serum_pro_brain_natriuretic_peptide_level_65': [-500.3805813941553,
#   931.2358042457979],
#  'Serum_sodium_24': [132.03160863389553, 146.18354380283108],
#  'Serum_total_25_hydroxy_vitamin_D_level_87': [-19.21453574592497,
#   123.71712888254261],
#  'Serum_total_bilirubin_level_56': [-0.9080738144377101, 25.216474031240438],
#  'Serum_total_cholesterol_level_98': [1.5711614293565521, 8.235506096659565],
#  'Serum_triglycerides_105': [-0.5318436003112276, 3.290010928117589],
#  'Serum_urea_level_29': [0.4114468717090314, 10.238402047218845],
#  'Serum_vitamin_B12_79': [-93.22949414672357, 819.1786997273009],
#  'Serum_vitamin_D2_level_89': [-7.7536513720123885, 20.591933568458607],
#  'Serum_vitamin_D_86': [-30.550752622660717, 119.38573952117095],
#  'Systolic_blood_pressure_4': [82.36669364711412, 183.85666774955536],
#  'TSH___thyroid_stim_hormone_72': [-1.5333567053448487, 5.129009386854207],
#  'TSH_level_74': [-1.96218612511019, 5.614789577423985],
#  'Total_25_hydroxyvitamin_D_level_91': [-27.638894215706785,
#   120.49809317816738],
#  'Total_alkaline_phosphatase_48': [13.39294673862522, 138.91568479544804],
#  'Total_bilirubin_55': [-2.3190863110976405, 22.56069446003125],
#  'Total_cholesterol_HDL_ratio_95': [0.4866857042111552, 6.881644518067365],
#  'Total_white_cell_count_18': [1.5810309066039334, 12.079522301108062],
#  'Urine_albumin_creatinine_ratio_35': [-3.7778280442706547, 7.89600583330213],
#  'Urine_microalbumin_creatinine_ratio_36': [-4.119704913383878,
#   8.247756432083156],
#  'eGFR_using_creatinine_CKD_EPI_per_1_73_square_metres_33': [22.686685686392153,
#   129.95558995906424],
#  'ACE_Inhibitors_D2T': [nan, nan],
#  'AMD_DH_Donepezil': [nan, nan],
#  'AMD_DH_Memantine': [nan, nan],
#  'ARBs_Luyuan': [nan, nan],
#  'Acarbose_AURUM': [nan, nan],
#  'AldosteroneAntagonist_D2T': [nan, nan],
#  'AllHIVdrugs_HIV': [nan, nan],
#  'All_AntiArrhythmics_D2T': [nan, nan],
#  'All_Antiplatelets': [nan, nan],
#  'All_Diuretics_D2T': [nan, nan],
#  'All_Diuretics_ExclLactones_D2T': [nan, nan],
#  'AlphaBlocker': [nan, nan],
#  'Amantadine': [nan, nan],
#  'Amitriptyline_optimal': [nan, nan],
#  'Anticonvulsants_OPTIMAL': [nan, nan],
#  'Antihistamines_second_generation_H1_antagonists': [nan, nan],
#  'Antipsychotics_OPTIMAL': [nan, nan],
#  'Anxiolytics_mumpredict': [nan, nan],
#  'Aspirin_OPTIMAL': [nan, nan],
#  'Benzodiazepines': [nan, nan],
#  'BetaBlockers_OPTIMAL': [nan, nan],
#  'Bisphosphonates_osteoporosis': [nan, nan],
#  'COCP_reg_contraception': [nan, nan],
#  'COMT_Optimal': [nan, nan],
#  'CalciumChannelBlck_D2T': [nan, nan],
#  'Calcium_supplements_Optimal': [nan, nan],
#  'Carbamazepine_Optimal': [nan, nan],
#  'DPP4inhibitors_OPTIMAL': [nan, nan],
#  'Dementia': [nan, nan],
#  'Digoxin_': [nan, nan],
#  'Direct_Acting_Oral_Anticoagulants_DOAC': [nan, nan],
#  'Fibrate_FenofibrateOnly': [nan, nan],
#  'First_gen_H1_antihistamines': [nan, nan],
#  'GLP_1Aurum': [nan, nan],
#  'Gabapentin_Oral_OPTIMAL': [nan, nan],
#  'Galantamine_NEW': [nan, nan],
#  'HydroxychloroquineAURUM_Zhaonan': [nan, nan],
#  'ICS_PUSHAsthma': [nan, nan],
#  'Insulin_Aurum_v2': [nan, nan],
#  'LABA_PUSH_Asthma': [nan, nan],
#  'LAMA_PUSHAsthma': [nan, nan],
#  'LKA_PUSHAsthma': [nan, nan],
#  'LeflunomideAURUM_Zhaonan': [nan, nan],
#  'Levothyroxine_': [nan, nan],
#  'Lipid_lowering_drugs_Optimal': [nan, nan],
#  'Lithium_OPTIMAL': [nan, nan],
#  'MAO_B_Optimal': [nan, nan],
#  'Meglitinides_Aurum': [nan, nan],
#  'Metformin_612_A10BD2': [nan, nan],
#  'MethotrexateAURUM_Zhaonan': [nan, nan],
#  'Mirtazapine': [nan, nan],
#  'Monoamine_Oxidase_Inhibitors_OPTIMAL': [nan, nan],
#  'NSAIDS_oral_OPTIMAL_final': [nan, nan],
#  'Nasal_steroids_optimal': [nan, nan],
#  'OCS_PUSHAsthma2': [nan, nan],
#  'POP_reg_contraceptive': [nan, nan],
#  'Paracetamol_OPTIMAL': [nan, nan],
#  'Pregabalin_Optimal': [nan, nan],
#  'PropranololAnxiety_mumpredict': [nan, nan],
#  'Rivastigmine': [nan, nan],
#  'SABA_PUSHAsthma': [nan, nan],
#  'SGLT2inhibitors_Optimal': [nan, nan],
#  'SNRIs_OPTIMAL': [nan, nan],
#  'SSRIs_Optimal': [nan, nan],
#  'Statins': [nan, nan],
#  'Strong_Opioids_2022_Final': [nan, nan],
#  'SulfasalazineAURUM_Zhaonan': [nan, nan],
#  'Sulphonylureas_Aurum': [nan, nan],
#  'Systemic_oral_corticosteroids_optimal': [nan, nan],
#  'Thiazide_Diuretics_v2': [nan, nan],
#  'Thiazolidinediones_Aurum_JC': [nan, nan],
#  'Tricyclic_Antidepressants_final': [nan, nan],
#  'UricAcid_LoweringDrugs_optimal': [nan, nan],
#  'ValproateMigraine': [nan, nan],
#  'Vitamin_D': [nan, nan],
#  'Warfarin_': [nan, nan],
#  'Weak_Opioids_Final': [nan, nan],
#  'all_contraceptive': [nan, nan],
#  'asthma_combined_inhalers': [nan, nan],
#  'levodopa_Optimal': [nan, nan],
#  'phosphodiesterasetype5inhibitor_OPTIMAL': [nan, nan]}

# %% [markdown]
# ### Update with the clinician set bounds

# %%
# manually set clinician provided values
# Defaulting to lower and upper quantile approximations otherwise (TODO: modify these quantiles to be less rigid)
# when missing both lower and upper I have included name (not formatted) as comment

# 25-HYDROXYVITAMIN_D2_LEVEL_92
# ALBUMIN_/_CREATININE_RATIO_37
measurement_limit_list["AST___aspartate_transam_SGOT__46"]            = [0.1, 40000]
measurement_limit_list["AST_serum_level_47"]                          = [0.1, 40000]
measurement_limit_list["Basophil_count_22"][1]                        = 10
measurement_limit_list["Blood_calcium_level_38"]                      = [0.1, 10]
measurement_limit_list["Blood_urea_28"][0]                            = 0.1
measurement_limit_list["Body_mass_index_3"]                           = [5, 130]
# BRAIN_NATRIURETIC_PEPTIDE_LEVEL_66
measurement_limit_list["Calcium_adjusted_level_41"]                   = [0.1, 10]
measurement_limit_list["Calculated_LDL_cholesterol_level_103"]        = [0, 30]
measurement_limit_list["Combined_total_vitamin_D2_and_D3_level_93"][0]= 0.1
measurement_limit_list["Corrected_serum_calcium_level_42"]            = [0.1, 10]
measurement_limit_list["Current_smoker_83"]                           = [0, 80]                   # but manually treated as always missing inside model anyway - as awful quality
measurement_limit_list["Diastolic_blood_pressure_5"]                  = [20, 400]
measurement_limit_list["eGFR_using_creatinine_CKD_EPI_per_1_73_square_metres_33"][1] = 300
measurement_limit_list["Eosinophil_count_21"][1]                      = 10
measurement_limit_list["Erythrocyte_sedimentation_rate_61"][0]        = 0
measurement_limit_list["Ex_smoker_84"]                                = [0, 80]                   # but manually treated as always missing inside model anyway - as awful quality
measurement_limit_list["Free_T4_level_76"]                            = [0.1, 1000]
measurement_limit_list["GFR_calculated_abbreviated_MDRD_34"]          = [0.1, 300]
measurement_limit_list["Haematocrit___PCV_16"]                        = [0.1, 1]
measurement_limit_list["Haematocrit_15"]                              = [0, 1]
measurement_limit_list["Haemoglobin_A1c_level___IFCC_standardised_6"] = [5, 250]
measurement_limit_list["Haemoglobin_A1c_level_8"]                     = [5, 250]
measurement_limit_list["Haemoglobin_estimation_9"]                    = [10, 300]
measurement_limit_list["HbA1c_level__DCCT_aligned__7"]                = [5, 250]
measurement_limit_list["INR___international_normalised_ratio_81"][1]  = 100
measurement_limit_list["International_normalised_ratio_82"][1]        = 100
measurement_limit_list["Lymphocyte_count_20"]                         = [0.1, 200]
measurement_limit_list["Mean_corpusc_Hb_conc__MCHC__14"]              = [10, 500]
measurement_limit_list["Mean_corpusc_haemoglobin_MCH__13"]            = [1, 100]
measurement_limit_list["Mean_corpuscular_volume__MCV__11"]            = [10, 250]
measurement_limit_list["Monocyte_count_23"][1]                        = 20
measurement_limit_list["Neutrophil_count_19"]                         = [0, 50]
measurement_limit_list["Never_smoked_tobacco_85"]                     = [0, 0]                 # but manually treated as always missing inside model anyway
measurement_limit_list["Non_HDL_cholesterol_level_108"][0]            = 0
# N_TERMINAL_PRO-BRAIN_NATRIURETIC_PEPTIDE_LEVEL_67
measurement_limit_list["O_E___height_1"]                              = [20, 272]
measurement_limit_list["O_E___weight_2"]                              = [0.25, 650]
measurement_limit_list["Serum_alanine_aminotransferase_level_45"]     = [0.1, 40000]
measurement_limit_list["Plasma_albumin_level_52"]                     = [2, 180]
measurement_limit_list["Plasma_alkaline_phosphatase_level_49"][0]     = 1
# PLASMA_B_NATRIURETIC_PEPTIDE_LEVEL_69
measurement_limit_list["Plasma_calcium_level_40"]                     = [0.1, 10]
measurement_limit_list["Plasma_cholesterol_HDL_ratio_96"]             = [1, 250]
measurement_limit_list["Plasma_corrected_calcium_level_43"]           = [0.1, 1]
measurement_limit_list["Plasma_creatinine_level_32"][0]               = 1
# PLASMA_C_REACTIVE_PROTEIN_60
measurement_limit_list["Plasma_ferritin_level_62"][1]                 = 500000
measurement_limit_list["Plasma_free_T4_level_77"]                     = [0.1, 1000]
# PLASMA_GAMMA-GLUTAMYL_TRANSFERASE_LEVEL_58
measurement_limit_list["Plasma_HDL_cholesterol_level_101"][1]         = 3.9
measurement_limit_list["Plasma_LDL_cholesterol_level_104"]            = [0, 30]
# PLASMA_N-TERMINAL_PRO_B-TYPE_NATRIURETIC_PEPTIDE_CONC_70
measurement_limit_list["Plasma_potassium_level_27"]                   = [0.1, 10]
# PLASMA_PRO-BRAIN_NATRIURETIC_PEPTIDE_LEVEL_64
measurement_limit_list["Plasma_sodium_level_25"]                      = [90, 200]
measurement_limit_list["Plasma_total_bilirubin_level_54"][1]          = 900
measurement_limit_list["Plasma_total_cholesterol_level_99"][1]        = 50
# PLASMA_TRIGLYCERIDE_LEVEL_106
measurement_limit_list["Plasma_TSH_level_73"][1]                      = 500
measurement_limit_list["Plasma_urea_level_30"][0]                     = 0.1
measurement_limit_list["Platelet_count_12"]                           = [0, 10e6]
measurement_limit_list["Red_blood_cell_distribution_width_17"][1]     = 100
measurement_limit_list["Red_blood_cell__RBC__count_10"]               = [0, 500]
measurement_limit_list["Serum_25_Hydroxy_vitamin_D3_level_88"][0]     = 0.1
measurement_limit_list["Plasma_alanine_aminotransferase_level_44"]    = [0.1, 40000]                   # Jenny named this SERUM_ALANINE_AMINOTRANSFERASE_LEVEL_44?
measurement_limit_list["Serum_albumin_51"]                            = [2, 180]
measurement_limit_list["Serum_alkaline_phosphatase_50"]               = [1, 20000]
measurement_limit_list["Serum_bilirubin_level_53"][1]                 = 900
measurement_limit_list["Serum_calcium_39"]                            = [0.1, 10]
measurement_limit_list["Serum_cholesterol_97"][1]                     = 50
measurement_limit_list["Serum_cholesterol_HDL_ratio_94"]              = [1, 250]
measurement_limit_list["Serum_creatinine_31"]                         = [1, 10000]
# SERUM_C_REACTIVE_PROTEIN_LEVEL_59
measurement_limit_list["Serum_ferritin_63"][1]                        = 5e5
#SERUM_FOLATE_80
measurement_limit_list["Serum_free_T4_level_75"]                      = [0.1, 10000]
# SERUM_GAMMA-GLUTAMYL_TRANSFERASE_LEVEL_57
measurement_limit_list["Serum_HDL_cholesterol_level_100"]             = [0, 3.9]
measurement_limit_list["Serum_LDL_cholesterol_level_102"]             = [0, 30]
# SERUM_N-TERMINAL_PRO_B-TYPE_NATRIURETIC_PEPTIDE_CONC_68
measurement_limit_list["Serum_non_high_density_lipoprotein_cholesterol_level_107"] = [0, 3.9]
measurement_limit_list["Serum_potassium_26"]                          = [0.1, 10]
# SERUM_PRO-BRAIN_NATRIURETIC_PEPTIDE_LEVEL_65
measurement_limit_list["Serum_sodium_24"]                             = [90, 200]
measurement_limit_list["Serum_T4_level_78"]                           = [0.1, 1000]
# SERUM_TOTAL_25-HYDROXY_VITAMIN_D_LEVEL_87
measurement_limit_list["Serum_total_bilirubin_level_56"][1]           = 900
measurement_limit_list["Serum_total_cholesterol_level_98"][1]         = 50
measurement_limit_list["Serum_triglycerides_105"]                     = [0, 100]
measurement_limit_list["Serum_TSH_level_71"][1]                       = 500
measurement_limit_list["Serum_urea_level_29"][0]                      = 0.1
measurement_limit_list["Serum_vitamin_B12_79"]                        = [5, 20000]
# measurement_limit_list["Serum_vitamin_D2_level_89"] = 
measurement_limit_list["Serum_vitamin_D_86"]                          = [0.1, 1000]
measurement_limit_list["Systolic_blood_pressure_4"]                   = [30, 400]
measurement_limit_list["Total_25_hydroxyvitamin_D_level_91"]          = [0.1, 1000]
measurement_limit_list["Total_alkaline_phosphatase_48"][0]            = 0.1
measurement_limit_list["Total_bilirubin_55"][1]                       = 900
measurement_limit_list["Total_cholesterol_HDL_ratio_95"]              = [1, 250]
measurement_limit_list["Total_white_cell_count_18"]                   = [0.1, 5000]
measurement_limit_list["TSH___thyroid_stim_hormone_72"][1]            = 500
measurement_limit_list["TSH_level_74"][1]                             = 500
measurement_limit_list["Urine_albumin_creatinine_ratio_35"][1]        = 300
# measurement_limit_list["Urine_microalbumin_creatinine_ratio_36"]

# %%
for _key in measurement_limit_list.keys():
    print(f"{_key}".ljust(80) + f"{measurement_limit_list[_key][0]:.2f}".ljust(10) + f"to\t {measurement_limit_list[_key][1]:.2f}")
# Out:
# 25_Hydroxyvitamin_D2_level_92                                                   -4.67     to	 10.86
# 25_Hydroxyvitamin_D3_level_90                                                   -36.77    to	 121.65
# AST___aspartate_transam_SGOT__46                                                0.10      to	 40000.00
# AST_serum_level_47                                                              0.10      to	 40000.00
# Albumin___creatinine_ratio_37                                                   -4.32     to	 8.83
# Basophil_count_22                                                               -0.09     to	 10.00
# Blood_calcium_level_38                                                          0.10      to	 10.00
# Blood_urea_28                                                                   0.10      to	 11.06
# Body_mass_index_3                                                               5.00      to	 130.00
# Brain_natriuretic_peptide_level_66                                              -245.38   to	 483.32
# Calcium_adjusted_level_41                                                       0.10      to	 10.00
# Calculated_LDL_cholesterol_level_103                                            0.00      to	 30.00
# Combined_total_vitamin_D2_and_D3_level_93                                       0.10      to	 127.10
# Corrected_serum_calcium_level_42                                                0.10      to	 10.00
# Current_smoker_83                                                               0.00      to	 80.00
# Diastolic_blood_pressure_5                                                      20.00     to	 400.00
# Eosinophil_count_21                                                             -0.19     to	 10.00
# Erythrocyte_sedimentation_rate_61                                               0.00      to	 49.69
# Ex_smoker_84                                                                    0.00      to	 80.00
# Free_T4_level_76                                                                0.10      to	 1000.00
# GFR_calculated_abbreviated_MDRD_34                                              0.10      to	 300.00
# Haematocrit___PCV_16                                                            0.10      to	 1.00
# Haematocrit_15                                                                  0.00      to	 1.00
# Haemoglobin_A1c_level___IFCC_standardised_6                                     5.00      to	 250.00
# Haemoglobin_A1c_level_8                                                         5.00      to	 250.00
# Haemoglobin_estimation_9                                                        10.00     to	 300.00
# HbA1c_level__DCCT_aligned__7                                                    5.00      to	 250.00
# INR___international_normalised_ratio_81                                         0.63      to	 100.00
# International_normalised_ratio_82                                               0.42      to	 100.00
# Lymphocyte_count_20                                                             0.10      to	 200.00
# Mean_corpusc_Hb_conc__MCHC__14                                                  10.00     to	 500.00
# Mean_corpusc_haemoglobin_MCH__13                                                1.00      to	 100.00
# Mean_corpuscular_volume__MCV__11                                                10.00     to	 250.00
# Monocyte_count_23                                                               -0.02     to	 20.00
# N_terminal_pro_brain_natriuretic_peptide_level_67                               -609.08   to	 1182.27
# Neutrophil_count_19                                                             0.00      to	 50.00
# Never_smoked_tobacco_85                                                         0.00      to	 0.00
# Non_HDL_cholesterol_level_108                                                   0.00      to	 6.41
# O_E___height_1                                                                  20.00     to	 272.00
# O_E___weight_2                                                                  0.25      to	 650.00
# Plasma_B_natriuretic_peptide_level_69                                           -179.14   to	 367.80
# Plasma_C_reactive_protein_60                                                    -11.16    to	 22.94
# Plasma_HDL_cholesterol_level_101                                                0.34      to	 3.90
# Plasma_LDL_cholesterol_level_104                                                0.00      to	 30.00
# Plasma_N_terminal_pro_B_type_natriuretic_peptide_conc_70                        -634.07   to	 1243.26
# Plasma_TSH_level_73                                                             -1.34     to	 500.00
# Plasma_alanine_aminotransferase_level_44                                        0.10      to	 40000.00
# Plasma_albumin_level_52                                                         2.00      to	 180.00
# Plasma_alkaline_phosphatase_level_49                                            1.00      to	 281.11
# Plasma_calcium_level_40                                                         0.10      to	 10.00
# Plasma_cholesterol_HDL_ratio_96                                                 1.00      to	 250.00
# Plasma_corrected_calcium_level_43                                               0.10      to	 1.00
# Plasma_creatinine_level_32                                                      1.00      to	 139.68
# Plasma_ferritin_level_62                                                        -90.06    to	 500000.00
# Plasma_free_T4_level_77                                                         0.10      to	 1000.00
# Plasma_gamma_glutamyl_transferase_level_58                                      -26.34    to	 90.69
# Plasma_potassium_level_27                                                       0.10      to	 10.00
# Plasma_pro_brain_natriuretic_peptide_level_64                                   -347.01   to	 670.04
# Plasma_sodium_level_25                                                          90.00     to	 200.00
# Plasma_total_bilirubin_level_54                                                 -0.84     to	 900.00
# Plasma_total_cholesterol_level_99                                               1.64      to	 50.00
# Plasma_triglyceride_level_106                                                   -0.49     to	 3.46
# Plasma_urea_level_30                                                            0.10      to	 10.14
# Platelet_count_12                                                               0.00      to	 10000000.00
# Red_blood_cell__RBC__count_10                                                   0.00      to	 500.00
# Red_blood_cell_distribution_width_17                                            10.41     to	 100.00
# Serum_25_Hydroxy_vitamin_D3_level_88                                            0.10      to	 124.39
# Serum_C_reactive_protein_level_59                                               -8.03     to	 17.39
# Serum_HDL_cholesterol_level_100                                                 0.00      to	 3.90
# Serum_LDL_cholesterol_level_102                                                 0.00      to	 30.00
# Serum_N_terminal_pro_B_type_natriuretic_peptide_conc_68                         -616.02   to	 1198.09
# Serum_T4_level_78                                                               0.10      to	 1000.00
# Serum_TSH_level_71                                                              -1.16     to	 500.00
# Serum_alanine_aminotransferase_level_45                                         0.10      to	 40000.00
# Serum_albumin_51                                                                2.00      to	 180.00
# Serum_alkaline_phosphatase_50                                                   1.00      to	 20000.00
# Serum_bilirubin_level_53                                                        -0.92     to	 900.00
# Serum_calcium_39                                                                0.10      to	 10.00
# Serum_cholesterol_97                                                            1.76      to	 50.00
# Serum_cholesterol_HDL_ratio_94                                                  1.00      to	 250.00
# Serum_creatinine_31                                                             1.00      to	 10000.00
# Serum_ferritin_63                                                               -112.61   to	 500000.00
# Serum_folate_80                                                                 -4.58     to	 20.45
# Serum_free_T4_level_75                                                          0.10      to	 10000.00
# Serum_gamma_glutamyl_transferase_level_57                                       -29.03    to	 94.76
# Serum_non_high_density_lipoprotein_cholesterol_level_107                        0.00      to	 3.90
# Serum_potassium_26                                                              0.10      to	 10.00
# Serum_pro_brain_natriuretic_peptide_level_65                                    -500.38   to	 931.24
# Serum_sodium_24                                                                 90.00     to	 200.00
# Serum_total_25_hydroxy_vitamin_D_level_87                                       -19.21    to	 123.72
# Serum_total_bilirubin_level_56                                                  -0.91     to	 900.00
# Serum_total_cholesterol_level_98                                                1.57      to	 50.00
# Serum_triglycerides_105                                                         0.00      to	 100.00
# Serum_urea_level_29                                                             0.10      to	 10.24
# Serum_vitamin_B12_79                                                            5.00      to	 20000.00
# Serum_vitamin_D2_level_89                                                       -7.75     to	 20.59
# Serum_vitamin_D_86                                                              0.10      to	 1000.00
# Systolic_blood_pressure_4                                                       30.00     to	 400.00
# TSH___thyroid_stim_hormone_72                                                   -1.53     to	 500.00
# TSH_level_74                                                                    -1.96     to	 500.00
# Total_25_hydroxyvitamin_D_level_91                                              0.10      to	 1000.00
# Total_alkaline_phosphatase_48                                                   0.10      to	 138.92
# Total_bilirubin_55                                                              -2.32     to	 900.00
# Total_cholesterol_HDL_ratio_95                                                  1.00      to	 250.00
# Total_white_cell_count_18                                                       0.10      to	 5000.00
# Urine_albumin_creatinine_ratio_35                                               -3.78     to	 300.00
# Urine_microalbumin_creatinine_ratio_36                                          -4.12     to	 8.25
# eGFR_using_creatinine_CKD_EPI_per_1_73_square_metres_33                         22.69     to	 300.00
# ACE_Inhibitors_D2T                                                              nan       to	 nan
# AMD_DH_Donepezil                                                                nan       to	 nan
# AMD_DH_Memantine                                                                nan       to	 nan
# ARBs_Luyuan                                                                     nan       to	 nan
# Acarbose_AURUM                                                                  nan       to	 nan
# AldosteroneAntagonist_D2T                                                       nan       to	 nan
# AllHIVdrugs_HIV                                                                 nan       to	 nan
# All_AntiArrhythmics_D2T                                                         nan       to	 nan
# All_Antiplatelets                                                               nan       to	 nan
# All_Diuretics_D2T                                                               nan       to	 nan
# All_Diuretics_ExclLactones_D2T                                                  nan       to	 nan
# AlphaBlocker                                                                    nan       to	 nan
# Amantadine                                                                      nan       to	 nan
# Amitriptyline_optimal                                                           nan       to	 nan
# Anticonvulsants_OPTIMAL                                                         nan       to	 nan
# Antihistamines_second_generation_H1_antagonists                                 nan       to	 nan
# Antipsychotics_OPTIMAL                                                          nan       to	 nan
# Anxiolytics_mumpredict                                                          nan       to	 nan
# Aspirin_OPTIMAL                                                                 nan       to	 nan
# Benzodiazepines                                                                 nan       to	 nan
# BetaBlockers_OPTIMAL                                                            nan       to	 nan
# Bisphosphonates_osteoporosis                                                    nan       to	 nan
# COCP_reg_contraception                                                          nan       to	 nan
# COMT_Optimal                                                                    nan       to	 nan
# CalciumChannelBlck_D2T                                                          nan       to	 nan
# Calcium_supplements_Optimal                                                     nan       to	 nan
# Carbamazepine_Optimal                                                           nan       to	 nan
# DPP4inhibitors_OPTIMAL                                                          nan       to	 nan
# Dementia                                                                        nan       to	 nan
# Digoxin_                                                                        nan       to	 nan
# Direct_Acting_Oral_Anticoagulants_DOAC                                          nan       to	 nan
# Fibrate_FenofibrateOnly                                                         nan       to	 nan
# First_gen_H1_antihistamines                                                     nan       to	 nan
# GLP_1Aurum                                                                      nan       to	 nan
# Gabapentin_Oral_OPTIMAL                                                         nan       to	 nan
# Galantamine_NEW                                                                 nan       to	 nan
# HydroxychloroquineAURUM_Zhaonan                                                 nan       to	 nan
# ICS_PUSHAsthma                                                                  nan       to	 nan
# Insulin_Aurum_v2                                                                nan       to	 nan
# LABA_PUSH_Asthma                                                                nan       to	 nan
# LAMA_PUSHAsthma                                                                 nan       to	 nan
# LKA_PUSHAsthma                                                                  nan       to	 nan
# LeflunomideAURUM_Zhaonan                                                        nan       to	 nan
# Levothyroxine_                                                                  nan       to	 nan
# Lipid_lowering_drugs_Optimal                                                    nan       to	 nan
# Lithium_OPTIMAL                                                                 nan       to	 nan
# MAO_B_Optimal                                                                   nan       to	 nan
# Meglitinides_Aurum                                                              nan       to	 nan
# Metformin_612_A10BD2                                                            nan       to	 nan
# MethotrexateAURUM_Zhaonan                                                       nan       to	 nan
# Mirtazapine                                                                     nan       to	 nan
# Monoamine_Oxidase_Inhibitors_OPTIMAL                                            nan       to	 nan
# NSAIDS_oral_OPTIMAL_final                                                       nan       to	 nan
# Nasal_steroids_optimal                                                          nan       to	 nan
# OCS_PUSHAsthma2                                                                 nan       to	 nan
# POP_reg_contraceptive                                                           nan       to	 nan
# Paracetamol_OPTIMAL                                                             nan       to	 nan
# Pregabalin_Optimal                                                              nan       to	 nan
# PropranololAnxiety_mumpredict                                                   nan       to	 nan
# Rivastigmine                                                                    nan       to	 nan
# SABA_PUSHAsthma                                                                 nan       to	 nan
# SGLT2inhibitors_Optimal                                                         nan       to	 nan
# SNRIs_OPTIMAL                                                                   nan       to	 nan
# SSRIs_Optimal                                                                   nan       to	 nan
# Statins                                                                         nan       to	 nan
# Strong_Opioids_2022_Final                                                       nan       to	 nan
# SulfasalazineAURUM_Zhaonan                                                      nan       to	 nan
# Sulphonylureas_Aurum                                                            nan       to	 nan
# Systemic_oral_corticosteroids_optimal                                           nan       to	 nan
# Thiazide_Diuretics_v2                                                           nan       to	 nan
# Thiazolidinediones_Aurum_JC                                                     nan       to	 nan
# Tricyclic_Antidepressants_final                                                 nan       to	 nan
# UricAcid_LoweringDrugs_optimal                                                  nan       to	 nan
# ValproateMigraine                                                               nan       to	 nan
# Vitamin_D                                                                       nan       to	 nan
# Warfarin_                                                                       nan       to	 nan
# Weak_Opioids_Final                                                              nan       to	 nan
# all_contraceptive                                                               nan       to	 nan
# asthma_combined_inhalers                                                        nan       to	 nan
# levodopa_Optimal                                                                nan       to	 nan
# phosphodiesterasetype5inhibitor_OPTIMAL                                         nan       to	 nan

# %% [markdown]
# ### Update the meta information on file

# %%
# Load from file - this is the pre-processed information the dataloader loads back in. It is used for building the tokenizer and on-the-fly standardisation
with open(cfg.data.path_to_ds + 'meta_information.pickle', 'rb') as handle:
    meta_information = pickle.load(handle)

# %%
# we can update the contents of this file from the pre-processed quantile based limits to the clinician derived feasible limits
for _key in measurement_limit_list.keys():
    meta_information["measurement_tables"].loc[meta_information["measurement_tables"].event == _key, "approx_lqr"] = measurement_limit_list[_key][0]
    meta_information["measurement_tables"].loc[meta_information["measurement_tables"].event == _key, "approx_uqr"] = measurement_limit_list[_key][1]
    
print(meta_information["measurement_tables"].head())
# Out:
#                               event     count  count_obs  \
# 0     25_Hydroxyvitamin_D2_level_92    782791     693470
# 1     25_Hydroxyvitamin_D3_level_90    809104     781118
# 2  AST___aspartate_transam_SGOT__46   1738489    1680613
# 3                AST_serum_level_47  10837982   10485351
# 4     Albumin___creatinine_ratio_37    180911      78420
#
#                                               digest  min      max       mean  \
# 0  ({'m': 0.0, 'c': 9.0}, {'m': 0.1, 'c': 112.0},...  0.0    686.0   3.908721
# 1  ({'m': 0.1, 'c': 3.0}, {'m': 1.0, 'c': 314.0},...  0.0    951.8  47.148892
# 2  ({'m': 0.0, 'c': 3901.0}, {'m': 0.770571428571...  0.0  15330.0  26.619633
# 3  ({'m': 0.0, 'c': 53.0}, {'m': 1.8, 'c': 1.0}, ... -5.0  20700.0  27.251680
# 4  ({'m': -1.0, 'c': 1.0}, {'m': 0.0, 'c': 4213.0... -1.0  12821.0  10.672548
#
#    approx_lqr    approx_uqr
# 0   -4.673936     10.857805
# 1  -36.770239    121.653230
# 2    0.100000  40000.000000
# 3    0.100000  40000.000000
# 4   -4.318622      8.826145

# %%
with open(cfg.data.path_to_ds  + 'meta_information_QuantJenny.pickle', 'wb') as handle:
    pickle.dump(meta_information, handle, protocol=pickle.HIGHEST_PROTOCOL)

# test this looks correct
with open(cfg.data.path_to_ds  + 'meta_information_QuantJenny.pickle', 'rb') as handle:
    meta_information_new = pickle.load(handle)
print(meta_information_new["measurement_tables"].head())
# Out:
#                               event     count  count_obs  \
# 0     25_Hydroxyvitamin_D2_level_92    782791     693470
# 1     25_Hydroxyvitamin_D3_level_90    809104     781118
# 2  AST___aspartate_transam_SGOT__46   1738489    1680613
# 3                AST_serum_level_47  10837982   10485351
# 4     Albumin___creatinine_ratio_37    180911      78420
#
#                                               digest  min      max       mean  \
# 0  ({'m': 0.0, 'c': 9.0}, {'m': 0.1, 'c': 112.0},...  0.0    686.0   3.908721
# 1  ({'m': 0.1, 'c': 3.0}, {'m': 1.0, 'c': 314.0},...  0.0    951.8  47.148892
# 2  ({'m': 0.0, 'c': 3901.0}, {'m': 0.770571428571...  0.0  15330.0  26.619633
# 3  ({'m': 0.0, 'c': 53.0}, {'m': 1.8, 'c': 1.0}, ... -5.0  20700.0  27.251680
# 4  ({'m': -1.0, 'c': 1.0}, {'m': 0.0, 'c': 4213.0... -1.0  12821.0  10.672548
#
#    approx_lqr    approx_uqr
# 0   -4.673936     10.857805
# 1  -36.770239    121.653230
# 2    0.100000  40000.000000
# 3    0.100000  40000.000000
# 4   -4.318622      8.826145

# %% [markdown]
# ### Now we can load this file into the loader and it will use the updated bounds

# %%
# Build 

dm = FoundationalDataModule(path_to_db=cfg.data.path_to_db,
                            path_to_ds=cfg.data.path_to_ds,
                            load=True,
                            tokenizer="tabular",
                            batch_size=cfg.data.batch_size,
                            max_seq_length=cfg.transformer.block_size,
                            freq_threshold=cfg.data.unk_freq_threshold,
                            min_workers=cfg.data.min_workers,
                            inclusion_conditions=["COUNTRY = 'E'"],
                            overwrite_meta_information=cfg.data.path_to_ds  + 'meta_information_QuantJenny.pickle',
                           )

vocab_size = dm.train_set.tokenizer.vocab_size

# list of univariate measurements to model with Normal distribution
# Extract the measurements, using the fact that the diagnoses are all up upper case.
measurements_for_univariate_regression = dm.train_set.meta_information["measurement_tables"][dm.train_set.meta_information["measurement_tables"]["count_obs"] > 0]["event"].to_list()
cfg.head.tokens_for_univariate_regression = dm.encode(measurements_for_univariate_regression)
# display(measurements_for_univariate_regression)

display(dm.train_set.meta_information)
# Out:
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=train/ dataset, with 23,613,894 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=test/ dataset, with 1,508,320 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=val/ dataset, with 1,426,714 samples
# {'static_table': {'SEX':   category     count
#   0        F  14278868
#   1        I       683
#   2        M  13841966,
#   'IMD':    category    count
#   0       NaN  2442913
#   1       1.0  4789813
#   2       2.0  4981882
#   3       3.0  5072397
#   4       4.0  5650727
#   5       5.0  5183785,
#   'ETHNICITY':   category     count
#   0    ASIAN   2267997
#   1    BLACK   1156866
#   2  MISSING   8058247
#   3    MIXED    485838
#   4    OTHER    422374
#   5    WHITE  15730195},
#  'diagnosis_table':                                   event    count
#  0                      ADDISONS_DISEASE     6691
#  1                       ADDISON_DISEASE    11794
#  2                                    AF   731332
#  3                      ALCOHOLMISUSE_V2  1125212
#  4                ALLCANCER_NOHAEM_NOBCC  1496973
#  5                  ALLERGICRHINITISCONJ  3291165
#  6                          ALL_DEMENTIA   528602
#  7                               ANXIETY  3560978
#  8          ANY_DEAFNESS_HEARING_LOSS_V2  2282766
#  9                     AORTICANEURYSM_V2   101134
#  10                    ASTHMA_PUSHASTHMA  4175115
#  11                         ATOPICECZEMA  4369082
#  12                               AUTISM   156860
#  13                              BIPOLAR   108852
#  14                       BRONCHIECTASIS   112618
#  15          CHRONICFATIGUESYNDROMEMM_V2    82799
#  16        CHRONIC_LIVER_DISEASE_ALCOHOL    63405
#  17                         CKDSTAGE3TO5  1088754
#  18                                 COPD   751320
#  19                       CROHNS_DISEASE    81250
#  20                       CYSTICFIBROSIS     7053
#  21                                DEATH  1629100
#  22                           DEPRESSION  4109336
#  23                        DOWNSSYNDROME    17006
#  24                      EATINGDISORDERS   191873
#  25         ENDOMETRIOSIS_ADENOMYOSIS_V2   209157
#  26                             EPILEPSY   377341
#  27                         FIBROMYALGIA   153213
#  28                                 GOUT   632089
#  29                  HAEMOCHROMATOSIS_V2    18631
#  30                                HF_V3   524982
#  31                              HIVAIDS    41951
#  32                         HYPERTENSION  3934473
#  33                   HYPERTHYROIDISM_V2   217964
#  34              HYPOTHYROIDISM_DRAFT_V1   932079
#  35             IHDINCLUDINGMI_OPTIMALV2  1162843
#  36                               ILD_SH    58104
#  37                   ISCHAEMICSTROKE_V2   178437
#  38               LEUKAEMIA_PREVALENCEV2    54438
#  39               LYMPHOMA_PREVALENCE_V2    80511
#  40                      MENIERESDISEASE    73688
#  41                          MINFARCTION   477556
#  42                                   MS    53204
#  43                             NAFLD_V2   158688
#  44                                  OSA   234938
#  45                       OSTEOARTHRITIS  2653242
#  46                         OSTEOPOROSIS   628118
#  47  OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL   289252
#  48                           PAD_STRICT   254632
#  49                           PARKINSONS    91718
#  50                PERIPHERAL_NEUROPATHY   840638
#  51                    PERNICIOUSANAEMIA    73331
#  52               PLASMACELL_NEOPLASM_V2    20301
#  53                            PMRANDGCA   195907
#  54  POLYCYSTIC_OVARIAN_SYNDROME_PCOS_V2   332297
#  55                     PREVALENT_IBS_V2  1210229
#  56                            PSORIASIS   743897
#  57               PSORIATICARTHRITIS2021    51273
#  58                        PTSDDIAGNOSIS   126269
#  59                               PVD_V3   185904
#  60                  RHEUMATOIDARTHRITIS   197253
#  61                   SCHIZOPHRENIAMM_V2   125141
#  62               SICKLE_CELL_DISEASE_V2    11159
#  63                     SJOGRENSSYNDROME    23326
#  64                 STROKEUNSPECIFIED_V2   446046
#  65                      STROKE_HAEMRGIC    83609
#  66                      SUBSTANCEMISUSE   502552
#  67         SYSTEMIC_LUPUS_ERYTHEMATOSUS    26820
#  68                   SYSTEMIC_SCLEROSIS     8772
#  69                              TYPE1DM   145143
#  70                        TYPE2DIABETES  1404325
#  71                   ULCERATIVE_COLITIS   120361
#  72                  VALVULARDISEASES_V2   401061
#  73                    VISUAL_IMPAIRMENT   155707,
#  'measurement_tables':                                                  event      count  count_obs  \
#  0                        25_Hydroxyvitamin_D2_level_92     782791     693470
#  1                        25_Hydroxyvitamin_D3_level_90     809104     781118
#  2                     AST___aspartate_transam_SGOT__46    1738489    1680613
#  3                                   AST_serum_level_47   10837982   10485351
#  4                        Albumin___creatinine_ratio_37     180911      78420
#  5                                    Basophil_count_22   86869779   85642540
#  6                               Blood_calcium_level_38     415717     385464
#  7                                        Blood_urea_28     785766     671861
#  8                                    Body_mass_index_3   99868822   97759312
#  9                   Brain_natriuretic_peptide_level_66     229202     159318
#  10                           Calcium_adjusted_level_41    1464226    1457911
#  11                Calculated_LDL_cholesterol_level_103    6967780    6719746
#  12           Combined_total_vitamin_D2_and_D3_level_93     452984     424568
#  13                    Corrected_serum_calcium_level_42   16683796   16264645
#  14                                   Current_smoker_83   10592787    2509612
#  15                          Diastolic_blood_pressure_5  241026671  240724855
#  16                                 Eosinophil_count_21   92193433   91608967
#  17                   Erythrocyte_sedimentation_rate_61   29892785   24659777
#  18                                        Ex_smoker_84   24891632    1988555
#  19                                    Free_T4_level_76    1405341    1254654
#  20                  GFR_calculated_abbreviated_MDRD_34   73709249   65832806
#  21                                Haematocrit___PCV_16    4346108    4313923
#  22                                      Haematocrit_15   76582325   76295018
#  23         Haemoglobin_A1c_level___IFCC_standardised_6   35091904   32542190
#  24                             Haemoglobin_A1c_level_8    6516701    2279027
#  25                            Haemoglobin_estimation_9   97391693   96533626
#  26                        HbA1c_level__DCCT_aligned__7   14948615   12120543
#  27             INR___international_normalised_ratio_81     426165     409175
#  28                   International_normalised_ratio_82   27966697   24573431
#  29                                 Lymphocyte_count_20   92896401   92370088
#  30                      Mean_corpusc_Hb_conc__MCHC__14   70867102   70624255
#  31                    Mean_corpusc_haemoglobin_MCH__13   90498376   90220814
#  32                    Mean_corpuscular_volume__MCV__11   94723195   94409919
#  33                                   Monocyte_count_23   92489278   91979180
#  34   N_terminal_pro_brain_natriuretic_peptide_level_67      57470      53401
#  35                                 Neutrophil_count_19   93489124   92851403
#  36                             Never_smoked_tobacco_85   60751822    1538646
#  37                       Non_HDL_cholesterol_level_108    2408310    2393900
#  38                                      O_E___height_1   69089436   68753070
#  39                                      O_E___weight_2  117401338  116811930
#  40               Plasma_B_natriuretic_peptide_level_69      82488      78777
#  41                        Plasma_C_reactive_protein_60    9155551    7401061
#  42                    Plasma_HDL_cholesterol_level_101    2173456    2111774
#  43                    Plasma_LDL_cholesterol_level_104    1434461    1249520
#  44   Plasma_N_terminal_pro_B_type_natriuretic_pepti...      53534      52305
#  45                                 Plasma_TSH_level_73    2049380    2017201
#  46            Plasma_alanine_aminotransferase_level_44    4012790    3989304
#  47                             Plasma_albumin_level_52    3719377    3707409
#  48                Plasma_alkaline_phosphatase_level_49    3290802    3281396
#  49                             Plasma_calcium_level_40    1294409    1286874
#  50                     Plasma_cholesterol_HDL_ratio_96     587483     575593
#  51                   Plasma_corrected_calcium_level_43    1168224     900092
#  52                          Plasma_creatinine_level_32    4513054    4489265
#  53                            Plasma_ferritin_level_62     220380     167898
#  54                             Plasma_free_T4_level_77     724108     681695
#  55          Plasma_gamma_glutamyl_transferase_level_58    1762750    1749440
#  56                           Plasma_potassium_level_27    4445152    4402840
#  57       Plasma_pro_brain_natriuretic_peptide_level_64      83343      70129
#  58                              Plasma_sodium_level_25    4458632    4425530
#  59                     Plasma_total_bilirubin_level_54    3443114    3429483
#  60                   Plasma_total_cholesterol_level_99    2331589    2302691
#  61                       Plasma_triglyceride_level_106    1573268    1548859
#  62                                Plasma_urea_level_30    1991274    1968449
#  63                                   Platelet_count_12   95904116   95382243
#  64                       Red_blood_cell__RBC__count_10   92326200   91855577
#  65                Red_blood_cell_distribution_width_17   49751137   46387000
#  66                Serum_25_Hydroxy_vitamin_D3_level_88    1211141     847628
#  67                   Serum_C_reactive_protein_level_59   19234068   16340825
#  68                     Serum_HDL_cholesterol_level_100   50953183   50016821
#  69                     Serum_LDL_cholesterol_level_102   30073152   29091476
#  70   Serum_N_terminal_pro_B_type_natriuretic_peptid...     383790     335656
#  71                                   Serum_T4_level_78     524777     450988
#  72                                  Serum_TSH_level_71   55655662   52458151
#  73             Serum_alanine_aminotransferase_level_45   46896239   46118828
#  74                                    Serum_albumin_51   83105055   82755894
#  75                       Serum_alkaline_phosphatase_50   76052242   75709587
#  76                            Serum_bilirubin_level_53   24090337   23943058
#  77                                    Serum_calcium_39   28049902   26929397
#  78                                Serum_cholesterol_97   57393841   55137024
#  79                      Serum_cholesterol_HDL_ratio_94   28586515   27949257
#  80                                 Serum_creatinine_31  102915170  101600210
#  81                                   Serum_ferritin_63   21412371   18831052
#  82                                     Serum_folate_80   14643748   13245269
#  83                              Serum_free_T4_level_75   22579062   21978910
#  84           Serum_gamma_glutamyl_transferase_level_57   22592131   21804090
#  85   Serum_non_high_density_lipoprotein_cholesterol...   10648096   10620740
#  86                                  Serum_potassium_26   99036754   97495916
#  87        Serum_pro_brain_natriuretic_peptide_level_65     243565     196058
#  88                                     Serum_sodium_24   99409745   98817250
#  89           Serum_total_25_hydroxy_vitamin_D_level_87    2178432    1882341
#  90                      Serum_total_bilirubin_level_56   54098383   53753453
#  91                    Serum_total_cholesterol_level_98    5185017    5100659
#  92                             Serum_triglycerides_105   42415036   41980818
#  93                                 Serum_urea_level_29   78670253   78276364
#  94                                Serum_vitamin_B12_79   16797696   15132281
#  95                           Serum_vitamin_D2_level_89     249092     204719
#  96                                  Serum_vitamin_D_86    2478806    1741767
#  97                           Systolic_blood_pressure_4  241541988  241223179
#  98                       TSH___thyroid_stim_hormone_72    3568579    3063531
#  99                                        TSH_level_74     507085     272902
#  100                 Total_25_hydroxyvitamin_D_level_91     333324     283455
#  101                      Total_alkaline_phosphatase_48    6461505    6422922
#  102                                 Total_bilirubin_55    2193031    2141609
#  103                     Total_cholesterol_HDL_ratio_95   15760772   15489099
#  104                          Total_white_cell_count_18   94827537   94179010
#  105                  Urine_albumin_creatinine_ratio_35   15107807   10249206
#  106             Urine_microalbumin_creatinine_ratio_36     201318      94009
#  107  eGFR_using_creatinine_CKD_EPI_per_1_73_square_...   12869245   11902149
#  108                                 ACE_Inhibitors_D2T  191462111          0
#  109                                   AMD_DH_Donepezil    5635153          0
#  110                                   AMD_DH_Memantine    2309471          0
#  111                                        ARBs_Luyuan   72329278          0
#  112                                     Acarbose_AURUM     507434          0
#  113                          AldosteroneAntagonist_D2T   11182704          0
#  114                                    AllHIVdrugs_HIV      82262          0
#  115                            All_AntiArrhythmics_D2T   29502352          0
#  116                                  All_Antiplatelets  162940629          0
#  117                                  All_Diuretics_D2T  176070847          0
#  118                     All_Diuretics_ExclLactones_D2T  176070847          0
#  119                                       AlphaBlocker   51635379          0
#  120                                         Amantadine     479791          0
#  121                              Amitriptyline_optimal   46415710          0
#  122                            Anticonvulsants_OPTIMAL   90774779          0
#  123    Antihistamines_second_generation_H1_antagonists   47308115          0
#  124                             Antipsychotics_OPTIMAL   31658166          0
#  125                             Anxiolytics_mumpredict   32874923          0
#  126                                    Aspirin_OPTIMAL  131327634          0
#  127                                    Benzodiazepines   55608827          0
#  128                               BetaBlockers_OPTIMAL   79374522          0
#  129                       Bisphosphonates_osteoporosis   30294675          0
#  130                             COCP_reg_contraception   34316525          0
#  131                                       COMT_Optimal     886259          0
#  132                             CalciumChannelBlck_D2T  108721302          0
#  133                        Calcium_supplements_Optimal   57542223          0
#  134                              Carbamazepine_Optimal   12812897          0
#  135                             DPP4inhibitors_OPTIMAL   12000147          0
#  136                                           Dementia    9738544          0
#  137                                           Digoxin_   17497910          0
#  138             Direct_Acting_Oral_Anticoagulants_DOAC   14815747          0
#  139                            Fibrate_FenofibrateOnly    2305308          0
#  140                        First_gen_H1_antihistamines   16181607          0
#  141                                         GLP_1Aurum    2676211          0
#  142                            Gabapentin_Oral_OPTIMAL   17508445          0
#  143                                    Galantamine_NEW     830429          0
#  144                    HydroxychloroquineAURUM_Zhaonan    3312310          0
#  145                                     ICS_PUSHAsthma   94873269          0
#  146                                   Insulin_Aurum_v2   28641496          0
#  147                                   LABA_PUSH_Asthma   14958767          0
#  148                                    LAMA_PUSHAsthma   15239995          0
#  149                                     LKA_PUSHAsthma    8537907          0
#  150                           LeflunomideAURUM_Zhaonan     586799          0
#  151                                     Levothyroxine_  117844926          0
#  152                       Lipid_lowering_drugs_Optimal  263876709          0
#  153                                    Lithium_OPTIMAL    4395155          0
#  154                                      MAO_B_Optimal     829174          0
#  155                                 Meglitinides_Aurum     486644          0
#  156                               Metformin_612_A10BD2   74162080          0
#  157                          MethotrexateAURUM_Zhaonan    7884622          0
#  158                                        Mirtazapine   23524446          0
#  159               Monoamine_Oxidase_Inhibitors_OPTIMAL     236966          0
#  160                          NSAIDS_oral_OPTIMAL_final  219183349          0
#  161                             Nasal_steroids_optimal   29010523          0
#  162                                    OCS_PUSHAsthma2   29568929          0
#  163                              POP_reg_contraceptive   12186107          0
#  164                                Paracetamol_OPTIMAL   85242874          0
#  165                                 Pregabalin_Optimal   14497547          0
#  166                      PropranololAnxiety_mumpredict   12924874          0
#  167                                       Rivastigmine     963471          0
#  168                                    SABA_PUSHAsthma   91182585          0
#  169                            SGLT2inhibitors_Optimal    4059940          0
#  170                                      SNRIs_OPTIMAL   21379065          0
#  171                                      SSRIs_Optimal  132417423          0
#  172                                            Statins  249911634          0
#  173                          Strong_Opioids_2022_Final   31728471          0
#  174                         SulfasalazineAURUM_Zhaonan    4084855          0
#  175                               Sulphonylureas_Aurum   34289555          0
#  176              Systemic_oral_corticosteroids_optimal   33516650          0
#  177                              Thiazide_Diuretics_v2  105228802          0
#  178                        Thiazolidinediones_Aurum_JC    6191596          0
#  179                    Tricyclic_Antidepressants_final   68893019          0
#  180                     UricAcid_LoweringDrugs_optimal   20559558          0
#  181                                  ValproateMigraine   13594697          0
#  182                                          Vitamin_D   72657845          0
#  183                                          Warfarin_   37353354          0
#  184                                 Weak_Opioids_Final  140622354          0
#  185                                  all_contraceptive   53655141          0
#  186                           asthma_combined_inhalers   29469516          0
#  187                                   levodopa_Optimal    8483033          0
#  188            phosphodiesterasetype5inhibitor_OPTIMAL   15057609          0
#
#                                                  digest           min  \
#  0    ({'m': 0.0, 'c': 9.0}, {'m': 0.1, 'c': 112.0},...  0.000000e+00
#  1    ({'m': 0.1, 'c': 3.0}, {'m': 1.0, 'c': 314.0},...  0.000000e+00
#  2    ({'m': 0.0, 'c': 3901.0}, {'m': 0.770571428571...  0.000000e+00
#  3    ({'m': 0.0, 'c': 53.0}, {'m': 1.8, 'c': 1.0}, ... -5.000000e+00
#  4    ({'m': -1.0, 'c': 1.0}, {'m': 0.0, 'c': 4213.0... -1.000000e+00
#  5    ({'m': 0.0, 'c': 37098.0}, {'m': 0.01, 'c': 28... -1.000000e-01
#  6    ({'m': 0.0, 'c': 33.0}, {'m': 1.0, 'c': 1.0}, ...  0.000000e+00
#  7    ({'m': 0.0, 'c': 2746.0}, {'m': 0.09, 'c': 1.0...  0.000000e+00
#  8    ({'m': 0.0, 'c': 14.0}, {'m': 0.05, 'c': 1.0},... -3.268000e+04
#  9    ({'m': 0.0, 'c': 120.0}, {'m': 0.1, 'c': 1.0},...  0.000000e+00
#  10   ({'m': 0.99, 'c': 1.0}, {'m': 1.04, 'c': 1.0},...  0.000000e+00
#  11   ({'m': 0.0, 'c': 1.0}, {'m': 0.1, 'c': 15.0}, ... -8.400000e+00
#  12   ({'m': 0.0, 'c': 9.0}, {'m': 2.2, 'c': 1.0}, {...  0.000000e+00
#  13   ({'m': 0.0, 'c': 4.0}, {'m': 0.16, 'c': 1.0}, ... -2.580000e+00
#  14   ({'m': 0.0, 'c': 893.0}, {'m': 0.2, 'c': 2.0},... -2.030000e+03
#  15   ({'m': 0.0, 'c': 8.0}, {'m': 5.0, 'c': 1.0}, {... -1.200000e+02
#  16   ({'m': 0.0, 'c': 3017.0}, {'m': 0.01, 'c': 255... -6.000000e-01
#  17   ({'m': -4.0, 'c': 2.0}, {'m': 0.0, 'c': 127.0}... -2.000000e+01
#  18   ({'m': -1.0, 'c': 1.0}, {'m': 0.0, 'c': 3006.0... -2.030000e+03
#  19   ({'m': -9.1, 'c': 1.0}, {'m': -8.8, 'c': 1.0},... -1.340000e+02
#  20   ({'m': 0.0, 'c': 17.0}, {'m': 1.73, 'c': 1.0},... -9.000000e+01
#  21   ({'m': -0.29, 'c': 1.0}, {'m': -0.28, 'c': 5.0... -4.650000e-01
#  22   ({'m': 0.003, 'c': 2.0}, {'m': 0.004, 'c': 1.0...  0.000000e+00
#  23   ({'m': 0.0, 'c': 2.0}, {'m': 3.9, 'c': 1.0}, {... -7.900000e+01
#  24   ({'m': 0.0, 'c': 6.0}, {'m': 0.1, 'c': 1.0}, {...  0.000000e+00
#  25   ({'m': 1.38, 'c': 1.0}, {'m': 6.9, 'c': 1.0}, ... -1.120000e+02
#  26   ({'m': 0.0, 'c': 17.0}, {'m': 0.67, 'c': 1.0},... -4.100000e+01
#  27   ({'m': 0.0, 'c': 22.0}, {'m': 0.1, 'c': 3.0}, ...  0.000000e+00
#  28   ({'m': 0.0, 'c': 36.0}, {'m': 0.2, 'c': 2.0}, ... -3.400000e+01
#  29   ({'m': 0.0, 'c': 3.0}, {'m': 0.03, 'c': 2.0}, ... -3.500000e+01
#  30   ({'m': 0.0, 'c': 1.0}, {'m': 0.36, 'c': 1.0}, ... -2.950000e+02
#  31   ({'m': 10.8, 'c': 1.0}, {'m': 12.7, 'c': 2.0},... -2.890000e+01
#  32   ({'m': 0.3, 'c': 1.0}, {'m': 0.4, 'c': 1.0}, {... -1.004000e+02
#  33   ({'m': 0.0, 'c': 10.0}, {'m': 0.03, 'c': 2.0},... -4.000000e+00
#  34   ({'m': 0.0, 'c': 1.0}, {'m': 1.0, 'c': 8.0}, {...  0.000000e+00
#  35   ({'m': 0.0, 'c': 7.0}, {'m': 0.01, 'c': 1.0}, ... -6.700000e+01
#  36   ({'m': -25.0, 'c': 3.0}, {'m': -1.0, 'c': 2.0}... -2.500000e+01
#  37   ({'m': -1.6, 'c': 1.0}, {'m': -1.2, 'c': 1.0},... -1.600000e+00
#  38   ({'m': 0.0, 'c': 148.0}, {'m': 0.14, 'c': 1.0}... -1.079000e+05
#  39   ({'m': 0.0, 'c': 23.0}, {'m': 0.093, 'c': 1.0}... -1.170000e+04
#  40   ({'m': 0.0, 'c': 51.0}, {'m': 0.58, 'c': 12.0}...  0.000000e+00
#  41   ({'m': 0.0, 'c': 17.0}, {'m': 0.1, 'c': 821.0}... -3.814000e+03
#  42   ({'m': 0.0, 'c': 4.0}, {'m': 0.05, 'c': 1.0}, ...  0.000000e+00
#  43   ({'m': 0.0, 'c': 37.0}, {'m': 0.1, 'c': 3.0}, ...  0.000000e+00
#  44   ({'m': 0.2, 'c': 1.0}, {'m': 1.0, 'c': 31.0}, ...  2.000000e-01
#  45   ({'m': 0.0, 'c': 74.0}, {'m': 0.001, 'c': 1.0}... -7.800000e+00
#  46   ({'m': 0.0, 'c': 13.0}, {'m': 1.0, 'c': 4.0}, ...  0.000000e+00
#  47   ({'m': 0.0, 'c': 3.0}, {'m': 10.0, 'c': 1.0}, ...  0.000000e+00
#  48   ({'m': 0.0, 'c': 6.0}, {'m': 0.69, 'c': 1.0}, ... -2.400000e+01
#  49   ({'m': 0.0, 'c': 2.0}, {'m': 0.13, 'c': 2.0}, ...  0.000000e+00
#  50   ({'m': 0.0, 'c': 6.0}, {'m': 0.16, 'c': 1.0}, ...  0.000000e+00
#  51   ({'m': 0.0, 'c': 13.0}, {'m': 0.12, 'c': 1.0},...  0.000000e+00
#  52   ({'m': 0.0, 'c': 7.0}, {'m': 2.42, 'c': 1.0}, ...  0.000000e+00
#  53   ({'m': 0.0, 'c': 3655.0}, {'m': 0.1, 'c': 1.0}...  0.000000e+00
#  54   ({'m': 0.0, 'c': 547.0}, {'m': 0.0199999999999... -7.720000e+01
#  55   ({'m': 0.0, 'c': 6.0}, {'m': 3.0, 'c': 4.0}, {...  0.000000e+00
#  56   ({'m': 0.0, 'c': 33.0}, {'m': 1.3, 'c': 1.0}, ...  0.000000e+00
#  57   ({'m': 0.0, 'c': 12.0}, {'m': 0.01, 'c': 1.0},...  0.000000e+00
#  58   ({'m': 0.0, 'c': 6.0}, {'m': 4.5, 'c': 1.0}, {...  0.000000e+00
#  59   ({'m': 0.0, 'c': 36.0}, {'m': 0.9, 'c': 1.0}, ...  0.000000e+00
#  60   ({'m': 0.0, 'c': 2073.0}, {'m': 1.01, 'c': 3.0...  0.000000e+00
#  61   ({'m': 0.0, 'c': 8.0}, {'m': 0.1, 'c': 2.0}, {...  0.000000e+00
#  62   ({'m': 0.0, 'c': 5.0}, {'m': 0.3, 'c': 3.0}, {...  0.000000e+00
#  63   ({'m': 0.0, 'c': 4.0}, {'m': 1.44, 'c': 1.0}, ... -5.600000e+02
#  64   ({'m': 0.0, 'c': 3.0}, {'m': 0.81, 'c': 1.0}, ... -4.460000e+00
#  65   ({'m': 0.0, 'c': 2.0}, {'m': 5.2, 'c': 1.0}, {...  0.000000e+00
#  66   ({'m': 0.0, 'c': 18.0}, {'m': 0.5, 'c': 3.0}, ...  0.000000e+00
#  67   ({'m': 0.0, 'c': 21.0}, {'m': 0.1, 'c': 219.0}... -1.150000e+02
#  68   ({'m': 0.0, 'c': 9.0}, {'m': 0.06, 'c': 1.0}, ... -3.900000e+01
#  69   ({'m': -999994.31, 'c': 2.0}, {'m': -1.1, 'c':... -9.999943e+05
#  70   ({'m': 1.0, 'c': 13.0}, {'m': 1.478, 'c': 1.0}...  0.000000e+00
#  71   ({'m': -25.0, 'c': 7.0}, {'m': -20.0, 'c': 1.0... -2.500000e+01
#  72   ({'m': 0.0, 'c': 5.0}, {'m': 0.008, 'c': 12.0}... -2.143000e+01
#  73   ({'m': 2.0, 'c': 2.0}, {'m': 3.0, 'c': 12.0}, ... -4.300000e+01
#  74   ({'m': 2.14, 'c': 1.0}, {'m': 4.0, 'c': 1.0}, ... -4.500000e+01
#  75   ({'m': 0.6, 'c': 1.0}, {'m': 0.77, 'c': 1.0}, ... -1.650000e+02
#  76   ({'m': 0.0, 'c': 17.0}, {'m': 0.66, 'c': 1.0},... -1.912620e+05
#  77   ({'m': 0.0, 'c': 13.0}, {'m': 0.5, 'c': 1.0}, ... -2.120000e+00
#  78   ({'m': 0.0, 'c': 67.0}, {'m': 0.7, 'c': 1.0}, ... -7.500000e+01
#  79   ({'m': 0.0, 'c': 13.0}, {'m': 0.14, 'c': 1.0},... -3.400000e+00
#  80   ({'m': 1.0, 'c': 1.0}, {'m': 1.09, 'c': 1.0}, ... -4.212000e+04
#  81   ({'m': 0.0, 'c': 10.0}, {'m': 0.1, 'c': 1.0}, ... -2.810200e+06
#  82   ({'m': 0.0, 'c': 27.0}, {'m': 0.009, 'c': 1.0}... -2.000000e+01
#  83   ({'m': 0.0, 'c': 2.0}, {'m': 0.3, 'c': 4.0}, {...  0.000000e+00
#  84   ({'m': 0.0, 'c': 4.0}, {'m': 1.0, 'c': 1.0}, {... -4.620000e+02
#  85   ({'m': 0.17, 'c': 2.0}, {'m': 0.4, 'c': 2.0}, ... -2.500000e+00
#  86   ({'m': 1.8, 'c': 1.0}, {'m': 2.0, 'c': 1.0}, {... -2.179000e+03
#  87   ({'m': 0.0, 'c': 44.0}, {'m': 0.05, 'c': 2.0},...  0.000000e+00
#  88   ({'m': 1.18, 'c': 1.0}, {'m': 1.32, 'c': 1.0},... -1.400000e+02
#  89   ({'m': 2.0, 'c': 20.0}, {'m': 5.0, 'c': 15.0},...  0.000000e+00
#  90   ({'m': 1.0, 'c': 15.0}, {'m': 2.0, 'c': 110.0}... -2.000000e+00
#  91   ({'m': 0.0, 'c': 4.0}, {'m': 0.6, 'c': 1.0}, {... -7.600000e+00
#  92   ({'m': 0.0, 'c': 18.0}, {'m': 0.08, 'c': 1.0},... -3.762000e+02
#  93   ({'m': 0.2, 'c': 1.0}, {'m': 0.4, 'c': 1.0}, {... -2.410000e+01
#  94   ({'m': 0.0, 'c': 8.0}, {'m': 1.57, 'c': 1.0}, ... -5.781707e+08
#  95   ({'m': -5.0, 'c': 1.0}, {'m': 0.0, 'c': 1786.0... -5.000000e+00
#  96   ({'m': 0.0, 'c': 26.0}, {'m': 0.1, 'c': 2.0}, ... -3.970000e+01
#  97   ({'m': 0.0, 'c': 8.0}, {'m': 50.0, 'c': 1.0}, ... -2.000000e+02
#  98   ({'m': -0.36, 'c': 1.0}, {'m': -0.1, 'c': 1.0}... -5.000000e+01
#  99   ({'m': 0.0, 'c': 2901.0}, {'m': 0.001, 'c': 1.... -5.000000e-01
#  100  ({'m': 0.0, 'c': 1.0}, {'m': 0.9, 'c': 1.0}, {...  0.000000e+00
#  101  ({'m': 0.96, 'c': 1.0}, {'m': 1.09, 'c': 1.0},...  0.000000e+00
#  102  ({'m': 0.0, 'c': 314.0}, {'m': 0.14, 'c': 1.0}... -7.000000e+00
#  103  ({'m': 0.0, 'c': 21.0}, {'m': 0.001, 'c': 2.0}... -3.100000e+00
#  104  ({'m': -0.3, 'c': 1.0}, {'m': 0.0, 'c': 3.0}, ... -1.470000e+01
#  105  ({'m': 0.0, 'c': 213.0}, {'m': 0.01, 'c': 3.0}... -1.400000e+01
#  106  ({'m': 0.0, 'c': 5691.0}, {'m': 0.001, 'c': 53... -5.803000e+00
#  107  ({'m': 0.0, 'c': 1.0}, {'m': 4.0, 'c': 9.0}, {... -9.000000e+01
#  108                                               None           NaN
#  109                                               None           NaN
#  110                                               None           NaN
#  111                                               None           NaN
#  112                                               None           NaN
#  113                                               None           NaN
#  114                                               None           NaN
#  115                                               None           NaN
#  116                                               None           NaN
#  117                                               None           NaN
#  118                                               None           NaN
#  119                                               None           NaN
#  120                                               None           NaN
#  121                                               None           NaN
#  122                                               None           NaN
#  123                                               None           NaN
#  124                                               None           NaN
#  125                                               None           NaN
#  126                                               None           NaN
#  127                                               None           NaN
#  128                                               None           NaN
#  129                                               None           NaN
#  130                                               None           NaN
#  131                                               None           NaN
#  132                                               None           NaN
#  133                                               None           NaN
#  134                                               None           NaN
#  135                                               None           NaN
#  136                                               None           NaN
#  137                                               None           NaN
#  138                                               None           NaN
#  139                                               None           NaN
#  140                                               None           NaN
#  141                                               None           NaN
#  142                                               None           NaN
#  143                                               None           NaN
#  144                                               None           NaN
#  145                                               None           NaN
#  146                                               None           NaN
#  147                                               None           NaN
#  148                                               None           NaN
#  149                                               None           NaN
#  150                                               None           NaN
#  151                                               None           NaN
#  152                                               None           NaN
#  153                                               None           NaN
#  154                                               None           NaN
#  155                                               None           NaN
#  156                                               None           NaN
#  157                                               None           NaN
#  158                                               None           NaN
#  159                                               None           NaN
#  160                                               None           NaN
#  161                                               None           NaN
#  162                                               None           NaN
#  163                                               None           NaN
#  164                                               None           NaN
#  165                                               None           NaN
#  166                                               None           NaN
#  167                                               None           NaN
#  168                                               None           NaN
#  169                                               None           NaN
#  170                                               None           NaN
#  171                                               None           NaN
#  172                                               None           NaN
#  173                                               None           NaN
#  174                                               None           NaN
#  175                                               None           NaN
#  176                                               None           NaN
#  177                                               None           NaN
#  178                                               None           NaN
#  179                                               None           NaN
#  180                                               None           NaN
#  181                                               None           NaN
#  182                                               None           NaN
#  183                                               None           NaN
#  184                                               None           NaN
#  185                                               None           NaN
#  186                                               None           NaN
#  187                                               None           NaN
#  188                                               None           NaN
#
#                max          mean  approx_lqr    approx_uqr
#  0    6.860000e+02  3.908721e+00   -4.673936  1.085780e+01
#  1    9.518000e+02  4.714889e+01  -36.770239  1.216532e+02
#  2    1.533000e+04  2.661963e+01    0.100000  4.000000e+04
#  3    2.070000e+04  2.725168e+01    0.100000  4.000000e+04
#  4    1.282100e+04  1.067255e+01   -4.318622  8.826145e+00
#  5    1.111110e+05  5.008992e-02   -0.093801  1.000000e+01
#  6    4.400000e+02  2.352980e+00    0.100000  1.000000e+01
#  7    1.265000e+03  6.513018e+00    0.100000  1.106345e+01
#  8    2.100000e+09  2.933050e+02    5.000000  1.300000e+02
#  9    5.001420e+05  4.168786e+02 -245.377936  4.833250e+02
#  10   2.790000e+02  2.365999e+00    0.100000  1.000000e+01
#  11   2.400000e+02  2.819830e+00    0.000000  3.000000e+01
#  12   1.222000e+03  5.235274e+01    0.100000  1.271046e+02
#  13   1.205201e+07  3.892081e+00    0.100000  1.000000e+01
#  14   1.710202e+07  6.982623e+01    0.000000  8.000000e+01
#  15   9.066667e+11  3.849124e+03   20.000000  4.000000e+02
#  16   4.444440e+05  2.339810e-01   -0.185129  1.000000e+01
#  17   1.315371e+07  1.843387e+01    0.000000  4.968605e+01
#  18   2.000000e+08  4.101646e+02    0.000000  8.000000e+01
#  19   9.800000e+10  2.859576e+05    0.100000  1.000000e+03
#  20   1.816032e+07  7.195087e+01    0.100000  3.000000e+02
#  21   9.385000e+03  5.573050e+00    0.100000  1.000000e+00
#  22   2.090678e+05  3.781405e+00    0.000000  1.000000e+00
#  23   6.000952e+12  1.888003e+05    5.000000  2.500000e+02
#  24   9.999990e+05  1.350703e+01    5.000000  2.500000e+02
#  25   1.411201e+07  7.961700e+01   10.000000  3.000000e+02
#  26   3.302112e+07  1.169712e+01    5.000000  2.500000e+02
#  27   3.112000e+04  2.775144e+00    0.625480  1.000000e+02
#  28   3.012201e+07  2.391763e+01    0.424929  1.000000e+02
#  29   3.720369e+09  3.650021e+02    0.100000  2.000000e+02
#  30   3.512660e+05  1.861975e+02   10.000000  5.000000e+02
#  31   3.550000e+07  8.281642e+01    1.000000  1.000000e+02
#  32   2.000000e+12  2.127458e+04   10.000000  2.500000e+02
#  33   3.720369e+09  8.190597e+01   -0.015277  2.000000e+01
#  34   7.501200e+04  7.599375e+02 -609.082298  1.182273e+03
#  35   3.720369e+09  8.505009e+01    0.000000  5.000000e+01
#  36   2.004000e+03  5.093185e+00    0.000000  0.000000e+00
#  37   3.407000e+03  3.447365e+00    0.000000  6.406608e+00
#  38   1.980230e+10  6.643426e+02   20.000000  2.720000e+02
#  39   4.000000e+12  5.843027e+04    0.250000  6.500000e+02
#  40   5.711570e+05  2.149659e+02 -179.142854  3.677963e+02
#  41   1.255000e+07  1.373701e+01  -11.163921  2.294427e+01
#  42   3.720369e+09  1.763100e+03    0.342956  3.900000e+00
#  43   5.020000e+02  2.839491e+00    0.000000  3.000000e+01
#  44   1.012460e+05  8.320501e+02 -634.067509  1.243258e+03
#  45   2.470000e+04  2.591849e+00   -1.342745  5.000000e+02
#  46   1.096500e+04  2.680884e+01    0.100000  4.000000e+04
#  47   4.354350e+04  4.083299e+01    2.000000  1.800000e+02
#  48   2.021600e+04  1.284950e+02    1.000000  2.811105e+02
#  49   3.780000e+02  2.376339e+00    0.100000  1.000000e+01
#  50   9.990000e+02  3.794378e+00    1.000000  2.500000e+02
#  51   2.480000e+02  2.347791e+00    0.100000  1.000000e+00
#  52   3.720369e+09  9.151366e+02    1.000000  1.396770e+02
#  53   2.478000e+04  8.423415e+01  -90.055064  5.000000e+05
#  54   2.530000e+10  5.727122e+05    0.100000  1.000000e+03
#  55   1.215100e+04  5.360479e+01  -26.335878  9.069391e+01
#  56   3.720369e+09  8.491083e+02    0.100000  1.000000e+01
#  57   6.686000e+04  5.495602e+02 -347.007866  6.700424e+02
#  58   3.720369e+09  9.799688e+02   90.000000  2.000000e+02
#  59   1.100000e+04  1.104913e+01   -0.840618  9.000000e+02
#  60   3.720369e+09  1.620601e+03    1.636645  5.000000e+01
#  61   3.720369e+09  2.403661e+03   -0.488123  3.457336e+00
#  62   8.080000e+02  5.956689e+00    0.100000  1.013932e+01
#  63   3.720369e+09  2.535123e+04    0.000000  1.000000e+07
#  64   3.720369e+09  6.149268e+04    0.000000  5.000000e+02
#  65   2.603070e+05  1.398563e+01   10.411794  1.000000e+02
#  66   2.000000e+04  4.997980e+01    0.100000  1.243850e+02
#  67   2.104936e+08  2.375269e+01   -8.026632  1.738617e+01
#  68   1.762016e+06  1.506581e+00    0.000000  3.900000e+00
#  69   3.720369e+09  3.871861e+02    0.000000  3.000000e+01
#  70   1.247610e+05  7.859756e+02 -616.021339  1.198091e+03
#  71   1.550000e+11  5.216837e+06    0.100000  1.000000e+03
#  72   1.990000e+07  1.537853e+01   -1.159385  5.000000e+02
#  73   2.060000e+05  2.705385e+01    0.100000  4.000000e+04
#  74   9.000000e+09  7.911712e+02    2.000000  1.800000e+02
#  75   1.523013e+07  8.934480e+01    1.000000  2.000000e+04
#  76   1.232190e+08  1.615846e+01   -0.918125  9.000000e+02
#  77   7.042004e+06  2.638354e+00    0.100000  1.000000e+01
#  78   3.720369e+09  7.465021e+01    1.756148  5.000000e+01
#  79   3.720369e+09  1.368317e+02    1.000000  2.500000e+02
#  80   3.720369e+09  5.354401e+02    1.000000  1.000000e+04
#  81   1.905228e+08  1.202831e+02 -112.607179  5.000000e+05
#  82   2.400000e+04  8.601245e+00   -4.577850  2.045037e+01
#  83   1.000000e+11  5.508446e+05    0.100000  1.000000e+04
#  84   7.022400e+04  5.737895e+01  -29.034568  9.475825e+01
#  85   7.265600e+03  3.402179e+00    0.000000  3.900000e+00
#  86   3.720369e+09  4.322233e+01    0.100000  1.000000e+01
#  87   7.700000e+05  7.009120e+02 -500.380581  9.312358e+02
#  88   6.910678e+07  1.413177e+02   90.000000  2.000000e+02
#  89   9.210000e+02  5.323836e+01  -19.214536  1.237171e+02
#  90   4.300000e+07  3.203331e+01   -0.908074  9.000000e+02
#  91   1.010101e+06  5.174581e+00    1.571161  5.000000e+01
#  92   3.720369e+09  4.449784e+02    0.000000  1.000000e+02
#  93   2.400000e+10  5.770647e+03    0.100000  1.023840e+01
#  94   3.720369e+09  7.152044e+02    5.000000  2.000000e+04
#  95   7.280000e+02  1.481123e+01   -7.753651  2.059193e+01
#  96   3.000000e+06  5.367082e+01    0.100000  1.000000e+03
#  97   1.111111e+11  6.007336e+02   30.000000  4.000000e+02
#  98   8.100000e+06  2.560645e+01   -1.533357  5.000000e+02
#  99   9.780000e+03  4.040092e+00   -1.962186  5.000000e+02
#  100  1.229000e+03  4.803738e+01    0.100000  1.000000e+03
#  101  9.014000e+03  8.453068e+01    0.100000  1.389157e+02
#  102  1.800000e+07  1.466419e+02   -2.319086  9.000000e+02
#  103  3.720369e+09  9.647043e+02    1.000000  2.500000e+02
#  104  3.720369e+09  2.501895e+02    0.100000  5.000000e+03
#  105  1.000000e+10  9.960699e+02   -3.777828  3.000000e+02
#  106  3.176800e+04  1.077503e+01   -4.119705  8.247756e+00
#  107  8.713000e+04  7.427459e+01   22.686686  3.000000e+02
#  108           NaN           NaN         NaN           NaN
#  109           NaN           NaN         NaN           NaN
#  110           NaN           NaN         NaN           NaN
#  111           NaN           NaN         NaN           NaN
#  112           NaN           NaN         NaN           NaN
#  113           NaN           NaN         NaN           NaN
#  114           NaN           NaN         NaN           NaN
#  115           NaN           NaN         NaN           NaN
#  116           NaN           NaN         NaN           NaN
#  117           NaN           NaN         NaN           NaN
#  118           NaN           NaN         NaN           NaN
#  119           NaN           NaN         NaN           NaN
#  120           NaN           NaN         NaN           NaN
#  121           NaN           NaN         NaN           NaN
#  122           NaN           NaN         NaN           NaN
#  123           NaN           NaN         NaN           NaN
#  124           NaN           NaN         NaN           NaN
#  125           NaN           NaN         NaN           NaN
#  126           NaN           NaN         NaN           NaN
#  127           NaN           NaN         NaN           NaN
#  128           NaN           NaN         NaN           NaN
#  129           NaN           NaN         NaN           NaN
#  130           NaN           NaN         NaN           NaN
#  131           NaN           NaN         NaN           NaN
#  132           NaN           NaN         NaN           NaN
#  133           NaN           NaN         NaN           NaN
#  134           NaN           NaN         NaN           NaN
#  135           NaN           NaN         NaN           NaN
#  136           NaN           NaN         NaN           NaN
#  137           NaN           NaN         NaN           NaN
#  138           NaN           NaN         NaN           NaN
#  139           NaN           NaN         NaN           NaN
#  140           NaN           NaN         NaN           NaN
#  141           NaN           NaN         NaN           NaN
#  142           NaN           NaN         NaN           NaN
#  143           NaN           NaN         NaN           NaN
#  144           NaN           NaN         NaN           NaN
#  145           NaN           NaN         NaN           NaN
#  146           NaN           NaN         NaN           NaN
#  147           NaN           NaN         NaN           NaN
#  148           NaN           NaN         NaN           NaN
#  149           NaN           NaN         NaN           NaN
#  150           NaN           NaN         NaN           NaN
#  151           NaN           NaN         NaN           NaN
#  152           NaN           NaN         NaN           NaN
#  153           NaN           NaN         NaN           NaN
#  154           NaN           NaN         NaN           NaN
#  155           NaN           NaN         NaN           NaN
#  156           NaN           NaN         NaN           NaN
#  157           NaN           NaN         NaN           NaN
#  158           NaN           NaN         NaN           NaN
#  159           NaN           NaN         NaN           NaN
#  160           NaN           NaN         NaN           NaN
#  161           NaN           NaN         NaN           NaN
#  162           NaN           NaN         NaN           NaN
#  163           NaN           NaN         NaN           NaN
#  164           NaN           NaN         NaN           NaN
#  165           NaN           NaN         NaN           NaN
#  166           NaN           NaN         NaN           NaN
#  167           NaN           NaN         NaN           NaN
#  168           NaN           NaN         NaN           NaN
#  169           NaN           NaN         NaN           NaN
#  170           NaN           NaN         NaN           NaN
#  171           NaN           NaN         NaN           NaN
#  172           NaN           NaN         NaN           NaN
#  173           NaN           NaN         NaN           NaN
#  174           NaN           NaN         NaN           NaN
#  175           NaN           NaN         NaN           NaN
#  176           NaN           NaN         NaN           NaN
#  177           NaN           NaN         NaN           NaN
#  178           NaN           NaN         NaN           NaN
#  179           NaN           NaN         NaN           NaN
#  180           NaN           NaN         NaN           NaN
#  181           NaN           NaN         NaN           NaN
#  182           NaN           NaN         NaN           NaN
#  183           NaN           NaN         NaN           NaN
#  184           NaN           NaN         NaN           NaN
#  185           NaN           NaN         NaN           NaN
#  186           NaN           NaN         NaN           NaN
#  187           NaN           NaN         NaN           NaN
#  188           NaN           NaN         NaN           NaN  }
