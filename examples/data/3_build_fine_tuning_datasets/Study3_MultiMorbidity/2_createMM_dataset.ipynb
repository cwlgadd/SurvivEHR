# %% [markdown]
# # Creating the parquet dataset from SQLite tables

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# !pwd

# %load_ext autoreload
# %autoreload 2
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# /rds/homes/g/gaddcz/Projects/CPRD/examples/data/3_build_fine_tuning_datasets/Study3_MultiMorbidity

# %%
import torch
from hydra import compose, initialize
from omegaconf import OmegaConf
from FastEHR.dataloader.foundational_loader import FoundationalDataModule

import logging
import time

from CPRD.examples.data.study_criteria import multimorbidity_inclusion_method

torch.manual_seed(1337)

logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")
# Out:
# Using device: cuda.

# %%
# load the configuration file, override any settings 
with initialize(version_base=None, config_path="../../../modelling/SurvivEHR/confs", job_name="dataset_creation_notebook"):
    cfg = compose(config_name="config_CompetingRisk11M", overrides=[])

# Create new dataset 
cfg.data.path_to_ds = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/"
print(OmegaConf.to_yaml(cfg))
# Out:
# is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: SurvivEHR
#   run_id: ${head.SurvLayer}PreTrain_small_${experiment.seed}
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: true
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
# fine_tuning:
#   fine_tune_outcomes: null
#   custom_outcome_method:
#     _target_: null
#   custom_stratification_method:
#     _target_: null
#   use_callbacks:
#     hidden_embedding:
#       num_batches: 1
#       mask_static: false
#       mask_value: false
#     performance_metrics: true
#     rmst: false
#   head:
#     surv_weight: 1
#     value_weight: 0
#     learning_rate: 0.0005
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: null
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression: None
#   value_weight: 0.1

# %%
# Build 
dm = FoundationalDataModule(path_to_db=cfg.data.path_to_db,
                            path_to_ds=cfg.data.path_to_ds,
                            load=True,
                            overwrite_meta_information=cfg.data.meta_information_path,
                           )

vocab_size = dm.train_set.tokenizer.vocab_size

print(f"{len(dm.train_set)} training patients")
print(f"{len(dm.val_set)} validation patients")
print(f"{len(dm.test_set)} test patients")
print(f"{vocab_size} vocab elements")
# Out:
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dict from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dict from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dict from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/split=train/ dataset
# INFO:root:with 3,159,376 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/split=test/ dataset
# INFO:root:with 206,187 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_MultiMorbidity/split=val/ dataset
# INFO:root:with 173,003 samples
# INFO:root:Creating unsupervised collator for DataModule
# 3159376 training patients
# 173003 validation patients
# 206187 test patients
# 265 vocab elements

# %%
print(50*365)
dm.train_set.view_sample(12345, max_dynamic_events=None, report_time=True)
# Out:
# 18250
# Time to retrieve: 0.3252 seconds
#
# SEX                 | M
# IMD                 | 5.0
# ETHNICITY           | WHITE
# birth_year          | 1956.0
# Sequence of 131 events
#
# Token                                                                      | Age at event (days)         | Standardized value
# =============================================================================================================================
# HYPERTHYROIDISM_V2                                                         | 13684                         | nan
# PERNICIOUSANAEMIA                                                          | 13684                         | nan
# HYPOTHYROIDISM_DRAFT_V1                                                    | 14780                         | nan
# Body_mass_index_3                                                          | 14998                         | -0.35
# Diastolic_blood_pressure_5                                                 | 14998                         | -0.34
# Never_smoked_tobacco_85                                                    | 14998                         | nan
# O_E___height_1                                                             | 14998                         | nan
# O_E___height_1                                                             | 14998                         | 0.11
# O_E___weight_2                                                             | 14998                         | nan
# O_E___weight_2                                                             | 14998                         | -0.39
# Systolic_blood_pressure_4                                                  | 14998                         | -0.28
# Levothyroxine_                                                             | 15016                         | nan
# Levothyroxine_                                                             | 15016                         | nan
# Levothyroxine_                                                             | 15103                         | nan
# Levothyroxine_                                                             | 15103                         | nan
# Levothyroxine_                                                             | 15199                         | nan
# Levothyroxine_                                                             | 15199                         | nan
# Levothyroxine_                                                             | 15303                         | nan
# Levothyroxine_                                                             | 15303                         | nan
# Levothyroxine_                                                             | 15392                         | nan
# Levothyroxine_                                                             | 15392                         | nan
# Levothyroxine_                                                             | 15486                         | nan
# Levothyroxine_                                                             | 15486                         | nan
# Levothyroxine_                                                             | 15598                         | nan
# Levothyroxine_                                                             | 15598                         | nan
# Levothyroxine_                                                             | 15705                         | nan
# Levothyroxine_                                                             | 15705                         | nan
# Levothyroxine_                                                             | 15795                         | nan
# Levothyroxine_                                                             | 15795                         | nan
# Levothyroxine_                                                             | 15907                         | nan
# Levothyroxine_                                                             | 15907                         | nan
# Levothyroxine_                                                             | 15998                         | nan
# Levothyroxine_                                                             | 15998                         | nan
# Levothyroxine_                                                             | 16096                         | nan
# Levothyroxine_                                                             | 16096                         | nan
# Levothyroxine_                                                             | 16199                         | nan
# Levothyroxine_                                                             | 16199                         | nan
# Levothyroxine_                                                             | 16297                         | nan
# Levothyroxine_                                                             | 16297                         | nan
# Levothyroxine_                                                             | 16396                         | nan
# Levothyroxine_                                                             | 16396                         | nan
# TSH___thyroid_stim_hormone_72                                              | 16405                         | -0.50
# Levothyroxine_                                                             | 16418                         | nan
# TSH___thyroid_stim_hormone_72                                              | 16516                         | -0.49
# Levothyroxine_                                                             | 16528                         | nan
# Levothyroxine_                                                             | 16528                         | nan
# Levothyroxine_                                                             | 16628                         | nan
# Levothyroxine_                                                             | 16628                         | nan
# Levothyroxine_                                                             | 16746                         | nan
# Levothyroxine_                                                             | 16746                         | nan
# Levothyroxine_                                                             | 16864                         | nan
# Levothyroxine_                                                             | 16864                         | nan
# Serum_TSH_level_71                                                         | 16878                         | -0.50
# Serum_free_T4_level_75                                                     | 16878                         | -0.50
# Levothyroxine_                                                             | 16980                         | nan
# Levothyroxine_                                                             | 16980                         | nan
# Diastolic_blood_pressure_5                                                 | 17015                         | -0.34
# Never_smoked_tobacco_85                                                    | 17015                         | nan
# Systolic_blood_pressure_4                                                  | 17015                         | -0.23
# Levothyroxine_                                                             | 17089                         | nan
# Levothyroxine_                                                             | 17089                         | nan
# Basophil_count_22                                                          | 17113                         | -0.48
# Eosinophil_count_21                                                        | 17113                         | -0.47
# Haemoglobin_estimation_9                                                   | 17113                         | -0.49
# Lymphocyte_count_20                                                        | 17113                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 17113                         | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 17113                         | -0.20
# Mean_corpuscular_volume__MCV__11                                           | 17113                         | -0.16
# Monocyte_count_23                                                          | 17113                         | -0.48
# Neutrophil_count_19                                                        | 17113                         | -0.45
# Platelet_count_12                                                          | 17113                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 17113                         | -0.49
# Red_blood_cell_distribution_width_17                                       | 17113                         | -0.47
# Serum_TSH_level_71                                                         | 17113                         | -0.49
# Serum_free_T4_level_75                                                     | 17113                         | -0.50
# Total_white_cell_count_18                                                  | 17113                         | -0.50
# Levothyroxine_                                                             | 17201                         | nan
# Levothyroxine_                                                             | 17201                         | nan
# Levothyroxine_                                                             | 17306                         | nan
# Levothyroxine_                                                             | 17306                         | nan
# Levothyroxine_                                                             | 17406                         | nan
# Levothyroxine_                                                             | 17406                         | nan
# Levothyroxine_                                                             | 17515                         | nan
# Levothyroxine_                                                             | 17515                         | nan
# Serum_TSH_level_71                                                         | 17523                         | -0.50
# Serum_free_T4_level_75                                                     | 17523                         | -0.50
# Basophil_count_22                                                          | 17609                         | -0.48
# Eosinophil_count_21                                                        | 17609                         | -0.47
# Haemoglobin_estimation_9                                                   | 17609                         | -0.49
# Lymphocyte_count_20                                                        | 17609                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 17609                         | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 17609                         | -0.20
# Mean_corpuscular_volume__MCV__11                                           | 17609                         | -0.17
# Monocyte_count_23                                                          | 17609                         | -0.48
# Neutrophil_count_19                                                        | 17609                         | -0.45
# Platelet_count_12                                                          | 17609                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 17609                         | -0.49
# Red_blood_cell_distribution_width_17                                       | 17609                         | -0.47
# Serum_vitamin_B12_79                                                       | 17609                         | -0.40
# Serum_vitamin_B12_79                                                       | 17609                         | nan
# Total_white_cell_count_18                                                  | 17609                         | -0.50
# Levothyroxine_                                                             | 17621                         | nan
# Levothyroxine_                                                             | 17621                         | nan
# Levothyroxine_                                                             | 17736                         | nan
# Levothyroxine_                                                             | 17736                         | nan
# Levothyroxine_                                                             | 17845                         | nan
# Levothyroxine_                                                             | 17845                         | nan
# Serum_TSH_level_71                                                         | 17901                         | -0.50
# Serum_free_T4_level_75                                                     | 17901                         | -0.50
# Levothyroxine_                                                             | 17963                         | nan
# Levothyroxine_                                                             | 17963                         | nan
# Basophil_count_22                                                          | 18034                         | -0.48
# Eosinophil_count_21                                                        | 18034                         | -0.46
# Haemoglobin_estimation_9                                                   | 18034                         | -0.48
# Lymphocyte_count_20                                                        | 18034                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 18034                         | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 18034                         | -0.21
# Mean_corpuscular_volume__MCV__11                                           | 18034                         | -0.18
# Monocyte_count_23                                                          | 18034                         | -0.47
# Neutrophil_count_19                                                        | 18034                         | -0.45
# Platelet_count_12                                                          | 18034                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 18034                         | -0.49
# Red_blood_cell_distribution_width_17                                       | 18034                         | -0.46
# Total_white_cell_count_18                                                  | 18034                         | -0.50
# Levothyroxine_                                                             | 18078                         | nan
# Levothyroxine_                                                             | 18078                         | nan
# Levothyroxine_                                                             | 18190                         | nan
# Levothyroxine_                                                             | 18190                         | nan
# Serum_TSH_level_71                                                         | 18252                         | -0.50
# Serum_free_T4_level_75                                                     | 18252                         | -0.50
# Levothyroxine_                                                             | 19337                         | nan
# =============================================================================================================================

# %%
dm.meta_information["diagnosis_table"].event.to_list()

# %%
import polars as pl
pl.Config.set_tbl_rows(300)
pl.Config.set_fmt_str_lengths(100)

print(dm.train_set.tokenizer._event_counts)

# %% [markdown]
# # Test data loading times (so we can optimise cpu usage)

# %%
import pyarrow.parquet as pq

dataset1 = pq.ParquetDataset(path_to_db + "polars/split=train/", 
                            filters=[('PRACTICE_ID','=','p20763')]
                            )

import time

start = time.time()   # starting time
df  = dataset1.read().to_pandas()
df = df[df["row_nr"] == 100]
print(df)
print(time.time() - start)

# %%
from tqdm import tqdm
import numpy as np

times = []
start = time.time()   # starting time
for row_idx, row in enumerate(tqdm(dm.train_set)):
    # print(f"Sample loaded in {time.time()-start} seconds")
    times.append(time.time()-start)
    start = time.time()
    if row_idx > 1e4:
        break
print(np.mean(times))

# %%
times = []
start = time.time()   # starting time
for batch_idx, batch in enumerate(tqdm(dm.train_dataloader())):
    # print(f"batch loaded in {time.time()-start} seconds")    
    times.append(time.time()-start)
    start = time.time()
    if batch_idx > 1e4:
        break
print(np.mean(times))

# for key in batch.keys():
#     print(f"{key}".ljust(20) + f"{batch[key].shape}")

# tokens = batch["tokens"][0].tolist()    
# sentence = dm.decode(tokens).split(" ")
# for token, value in zip(sentence, batch["values"][0].tolist()):
#     print(f"{token}:".ljust(40) + f"{value}")

# %%
dm.train_set.view_sample(1236, max_dynamic_events=12, report_time=True)
