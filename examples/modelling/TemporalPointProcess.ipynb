# %% [markdown]
# # Demo Notebook:
# ## Temporal Point Process Transformer For Causal Sequence Modelling
#
# Including time (and TODO: values)

# %%
import pytorch_lightning 
import torch
import numpy as np
import matplotlib.pyplot as plt
import random
import sqlite3
from dataclasses import dataclass
import logging
from CPRD.data.foundational_loader import FoundationalDataModule
from CPRD.src.models.TPP.task_heads.causal_tpp import TPPTransformerForCausalSequenceModelling

# TODO:
# replace experiment boilerplate with pytorch lightning

torch.manual_seed(1337)
logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# device = "cpu"    # if more informative debugging statements are needed
# !pwd
# Out:
# cuda
# /rds/homes/g/gaddcz/Projects/CPRD/examples/modelling

# %% [markdown]
# ## Build configurations

# %%
# Set config to be equivalent architecture of kaparthy benchmark, however they are not comparable tasks.
@dataclass
class DemoConfig:
    block_size: int = 256        # what is the maximum context length for predictions?
    n_layer: int = 6
    n_head: int = 6
    n_embd: int = 384
    bias: bool = True
    attention_type: str = "global"    
    dropout: float = 0.0
    unk_freq_threshold: float = 0.0
    TTELayer = "Exponential"

config = DemoConfig()

@dataclass
class OptConfig:
    batch_size: int = 64
    eval_interval: int = 1
    learning_rate: float = 3e-4
    epochs: int = 50
    
opt = OptConfig()

# %% [markdown]
# ## Create data loader on a reduced cohort

# %%
from CPRD.data.database import queries

# Get a list of patients which fit a reduced set of criterion
PATH_TO_DB = "/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModel/preprocessing/processed/cprd.db"
conn = sqlite3.connect(PATH_TO_DB)
cursor = conn.cursor()
# identifiers1 = queries.query_measurement(["bmi", "diastolic_blood_pressure"], cursor)        
identifiers2 = queries.query_diagnosis(["DEPRESSION", "TYPE1DM", "TYPE2DIABETES"], cursor)    #  "DEPRESSION"  ,  "ANXIETY"
# all_identifiers = list(set(identifiers1).intersection(identifiers2))    # Turn smaller list into the set
all_identifiers = identifiers2

if False:
    # Lets take only the first N for faster run-time
    N = np.min((len(all_identifiers), 10000))
    print(f"Using N={N} random samples, from the available {len(all_identifiers)}")
    identifiers = random.choices(all_identifiers, k=N)
else:
    print(f"Using all available {len(all_identifiers)} samples")
    identifiers = all_identifiers

# Build 
dm = FoundationalDataModule(identifiers=identifiers,
                            tokenizer="tabular",    # non-
                            batch_size=opt.batch_size,
                            max_seq_length=config.block_size,
                            unk_freq_threshold=config.unk_freq_threshold,
                            include_measurements=False,
                            include_diagnoses=True
                           )

vocab_size = dm.train_set.tokenizer.vocab_size

print(f"{len(dm.train_set)} training samples")
print(f"{len(dm.val_set)} validation samples")
print(f"{len(dm.test_set)} test samples")
print(f"{vocab_size} vocab elements")
# print(dm.train_set.tokenizer._itos)
# Out:
# INFO:root:Building DL-friendly representation
# Using all available 129717 samples
# INFO:root:Dropping samples with no dynamic events
# INFO:root:Using tabular tokenizer
# 107680 training samples
# 5983 validation samples
# 5982 test samples
# 74 vocab elements

# %%
import polars as pl
pl.Config.set_tbl_rows(vocab_size + 1)
print(dm.tokenizer._event_counts)
# Out:
# shape: (73, 3)
# ┌───────────────────────────────────┬────────┬──────────┐
# │ EVENT                             ┆ counts ┆ freq     │
# │ ---                               ┆ ---    ┆ ---      │
# │ str                               ┆ u32    ┆ f64      │
# ╞═══════════════════════════════════╪════════╪══════════╡
# │ UNK                               ┆ 0      ┆ 0.0      │
# │ DEPRESSION                        ┆ 86544  ┆ 0.177533 │
# │ ANXIETY                           ┆ 48204  ┆ 0.098884 │
# │ HYPERTENSION                      ┆ 32877  ┆ 0.067442 │
# │ TYPE2DIABETES                     ┆ 27261  ┆ 0.055922 │
# │ OSTEOARTHRITIS                    ┆ 25362  ┆ 0.052027 │
# │ ASTHMA_PUSHASTHMA                 ┆ 25296  ┆ 0.051891 │
# │ ATOPICECZEMA                      ┆ 23197  ┆ 0.047585 │
# │ ALLERGICRHINITISCONJ              ┆ 18510  ┆ 0.037971 │
# │ ANY_DEAFNESS_HEARING_LOSS         ┆ 17244  ┆ 0.035374 │
# │ PREVALENT_IBS                     ┆ 11714  ┆ 0.02403  │
# │ ALLCA_NOBCC_VFINAL                ┆ 11648  ┆ 0.023894 │
# │ IHD_NOMI                          ┆ 11295  ┆ 0.02317  │
# │ ALCOHOLMISUSE                     ┆ 11163  ┆ 0.022899 │
# │ CKDSTAGE3TO5                      ┆ 10456  ┆ 0.021449 │
# │ PERIPHERAL_NEUROPATHY             ┆ 8857   ┆ 0.018169 │
# │ HYPOTHYROIDISM_DRAFT_V1           ┆ 8002   ┆ 0.016415 │
# │ COPD                              ┆ 7637   ┆ 0.015666 │
# │ AF                                ┆ 6238   ┆ 0.012796 │
# │ OSTEOPOROSIS                      ┆ 5745   ┆ 0.011785 │
# │ HF                                ┆ 5739   ┆ 0.011773 │
# │ PSORIASIS                         ┆ 5647   ┆ 0.011584 │
# │ SUBSTANCEMISUSE                   ┆ 5567   ┆ 0.01142  │
# │ GOUT                              ┆ 5357   ┆ 0.010989 │
# │ MINFARCTION                       ┆ 4971   ┆ 0.010197 │
# │ STROKEUNSPECIFIED                 ┆ 4493   ┆ 0.009217 │
# │ ALL_DEMENTIA                      ┆ 4440   ┆ 0.009108 │
# │ PAD_STRICT                        ┆ 3238   ┆ 0.006642 │
# │ VALVULARDISEASES                  ┆ 3197   ┆ 0.006558 │
# │ OTHER_CHRONIC_LIVER_DISEASE_OPTI… ┆ 2963   ┆ 0.006078 │
# │ TYPE1DM                           ┆ 2858   ┆ 0.005863 │
# │ EPILEPSY                          ┆ 2598   ┆ 0.005329 │
# │ OSA                               ┆ 2444   ┆ 0.005014 │
# │ FIBROMYALGIA                      ┆ 2420   ┆ 0.004964 │
# │ POLYCYSTIC_OVARIAN_SYNDROME_PCOS  ┆ 2212   ┆ 0.004538 │
# │ NAFLD                             ┆ 2168   ┆ 0.004447 │
# │ RHEUMATOIDARTHRITIS               ┆ 2074   ┆ 0.004255 │
# │ EATINGDISORDERS                   ┆ 2019   ┆ 0.004142 │
# │ HYPERTHYROIDISM                   ┆ 1915   ┆ 0.003928 │
# │ PMRANDGCA                         ┆ 1903   ┆ 0.003904 │
# │ ENDOMETRIOSIS_ADENOMYOSIS_V2      ┆ 1813   ┆ 0.003719 │
# │ PTSDDIAGNOSIS                     ┆ 1689   ┆ 0.003465 │
# │ ISCHAEMICSTROKE                   ┆ 1517   ┆ 0.003112 │
# │ VISUAL_IMPAIRMENT                 ┆ 1421   ┆ 0.002915 │
# │ BIPOLAR                           ┆ 1362   ┆ 0.002794 │
# │ SCHIZOPHRENIAMM                   ┆ 1321   ┆ 0.00271  │
# │ BRONCHIECTASIS                    ┆ 1050   ┆ 0.002154 │
# │ CHRONIC_LIVER_DISEASE_ALCOHOL     ┆ 899    ┆ 0.001844 │
# │ AORTICANEURYSM                    ┆ 889    ┆ 0.001824 │
# │ CHRONICFATIGUESYNDROMEMM          ┆ 839    ┆ 0.001721 │
# │ ULCERATIVE_COLITIS                ┆ 820    ┆ 0.001682 │
# │ LEARNINGDISABILITY                ┆ 742    ┆ 0.001522 │
# │ PERNICIOUSANAEMIA                 ┆ 716    ┆ 0.001469 │
# │ MENIERESDISEASE                   ┆ 701    ┆ 0.001438 │
# │ PARKINSONS                        ┆ 698    ┆ 0.001432 │
# │ STROKE_HAEMRGIC                   ┆ 695    ┆ 0.001426 │
# │ LYMPHOMA_PREVALENCE               ┆ 583    ┆ 0.001196 │
# │ ILD_SH                            ┆ 546    ┆ 0.00112  │
# │ CROHNS_DISEASE                    ┆ 539    ┆ 0.001106 │
# │ AUTISM                            ┆ 512    ┆ 0.00105  │
# │ PSORIATICARTHRITIS2021            ┆ 487    ┆ 0.000999 │
# │ MS                                ┆ 415    ┆ 0.000851 │
# │ LEUKAEMIA_PREVALENCE              ┆ 389    ┆ 0.000798 │
# │ HIVAIDS                           ┆ 304    ┆ 0.000624 │
# │ SJOGRENSSYNDROME                  ┆ 241    ┆ 0.000494 │
# │ SYSTEMIC_LUPUS_ERYTHEMATOSUS      ┆ 220    ┆ 0.000451 │
# │ HAEMOCHROMATOSIS                  ┆ 198    ┆ 0.000406 │
# │ PLASMACELL_NEOPLASM               ┆ 124    ┆ 0.000254 │
# │ ADDISON_DISEASE                   ┆ 97     ┆ 0.000199 │
# │ SYSTEMIC_SCLEROSIS                ┆ 72     ┆ 0.000148 │
# │ DOWNSSYNDROME                     ┆ 47     ┆ 0.000096 │
# │ CYSTICFIBROSIS                    ┆ 41     ┆ 0.000084 │
# │ SICKLE_CELL_DISEASE               ┆ 22     ┆ 0.000045 │
# └───────────────────────────────────┴────────┴──────────┘

# %% [markdown]
# ## Create models and train

# %%
models, m_names = [], []

# My development model
for tte_layer in ["Geometric", "Exponential"]:
    config = DemoConfig()
    config.TTELayer = tte_layer
    models.append(TPPTransformerForCausalSequenceModelling(config, vocab_size).to(device))
    m_names.append(f"TPPTransformerForCausalSequenceModelling_{tte_layer}")
# Out:
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using GeometricTTELayer. This module predicts the time until next event as a geometric distribution, supported on the set {0,1,...}
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using ExponentialTTELayer. This module predicts the time until next event as an exponential distribution

# %%
loss_curves_train = [[] for _ in models]
loss_curves_train_clf = [[] for _ in models]
loss_curves_train_tte = [[] for _ in models]

loss_curves_val = [[] for _ in models]
loss_curves_val_clf = [[] for _ in models]
loss_curves_val_tte = [[] for _ in models]

# %%
for m_idx, (model, m_name) in enumerate(zip(models, m_names)):
    
    print(f"Training model `{m_name}`, with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
    model = model.to(device)

    # create a PyTorch optimizer
    optimizer = torch.optim.AdamW(model.parameters(), lr=opt.learning_rate)

    best_val, epochs_since_best = np.inf, 0
    for epoch in range(opt.epochs):
        epoch_loss, epoch_clf_loss, epoch_tte_loss = 0, 0, 0
        model.train()
        for i, batch in enumerate(dm.train_dataloader()):
            # evaluate the loss
            _, (loss_clf, loss_tte), loss = model(batch['tokens'].to(device), 
                                                     ages=batch['ages'].to(device), 
                                                     # values=batch['values'].to(device),
                                                     attention_mask=batch['attention_mask'].to(device)   
                                                     )
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            # record
            epoch_clf_loss += loss_clf.item()
            epoch_tte_loss += loss_tte.item()
        epoch_loss /= i
        epoch_clf_loss /= i
        epoch_tte_loss /= i
        loss_curves_train[m_idx].append(epoch_loss)
        loss_curves_train_clf[m_idx].append(epoch_clf_loss)
        loss_curves_train_tte[m_idx].append(epoch_tte_loss)

        # evaluate the loss on val set
        with torch.no_grad(): 
            model.eval()
            if epoch % opt.eval_interval == 0 or epoch == opt.epochs - 1:
                val_loss, val_clf_loss, val_tte_loss = 0, 0, 0
                for j, batch in enumerate(dm.val_dataloader()):
                    _, (loss_clf, loss_tte), loss = model(batch['tokens'].to(device), 
                                                             ages=batch['ages'].to(device),
                                                             # values=batch['values'].to(device),
                                                             attention_mask=batch['attention_mask'].to(device)   
                                                             )
                    val_loss += loss.item()
                    # record
                    val_clf_loss += loss_clf.item()
                    val_tte_loss += loss_tte.item()
                val_loss /= j
                val_clf_loss /= j
                val_tte_loss /= j
                loss_curves_val[m_idx].append(val_loss)
                loss_curves_val_clf[m_idx].append(val_clf_loss)
                loss_curves_val_tte[m_idx].append(val_tte_loss)
                print(f"Epoch {epoch}:\tTrain loss {epoch_loss:.2f}  ({epoch_clf_loss:.2f}, {epoch_tte_loss:.2f}). Val loss {val_loss:.2f} ({val_clf_loss:.2f}, {val_tte_loss:.2f})")          
                # TODO: Note not fully accurate as last batch is likely not the same size, will be fixed with lightning
        
            if val_loss >= best_val:
                epochs_since_best += 1
                if epochs_since_best >= 5:
                    break
            else:
                best_val = val_loss
                epochs_since_best = 0

    # Test trained model with a prompt
    # ----------------    
    # set context: diagnosis of depression at 20 years old
    tokens = torch.from_numpy(np.array(dm.encode(["DEPRESSION"])).reshape((1,-1))).to(device)
    ages = torch.tensor([[20*365]], device=device)
    # values = torch.tensor([[torch.nan]], device=device)
    # generate: sample the next 10 tokens
    new_tokens, new_ages = model.generate(tokens, ages, max_new_tokens=10)
    generated = dm.decode(new_tokens[0].tolist())
    # report:
    #    note, Not considering value yet.
    for _cat, _age in zip(generated.split(" "), new_ages[0, :]):
        print(f"\t {_cat} at age {_age/365:.0f} ({_age:.1f} days)")    # with value {_value}
# Out:
# Training model `TPPTransformerForCausalSequenceModelling_Geometric`, with 10.669633 M parameters
# Epoch 0:	Train loss 5.46  (3.10, 7.82). Val loss 5.44 (3.02, 7.86)
# Epoch 1:	Train loss 5.37  (2.95, 7.78). Val loss 5.41 (2.97, 7.84)
# Epoch 2:	Train loss 5.34  (2.90, 7.77). Val loss 5.38 (2.93, 7.84)
# Epoch 3:	Train loss 5.32  (2.87, 7.77). Val loss 5.37 (2.91, 7.84)
# Epoch 4:	Train loss 5.31  (2.86, 7.76). Val loss 5.37 (2.90, 7.83)
# Epoch 5:	Train loss 5.31  (2.85, 7.76). Val loss 5.36 (2.89, 7.83)
# Epoch 6:	Train loss 5.29  (2.83, 7.76). Val loss 5.36 (2.88, 7.84)
# Epoch 7:	Train loss 5.29  (2.82, 7.76). Val loss 5.35 (2.86, 7.83)
# Epoch 8:	Train loss 5.28  (2.80, 7.76). Val loss 5.34 (2.85, 7.83)
# Epoch 9:	Train loss 5.27  (2.79, 7.75). Val loss 5.33 (2.84, 7.83)
# Epoch 10:	Train loss 5.27  (2.78, 7.75). Val loss 5.34 (2.85, 7.83)
# Epoch 11:	Train loss 5.27  (2.78, 7.75). Val loss 5.33 (2.83, 7.83)
# Epoch 12:	Train loss 5.26  (2.77, 7.75). Val loss 5.33 (2.83, 7.83)
# Epoch 13:	Train loss 5.26  (2.77, 7.75). Val loss 5.34 (2.85, 7.83)
# Epoch 14:	Train loss 5.26  (2.77, 7.75). Val loss 5.33 (2.83, 7.83)
# Epoch 15:	Train loss 5.25  (2.76, 7.75). Val loss 5.33 (2.82, 7.83)
# Epoch 16:	Train loss 5.25  (2.76, 7.75). Val loss 5.34 (2.84, 7.84)
# Epoch 17:	Train loss 5.25  (2.76, 7.75). Val loss 5.33 (2.82, 7.83)
# Epoch 18:	Train loss 5.25  (2.75, 7.74). Val loss 5.33 (2.82, 7.84)
# Epoch 19:	Train loss 5.25  (2.75, 7.74). Val loss 5.32 (2.81, 7.83)
# Epoch 20:	Train loss 5.24  (2.74, 7.74). Val loss 5.33 (2.82, 7.84)
# Epoch 21:	Train loss 5.24  (2.74, 7.74). Val loss 5.33 (2.82, 7.84)
# Epoch 22:	Train loss 5.24  (2.74, 7.74). Val loss 5.33 (2.82, 7.84)
# Epoch 23:	Train loss 5.24  (2.74, 7.74). Val loss 5.33 (2.81, 7.84)
# WARNING:root:Using XXX requires value embeddings, but this head ``CURRENTLY`` has no way of sampling value of next event. Setting generated values to nan until this is implemented
# Epoch 24:	Train loss 5.23  (2.73, 7.74). Val loss 5.33 (2.81, 7.85)
# 	 DEPRESSION at age 20 (7300.0 days)
# 	 ANXIETY at age 20 (7447.0 days)
# 	 PREVALENT_IBS at age 22 (8199.0 days)
# 	 ALCOHOLMISUSE at age 27 (9723.0 days)
# 	 OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL at age 33 (12045.0 days)
# 	 EATINGDISORDERS at age 35 (12911.0 days)
# 	 STROKEUNSPECIFIED at age 38 (13833.0 days)
# 	 ENDOMETRIOSIS_ADENOMYOSIS_V2 at age 40 (14687.0 days)
# 	 ALLCA_NOBCC_VFINAL at age 41 (14878.0 days)
# 	 OSTEOARTHRITIS at age 44 (15881.0 days)
# 	 HAEMOCHROMATOSIS at age 45 (16504.0 days)
# Training model `TPPTransformerForCausalSequenceModelling_Exponential`, with 10.669633 M parameters
# Epoch 0:	Train loss 2.25  (3.06, 1.43). Val loss 2.22 (3.02, 1.43)
# Epoch 1:	Train loss 2.18  (2.95, 1.41). Val loss 2.20 (2.97, 1.43)
# Epoch 2:	Train loss 2.15  (2.90, 1.41). Val loss 2.17 (2.91, 1.42)
# Epoch 3:	Train loss 2.13  (2.87, 1.40). Val loss 2.16 (2.91, 1.42)
# Epoch 4:	Train loss 2.13  (2.86, 1.40). Val loss 2.15 (2.90, 1.41)
# Epoch 5:	Train loss 2.12  (2.85, 1.40). Val loss 2.16 (2.90, 1.42)
# Epoch 6:	Train loss 2.12  (2.84, 1.39). Val loss 2.14 (2.87, 1.41)
# Epoch 7:	Train loss 2.11  (2.83, 1.39). Val loss 2.14 (2.87, 1.41)
# Epoch 8:	Train loss 2.10  (2.81, 1.39). Val loss 2.13 (2.86, 1.41)
# Epoch 9:	Train loss 2.10  (2.80, 1.39). Val loss 2.13 (2.85, 1.41)
# Epoch 10:	Train loss 2.09  (2.80, 1.39). Val loss 2.12 (2.84, 1.40)
# Epoch 11:	Train loss 2.09  (2.79, 1.39). Val loss 2.12 (2.84, 1.41)
# Epoch 12:	Train loss 2.08  (2.78, 1.39). Val loss 2.12 (2.84, 1.41)
# Epoch 13:	Train loss 2.08  (2.78, 1.39). Val loss 2.12 (2.83, 1.41)
# Epoch 14:	Train loss 2.08  (2.77, 1.38). Val loss 2.12 (2.83, 1.40)
# Epoch 15:	Train loss 2.08  (2.77, 1.38). Val loss 2.12 (2.83, 1.41)
# Epoch 16:	Train loss 2.07  (2.76, 1.38). Val loss 2.11 (2.82, 1.41)
# Epoch 17:	Train loss 2.08  (2.77, 1.38). Val loss 2.12 (2.82, 1.41)
# Epoch 18:	Train loss 2.07  (2.76, 1.38). Val loss 2.11 (2.82, 1.41)
# Epoch 19:	Train loss 2.07  (2.76, 1.38). Val loss 2.11 (2.81, 1.40)
# Epoch 20:	Train loss 2.07  (2.75, 1.38). Val loss 2.11 (2.81, 1.41)
# Epoch 21:	Train loss 2.06  (2.74, 1.38). Val loss 2.11 (2.81, 1.41)
# Epoch 22:	Train loss 2.06  (2.75, 1.38). Val loss 2.11 (2.80, 1.41)
# Epoch 23:	Train loss 2.06  (2.75, 1.38). Val loss 2.11 (2.81, 1.41)
# Epoch 24:	Train loss 2.06  (2.74, 1.38). Val loss 2.11 (2.81, 1.41)
# Epoch 25:	Train loss 2.06  (2.74, 1.38). Val loss 2.11 (2.81, 1.41)
# Epoch 26:	Train loss 2.05  (2.73, 1.38). Val loss 2.11 (2.80, 1.42)
# Epoch 27:	Train loss 2.05  (2.73, 1.38). Val loss 2.10 (2.80, 1.41)
# Epoch 28:	Train loss 2.05  (2.72, 1.37). Val loss 2.11 (2.80, 1.41)
# Epoch 29:	Train loss 2.05  (2.72, 1.37). Val loss 2.12 (2.81, 1.42)
# Epoch 30:	Train loss 2.05  (2.73, 1.37). Val loss 2.12 (2.81, 1.43)
# Epoch 31:	Train loss 2.05  (2.72, 1.37). Val loss 2.12 (2.81, 1.43)
# WARNING:root:Using XXX requires value embeddings, but this head ``CURRENTLY`` has no way of sampling value of next event. Setting generated values to nan until this is implemented
# Epoch 32:	Train loss 2.04  (2.71, 1.37). Val loss 2.11 (2.81, 1.42)
# 	 DEPRESSION at age 20 (7300.0 days)
# 	 ANXIETY at age 33 (12092.6 days)
# 	 ASTHMA_PUSHASTHMA at age 48 (17498.3 days)
# 	 OSTEOARTHRITIS at age 49 (17802.3 days)
# 	 HYPERTENSION at age 53 (19384.4 days)
# 	 SUBSTANCEMISUSE at age 54 (19769.8 days)
# 	 PREVALENT_IBS at age 54 (19771.3 days)
# 	 ALLERGICRHINITISCONJ at age 64 (23256.4 days)
# 	 ALLCA_NOBCC_VFINAL at age 65 (23618.5 days)
# 	 ANY_DEAFNESS_HEARING_LOSS at age 67 (24484.4 days)
# 	 ALCOHOLMISUSE at age 73 (26482.1 days)

# %% [markdown]
# ## Comparing output to real data

# %%
for batch in dm.train_dataloader():
    break
conditions = batch["tokens"].numpy().tolist()
# delta_ages = batch["ages"][:, 1:] - batch["ages"][:, :-1]
for idx, (token, age) in enumerate(zip(conditions[0], batch["ages"][0,:])):
    if token == 0 or idx >= 10:
        break
    print(f"{dm.decode([token])}, at age {age/365:.0f} ({age:.1f} days)")
# Out:
# ATOPICECZEMA, at age 68 (24782.0 days)
# HYPERTENSION, at age 71 (25853.0 days)
# TYPE2DIABETES, at age 73 (26609.0 days)
# CKDSTAGE3TO5, at age 74 (27156.0 days)
# HYPOTHYROIDISM_DRAFT_V1, at age 76 (27877.0 days)
# GOUT, at age 84 (30580.0 days)
# AF, at age 85 (31115.0 days)
# PMRANDGCA, at age 85 (31127.0 days)
# IHD_NOMI, at age 86 (31321.0 days)

# %%
cols = ["k", "r", "b", "y"]

# Plot loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train[m_idx]), len(loss_curves_train[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val[m_idx]), len(loss_curves_val[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/loss_curves_TPP.png")

# Plot classifier loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train_clf[m_idx]), len(loss_curves_train_clf[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train_clf[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val_clf[m_idx]), len(loss_curves_val_clf[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val_clf[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/loss_clf_curves_TPP.png")

# Plot tte loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train_tte[m_idx]), len(loss_curves_train_tte[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train_tte[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val_tte[m_idx]), len(loss_curves_val_tte[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val_tte[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/loss_tte_curves_TPP.png")

# %% [markdown]
# # Prompt testing

# %% [markdown]
# ## Diabetes: How related conditions are impacted by each other
# Probability of type II diabetes before and after a type I diagnosis

# %%
t1_token = dm.tokenizer._stoi["TYPE1DM"]
t2_token = dm.tokenizer._stoi["TYPE2DIABETES"]


base_prompt = ["DEPRESSION"]
ages_in_years = [20]

to_days = lambda a_list: torch.FloatTensor([365 * _a for _a in a_list]).reshape((1,-1)).to(device)

# Create a set of prompts
prompts, ages, values, desc = [], [], [], []
desc.append("Control")
prompts.append(base_prompt)
ages.append(ages_in_years)
desc.append("Type 1")
prompts.append(base_prompt + ["TYPE1DM"])
ages.append(ages_in_years + [21])
desc.append("Type 2")
prompts.append(base_prompt + ["TYPE2DIABETES"])
ages.append(ages_in_years + [21])

for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n--------------------------------------")
    with torch.no_grad(): 
            model.eval()
    
            for p_idx, (prompt, age) in enumerate(zip(prompts, ages)):
                print(f"\n{desc[p_idx]}: \t ({','.join(prompt)}): ")
                encoded_prompt = torch.from_numpy(np.array(dm.encode(prompt)).reshape((1,-1))).to(device)
                (lgts, tte_dist), _, _ = model(encoded_prompt,
                                                       # values=torch.tensor(value).to(device),
                                                       ages=to_days(age),
                                                       is_generation=True)
                probs = torch.nn.functional.softmax(lgts, dim=2)
                print(f"\tprobability of type I diabetes: {100*float(probs[0, 0, t1_token].cpu().detach().numpy()):.4f}%")
                print(f"\tprobability of type II diabetes: {100*float(probs[0, 0, t2_token].cpu().detach().numpy()):.4f}%")

# Note: adding a diagnosis (even if potentially orthogonal) at the beginning of the prompt increases probability of either type
# Out:
# TPPTransformerForCausalSequenceModelling_Geometric
# --------------------------------------
#
# Control: 	 (DEPRESSION):
# 	probability of type I diabetes: 0.0738%
# 	probability of type II diabetes: 0.2351%
#
# Type 1: 	 (DEPRESSION,TYPE1DM):
# 	probability of type I diabetes: 0.0884%
# 	probability of type II diabetes: 2.5615%
#
# Type 2: 	 (DEPRESSION,TYPE2DIABETES):
# 	probability of type I diabetes: 1.7410%
# 	probability of type II diabetes: 0.1133%
#
#
# TPPTransformerForCausalSequenceModelling_Exponential
# --------------------------------------
#
# Control: 	 (DEPRESSION):
# 	probability of type I diabetes: 0.0653%
# 	probability of type II diabetes: 0.2518%
#
# Type 1: 	 (DEPRESSION,TYPE1DM):
# 	probability of type I diabetes: 0.3059%
# 	probability of type II diabetes: 2.1283%
#
# Type 2: 	 (DEPRESSION,TYPE2DIABETES):
# 	probability of type I diabetes: 3.1414%
# 	probability of type II diabetes: 0.0096%

# %% [markdown]
# ## Age: How increasing prompt age affects likelihood of age related diagnoses

# %%
prompt = ["DEPRESSION"]
ages = [[4],[8],[20],[30],[60],[80],[90]]

# target_conditions=["TYPE1DM"]#, "TYPE2DIABETES", "OSTEOARTHRITIS", "ANY_DEAFNESS_HEARING_LOSS"]

for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n--------------------------------------")

    # for condition in target_conditions:
    #     print(f"Probability of {condition}")
    #     target_token = dm.tokenizer._stoi[condition]

    for p_idx, age in enumerate(ages):
        print(f"\nAge {age[-1]}\n======")
        encoded_prompt = torch.from_numpy(np.array(dm.encode(prompt)).reshape((1,-1))).to(device)
        (lgts, tte_dist), _, _ = model(encoded_prompt,
                                       ages=to_days(age),
                                       is_generation=True)
        probs = torch.nn.functional.softmax(lgts, dim=2) * 100

        # top K
        k = 10
        print(f"Top {k}")
        topk_prob, topk_ind = torch.topk(probs[0,0,:], k)
        for i, j in zip(dm.decode(topk_ind.tolist()).split(" "), topk_prob):
            print(f"\t{i}: {j:.2f}%")

        # bottom K
        k = 30
        print(f"Bottom {k}")
        topk_prob, topk_ind = torch.topk(-probs[0,0,:], k)
        for i, j in zip(dm.decode(topk_ind.tolist()).split(" "), topk_prob):
            print(f"\t{i}: {-j:.2f}%")
        
            # print(f"Age: {age[-1]} years old:  {100*float(probs[0, 0, target_token].cpu().detach().numpy()):.4f}%")

# Note: adding a diagnosis (even if potentially orthogonal) at the beginning of the prompt increases probability of either type
# Out:
# TPPTransformerForCausalSequenceModelling_Geometric
# --------------------------------------
#
# Age 4
# ======
# Top 10
# 	ANXIETY: 32.00%
# 	ATOPICECZEMA: 22.54%
# 	ASTHMA_PUSHASTHMA: 9.23%
# 	ALLERGICRHINITISCONJ: 7.06%
# 	EATINGDISORDERS: 4.33%
# 	ANY_DEAFNESS_HEARING_LOSS: 4.17%
# 	PREVALENT_IBS: 2.97%
# 	SUBSTANCEMISUSE: 2.40%
# 	ALCOHOLMISUSE: 1.97%
# 	AUTISM: 1.74%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	ILD_SH: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	HAEMOCHROMATOSIS: 0.01%
# 	PARKINSONS: 0.01%
# 	NAFLD: 0.01%
# 	DOWNSSYNDROME: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	MINFARCTION: 0.01%
# 	PAD_STRICT: 0.01%
# 	PMRANDGCA: 0.01%
# 	ALL_DEMENTIA: 0.02%
# 	AF: 0.02%
# 	MENIERESDISEASE: 0.02%
# 	PERNICIOUSANAEMIA: 0.02%
# 	ISCHAEMICSTROKE: 0.02%
# 	ADDISON_DISEASE: 0.02%
# 	CKDSTAGE3TO5: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	LEUKAEMIA_PREVALENCE: 0.03%
# 	BRONCHIECTASIS: 0.03%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.04%
# 	HF: 0.04%
#
# Age 8
# ======
# Top 10
# 	ANXIETY: 50.51%
# 	ASTHMA_PUSHASTHMA: 8.04%
# 	ATOPICECZEMA: 7.51%
# 	PREVALENT_IBS: 4.38%
# 	ALCOHOLMISUSE: 3.74%
# 	ALLERGICRHINITISCONJ: 3.64%
# 	SUBSTANCEMISUSE: 3.04%
# 	EATINGDISORDERS: 1.91%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.76%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 1.25%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	ILD_SH: 0.00%
# 	HAEMOCHROMATOSIS: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	DEPRESSION: 0.01%
# 	PARKINSONS: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	SJOGRENSSYNDROME: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	BRONCHIECTASIS: 0.02%
# 	PSORIATICARTHRITIS2021: 0.02%
# 	PMRANDGCA: 0.03%
# 	PERNICIOUSANAEMIA: 0.03%
# 	PAD_STRICT: 0.03%
# 	AF: 0.03%
# 	ISCHAEMICSTROKE: 0.03%
# 	MENIERESDISEASE: 0.04%
# 	NAFLD: 0.04%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.04%
# 	MINFARCTION: 0.04%
# 	STROKE_HAEMRGIC: 0.04%
# 	LYMPHOMA_PREVALENCE: 0.04%
#
# Age 20
# ======
# Top 10
# 	ANXIETY: 64.03%
# 	ALCOHOLMISUSE: 4.27%
# 	ASTHMA_PUSHASTHMA: 3.77%
# 	PREVALENT_IBS: 3.42%
# 	ATOPICECZEMA: 3.24%
# 	SUBSTANCEMISUSE: 2.89%
# 	ALLERGICRHINITISCONJ: 2.52%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 1.91%
# 	PERIPHERAL_NEUROPATHY: 1.21%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.03%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	ILD_SH: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	DEPRESSION: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	BRONCHIECTASIS: 0.01%
# 	PARKINSONS: 0.01%
# 	SJOGRENSSYNDROME: 0.02%
# 	ALL_DEMENTIA: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	ISCHAEMICSTROKE: 0.03%
# 	STROKE_HAEMRGIC: 0.03%
# 	PAD_STRICT: 0.03%
# 	PMRANDGCA: 0.04%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.04%
# 	MS: 0.05%
# 	AF: 0.05%
# 	MENIERESDISEASE: 0.05%
# 	PERNICIOUSANAEMIA: 0.06%
# 	MINFARCTION: 0.06%
#
# Age 30
# ======
# Top 10
# 	ANXIETY: 48.82%
# 	ALCOHOLMISUSE: 5.17%
# 	PREVALENT_IBS: 5.05%
# 	ASTHMA_PUSHASTHMA: 4.41%
# 	ATOPICECZEMA: 4.23%
# 	ALLERGICRHINITISCONJ: 3.54%
# 	OSTEOARTHRITIS: 3.02%
# 	HYPERTENSION: 2.55%
# 	SUBSTANCEMISUSE: 2.23%
# 	PERIPHERAL_NEUROPATHY: 2.02%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	ILD_SH: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	PARKINSONS: 0.02%
# 	HAEMOCHROMATOSIS: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	BRONCHIECTASIS: 0.03%
# 	DEPRESSION: 0.03%
# 	SJOGRENSSYNDROME: 0.04%
# 	PSORIATICARTHRITIS2021: 0.05%
# 	LYMPHOMA_PREVALENCE: 0.05%
# 	STROKE_HAEMRGIC: 0.05%
# 	AUTISM: 0.06%
# 	VISUAL_IMPAIRMENT: 0.06%
# 	ISCHAEMICSTROKE: 0.06%
# 	PAD_STRICT: 0.07%
# 	PMRANDGCA: 0.07%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.08%
# 	PERNICIOUSANAEMIA: 0.08%
# 	HF: 0.08%
# 	MENIERESDISEASE: 0.09%
#
# Age 60
# ======
# Top 10
# 	ANXIETY: 35.62%
# 	OSTEOARTHRITIS: 11.34%
# 	HYPERTENSION: 9.66%
# 	ATOPICECZEMA: 3.49%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.48%
# 	ALLCA_NOBCC_VFINAL: 3.29%
# 	ALCOHOLMISUSE: 3.19%
# 	TYPE2DIABETES: 2.59%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.34%
# 	ASTHMA_PUSHASTHMA: 2.04%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	DEPRESSION: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	PSORIATICARTHRITIS2021: 0.02%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.02%
# 	PLASMACELL_NEOPLASM: 0.02%
# 	AUTISM: 0.02%
# 	ILD_SH: 0.03%
# 	TYPE1DM: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.04%
# 	HAEMOCHROMATOSIS: 0.04%
# 	HIVAIDS: 0.04%
# 	SJOGRENSSYNDROME: 0.04%
# 	CROHNS_DISEASE: 0.05%
# 	CHRONICFATIGUESYNDROMEMM: 0.05%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.05%
# 	MS: 0.06%
# 	EATINGDISORDERS: 0.09%
# 	ULCERATIVE_COLITIS: 0.10%
# 	LYMPHOMA_PREVALENCE: 0.10%
# 	BRONCHIECTASIS: 0.10%
# 	LEUKAEMIA_PREVALENCE: 0.11%
# 	STROKE_HAEMRGIC: 0.11%
# 	LEARNINGDISABILITY: 0.12%
#
# Age 80
# ======
# Top 10
# 	ANXIETY: 36.24%
# 	ALL_DEMENTIA: 7.54%
# 	HYPERTENSION: 6.87%
# 	OSTEOARTHRITIS: 6.55%
# 	ANY_DEAFNESS_HEARING_LOSS: 4.16%
# 	ATOPICECZEMA: 3.45%
# 	ALLCA_NOBCC_VFINAL: 3.18%
# 	CKDSTAGE3TO5: 2.42%
# 	OSTEOPOROSIS: 2.38%
# 	STROKEUNSPECIFIED: 2.03%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	HAEMOCHROMATOSIS: 0.01%
# 	HIVAIDS: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	AUTISM: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	TYPE1DM: 0.02%
# 	MS: 0.02%
# 	FIBROMYALGIA: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.02%
# 	CROHNS_DISEASE: 0.02%
# 	DEPRESSION: 0.03%
# 	NAFLD: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	ULCERATIVE_COLITIS: 0.03%
# 	OSA: 0.03%
# 	ILD_SH: 0.05%
# 	PLASMACELL_NEOPLASM: 0.05%
# 	PTSDDIAGNOSIS: 0.05%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.06%
# 	EATINGDISORDERS: 0.07%
#
# Age 90
# ======
# Top 10
# 	ANXIETY: 31.49%
# 	ALL_DEMENTIA: 13.11%
# 	OSTEOARTHRITIS: 7.24%
# 	ANY_DEAFNESS_HEARING_LOSS: 5.16%
# 	HYPERTENSION: 4.26%
# 	ATOPICECZEMA: 3.89%
# 	ALLCA_NOBCC_VFINAL: 3.30%
# 	CKDSTAGE3TO5: 2.73%
# 	AF: 2.59%
# 	STROKEUNSPECIFIED: 2.30%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	ADDISON_DISEASE: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	HIVAIDS: 0.01%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	DOWNSSYNDROME: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	FIBROMYALGIA: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	MS: 0.01%
# 	CROHNS_DISEASE: 0.01%
# 	SJOGRENSSYNDROME: 0.02%
# 	AUTISM: 0.02%
# 	OSA: 0.02%
# 	ULCERATIVE_COLITIS: 0.02%
# 	TYPE1DM: 0.02%
# 	NAFLD: 0.02%
# 	ILD_SH: 0.04%
# 	MENIERESDISEASE: 0.04%
# 	PLASMACELL_NEOPLASM: 0.05%
# 	PTSDDIAGNOSIS: 0.06%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.07%
# 	BRONCHIECTASIS: 0.08%
#
#
# TPPTransformerForCausalSequenceModelling_Exponential
# --------------------------------------
#
# Age 4
# ======
# Top 10
# 	ANXIETY: 36.22%
# 	ATOPICECZEMA: 14.37%
# 	ASTHMA_PUSHASTHMA: 13.41%
# 	ALLERGICRHINITISCONJ: 6.62%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.44%
# 	EATINGDISORDERS: 3.20%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 2.99%
# 	PREVALENT_IBS: 2.68%
# 	ALCOHOLMISUSE: 2.48%
# 	AUTISM: 2.36%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	HAEMOCHROMATOSIS: 0.00%
# 	ILD_SH: 0.00%
# 	PARKINSONS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	PMRANDGCA: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	DOWNSSYNDROME: 0.01%
# 	ALL_DEMENTIA: 0.01%
# 	MENIERESDISEASE: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	PERNICIOUSANAEMIA: 0.01%
# 	PAD_STRICT: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	MINFARCTION: 0.01%
# 	ISCHAEMICSTROKE: 0.02%
# 	AF: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.02%
# 	STROKE_HAEMRGIC: 0.02%
# 	BRONCHIECTASIS: 0.03%
# 	CKDSTAGE3TO5: 0.03%
# 	NAFLD: 0.03%
# 	HF: 0.03%
# 	ADDISON_DISEASE: 0.03%
#
# Age 8
# ======
# Top 10
# 	ANXIETY: 26.63%
# 	ASTHMA_PUSHASTHMA: 14.43%
# 	ATOPICECZEMA: 11.26%
# 	ALLERGICRHINITISCONJ: 8.25%
# 	PREVALENT_IBS: 4.79%
# 	EATINGDISORDERS: 3.54%
# 	ALCOHOLMISUSE: 2.99%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.63%
# 	AUTISM: 2.09%
# 	HYPERTENSION: 2.06%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	HAEMOCHROMATOSIS: 0.01%
# 	ILD_SH: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	PLASMACELL_NEOPLASM: 0.01%
# 	DOWNSSYNDROME: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	PARKINSONS: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	PMRANDGCA: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.03%
# 	PERNICIOUSANAEMIA: 0.03%
# 	MENIERESDISEASE: 0.03%
# 	NAFLD: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	STROKE_HAEMRGIC: 0.04%
# 	PAD_STRICT: 0.04%
# 	PSORIATICARTHRITIS2021: 0.04%
# 	CKDSTAGE3TO5: 0.05%
# 	AF: 0.05%
# 	HF: 0.05%
# 	ISCHAEMICSTROKE: 0.06%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.06%
# 	MINFARCTION: 0.07%
# 	ADDISON_DISEASE: 0.07%
#
# Age 20
# ======
# Top 10
# 	ANXIETY: 49.28%
# 	ALCOHOLMISUSE: 7.63%
# 	ASTHMA_PUSHASTHMA: 6.10%
# 	SUBSTANCEMISUSE: 4.81%
# 	ATOPICECZEMA: 4.51%
# 	PREVALENT_IBS: 4.41%
# 	ALLERGICRHINITISCONJ: 3.87%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.79%
# 	EATINGDISORDERS: 1.76%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 1.64%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	ADDISON_DISEASE: 0.01%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	ILD_SH: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	DEPRESSION: 0.02%
# 	BRONCHIECTASIS: 0.03%
# 	PARKINSONS: 0.03%
# 	ALL_DEMENTIA: 0.03%
# 	PMRANDGCA: 0.03%
# 	ISCHAEMICSTROKE: 0.03%
# 	PERNICIOUSANAEMIA: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.04%
# 	LYMPHOMA_PREVALENCE: 0.04%
# 	MENIERESDISEASE: 0.04%
# 	PAD_STRICT: 0.04%
# 	VISUAL_IMPAIRMENT: 0.04%
# 	STROKE_HAEMRGIC: 0.06%
# 	AF: 0.06%
# 	MS: 0.07%
#
# Age 30
# ======
# Top 10
# 	ANXIETY: 45.92%
# 	ATOPICECZEMA: 5.77%
# 	ALCOHOLMISUSE: 5.52%
# 	ASTHMA_PUSHASTHMA: 4.91%
# 	ALLERGICRHINITISCONJ: 4.47%
# 	PREVALENT_IBS: 4.22%
# 	HYPERTENSION: 3.48%
# 	OSTEOARTHRITIS: 3.00%
# 	PERIPHERAL_NEUROPATHY: 2.27%
# 	TYPE2DIABETES: 2.08%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	ILD_SH: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	PARKINSONS: 0.01%
# 	ALL_DEMENTIA: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	BRONCHIECTASIS: 0.03%
# 	HAEMOCHROMATOSIS: 0.03%
# 	PMRANDGCA: 0.05%
# 	AUTISM: 0.05%
# 	VISUAL_IMPAIRMENT: 0.06%
# 	LEARNINGDISABILITY: 0.06%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.06%
# 	PAD_STRICT: 0.06%
# 	STROKE_HAEMRGIC: 0.06%
# 	ISCHAEMICSTROKE: 0.06%
# 	PERNICIOUSANAEMIA: 0.07%
# 	LYMPHOMA_PREVALENCE: 0.07%
# 	AF: 0.09%
# 	MENIERESDISEASE: 0.09%
# 	PSORIATICARTHRITIS2021: 0.09%
#
# Age 60
# ======
# Top 10
# 	ANXIETY: 36.35%
# 	HYPERTENSION: 11.23%
# 	OSTEOARTHRITIS: 10.00%
# 	ALLCA_NOBCC_VFINAL: 5.07%
# 	ATOPICECZEMA: 4.64%
# 	ANY_DEAFNESS_HEARING_LOSS: 4.29%
# 	ASTHMA_PUSHASTHMA: 3.01%
# 	ALCOHOLMISUSE: 2.34%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.02%
# 	TYPE2DIABETES: 1.97%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	DEPRESSION: 0.01%
# 	TYPE1DM: 0.01%
# 	AUTISM: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	PLASMACELL_NEOPLASM: 0.02%
# 	HIVAIDS: 0.02%
# 	HAEMOCHROMATOSIS: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	ILD_SH: 0.03%
# 	CROHNS_DISEASE: 0.04%
# 	LEARNINGDISABILITY: 0.04%
# 	MS: 0.05%
# 	SJOGRENSSYNDROME: 0.05%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.06%
# 	EATINGDISORDERS: 0.06%
# 	LEUKAEMIA_PREVALENCE: 0.07%
# 	LYMPHOMA_PREVALENCE: 0.08%
# 	CHRONICFATIGUESYNDROMEMM: 0.08%
# 	BRONCHIECTASIS: 0.10%
# 	ULCERATIVE_COLITIS: 0.10%
# 	PERNICIOUSANAEMIA: 0.11%
#
# Age 80
# ======
# Top 10
# 	ANXIETY: 28.40%
# 	ALL_DEMENTIA: 10.19%
# 	HYPERTENSION: 9.77%
# 	OSTEOARTHRITIS: 6.52%
# 	ANY_DEAFNESS_HEARING_LOSS: 6.16%
# 	ALLCA_NOBCC_VFINAL: 5.01%
# 	OSTEOPOROSIS: 3.41%
# 	ATOPICECZEMA: 3.18%
# 	HYPOTHYROIDISM_DRAFT_V1: 3.16%
# 	AF: 2.40%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	HIVAIDS: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	AUTISM: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	TYPE1DM: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	MS: 0.01%
# 	FIBROMYALGIA: 0.02%
# 	OSA: 0.02%
# 	EATINGDISORDERS: 0.03%
# 	CROHNS_DISEASE: 0.03%
# 	NAFLD: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	LEARNINGDISABILITY: 0.03%
# 	PTSDDIAGNOSIS: 0.04%
# 	DEPRESSION: 0.04%
# 	ULCERATIVE_COLITIS: 0.05%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.06%
# 	PLASMACELL_NEOPLASM: 0.07%
#
# Age 90
# ======
# Top 10
# 	ANXIETY: 23.04%
# 	ALL_DEMENTIA: 12.93%
# 	HYPERTENSION: 10.37%
# 	ANY_DEAFNESS_HEARING_LOSS: 8.59%
# 	OSTEOARTHRITIS: 6.50%
# 	ALLCA_NOBCC_VFINAL: 5.62%
# 	ATOPICECZEMA: 4.41%
# 	HYPOTHYROIDISM_DRAFT_V1: 3.80%
# 	STROKEUNSPECIFIED: 3.07%
# 	CKDSTAGE3TO5: 2.77%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	CHRONICFATIGUESYNDROMEMM: 0.00%
# 	FIBROMYALGIA: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.00%
# 	AUTISM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	HIVAIDS: 0.00%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.00%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	MS: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	TYPE1DM: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	LEARNINGDISABILITY: 0.01%
# 	OSA: 0.01%
# 	NAFLD: 0.01%
# 	CROHNS_DISEASE: 0.02%
# 	PTSDDIAGNOSIS: 0.02%
# 	BRONCHIECTASIS: 0.03%
# 	ILD_SH: 0.03%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.04%
# 	PLASMACELL_NEOPLASM: 0.04%
# 	MENIERESDISEASE: 0.04%

# %% [markdown]
# # Appendix: model architectures

# %%
for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n" + "="*len(m_names[model_idx]))
    print(f"\n\n{model}")
# Out:
# TPPTransformerForCausalSequenceModelling_Geometric
# ==================================================
#
#
# TPPTransformerForCausalSequenceModelling(
#   (transformer): TPPTransformer(
#     (wpe): TemporalPositionalEncoding()
#     (wte): Embedding(74, 384)
#     (drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=384, out_features=74, bias=False)
#   (tte_layer): GeometricTTELayer(
#     (proj): Linear(in_features=384, out_features=1, bias=True)
#   )
# )
#
#
# TPPTransformerForCausalSequenceModelling_Exponential
# ====================================================
#
#
# TPPTransformerForCausalSequenceModelling(
#   (transformer): TPPTransformer(
#     (wpe): TemporalPositionalEncoding()
#     (wte): Embedding(74, 384)
#     (drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=384, out_features=74, bias=False)
#   (tte_layer): ExponentialTTELayer(
#     (proj): Linear(in_features=384, out_features=1, bias=True)
#   )
# )
