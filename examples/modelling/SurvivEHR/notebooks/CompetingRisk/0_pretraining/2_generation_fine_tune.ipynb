# %% [markdown]
# # Demo Notebook:
# ## SurvivEHR: Competing Risk Survival Transformer For Causal Sequence Modelling
#
# In this notebook we demonstrate how a pre-trained model can be used for generation

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# !pwd

# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import logging
from pycox.evaluation import EvalSurv
from tqdm import tqdm
from hydra import compose, initialize
from omegaconf import OmegaConf
from CPRD.examples.modelling.SurvStreamGPT.run_experiment import run
from CPRD.data.foundational_loader import FoundationalDataModule
from CPRD.src.models.survival.task_heads.causal import SurvStreamGPTForCausalModelling

torch.manual_seed(1337)
torch.set_float32_matmul_precision('medium')

logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")

# %% [markdown]
# # Demo Version of SurvStreamGPT

# %% [markdown]
# ## Build configurations

# %%
# load the configuration file, override any settings 
with initialize(version_base=None, config_path="../../confs", job_name="testing_notebook"):
    cfg = compose(config_name="config_CompetingRisk11M", 
                  overrides=["experiment.type='zero-shot'",
                             "experiment.run_id='CR_11M'",
                             "experiment.train=False",
                             "experiment.test=False",
                             "data.path_to_ds=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/",
                             "optim.limit_test_batches=null"
                            ]
                 )     

cfg.data.min_workers = 12

# Just load in pretrained model
cfg.experiment.log = False

print(OmegaConf.to_yaml(cfg))

save_path = f"/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/{cfg.experiment.run_id}/"

# %%
 # TODO: define an env variable to fix for a local hpc environment issue, this shouldn't be needed
# %env SLURM_NTASKS_PER_NODE=28      

model, dm_pretrain = run(cfg)     
print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
# Out:
# env: SLURM_NTASKS_PER_NODE=28
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 4
#       1 # TODO: define an env variable to fix for a local hpc environment issue, this shouldn't be needed
#       2 get_ipython().run_line_magic('env', 'SLURM_NTASKS_PER_NODE=28')
# ----> 4 model, dm_pretrain = run(cfg)
#       5 print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
#
# NameError: name 'run' is not defined

# %%
# Update dataset path to point to the new dataset 
cfg.data.path_to_ds = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/"

# Build 
dm = FoundationalDataModule(path_to_db=cfg.data.path_to_db,
                            path_to_ds=cfg.data.path_to_ds,
                            load=True,
                            tokenizer="tabular",
                            batch_size=cfg.data.batch_size,
                            max_seq_length=cfg.transformer.block_size,
                            freq_threshold=cfg.data.unk_freq_threshold,
                            min_workers=cfg.data.min_workers,
                            overwrite_meta_information=cfg.data.meta_information_path,
                           )

vocab_size = dm.train_set.tokenizer.vocab_size
print(f"{vocab_size} vocab elements")

# list of univariate measurements to model with Normal distribution
# Extract the measurements, using the fact that the diagnoses are all up upper case.
measurements_for_univariate_regression = [record for record in dm.tokenizer._event_counts["EVENT"] if record.upper() != record]
cfg.head.tokens_for_univariate_regression = dm.encode(measurements_for_univariate_regression) 
# display(measurements_for_univariate_regression)
# Out:
# INFO:root:Creating unsupervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=train/ dataset, with 572,096 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=test/ dataset, with 35,758 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=val/ dataset, with 33,280 samples
# 265 vocab elements

# %%
import pickle
with open("/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/practice_id_splits.pickle", 'rb') as f:
    splits = pickle.load(f)
type(splits["test"][0])
# Out:
# int

# %%
from CPRD.data.dataset.collector import SQLiteDataCollector
collector = SQLiteDataCollector(cfg.data.path_to_db + "cprd.db")
collector.connect()
collector.disconnect()

# %% [markdown]
# Full example from the fine-tuning dataset. This includes all events up and including the index event, followed by the outcome or last seen event. This outcome/censoring event is not relevant to this notebook.

# %%
dm.train_set.view_sample(100, max_dynamic_events=None, report_time=True)

# for batch in dm.train_dataloader():
#     break
# print(batch.keys())
# Out:
# Time to retrieve sample index 100 was 0.23813700675964355 seconds
#
# SEX                 | F
# IMD                 | 4.0
# ETHNICITY           | WHITE
# birth_year          | 1972.0
# Sequence of 128 events
#
# Token                                                                      | Age               | Standardised value
# ===================================================================================================================
# Red_blood_cell__RBC__count_10                                              | 13971             | -0.49
# Serum_HDL_cholesterol_level_100                                            | 13971             | -0.18
# Serum_LDL_cholesterol_level_102                                            | 13971             | -0.39
# Serum_TSH_level_71                                                         | 13971             | -0.50
# Serum_albumin_51                                                           | 13971             | -0.29
# Serum_alkaline_phosphatase_50                                              | 13971             | -0.50
# Serum_cholesterol_97                                                       | 13971             | -0.42
# Serum_creatinine_31                                                        | 13971             | -0.49
# Serum_free_T4_level_75                                                     | 13971             | -0.50
# Serum_gamma_glutamyl_transferase_level_57                                  | 13971             | -0.05
# Serum_potassium_26                                                         | 13971             | -0.07
# Serum_sodium_24                                                            | 13971             | -0.05
# Serum_total_bilirubin_level_56                                             | 13971             | -0.49
# Serum_triglycerides_105                                                    | 13971             | -0.48
# Serum_urea_level_29                                                        | 13971             | -0.14
# Systolic_blood_pressure_4                                                  | 13971             | -0.18
# Systolic_blood_pressure_4                                                  | 13971             | -0.11
# Total_white_cell_count_18                                                  | 13971             | -0.50
# All_Diuretics_D2T                                                          | 14013             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14013             | nan
# Thiazide_Diuretics_v2                                                      | 14013             | nan
# All_Diuretics_D2T                                                          | 14062             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14062             | nan
# Thiazide_Diuretics_v2                                                      | 14062             | nan
# Diastolic_blood_pressure_5                                                 | 14124             | -0.29
# Systolic_blood_pressure_4                                                  | 14124             | -0.18
# All_Diuretics_D2T                                                          | 14157             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14157             | nan
# Thiazide_Diuretics_v2                                                      | 14157             | nan
# Body_mass_index_3                                                          | 14174             | -0.14
# Current_smoker_83                                                          | 14174             | -0.38
# Diastolic_blood_pressure_5                                                 | 14174             | -0.30
# O_E___height_1                                                             | 14174             | 0.08
# O_E___weight_2                                                             | 14174             | -0.29
# Systolic_blood_pressure_4                                                  | 14174             | -0.13
# Total_cholesterol_HDL_ratio_95                                             | 14174             | -0.49
# SABA_PUSHAsthma                                                            | 14174             | nan
# Diastolic_blood_pressure_5                                                 | 14185             | -0.32
# Systolic_blood_pressure_4                                                  | 14185             | -0.19
# Total_cholesterol_HDL_ratio_95                                             | 14185             | -0.49
# All_Diuretics_D2T                                                          | 14227             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14227             | nan
# Thiazide_Diuretics_v2                                                      | 14227             | nan
# Diastolic_blood_pressure_5                                                 | 14237             | -0.29
# Systolic_blood_pressure_4                                                  | 14237             | -0.17
# Diastolic_blood_pressure_5                                                 | 14244             | -0.32
# Systolic_blood_pressure_4                                                  | 14244             | -0.15
# Diastolic_blood_pressure_5                                                 | 14257             | -0.33
# Systolic_blood_pressure_4                                                  | 14257             | -0.15
# Total_cholesterol_HDL_ratio_95                                             | 14257             | -0.49
# CalciumChannelBlck_D2T                                                     | 14257             | nan
# Diastolic_blood_pressure_5                                                 | 14300             | -0.34
# Systolic_blood_pressure_4                                                  | 14300             | -0.18
# Total_cholesterol_HDL_ratio_95                                             | 14300             | -0.49
# All_Diuretics_D2T                                                          | 14300             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14300             | nan
# CalciumChannelBlck_D2T                                                     | 14300             | nan
# Thiazide_Diuretics_v2                                                      | 14300             | nan
# Current_smoker_83                                                          | 14314             | -0.38
# Diastolic_blood_pressure_5                                                 | 14314             | -0.34
# Systolic_blood_pressure_4                                                  | 14314             | -0.19
# Total_cholesterol_HDL_ratio_95                                             | 14314             | -0.49
# Weak_Opioids_Final                                                         | 14320             | nan
# NSAIDS_oral_OPTIMAL_final                                                  | 14327             | nan
# Weak_Opioids_Final                                                         | 14327             | nan
# Body_mass_index_3                                                          | 14341             | -0.14
# Current_smoker_83                                                          | 14341             | -0.38
# Diastolic_blood_pressure_5                                                 | 14341             | -0.32
# O_E___height_1                                                             | 14341             | 0.08
# O_E___weight_2                                                             | 14341             | -0.29
# Systolic_blood_pressure_4                                                  | 14341             | -0.20
# Total_cholesterol_HDL_ratio_95                                             | 14341             | -0.49
# All_Diuretics_D2T                                                          | 14369             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14369             | nan
# CalciumChannelBlck_D2T                                                     | 14369             | nan
# Thiazide_Diuretics_v2                                                      | 14369             | nan
# Amitriptyline_optimal                                                      | 14404             | nan
# Tricyclic_Antidepressants_final                                            | 14404             | nan
# Weak_Opioids_Final                                                         | 14404             | nan
# Diastolic_blood_pressure_5                                                 | 14416             | -0.32
# Systolic_blood_pressure_4                                                  | 14416             | -0.18
# Total_cholesterol_HDL_ratio_95                                             | 14416             | -0.49
# All_Diuretics_D2T                                                          | 14437             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14437             | nan
# CalciumChannelBlck_D2T                                                     | 14437             | nan
# Thiazide_Diuretics_v2                                                      | 14437             | nan
# Basophil_count_22                                                          | 14464             | -0.48
# Eosinophil_count_21                                                        | 14464             | -0.45
# GFR_calculated_abbreviated_MDRD_34                                         | 14464             | -0.20
# Haematocrit_15                                                             | 14464             | -0.12
# Haemoglobin_estimation_9                                                   | 14464             | -0.49
# Lymphocyte_count_20                                                        | 14464             | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 14464             | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 14464             | -0.26
# Mean_corpuscular_volume__MCV__11                                           | 14464             | -0.22
# Monocyte_count_23                                                          | 14464             | -0.47
# Neutrophil_count_19                                                        | 14464             | -0.41
# Platelet_count_12                                                          | 14464             | -0.50
# Red_blood_cell__RBC__count_10                                              | 14464             | -0.49
# Serum_creatinine_31                                                        | 14464             | -0.50
# Serum_potassium_26                                                         | 14464             | -0.02
# Serum_sodium_24                                                            | 14464             | -0.04
# Serum_urea_level_29                                                        | 14464             | -0.16
# Total_white_cell_count_18                                                  | 14464             | -0.50
# All_Diuretics_D2T                                                          | 14471             | nan
# All_Diuretics_ExclLactones_D2T                                             | 14471             | nan
# CalciumChannelBlck_D2T                                                     | 14471             | nan
# SABA_PUSHAsthma                                                            | 14471             | nan
# Thiazide_Diuretics_v2                                                      | 14471             | nan
# Basophil_count_22                                                          | 14492             | -0.48
# Eosinophil_count_21                                                        | 14492             | -0.46
# Haematocrit_15                                                             | 14492             | -0.13
# Haemoglobin_A1c_level___IFCC_standardised_6                                | 14492             | -0.33
# Haemoglobin_A1c_level_8                                                    | 14492             | nan
# Haemoglobin_estimation_9                                                   | 14492             | -0.49
# HbA1c_level__DCCT_aligned__7                                               | 14492             | -0.49
# Lymphocyte_count_20                                                        | 14492             | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 14492             | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 14492             | -0.26
# Mean_corpuscular_volume__MCV__11                                           | 14492             | -0.23
# Monocyte_count_23                                                          | 14492             | -0.48
# Neutrophil_count_19                                                        | 14492             | -0.43
# Platelet_count_12                                                          | 14492             | -0.50
# Red_blood_cell__RBC__count_10                                              | 14492             | -0.49
# Serum_ferritin_63                                                          | 14492             | -0.50
# Total_white_cell_count_18                                                  | 14492             | -0.50
# TYPE2DIABETES                                                              | 14500             | nan
# Serum_urea_level_29                                                        | 17321             | 0.05

# %% [markdown]
# # Generation from real prompts

# %%
# Utility function

# define encoding functions (TODO: add this wrap to datamodule
encode_prompt = lambda prompt_list: torch.from_numpy(np.array(dm.encode(prompt_list)).reshape((1,-1))).to(device)
encode_value = lambda prompt_list, value_list: torch.tensor(np.array([dm.standardise(_cat, _val) for _cat, _val in zip(prompt_list, value_list) ]).reshape((1,-1)), dtype=torch.float32).to(device)
encode_age = lambda age_list: torch.tensor([365 * _age for _age in age_list], dtype=torch.int64).reshape((1,-1)).to(device)

def table(_tokens,_ages,_values):
    # print table rows 
    assert _tokens.shape[0] == 1
    assert _ages.shape[0] == 1
    assert _values.shape[0] == 1
    
    for _idx, (_cat, _age, _value) in enumerate(zip(dm.decode(_tokens[0].tolist()).split(" "), 
                                                    _ages[0, :], 
                                                    _values[0, :]
                                                    )
                                                ):
        _value = dm.unstandardise(_cat, _value)
        print(f"\t{_cat}".ljust(60) + f"{_value:.02f}".ljust(15) + f"at age {_age/365:.0f} ({int(_age)} days)")    # with value {_value}


indexing_token_to_pivot_on = dm.encode(["TYPE2DIABETES"])[0]
stop_token =  dm.encode(["DEATH"])[0]

# %% [markdown]
# For a number of patients, split by a `document break`,
# 1) take the context before the index event day and predict what will be the subsequent series of events
# 2) take the context up to and including the index event day, and predict what will be the subsequent series of events
#
# We can then observe how the index event correlated with future time-series predictions

# %%
for idx_sample, sample in enumerate(dm.test_set):

    # Get the sample
    # sample = dm.test_set[_patient_idx]
    _index = (sample["tokens"] == indexing_token_to_pivot_on).nonzero(as_tuple=True)[0].item()

    # chunk by day
    _day_at_index = int(sample["ages"][_index])
    _index_pre = sum(sample["ages"] < _day_at_index)
    _index_inc = sum(sample["ages"] <= _day_at_index)
    
    for _phase, _split_at in enumerate([_index_pre, _index_inc]):

        if _phase == 0:
            print(f"\n\nBefore {dm.decode([indexing_token_to_pivot_on]).lower()} is seen in the medical history")
        else:
            print('\n------------------------------------ page break ------------------------------------')
            print(f"\n\nAfter the diagnosis of {dm.decode([indexing_token_to_pivot_on]).lower()} is then seen in the medical history")

        _covariates = sample["static_covariates"].reshape((1,-1))
        _tokens = sample["tokens"][:_split_at].reshape((1,-1))
        _ages = sample["ages"][:_split_at].reshape((1,-1))
        _values = sample["values"][:_split_at].reshape((1,-1))

        # Report the initial part of their historical context
        _dec_covariates = dm.train_set._decode_covariates(_covariates)
        print(f"\n\nMedical history of a \n\t" + \
                        f"{_dec_covariates['ETHNICITY'][0].lower()}, " + \
                        f"{'male' if _dec_covariates['SEX'][0] == 'M' else 'female'} patient, " + \
                        f"born in {int(_dec_covariates['birth_year'][0])}, " + \
                        f"with IMD (deprivation) level {int(_dec_covariates['IMD'][0])}. \n\n" 
              )
        table(_tokens, _ages, _values)

        
        # Predict the future and report
        new_tokens, new_ages, new_values = model.generate(_tokens.to(device), _ages.to(device), _values.to(device), _covariates.to(device), max_new_tokens=20, eos_token=stop_token)
        print(f"""\nSurvivEHR then predicts the next events to be:
               """)
        table(new_tokens[:, _tokens.shape[1]:].reshape((1,-1)), 
              new_ages[:, _tokens.shape[1]:].reshape((1,-1)),
              new_values[:, _tokens.shape[1]:].reshape((1,-1))
             )

    print('\n----------------------------------------------------------------------------------------')
    print('------------------------------------ document break ------------------------------------')
    print('----------------------------------------------------------------------------------------')

    if idx_sample > 20:
        break
# Out:
# Before type2diabetes is seen in the medical history
#
#
# Medical history of a
# 	black, male patient, born in 1968, with IMD (deprivation) level 5.
#
#
# 	SUBSTANCEMISUSE                                            nan            at age 26 (9605 days)
# 	SCHIZOPHRENIAMM_V2                                         nan            at age 36 (12977 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	ACE_Inhibitors_D2T                                         nan            at age 36 (13138 days)
# 	Serum_albumin_51                                           36.11          at age 37 (13341 days)
# 	Tricyclic_Antidepressants_final                            nan            at age 37 (13372 days)
# 	Lipid_lowering_drugs_Optimal                               nan            at age 37 (13676 days)
# 	O_E___weight_2                                             92.05          at age 38 (13764 days)
# 	Diastolic_blood_pressure_5                                 71.18          at age 38 (13856 days)
# 	COCP_reg_contraception                                     nan            at age 38 (13869 days)
# 	Serum_cholesterol_97                                       2.36           at age 38 (13884 days)
# 	Serum_triglycerides_105                                    2.03           at age 38 (13884 days)
# 	Systolic_blood_pressure_4                                  137.20         at age 38 (13936 days)
# 	Serum_alanine_aminotransferase_level_45                    706.72         at age 38 (13958 days)
# 	O_E___weight_2                                             113.11         at age 38 (13998 days)
# 	SSRIs_Optimal                                              nan            at age 39 (14284 days)
# 	Lipid_lowering_drugs_Optimal                               nan            at age 40 (14494 days)
# 	Serum_C_reactive_protein_level_59                          2.94           at age 40 (14499 days)
# 	Body_mass_index_3                                          24.64          at age 41 (14821 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 41 (15011 days)
# 	O_E___weight_2                                             79.18          at age 41 (15091 days)
# 	Lymphocyte_count_20                                        6.44           at age 42 (15258 days)
# 	Serum_total_bilirubin_level_56                             14.35          at age 42 (15358 days)
#
# ------------------------------------ page break ------------------------------------
#
#
# After the diagnosis of type2diabetes is then seen in the medical history
#
#
# Medical history of a
# 	black, male patient, born in 1968, with IMD (deprivation) level 5.
#
#
# 	SUBSTANCEMISUSE                                            nan            at age 26 (9605 days)
# 	SCHIZOPHRENIAMM_V2                                         nan            at age 36 (12977 days)
# 	TYPE2DIABETES                                              nan            at age 38 (13927 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	Serum_creatinine_31                                        250.34         at age 38 (14001 days)
# 	Haemoglobin_estimation_9                                   108.03         at age 39 (14182 days)
# 	Serum_cholesterol_97                                       4.06           at age 39 (14199 days)
# 	Paracetamol_OPTIMAL                                        nan            at age 40 (14537 days)
# 	Lipid_lowering_drugs_Optimal                               nan            at age 40 (14639 days)
# 	Platelet_count_12                                          32806.70       at age 40 (14740 days)
# 	Serum_non_high_density_lipoprotein_cholesterol_level_107   3.13           at age 41 (14876 days)
# 	First_gen_H1_antihistamines                                nan            at age 41 (14893 days)
# 	Haemoglobin_estimation_9                                   114.27         at age 41 (14954 days)
# 	Systolic_blood_pressure_4                                  120.15         at age 41 (15014 days)
# 	PropranololAnxiety_mumpredict                              nan            at age 42 (15419 days)
# 	Weak_Opioids_Final                                         nan            at age 42 (15497 days)
# 	Serum_HDL_cholesterol_level_100                            1.18           at age 43 (15577 days)
# 	Platelet_count_12                                          -33578.87      at age 43 (15716 days)
# 	GFR_calculated_abbreviated_MDRD_34                         38.15          at age 43 (15857 days)
# 	Paracetamol_OPTIMAL                                        nan            at age 44 (15971 days)
# 	Serum_sodium_24                                            139.92         at age 44 (16031 days)
# 	Serum_creatinine_31                                        -18.54         at age 44 (16031 days)
# 	Never_smoked_tobacco_85                                    0.00           at age 47 (17092 days)
# 	Systolic_blood_pressure_4                                  135.00         at age 47 (17150 days)
#
# ----------------------------------------------------------------------------------------
# ------------------------------------ document break ------------------------------------
# ----------------------------------------------------------------------------------------
#
#
# Before type2diabetes is seen in the medical history
#
#
# Medical history of a
# 	white, female patient, born in 1965, with IMD (deprivation) level 5.
#
#
# 	Serum_TSH_level_71                                         2.14           at age 52 (18949 days)
# 	Serum_alanine_aminotransferase_level_45                    41.00          at age 52 (18949 days)
# 	Serum_albumin_51                                           43.00          at age 52 (18949 days)
# 	Serum_alkaline_phosphatase_50                              63.00          at age 52 (18949 days)
# 	Serum_bilirubin_level_53                                   7.00           at age 52 (18949 days)
# 	Serum_cholesterol_97                                       4.70           at age 52 (18949 days)
# 	Serum_creatinine_31                                        76.00          at age 52 (18949 days)
# 	Serum_potassium_26                                         3.70           at age 52 (18949 days)
# 	Serum_sodium_24                                            138.00         at age 52 (18949 days)
# 	Serum_triglycerides_105                                    1.64           at age 52 (18949 days)
# 	Serum_urea_level_29                                        7.80           at age 52 (18949 days)
# 	Total_cholesterol_HDL_ratio_95                             5.00           at age 52 (18949 days)
# 	Total_white_cell_count_18                                  6.10           at age 52 (18949 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18949 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18949 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18949 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18949 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18949 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18949 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18949 days)
# 	Levothyroxine_                                             nan            at age 52 (18949 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18949 days)
# 	Vitamin_D                                                  nan            at age 52 (18949 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18950 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18950 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18950 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18950 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18950 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18950 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18950 days)
# 	Levothyroxine_                                             nan            at age 52 (18950 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18950 days)
# 	Vitamin_D                                                  nan            at age 52 (18950 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18957 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18957 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18957 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18957 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18957 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18957 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18957 days)
# 	Levothyroxine_                                             nan            at age 52 (18957 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18957 days)
# 	Vitamin_D                                                  nan            at age 52 (18957 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18964 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18964 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18964 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18964 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18964 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18964 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18964 days)
# 	Levothyroxine_                                             nan            at age 52 (18964 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18964 days)
# 	Vitamin_D                                                  nan            at age 52 (18964 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18977 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18977 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18977 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18977 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18977 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18977 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18977 days)
# 	Levothyroxine_                                             nan            at age 52 (18977 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18977 days)
# 	Vitamin_D                                                  nan            at age 52 (18977 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (19005 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (19005 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (19005 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (19005 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (19005 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (19005 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (19005 days)
# 	Levothyroxine_                                             nan            at age 52 (19005 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (19005 days)
# 	Vitamin_D                                                  nan            at age 52 (19005 days)
# 	HYPERTENSION                                               nan            at age 52 (19133 days)
# 	Basophil_count_22                                          0.10           at age 53 (19256 days)
# 	Calculated_LDL_cholesterol_level_103                       3.30           at age 53 (19256 days)
# 	Eosinophil_count_21                                        0.10           at age 53 (19256 days)
# 	GFR_calculated_abbreviated_MDRD_34                         60.00          at age 53 (19256 days)
# 	Haematocrit___PCV_16                                       0.40           at age 53 (19256 days)
# 	Haemoglobin_A1c_level___IFCC_standardised_6                48.00          at age 53 (19256 days)
# 	Haemoglobin_estimation_9                                   130.00         at age 53 (19256 days)
# 	Lymphocyte_count_20                                        2.50           at age 53 (19256 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             325.00         at age 53 (19256 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           28.40          at age 53 (19256 days)
# 	Mean_corpuscular_volume__MCV__11                           87.40          at age 53 (19256 days)
# 	Monocyte_count_23                                          0.40           at age 53 (19256 days)
# 	Neutrophil_count_19                                        4.10           at age 53 (19256 days)
# 	Non_HDL_cholesterol_level_108                              4.50           at age 53 (19256 days)
# 	Platelet_count_12                                          318.88         at age 53 (19256 days)
# 	Red_blood_cell__RBC__count_10                              4.58           at age 53 (19256 days)
# 	Red_blood_cell_distribution_width_17                       15.70          at age 53 (19256 days)
# 	Serum_25_Hydroxy_vitamin_D3_level_88                       56.00          at age 53 (19256 days)
# 	Serum_HDL_cholesterol_level_100                            0.84           at age 53 (19256 days)
# 	Serum_TSH_level_71                                         2.05           at age 53 (19256 days)
# 	Serum_alanine_aminotransferase_level_45                    39.00          at age 53 (19256 days)
# 	Serum_albumin_51                                           38.00          at age 53 (19256 days)
# 	Serum_alkaline_phosphatase_50                              55.00          at age 53 (19256 days)
# 	Serum_bilirubin_level_53                                   5.00           at age 53 (19256 days)
# 	Serum_calcium_39                                           2.24           at age 53 (19256 days)
# 	Serum_cholesterol_97                                       5.00           at age 53 (19256 days)
# 	Serum_cholesterol_97                                       5.40           at age 53 (19256 days)
# 	Serum_creatinine_31                                        72.00          at age 53 (19256 days)
# 	Serum_potassium_26                                         4.10           at age 53 (19256 days)
# 	Serum_sodium_24                                            142.00         at age 53 (19256 days)
# 	Serum_triglycerides_105                                    2.65           at age 53 (19256 days)
# 	Serum_urea_level_29                                        6.10           at age 53 (19256 days)
# 	Total_cholesterol_HDL_ratio_95                             6.40           at age 53 (19256 days)
# 	Total_white_cell_count_18                                  7.20           at age 53 (19256 days)
# 	Never_smoked_tobacco_85                                    nan            at age 53 (19261 days)
# 	SSRIs_Optimal                                              nan            at age 53 (19261 days)
# 	Serum_ferritin_63                                          81.00          at age 53 (19262 days)
# 	Serum_folate_80                                            20.00          at age 53 (19262 days)
# 	Serum_vitamin_B12_79                                       474.00         at age 53 (19262 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	Lipid_lowering_drugs_Optimal                               nan            at age 53 (19422 days)
# 	Antihistamines_second_generation_H1_antagonists            nan            at age 53 (19486 days)
# 	Serum_alkaline_phosphatase_50                              254.30         at age 54 (19633 days)
# 	Serum_HDL_cholesterol_level_100                            2.14           at age 54 (19877 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           29.19          at age 55 (19946 days)
# 	Systolic_blood_pressure_4                                  113.36         at age 55 (20057 days)
# 	Serum_alanine_aminotransferase_level_45                    107.41         at age 55 (20094 days)
# 	Serum_albumin_51                                           46.05          at age 55 (20131 days)
# 	Eosinophil_count_21                                        0.86           at age 56 (20480 days)
# 	BetaBlockers_OPTIMAL                                       nan            at age 56 (20518 days)
# 	Never_smoked_tobacco_85                                    0.00           at age 57 (20762 days)
# 	Paracetamol_OPTIMAL                                        nan            at age 57 (20816 days)
# 	Never_smoked_tobacco_85                                    0.00           at age 57 (20862 days)
# 	Never_smoked_tobacco_85                                    0.00           at age 58 (21151 days)
# 	Lipid_lowering_drugs_Optimal                               nan            at age 58 (21231 days)
# 	Serum_albumin_51                                           42.13          at age 58 (21232 days)
# 	International_normalised_ratio_82                          5.61           at age 58 (21324 days)
# 	Serum_TSH_level_71                                         1.90           at age 59 (21624 days)
# 	Total_white_cell_count_18                                  -0.69          at age 59 (21709 days)
# 	Eosinophil_count_21                                        0.48           at age 60 (21843 days)
#
# ------------------------------------ page break ------------------------------------
#
#
# After the diagnosis of type2diabetes is then seen in the medical history
#
#
# Medical history of a
# 	white, female patient, born in 1965, with IMD (deprivation) level 5.
#
#
# 	Serum_TSH_level_71                                         2.14           at age 52 (18949 days)
# 	Serum_alanine_aminotransferase_level_45                    41.00          at age 52 (18949 days)
# 	Serum_albumin_51                                           43.00          at age 52 (18949 days)
# 	Serum_alkaline_phosphatase_50                              63.00          at age 52 (18949 days)
# 	Serum_bilirubin_level_53                                   7.00           at age 52 (18949 days)
# 	Serum_cholesterol_97                                       4.70           at age 52 (18949 days)
# 	Serum_creatinine_31                                        76.00          at age 52 (18949 days)
# 	Serum_potassium_26                                         3.70           at age 52 (18949 days)
# 	Serum_sodium_24                                            138.00         at age 52 (18949 days)
# 	Serum_triglycerides_105                                    1.64           at age 52 (18949 days)
# 	Serum_urea_level_29                                        7.80           at age 52 (18949 days)
# 	Total_cholesterol_HDL_ratio_95                             5.00           at age 52 (18949 days)
# 	Total_white_cell_count_18                                  6.10           at age 52 (18949 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18949 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18949 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18949 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18949 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18949 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18949 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18949 days)
# 	Levothyroxine_                                             nan            at age 52 (18949 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18949 days)
# 	Vitamin_D                                                  nan            at age 52 (18949 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18950 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18950 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18950 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18950 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18950 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18950 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18950 days)
# 	Levothyroxine_                                             nan            at age 52 (18950 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18950 days)
# 	Vitamin_D                                                  nan            at age 52 (18950 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18957 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18957 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18957 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18957 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18957 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18957 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18957 days)
# 	Levothyroxine_                                             nan            at age 52 (18957 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18957 days)
# 	Vitamin_D                                                  nan            at age 52 (18957 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18964 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18964 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18964 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18964 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18964 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18964 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18964 days)
# 	Levothyroxine_                                             nan            at age 52 (18964 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18964 days)
# 	Vitamin_D                                                  nan            at age 52 (18964 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (18977 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18977 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (18977 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (18977 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (18977 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18977 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (18977 days)
# 	Levothyroxine_                                             nan            at age 52 (18977 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (18977 days)
# 	Vitamin_D                                                  nan            at age 52 (18977 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 52 (19005 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (19005 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 52 (19005 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 52 (19005 days)
# 	Calcium_supplements_Optimal                                nan            at age 52 (19005 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (19005 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 52 (19005 days)
# 	Levothyroxine_                                             nan            at age 52 (19005 days)
# 	SNRIs_OPTIMAL                                              nan            at age 52 (19005 days)
# 	Vitamin_D                                                  nan            at age 52 (19005 days)
# 	HYPERTENSION                                               nan            at age 52 (19133 days)
# 	Basophil_count_22                                          0.10           at age 53 (19256 days)
# 	Calculated_LDL_cholesterol_level_103                       3.30           at age 53 (19256 days)
# 	Eosinophil_count_21                                        0.10           at age 53 (19256 days)
# 	GFR_calculated_abbreviated_MDRD_34                         60.00          at age 53 (19256 days)
# 	Haematocrit___PCV_16                                       0.40           at age 53 (19256 days)
# 	Haemoglobin_A1c_level___IFCC_standardised_6                48.00          at age 53 (19256 days)
# 	Haemoglobin_estimation_9                                   130.00         at age 53 (19256 days)
# 	Lymphocyte_count_20                                        2.50           at age 53 (19256 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             325.00         at age 53 (19256 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           28.40          at age 53 (19256 days)
# 	Mean_corpuscular_volume__MCV__11                           87.40          at age 53 (19256 days)
# 	Monocyte_count_23                                          0.40           at age 53 (19256 days)
# 	Neutrophil_count_19                                        4.10           at age 53 (19256 days)
# 	Non_HDL_cholesterol_level_108                              4.50           at age 53 (19256 days)
# 	Platelet_count_12                                          318.88         at age 53 (19256 days)
# 	Red_blood_cell__RBC__count_10                              4.58           at age 53 (19256 days)
# 	Red_blood_cell_distribution_width_17                       15.70          at age 53 (19256 days)
# 	Serum_25_Hydroxy_vitamin_D3_level_88                       56.00          at age 53 (19256 days)
# 	Serum_HDL_cholesterol_level_100                            0.84           at age 53 (19256 days)
# 	Serum_TSH_level_71                                         2.05           at age 53 (19256 days)
# 	Serum_alanine_aminotransferase_level_45                    39.00          at age 53 (19256 days)
# 	Serum_albumin_51                                           38.00          at age 53 (19256 days)
# 	Serum_alkaline_phosphatase_50                              55.00          at age 53 (19256 days)
# 	Serum_bilirubin_level_53                                   5.00           at age 53 (19256 days)
# 	Serum_calcium_39                                           2.24           at age 53 (19256 days)
# 	Serum_cholesterol_97                                       5.00           at age 53 (19256 days)
# 	Serum_cholesterol_97                                       5.40           at age 53 (19256 days)
# 	Serum_creatinine_31                                        72.00          at age 53 (19256 days)
# 	Serum_potassium_26                                         4.10           at age 53 (19256 days)
# 	Serum_sodium_24                                            142.00         at age 53 (19256 days)
# 	Serum_triglycerides_105                                    2.65           at age 53 (19256 days)
# 	Serum_urea_level_29                                        6.10           at age 53 (19256 days)
# 	Total_cholesterol_HDL_ratio_95                             6.40           at age 53 (19256 days)
# 	Total_white_cell_count_18                                  7.20           at age 53 (19256 days)
# 	Never_smoked_tobacco_85                                    nan            at age 53 (19261 days)
# 	SSRIs_Optimal                                              nan            at age 53 (19261 days)
# 	Serum_ferritin_63                                          81.00          at age 53 (19262 days)
# 	Serum_folate_80                                            20.00          at age 53 (19262 days)
# 	Serum_vitamin_B12_79                                       474.00         at age 53 (19262 days)
# 	Diastolic_blood_pressure_5                                 88.00          at age 53 (19269 days)
# 	Systolic_blood_pressure_4                                  160.00         at age 53 (19269 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 53 (19269 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 53 (19269 days)
# 	Bisphosphonates_osteoporosis                               nan            at age 53 (19269 days)
# 	CalciumChannelBlck_D2T                                     nan            at age 53 (19269 days)
# 	Calcium_supplements_Optimal                                nan            at age 53 (19269 days)
# 	Gabapentin_Oral_OPTIMAL                                    nan            at age 53 (19269 days)
# 	Levothyroxine_                                             nan            at age 53 (19269 days)
# 	Lipid_lowering_drugs_Optimal                               nan            at age 53 (19269 days)
# 	Metformin_612_A10BD2                                       nan            at age 53 (19269 days)
# 	Statins                                                    nan            at age 53 (19269 days)
# 	Vitamin_D                                                  nan            at age 53 (19269 days)
# 	TYPE2DIABETES                                              nan            at age 53 (19269 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	Haematocrit_15                                             0.45           at age 53 (19417 days)
# 	Serum_sodium_24                                            139.81         at age 54 (19621 days)
# 	Vitamin_D                                                  nan            at age 54 (19662 days)
# 	ALLERGICRHINITISCONJ                                       nan            at age 54 (19888 days)
# 	NAFLD_V2                                                   nan            at age 55 (20147 days)
# 	All_Diuretics_D2T                                          nan            at age 56 (20267 days)
# 	Never_smoked_tobacco_85                                    0.00           at age 56 (20479 days)
# 	O_E___weight_2                                             83.63          at age 56 (20490 days)
# 	Haemoglobin_estimation_9                                   104.45         at age 56 (20567 days)
# 	Serum_cholesterol_HDL_ratio_94                             1.20           at age 57 (20629 days)
# 	Strong_Opioids_2022_Final                                  nan            at age 57 (20740 days)
# 	Serum_sodium_24                                            142.60         at age 57 (20776 days)
# 	Total_white_cell_count_18                                  58.20          at age 57 (20812 days)
# 	Lymphocyte_count_20                                        1.05           at age 57 (20969 days)
# 	Platelet_count_12                                          181022.88      at age 57 (20982 days)
# 	Systolic_blood_pressure_4                                  130.26         at age 58 (21030 days)
# 	all_contraceptive                                          nan            at age 58 (21052 days)
# 	Serum_sodium_24                                            147.22         at age 58 (21171 days)
# 	O_E___height_1                                             158.09         at age 58 (21206 days)
# 	SNRIs_OPTIMAL                                              nan            at age 58 (21315 days)
#
# ----------------------------------------------------------------------------------------
# ------------------------------------ document break ------------------------------------
# ----------------------------------------------------------------------------------------
#
#
# Before type2diabetes is seen in the medical history
#
#
# Medical history of a
# 	white, female patient, born in 1922, with IMD (deprivation) level 5.
#
#
# 	Digoxin_                                                   nan            at age 77 (28177 days)
# 	Diastolic_blood_pressure_5                                 85.00          at age 77 (28184 days)
# 	Systolic_blood_pressure_4                                  135.00         at age 77 (28184 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 77 (28221 days)
# 	All_Antiplatelets                                          nan            at age 77 (28221 days)
# 	All_Diuretics_D2T                                          nan            at age 77 (28221 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 77 (28221 days)
# 	Aspirin_OPTIMAL                                            nan            at age 77 (28221 days)
# 	Digoxin_                                                   nan            at age 77 (28221 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 77 (28221 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 77 (28282 days)
# 	All_Diuretics_D2T                                          nan            at age 77 (28282 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 77 (28282 days)
# 	Digoxin_                                                   nan            at age 77 (28282 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 78 (28334 days)
# 	Digoxin_                                                   nan            at age 78 (28334 days)
# 	Body_mass_index_3                                          29.80          at age 78 (28403 days)
# 	Diastolic_blood_pressure_5                                 88.00          at age 78 (28403 days)
# 	O_E___weight_2                                             84.30          at age 78 (28403 days)
# 	Systolic_blood_pressure_4                                  140.00         at age 78 (28403 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 78 (28403 days)
# 	All_Antiplatelets                                          nan            at age 78 (28403 days)
# 	All_Diuretics_D2T                                          nan            at age 78 (28403 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 78 (28403 days)
# 	Aspirin_OPTIMAL                                            nan            at age 78 (28403 days)
# 	Digoxin_                                                   nan            at age 78 (28403 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 78 (28403 days)
# 	All_Diuretics_D2T                                          nan            at age 78 (28447 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 78 (28447 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 78 (28450 days)
# 	Digoxin_                                                   nan            at age 78 (28450 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 78 (28510 days)
# 	All_Antiplatelets                                          nan            at age 78 (28510 days)
# 	All_Diuretics_D2T                                          nan            at age 78 (28510 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 78 (28510 days)
# 	Aspirin_OPTIMAL                                            nan            at age 78 (28510 days)
# 	Digoxin_                                                   nan            at age 78 (28510 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 78 (28510 days)
# 	Diastolic_blood_pressure_5                                 80.00          at age 78 (28545 days)
# 	Systolic_blood_pressure_4                                  150.00         at age 78 (28545 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 78 (28545 days)
# 	All_Antiplatelets                                          nan            at age 78 (28545 days)
# 	All_Diuretics_D2T                                          nan            at age 78 (28545 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 78 (28545 days)
# 	Aspirin_OPTIMAL                                            nan            at age 78 (28545 days)
# 	Digoxin_                                                   nan            at age 78 (28545 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 78 (28545 days)
# 	Eosinophil_count_21                                        0.20           at age 78 (28639 days)
# 	Free_T4_level_76                                           10.70          at age 78 (28639 days)
# 	Haematocrit___PCV_16                                       0.42           at age 78 (28639 days)
# 	Lymphocyte_count_20                                        2.60           at age 78 (28639 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             32.80          at age 78 (28639 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           27.00          at age 78 (28639 days)
# 	Mean_corpuscular_volume__MCV__11                           82.50          at age 78 (28639 days)
# 	Monocyte_count_23                                          0.60           at age 78 (28639 days)
# 	Neutrophil_count_19                                        7.80           at age 78 (28639 days)
# 	Platelet_count_12                                          214.87         at age 78 (28639 days)
# 	Red_blood_cell__RBC__count_10                              5.11           at age 78 (28639 days)
# 	Serum_creatinine_31                                        69.00          at age 78 (28639 days)
# 	Serum_potassium_26                                         4.90           at age 78 (28639 days)
# 	Serum_sodium_24                                            141.00         at age 78 (28639 days)
# 	TSH___thyroid_stim_hormone_72                              14.55          at age 78 (28639 days)
# 	Total_white_cell_count_18                                  11.30          at age 78 (28639 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 78 (28639 days)
# 	Digoxin_                                                   nan            at age 78 (28639 days)
# 	Levothyroxine_                                             nan            at age 79 (28674 days)
# 	HYPOTHYROIDISM_DRAFT_V1                                    nan            at age 79 (28674 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 79 (28723 days)
# 	All_Antiplatelets                                          nan            at age 79 (28723 days)
# 	All_Diuretics_D2T                                          nan            at age 79 (28723 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 79 (28723 days)
# 	Aspirin_OPTIMAL                                            nan            at age 79 (28723 days)
# 	Digoxin_                                                   nan            at age 79 (28723 days)
# 	Levothyroxine_                                             nan            at age 79 (28723 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 79 (28723 days)
# 	Haemoglobin_estimation_9                                   13.90          at age 79 (28769 days)
# 	Mean_corpuscular_volume__MCV__11                           80.80          at age 79 (28769 days)
# 	Platelet_count_12                                          233.95         at age 79 (28769 days)
# 	Total_white_cell_count_18                                  12.10          at age 79 (28769 days)
# 	Levothyroxine_                                             nan            at age 79 (28769 days)
# 	Serum_creatinine_31                                        72.00          at age 79 (28772 days)
# 	Serum_potassium_26                                         4.90           at age 79 (28772 days)
# 	Serum_sodium_24                                            140.00         at age 79 (28772 days)
# 	TSH___thyroid_stim_hormone_72                              3.63           at age 79 (28772 days)
# 	Diastolic_blood_pressure_5                                 80.00          at age 79 (28783 days)
# 	Systolic_blood_pressure_4                                  150.00         at age 79 (28783 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 79 (28783 days)
# 	Digoxin_                                                   nan            at age 79 (28783 days)
# 	Levothyroxine_                                             nan            at age 79 (28783 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 79 (28867 days)
# 	All_Antiplatelets                                          nan            at age 79 (28867 days)
# 	All_Diuretics_D2T                                          nan            at age 79 (28867 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 79 (28867 days)
# 	Aspirin_OPTIMAL                                            nan            at age 79 (28867 days)
# 	Digoxin_                                                   nan            at age 79 (28867 days)
# 	Levothyroxine_                                             nan            at age 79 (28867 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 79 (28867 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 79 (28944 days)
# 	All_Antiplatelets                                          nan            at age 79 (28944 days)
# 	All_Diuretics_D2T                                          nan            at age 79 (28944 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 79 (28944 days)
# 	Aspirin_OPTIMAL                                            nan            at age 79 (28944 days)
# 	Digoxin_                                                   nan            at age 79 (28944 days)
# 	Levothyroxine_                                             nan            at age 79 (28944 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 79 (28944 days)
# 	Levothyroxine_                                             nan            at age 79 (29010 days)
# 	Diastolic_blood_pressure_5                                 90.00          at age 80 (29066 days)
# 	Systolic_blood_pressure_4                                  150.00         at age 80 (29066 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 80 (29066 days)
# 	All_Antiplatelets                                          nan            at age 80 (29066 days)
# 	All_Diuretics_D2T                                          nan            at age 80 (29066 days)
# 	All_Diuretics_ExclLactones_D2T                             nan            at age 80 (29066 days)
# 	Aspirin_OPTIMAL                                            nan            at age 80 (29066 days)
# 	Digoxin_                                                   nan            at age 80 (29066 days)
# 	Levothyroxine_                                             nan            at age 80 (29066 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 80 (29066 days)
# 	Haemoglobin_estimation_9                                   14.20          at age 80 (29095 days)
# 	Mean_corpuscular_volume__MCV__11                           81.20          at age 80 (29095 days)
# 	Platelet_count_12                                          227.99         at age 80 (29095 days)
# 	Serum_TSH_level_71                                         5.60           at age 80 (29095 days)
# 	Serum_creatinine_31                                        71.00          at age 80 (29095 days)
# 	Serum_free_T4_level_75                                     13.90          at age 80 (29095 days)
# 	Serum_potassium_26                                         4.60           at age 80 (29095 days)
# 	Serum_sodium_24                                            137.00         at age 80 (29095 days)
# 	Serum_urea_level_29                                        4.80           at age 80 (29095 days)
# 	Total_white_cell_count_18                                  12.60          at age 80 (29095 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	Calcium_supplements_Optimal                                nan            at age 80 (29239 days)
# 	Diastolic_blood_pressure_5                                 84.32          at age 80 (29264 days)
# 	Body_mass_index_3                                          25.24          at age 80 (29376 days)
# 	SSRIs_Optimal                                              nan            at age 81 (29436 days)
# 	GFR_calculated_abbreviated_MDRD_34                         67.74          at age 81 (29459 days)
# 	All_AntiArrhythmics_D2T                                    nan            at age 81 (29570 days)
# 	Serum_vitamin_B12_79                                       469.81         at age 81 (29583 days)
# 	Serum_albumin_51                                           34.62          at age 82 (29776 days)
# 	all_contraceptive                                          nan            at age 82 (29860 days)
# 	Aspirin_OPTIMAL                                            nan            at age 82 (29910 days)
# 	First_gen_H1_antihistamines                                nan            at age 83 (30134 days)
# 	LAMA_PUSHAsthma                                            nan            at age 83 (30219 days)
# 	Mean_corpuscular_volume__MCV__11                           92.55          at age 83 (30295 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             328.41         at age 83 (30374 days)
# 	Basophil_count_22                                          0.08           at age 84 (30604 days)
# 	All_Antiplatelets                                          nan            at age 84 (30806 days)
# 	Serum_sodium_24                                            136.66         at age 85 (30895 days)
# 	All_Antiplatelets                                          nan            at age 85 (30956 days)
# 	Basophil_count_22                                          0.14           at age 86 (31236 days)
# 	Serum_HDL_cholesterol_level_100                            1.27           at age 86 (31281 days)
#
# ...
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 48 (17684 days)
# 	Diastolic_blood_pressure_5                                 83.43          at age 49 (17743 days)
# 	Red_blood_cell__RBC__count_10                              -86.26         at age 49 (17746 days)
# 	O_E___weight_2                                             67.56          at age 49 (17769 days)
# 	LKA_PUSHAsthma                                             nan            at age 49 (17775 days)
# 	Statins                                                    nan            at age 49 (17826 days)
# 	Serum_urea_level_29                                        4.19           at age 49 (17912 days)
# 	Serum_cholesterol_HDL_ratio_94                             2.08           at age 49 (17916 days)
# 	Serum_HDL_cholesterol_level_100                            1.11           at age 49 (17963 days)
# 	all_contraceptive                                          nan            at age 49 (18059 days)
#
# ------------------------------------ page break ------------------------------------
#
#
# After the diagnosis of type2diabetes is then seen in the medical history
#
#
# Medical history of a
# 	black, female patient, born in 1974, with IMD (deprivation) level 4.
#
#
# 	Eosinophil_count_21                                        0.10           at age 34 (12311 days)
# 	Haematocrit_15                                             0.36           at age 34 (12311 days)
# 	Haemoglobin_estimation_9                                   12.20          at age 34 (12311 days)
# 	Lymphocyte_count_20                                        1.80           at age 34 (12311 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             33.50          at age 34 (12311 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           30.00          at age 34 (12311 days)
# 	Mean_corpuscular_volume__MCV__11                           89.60          at age 34 (12311 days)
# 	Monocyte_count_23                                          0.40           at age 34 (12311 days)
# 	Neutrophil_count_19                                        3.20           at age 34 (12311 days)
# 	Platelet_count_12                                          230.07         at age 34 (12311 days)
# 	Red_blood_cell__RBC__count_10                              4.06           at age 34 (12311 days)
# 	Red_blood_cell_distribution_width_17                       nan            at age 34 (12311 days)
# 	Total_white_cell_count_18                                  5.40           at age 34 (12311 days)
# 	Diastolic_blood_pressure_5                                 73.00          at age 34 (12336 days)
# 	Systolic_blood_pressure_4                                  112.00         at age 34 (12336 days)
# 	Basophil_count_22                                          0.00           at age 34 (12401 days)
# 	Eosinophil_count_21                                        0.10           at age 34 (12401 days)
# 	Haematocrit_15                                             0.32           at age 34 (12401 days)
# 	Haemoglobin_estimation_9                                   11.00          at age 34 (12401 days)
# 	Lymphocyte_count_20                                        1.80           at age 34 (12401 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             34.70          at age 34 (12401 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           29.80          at age 34 (12401 days)
# 	Mean_corpuscular_volume__MCV__11                           85.70          at age 34 (12401 days)
# 	Monocyte_count_23                                          0.50           at age 34 (12401 days)
# 	Neutrophil_count_19                                        5.50           at age 34 (12401 days)
# 	Platelet_count_12                                          219.05         at age 34 (12401 days)
# 	Red_blood_cell__RBC__count_10                              3.70           at age 34 (12401 days)
# 	Red_blood_cell_distribution_width_17                       nan            at age 34 (12401 days)
# 	Serum_TSH_level_71                                         0.92           at age 34 (12401 days)
# 	Total_white_cell_count_18                                  7.90           at age 34 (12401 days)
# 	Diastolic_blood_pressure_5                                 79.00          at age 34 (12441 days)
# 	Systolic_blood_pressure_4                                  121.00         at age 34 (12441 days)
# 	Basophil_count_22                                          0.00           at age 34 (12442 days)
# 	Eosinophil_count_21                                        0.10           at age 34 (12442 days)
# 	Haematocrit_15                                             0.35           at age 34 (12442 days)
# 	Haemoglobin_estimation_9                                   12.30          at age 34 (12442 days)
# 	Lymphocyte_count_20                                        1.50           at age 34 (12442 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             35.20          at age 34 (12442 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           31.00          at age 34 (12442 days)
# 	Mean_corpuscular_volume__MCV__11                           88.20          at age 34 (12442 days)
# 	Monocyte_count_23                                          0.40           at age 34 (12442 days)
# 	Neutrophil_count_19                                        4.50           at age 34 (12442 days)
# 	Platelet_count_12                                          213.98         at age 34 (12442 days)
# 	Red_blood_cell__RBC__count_10                              3.96           at age 34 (12442 days)
# 	Red_blood_cell_distribution_width_17                       nan            at age 34 (12442 days)
# 	Total_white_cell_count_18                                  6.40           at age 34 (12442 days)
# 	Diastolic_blood_pressure_5                                 90.00          at age 34 (12448 days)
# 	Systolic_blood_pressure_4                                  130.00         at age 34 (12448 days)
# 	Insulin_Aurum_v2                                           nan            at age 34 (12449 days)
# 	Diastolic_blood_pressure_5                                 78.00          at age 34 (12476 days)
# 	Systolic_blood_pressure_4                                  111.00         at age 34 (12476 days)
# 	Insulin_Aurum_v2                                           nan            at age 34 (12476 days)
# 	Diastolic_blood_pressure_5                                 74.00          at age 34 (12483 days)
# 	Systolic_blood_pressure_4                                  123.00         at age 34 (12483 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 34 (12511 days)
# 	Weak_Opioids_Final                                         nan            at age 34 (12511 days)
# 	Body_mass_index_3                                          37.20          at age 43 (15667 days)
# 	Diastolic_blood_pressure_5                                 112.00         at age 43 (15667 days)
# 	Diastolic_blood_pressure_5                                 119.00         at age 43 (15667 days)
# 	Never_smoked_tobacco_85                                    nan            at age 43 (15667 days)
# 	O_E___weight_2                                             96.50          at age 43 (15667 days)
# 	Systolic_blood_pressure_4                                  164.00         at age 43 (15667 days)
# 	Systolic_blood_pressure_4                                  171.00         at age 43 (15667 days)
# 	Calculated_LDL_cholesterol_level_103                       3.50           at age 43 (15674 days)
# 	Eosinophil_count_21                                        0.10           at age 43 (15674 days)
# 	GFR_calculated_abbreviated_MDRD_34                         60.00          at age 43 (15674 days)
# 	Haemoglobin_A1c_level___IFCC_standardised_6                90.00          at age 43 (15674 days)
# 	Haemoglobin_estimation_9                                   126.00         at age 43 (15674 days)
# 	Lymphocyte_count_20                                        2.20           at age 43 (15674 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             327.00         at age 43 (15674 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           28.00          at age 43 (15674 days)
# 	Mean_corpuscular_volume__MCV__11                           85.50          at age 43 (15674 days)
# 	Monocyte_count_23                                          0.40           at age 43 (15674 days)
# 	Neutrophil_count_19                                        2.60           at age 43 (15674 days)
# 	Non_HDL_cholesterol_level_108                              3.90           at age 43 (15674 days)
# 	Platelet_count_12                                          217.85         at age 43 (15674 days)
# 	Red_blood_cell__RBC__count_10                              4.51           at age 43 (15674 days)
# 	Red_blood_cell_distribution_width_17                       14.60          at age 43 (15674 days)
# 	Serum_HDL_cholesterol_level_100                            1.50           at age 43 (15674 days)
# 	Serum_TSH_level_71                                         1.07           at age 43 (15674 days)
# 	Serum_alanine_aminotransferase_level_45                    21.00          at age 43 (15674 days)
# 	Serum_albumin_51                                           39.00          at age 43 (15674 days)
# 	Serum_alkaline_phosphatase_50                              83.00          at age 43 (15674 days)
# 	Serum_bilirubin_level_53                                   12.00          at age 43 (15674 days)
# 	Serum_cholesterol_97                                       5.40           at age 43 (15674 days)
# 	Serum_creatinine_31                                        64.00          at age 43 (15674 days)
# 	Serum_potassium_26                                         4.30           at age 43 (15674 days)
# 	Serum_sodium_24                                            136.00         at age 43 (15674 days)
# 	Serum_triglycerides_105                                    0.92           at age 43 (15674 days)
# 	Serum_urea_level_29                                        2.50           at age 43 (15674 days)
# 	Total_cholesterol_HDL_ratio_95                             3.60           at age 43 (15674 days)
# 	Total_white_cell_count_18                                  5.30           at age 43 (15674 days)
# 	Body_mass_index_3                                          36.65          at age 45 (16254 days)
# 	O_E___height_1                                             161.00         at age 45 (16254 days)
# 	O_E___weight_2                                             95.00          at age 45 (16254 days)
# 	Diastolic_blood_pressure_5                                 90.00          at age 45 (16319 days)
# 	Systolic_blood_pressure_4                                  140.00         at age 45 (16319 days)
# 	Calculated_LDL_cholesterol_level_103                       3.50           at age 45 (16320 days)
# 	Eosinophil_count_21                                        0.10           at age 45 (16320 days)
# 	GFR_calculated_abbreviated_MDRD_34                         90.00          at age 45 (16320 days)
# 	Haematocrit_15                                             0.40           at age 45 (16320 days)
# 	Haemoglobin_A1c_level___IFCC_standardised_6                101.00         at age 45 (16320 days)
# 	Haemoglobin_estimation_9                                   128.00         at age 45 (16320 days)
# 	Lymphocyte_count_20                                        1.80           at age 45 (16320 days)
# 	Mean_corpusc_Hb_conc__MCHC__14                             322.00         at age 45 (16320 days)
# 	Mean_corpusc_haemoglobin_MCH__13                           27.50          at age 45 (16320 days)
# 	Mean_corpuscular_volume__MCV__11                           85.30          at age 45 (16320 days)
# 	Monocyte_count_23                                          0.40           at age 45 (16320 days)
# 	Neutrophil_count_19                                        2.50           at age 45 (16320 days)
# 	Platelet_count_12                                          233.95         at age 45 (16320 days)
# 	Red_blood_cell__RBC__count_10                              4.66           at age 45 (16320 days)
# 	Red_blood_cell_distribution_width_17                       14.40          at age 45 (16320 days)
# 	Serum_HDL_cholesterol_level_100                            1.36           at age 45 (16320 days)
# 	Serum_TSH_level_71                                         0.74           at age 45 (16320 days)
# 	Serum_alanine_aminotransferase_level_45                    20.00          at age 45 (16320 days)
# 	Serum_albumin_51                                           38.00          at age 45 (16320 days)
# 	Serum_alkaline_phosphatase_50                              96.00          at age 45 (16320 days)
# 	Serum_bilirubin_level_53                                   10.00          at age 45 (16320 days)
# 	Serum_cholesterol_97                                       5.20           at age 45 (16320 days)
# 	Serum_creatinine_31                                        63.00          at age 45 (16320 days)
# 	Serum_ferritin_63                                          12.99          at age 45 (16320 days)
# 	Serum_potassium_26                                         4.50           at age 45 (16320 days)
# 	Serum_sodium_24                                            136.00         at age 45 (16320 days)
# 	Serum_triglycerides_105                                    0.90           at age 45 (16320 days)
# 	Serum_urea_level_29                                        2.70           at age 45 (16320 days)
# 	Total_white_cell_count_18                                  4.80           at age 45 (16320 days)
# 	TYPE2DIABETES                                              nan            at age 45 (16322 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	O_E___weight_2                                             38.20          at age 45 (16459 days)
# 	Serum_creatinine_31                                        229.67         at age 45 (16519 days)
# 	all_contraceptive                                          nan            at age 46 (16880 days)
# 	Serum_vitamin_B12_79                                       190.15         at age 47 (17008 days)
# 	Anticonvulsants_OPTIMAL                                    nan            at age 47 (17160 days)
# 	Haemoglobin_estimation_9                                   145.29         at age 47 (17215 days)
# 	Lymphocyte_count_20                                        3.35           at age 47 (17231 days)
# 	SNRIs_OPTIMAL                                              nan            at age 48 (17517 days)
# 	COCP_reg_contraception                                     nan            at age 49 (17738 days)
# 	Systolic_blood_pressure_4                                  134.78         at age 49 (17835 days)
# 	POP_reg_contraceptive                                      nan            at age 49 (17910 days)
# 	ACE_Inhibitors_D2T                                         nan            at age 49 (17919 days)
# 	Total_white_cell_count_18                                  33.22          at age 49 (17935 days)
# 	Statins                                                    nan            at age 49 (17985 days)
# 	Haemoglobin_estimation_9                                   121.25         at age 50 (18120 days)
# 	Serum_ferritin_63                                          -4685.64       at age 50 (18137 days)
# 	Levothyroxine_                                             nan            at age 50 (18171 days)
# 	LABA_PUSH_Asthma                                           nan            at age 50 (18285 days)
# 	ANXIETY                                                    nan            at age 50 (18335 days)
# 	Lymphocyte_count_20                                        5.53           at age 51 (18435 days)
#
# ----------------------------------------------------------------------------------------
# ------------------------------------ document break ------------------------------------
# ----------------------------------------------------------------------------------------

# %%
# dm.test_set.view_sample(10, max_dynamic_events=None, report_time=True)

# %% [markdown]
# # Appendix: model architectures

# %%
display(model)

# %%
# !jupyter nbconvert --to html --no-input 2_generation_fine_tune.ipynb
