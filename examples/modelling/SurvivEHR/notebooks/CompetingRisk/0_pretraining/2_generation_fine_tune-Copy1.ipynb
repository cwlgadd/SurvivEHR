# %% [markdown]
# # Demo Notebook:
# ## SurvivEHR: Competing Risk Survival Transformer For Causal Sequence Modelling
#
# In this notebook we demonstrate how a pre-trained model can be used for generation

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# !pwd

# %load_ext autoreload
# %autoreload 2
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# /rds/homes/g/gaddcz/Projects/CPRD/examples/modelling/SurvivEHR/notebooks/CompetingRisk/0_pretraining

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import logging
from pycox.evaluation import EvalSurv
from tqdm import tqdm
from hydra import compose, initialize
from omegaconf import OmegaConf
from CPRD.examples.modelling.SurvivEHR.run_experiment import run
from CPRD.src.models.survival.task_heads.causal import SurvStreamGPTForCausalModelling

from FastEHR.dataloader import FoundationalDataModule

torch.manual_seed(1337)
torch.set_float32_matmul_precision('medium')

logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")
# Out:
# Using device: cuda.

# %% [markdown]
# # Demo Version of SurvStreamGPT

# %% [markdown]
# ## Build configurations

# %%
# load the configuration file, override any settings 
with initialize(version_base=None, config_path="../../../confs", job_name="testing_notebook"):
    cfg = compose(config_name="config_CompetingRisk11M", 
                  overrides=["experiment.run_id='SurvivEHR-cr-small-v1'",
                             "experiment.train=False",
                             "experiment.test=False",
                             "data.path_to_ds=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/",
                             "optim.limit_test_batches=null"
                            ]
                 )     

cfg.data.min_workers = 12

# Just load in pretrained model
cfg.experiment.log = False

print(OmegaConf.to_yaml(cfg))

save_path = f"/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/{cfg.experiment.run_id}/"
# Out:
# is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: SurvivEHR
#   run_id: SurvivEHR-cr-small-v1
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: false
#   test: false
#   verbose: true
#   seed: 1337
#   log: false
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
#   fine_tune_outcomes: null
# fine_tuning:
#   custom_stratification_method:
#     _target_: null
#     tokens: null
#   head:
#     surv_weight: 1
#     value_weight: 0
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: null
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression: None
#   value_weight: 0.1

# %%
 # TODO: define an env variable to fix for a local hpc environment issue, this shouldn't be needed
# %env SLURM_NTASKS_PER_NODE=28      

model, dm_pretrain = run(cfg)     
print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
# Out:
# INFO:root:Running cr on 72 CPUs and 1 GPUs
# env: SLURM_NTASKS_PER_NODE=28
# INFO:root:====================================================================================================
# INFO:root:# Loading DataModule for dataset /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/. This will be loaded in causal form.
# INFO:root:====================================================================================================
# INFO:root:Creating unsupervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Set seed to 1337
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=train/ dataset, with 572,096 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=test/ dataset, with 35,758 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=val/ dataset, with 33,280 samples
# INFO:root:is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: SurvivEHR
#   run_id: SurvivEHR-cr-small-v1
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: false
#   test: false
#   verbose: true
#   seed: 1337
#   log: false
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
#   fine_tune_outcomes: null
# fine_tuning:
#   custom_stratification_method:
#     _target_: null
#     tokens: null
#   head:
#     surv_weight: 1
#     value_weight: 0
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: null
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression:
#   - 84
#   - 86
#   - 107
#   - 154
#   - 42
#   - 231
#   - 63
#   - 85
#   - 247
#   - 51
#   - 103
#   - 146
#   - 66
#   - 172
#   - 152
#   - 261
#   - 235
#   - 193
#   - 184
#   - 101
#   - 223
#   - 135
#   - 226
#   - 202
#   - 145
#   - 244
#   - 165
#   - 64
#   - 185
#   - 238
#   - 220
#   - 232
#   - 240
#   - 237
#   - 17
#   - 239
#   - 217
#   - 118
#   - 219
#   - 251
#   - 25
#   - 150
#   - 111
#   - 102
#   - 15
#   - 110
#   - 130
#   - 128
#   - 122
#   - 99
#   - 77
#   - 96
#   - 140
#   - 50
#   - 80
#   - 108
#   - 138
#   - 27
#   - 139
#   - 125
#   - 117
#   - 105
#   - 109
#   - 243
#   - 236
#   - 208
#   - 98
#   - 176
#   - 209
#   - 194
#   - 61
#   - 73
#   - 214
#   - 206
#   - 229
#   - 225
#   - 183
#   - 186
#   - 215
#   - 187
#   - 248
#   - 179
#   - 163
#   - 180
#   - 181
#   - 153
#   - 245
#   - 54
#   - 246
#   - 112
#   - 212
#   - 141
#   - 204
#   - 227
#   - 173
#   - 55
#   - 119
#   - 262
#   - 127
#   - 71
#   - 59
#   - 144
#   - 113
#   - 170
#   - 241
#   - 168
#   - 47
#   - 159
#   value_weight: 0.1
#
# INFO:root:====================================================================================================
# INFO:root:# Pre-training experiment
# INFO:root:====================================================================================================
# INFO:root:Loading a pre-trained model with the checkpoint path /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/SurvivEHR-cr-small-v1.ckpt.
# INFO:torch.distributed.nn.jit.instantiator:Created a temporary directory at /tmp/tmp34nm_37t
# INFO:torch.distributed.nn.jit.instantiator:Writing /tmp/tmp34nm_37t/_remote_module_non_scriptable.py
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using Competing-Risk DeSurv head.
# INFO:root:In generation forwarding DeSurv on the grid between [0.0, 1.0] with 1000 intervals
# INFO:root:Creating hidden state embedding callback
# INFO:root:Created Performance metric callback for causal self-supervised tasks.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Loaded model with 11.211302 M parameters
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:67: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %%
# Update dataset path to point to the new dataset 
cfg.data.path_to_ds = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/"

# Build 
dm = FoundationalDataModule(path_to_db=cfg.data.path_to_db,
                            path_to_ds=cfg.data.path_to_ds,
                            load=True,
                            tokenizer="tabular",
                            batch_size=cfg.data.batch_size,
                            max_seq_length=cfg.transformer.block_size,
                            freq_threshold=cfg.data.unk_freq_threshold,
                            min_workers=cfg.data.min_workers,
                            overwrite_meta_information=cfg.data.meta_information_path,
                           )

vocab_size = dm.train_set.tokenizer.vocab_size
print(f"{vocab_size} vocab elements")

# list of univariate measurements to model with Normal distribution
# Extract the measurements, using the fact that the diagnoses are all up upper case.
measurements_for_univariate_regression = [record for record in dm.tokenizer._event_counts["EVENT"] if record.upper() != record]
cfg.head.tokens_for_univariate_regression = dm.encode(measurements_for_univariate_regression) 
# display(measurements_for_univariate_regression)
# Out:
# INFO:root:Creating unsupervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=train/ dataset, with 572,096 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=test/ dataset, with 35,758 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=val/ dataset, with 33,280 samples
# 265 vocab elements

# %%
import pickle
with open("/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/practice_id_splits.pickle", 'rb') as f:
    splits = pickle.load(f)
type(splits["test"][0])
# Out:
# int

# %%
from FastEHR.database.collector import SQLiteDataCollector
collector = SQLiteDataCollector(cfg.data.path_to_db + "cprd.db")
collector.connect()
collector.disconnect()

# %% [markdown]
# Full example from the fine-tuning dataset. This includes all events up and including the index event, followed by the outcome or last seen event. This outcome/censoring event is not relevant to this notebook.

# %%
dm.train_set.view_sample(100, max_dynamic_events=None, report_time=True)

# for batch in dm.train_dataloader():
#     break
# print(batch.keys())
# Out:
# Time to retrieve sample index 100: 0.3054 seconds
#
# SEX                 | F
# IMD                 | 4.0
# ETHNICITY           | WHITE
# birth_year          | 1972.0
# Sequence of 256 events
#
# Token                                                                       | Age at event (days)         | Standardized value
# =============================================================================================================================
# Eosinophil_count_21                                                        | 12366                         | -0.46
# Haematocrit_15                                                             | 12366                         | -0.13
# Haemoglobin_estimation_9                                                   | 12366                         | -0.49
# Lymphocyte_count_20                                                        | 12366                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 12366                         | -0.46
# Mean_corpusc_haemoglobin_MCH__13                                           | 12366                         | -0.25
# Mean_corpuscular_volume__MCV__11                                           | 12366                         | -0.20
# Monocyte_count_23                                                          | 12366                         | -0.47
# Neutrophil_count_19                                                        | 12366                         | -0.42
# Platelet_count_12                                                          | 12366                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 12366                         | -0.49
# Serum_TSH_level_71                                                         | 12366                         | -0.50
# Serum_free_T4_level_75                                                     | 12366                         | -0.50
# Total_white_cell_count_18                                                  | 12366                         | -0.50
# All_Diuretics_D2T                                                          | 12415                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12415                         | nan
# Thiazide_Diuretics_v2                                                      | 12415                         | nan
# All_Diuretics_D2T                                                          | 12421                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12421                         | nan
# Thiazide_Diuretics_v2                                                      | 12421                         | nan
# All_Diuretics_D2T                                                          | 12557                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12557                         | nan
# Thiazide_Diuretics_v2                                                      | 12557                         | nan
# Diastolic_blood_pressure_5                                                 | 12598                         | -0.34
# Systolic_blood_pressure_4                                                  | 12598                         | -0.18
# All_Diuretics_D2T                                                          | 12633                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12633                         | nan
# Thiazide_Diuretics_v2                                                      | 12633                         | nan
# All_Diuretics_D2T                                                          | 12695                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12695                         | nan
# Thiazide_Diuretics_v2                                                      | 12695                         | nan
# Serum_TSH_level_71                                                         | 12722                         | -0.50
# Serum_free_T4_level_75                                                     | 12722                         | -0.50
# NSAIDS_oral_OPTIMAL_final                                                  | 12724                         | nan
# All_Diuretics_D2T                                                          | 12760                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12760                         | nan
# Thiazide_Diuretics_v2                                                      | 12760                         | nan
# SABA_PUSHAsthma                                                            | 12777                         | nan
# All_Diuretics_D2T                                                          | 12787                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12787                         | nan
# First_gen_H1_antihistamines                                                | 12787                         | nan
# SABA_PUSHAsthma                                                            | 12787                         | nan
# Thiazide_Diuretics_v2                                                      | 12787                         | nan
# Body_mass_index_3                                                          | 12854                         | -0.19
# Diastolic_blood_pressure_5                                                 | 12854                         | -0.28
# O_E___weight_2                                                             | 12854                         | -0.32
# Systolic_blood_pressure_4                                                  | 12854                         | -0.13
# Body_mass_index_3                                                          | 12862                         | -0.19
# Diastolic_blood_pressure_5                                                 | 12862                         | -0.32
# O_E___height_1                                                             | 12862                         | 0.06
# O_E___weight_2                                                             | 12862                         | -0.32
# Systolic_blood_pressure_4                                                  | 12862                         | -0.18
# All_Diuretics_D2T                                                          | 12870                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12870                         | nan
# Thiazide_Diuretics_v2                                                      | 12870                         | nan
# All_Diuretics_D2T                                                          | 12941                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 12941                         | nan
# Thiazide_Diuretics_v2                                                      | 12941                         | nan
# All_Diuretics_D2T                                                          | 13011                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13011                         | nan
# Thiazide_Diuretics_v2                                                      | 13011                         | nan
# All_Diuretics_D2T                                                          | 13075                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13075                         | nan
# Thiazide_Diuretics_v2                                                      | 13075                         | nan
# All_Diuretics_D2T                                                          | 13134                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13134                         | nan
# Thiazide_Diuretics_v2                                                      | 13134                         | nan
# All_Diuretics_D2T                                                          | 13249                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13249                         | nan
# Thiazide_Diuretics_v2                                                      | 13249                         | nan
# All_Diuretics_D2T                                                          | 13302                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13302                         | nan
# Thiazide_Diuretics_v2                                                      | 13302                         | nan
# All_Diuretics_D2T                                                          | 13380                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13380                         | nan
# Thiazide_Diuretics_v2                                                      | 13380                         | nan
# Body_mass_index_3                                                          | 13402                         | -0.15
# Diastolic_blood_pressure_5                                                 | 13402                         | -0.32
# O_E___height_1                                                             | 13402                         | 0.06
# O_E___weight_2                                                             | 13402                         | -0.30
# Systolic_blood_pressure_4                                                  | 13402                         | -0.18
# All_Diuretics_D2T                                                          | 13449                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13449                         | nan
# Thiazide_Diuretics_v2                                                      | 13449                         | nan
# Diastolic_blood_pressure_5                                                 | 13456                         | -0.34
# Systolic_blood_pressure_4                                                  | 13456                         | -0.20
# SABA_PUSHAsthma                                                            | 13456                         | nan
# All_Diuretics_D2T                                                          | 13530                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13530                         | nan
# SABA_PUSHAsthma                                                            | 13530                         | nan
# Thiazide_Diuretics_v2                                                      | 13530                         | nan
# All_Diuretics_D2T                                                          | 13628                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13628                         | nan
# Thiazide_Diuretics_v2                                                      | 13628                         | nan
# All_Diuretics_D2T                                                          | 13705                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13705                         | nan
# Thiazide_Diuretics_v2                                                      | 13705                         | nan
# Diastolic_blood_pressure_5                                                 | 13719                         | -0.31
# Systolic_blood_pressure_4                                                  | 13719                         | -0.13
# All_Diuretics_D2T                                                          | 13800                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13800                         | nan
# Thiazide_Diuretics_v2                                                      | 13800                         | nan
# Diastolic_blood_pressure_5                                                 | 13816                         | -0.29
# Systolic_blood_pressure_4                                                  | 13816                         | -0.09
# NSAIDS_oral_OPTIMAL_final                                                  | 13816                         | nan
# Weak_Opioids_Final                                                         | 13816                         | nan
# All_Diuretics_D2T                                                          | 13877                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13877                         | nan
# Thiazide_Diuretics_v2                                                      | 13877                         | nan
# All_Diuretics_D2T                                                          | 13940                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 13940                         | nan
# Thiazide_Diuretics_v2                                                      | 13940                         | nan
# Diastolic_blood_pressure_5                                                 | 13946                         | -0.32
# Systolic_blood_pressure_4                                                  | 13946                         | -0.12
# Basophil_count_22                                                          | 13971                         | -0.49
# Diastolic_blood_pressure_5                                                 | 13971                         | -0.32
# Diastolic_blood_pressure_5                                                 | 13971                         | -0.26
# Eosinophil_count_21                                                        | 13971                         | -0.46
# GFR_calculated_abbreviated_MDRD_34                                         | 13971                         | -0.19
# Haematocrit_15                                                             | 13971                         | -0.13
# Haemoglobin_estimation_9                                                   | 13971                         | -0.49
# Lymphocyte_count_20                                                        | 13971                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 13971                         | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 13971                         | -0.26
# Mean_corpuscular_volume__MCV__11                                           | 13971                         | -0.22
# Monocyte_count_23                                                          | 13971                         | -0.48
# Neutrophil_count_19                                                        | 13971                         | -0.42
# Platelet_count_12                                                          | 13971                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 13971                         | -0.49
# Serum_HDL_cholesterol_level_100                                            | 13971                         | -0.18
# Serum_LDL_cholesterol_level_102                                            | 13971                         | -0.39
# Serum_TSH_level_71                                                         | 13971                         | -0.50
# Serum_albumin_51                                                           | 13971                         | -0.29
# Serum_alkaline_phosphatase_50                                              | 13971                         | -0.50
# Serum_cholesterol_97                                                       | 13971                         | -0.42
# Serum_creatinine_31                                                        | 13971                         | -0.49
# Serum_free_T4_level_75                                                     | 13971                         | -0.50
# Serum_gamma_glutamyl_transferase_level_57                                  | 13971                         | -0.05
# Serum_potassium_26                                                         | 13971                         | -0.07
# Serum_sodium_24                                                            | 13971                         | -0.05
# Serum_total_bilirubin_level_56                                             | 13971                         | -0.49
# Serum_triglycerides_105                                                    | 13971                         | -0.48
# Serum_urea_level_29                                                        | 13971                         | -0.14
# Systolic_blood_pressure_4                                                  | 13971                         | -0.18
# Systolic_blood_pressure_4                                                  | 13971                         | -0.11
# Total_white_cell_count_18                                                  | 13971                         | -0.50
# All_Diuretics_D2T                                                          | 14013                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14013                         | nan
# Thiazide_Diuretics_v2                                                      | 14013                         | nan
# All_Diuretics_D2T                                                          | 14062                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14062                         | nan
# Thiazide_Diuretics_v2                                                      | 14062                         | nan
# Diastolic_blood_pressure_5                                                 | 14124                         | -0.29
# Systolic_blood_pressure_4                                                  | 14124                         | -0.18
# All_Diuretics_D2T                                                          | 14157                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14157                         | nan
# Thiazide_Diuretics_v2                                                      | 14157                         | nan
# Body_mass_index_3                                                          | 14174                         | -0.14
# Current_smoker_83                                                          | 14174                         | -0.38
# Diastolic_blood_pressure_5                                                 | 14174                         | -0.30
# O_E___height_1                                                             | 14174                         | 0.08
# O_E___weight_2                                                             | 14174                         | -0.29
# Systolic_blood_pressure_4                                                  | 14174                         | -0.13
# Total_cholesterol_HDL_ratio_95                                             | 14174                         | -0.49
# SABA_PUSHAsthma                                                            | 14174                         | nan
# Diastolic_blood_pressure_5                                                 | 14185                         | -0.32
# Systolic_blood_pressure_4                                                  | 14185                         | -0.19
# Total_cholesterol_HDL_ratio_95                                             | 14185                         | -0.49
# All_Diuretics_D2T                                                          | 14227                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14227                         | nan
# Thiazide_Diuretics_v2                                                      | 14227                         | nan
# Diastolic_blood_pressure_5                                                 | 14237                         | -0.29
# Systolic_blood_pressure_4                                                  | 14237                         | -0.17
# Diastolic_blood_pressure_5                                                 | 14244                         | -0.32
# Systolic_blood_pressure_4                                                  | 14244                         | -0.15
# Diastolic_blood_pressure_5                                                 | 14257                         | -0.33
# Systolic_blood_pressure_4                                                  | 14257                         | -0.15
# Total_cholesterol_HDL_ratio_95                                             | 14257                         | -0.49
# CalciumChannelBlck_D2T                                                     | 14257                         | nan
# Diastolic_blood_pressure_5                                                 | 14300                         | -0.34
# Systolic_blood_pressure_4                                                  | 14300                         | -0.18
# Total_cholesterol_HDL_ratio_95                                             | 14300                         | -0.49
# All_Diuretics_D2T                                                          | 14300                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14300                         | nan
# CalciumChannelBlck_D2T                                                     | 14300                         | nan
# Thiazide_Diuretics_v2                                                      | 14300                         | nan
# Current_smoker_83                                                          | 14314                         | -0.38
# Diastolic_blood_pressure_5                                                 | 14314                         | -0.34
# Systolic_blood_pressure_4                                                  | 14314                         | -0.19
# Total_cholesterol_HDL_ratio_95                                             | 14314                         | -0.49
# Weak_Opioids_Final                                                         | 14320                         | nan
# NSAIDS_oral_OPTIMAL_final                                                  | 14327                         | nan
# Weak_Opioids_Final                                                         | 14327                         | nan
# Body_mass_index_3                                                          | 14341                         | -0.14
# Current_smoker_83                                                          | 14341                         | -0.38
# Diastolic_blood_pressure_5                                                 | 14341                         | -0.32
# O_E___height_1                                                             | 14341                         | 0.08
# O_E___weight_2                                                             | 14341                         | -0.29
# Systolic_blood_pressure_4                                                  | 14341                         | -0.20
# Total_cholesterol_HDL_ratio_95                                             | 14341                         | -0.49
# All_Diuretics_D2T                                                          | 14369                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14369                         | nan
# CalciumChannelBlck_D2T                                                     | 14369                         | nan
# Thiazide_Diuretics_v2                                                      | 14369                         | nan
# Amitriptyline_optimal                                                      | 14404                         | nan
# Tricyclic_Antidepressants_final                                            | 14404                         | nan
# Weak_Opioids_Final                                                         | 14404                         | nan
# Diastolic_blood_pressure_5                                                 | 14416                         | -0.32
# Systolic_blood_pressure_4                                                  | 14416                         | -0.18
# Total_cholesterol_HDL_ratio_95                                             | 14416                         | -0.49
# All_Diuretics_D2T                                                          | 14437                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14437                         | nan
# CalciumChannelBlck_D2T                                                     | 14437                         | nan
# Thiazide_Diuretics_v2                                                      | 14437                         | nan
# Basophil_count_22                                                          | 14464                         | -0.48
# Eosinophil_count_21                                                        | 14464                         | -0.45
# GFR_calculated_abbreviated_MDRD_34                                         | 14464                         | -0.20
# Haematocrit_15                                                             | 14464                         | -0.12
# Haemoglobin_estimation_9                                                   | 14464                         | -0.49
# Lymphocyte_count_20                                                        | 14464                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 14464                         | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 14464                         | -0.26
# Mean_corpuscular_volume__MCV__11                                           | 14464                         | -0.22
# Monocyte_count_23                                                          | 14464                         | -0.47
# Neutrophil_count_19                                                        | 14464                         | -0.41
# Platelet_count_12                                                          | 14464                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 14464                         | -0.49
# Serum_creatinine_31                                                        | 14464                         | -0.50
# Serum_potassium_26                                                         | 14464                         | -0.02
# Serum_sodium_24                                                            | 14464                         | -0.04
# Serum_urea_level_29                                                        | 14464                         | -0.16
# Total_white_cell_count_18                                                  | 14464                         | -0.50
# All_Diuretics_D2T                                                          | 14471                         | nan
# All_Diuretics_ExclLactones_D2T                                             | 14471                         | nan
# CalciumChannelBlck_D2T                                                     | 14471                         | nan
# SABA_PUSHAsthma                                                            | 14471                         | nan
# Thiazide_Diuretics_v2                                                      | 14471                         | nan
# Basophil_count_22                                                          | 14492                         | -0.48
# Eosinophil_count_21                                                        | 14492                         | -0.46
# Haematocrit_15                                                             | 14492                         | -0.13
# Haemoglobin_A1c_level___IFCC_standardised_6                                | 14492                         | -0.33
# Haemoglobin_A1c_level_8                                                    | 14492                         | nan
# Haemoglobin_estimation_9                                                   | 14492                         | -0.49
# HbA1c_level__DCCT_aligned__7                                               | 14492                         | -0.49
# Lymphocyte_count_20                                                        | 14492                         | -0.49
# Mean_corpusc_Hb_conc__MCHC__14                                             | 14492                         | -0.45
# Mean_corpusc_haemoglobin_MCH__13                                           | 14492                         | -0.26
# Mean_corpuscular_volume__MCV__11                                           | 14492                         | -0.23
# Monocyte_count_23                                                          | 14492                         | -0.48
# Neutrophil_count_19                                                        | 14492                         | -0.43
# Platelet_count_12                                                          | 14492                         | -0.50
# Red_blood_cell__RBC__count_10                                              | 14492                         | -0.49
# Serum_ferritin_63                                                          | 14492                         | -0.50
# Total_white_cell_count_18                                                  | 14492                         | -0.50
# TYPE2DIABETES                                                              | 14500                         | nan
# Serum_urea_level_29                                                        | 17321                         | 0.05
# =============================================================================================================================

# %% [markdown]
# # Generation from real prompts

# %%
# Utility function

# define encoding functions (TODO: add this wrap to datamodule
encode_prompt = lambda prompt_list: torch.from_numpy(np.array(dm.encode(prompt_list)).reshape((1,-1))).to(device)
encode_value = lambda prompt_list, value_list: torch.tensor(np.array([dm.standardise(_cat, _val) for _cat, _val in zip(prompt_list, value_list) ]).reshape((1,-1)), dtype=torch.float32).to(device)
encode_age = lambda age_list: torch.tensor([365 * _age for _age in age_list], dtype=torch.int64).reshape((1,-1)).to(device)

def table(_tokens,_ages,_values):
    # print table rows 
    assert _tokens.shape[0] == 1
    assert _ages.shape[0] == 1
    assert _values.shape[0] == 1
    
    for _idx, (_cat, _age, _value) in enumerate(zip(dm.decode(_tokens[0].tolist()).split(" "), 
                                                    _ages[0, :], 
                                                    _values[0, :]
                                                    )
                                                ):
        _value = dm.unstandardise(_cat, _value)
        print(f"\t{_cat}".ljust(60) + f"{_value:.02f}".ljust(15) + f"at age {_age/365:.0f} ({int(_age)} days)")    # with value {_value}


indexing_token_to_pivot_on = dm.encode(["TYPE2DIABETES"])[0]
stop_token =  dm.encode(["DEATH"])[0]

# %% [markdown]
# For a number of patients, split by a `document break`,
# 1) take the context before the index event day and predict what will be the subsequent series of events
# 2) take the context up to and including the index event day, and predict what will be the subsequent series of events
#
# We can then observe how the index event correlated with future time-series predictions

# %%
for idx_sample, sample in enumerate(dm.test_set):

    # Get the sample
    # sample = dm.test_set[_patient_idx]
    _index = (sample["tokens"] == indexing_token_to_pivot_on).nonzero(as_tuple=True)[0].item()

    # chunk by day
    _day_at_index = int(sample["ages"][_index])
    _index_pre = sum(sample["ages"] < _day_at_index)
    _index_inc = sum(sample["ages"] <= _day_at_index)
    
    for _phase, _split_at in enumerate([_index_pre, _index_inc]):

        if _phase == 0:
            print(f"\n\nBefore {dm.decode([indexing_token_to_pivot_on]).lower()} is seen in the medical history")
        else:
            print('\n------------------------------------ page break ------------------------------------')
            print(f"\n\nAfter the diagnosis of {dm.decode([indexing_token_to_pivot_on]).lower()} is then seen in the medical history")

        _covariates = sample["static_covariates"].reshape((1,-1))
        _tokens = sample["tokens"][:_split_at].reshape((1,-1))
        _ages = sample["ages"][:_split_at].reshape((1,-1))
        _values = sample["values"][:_split_at].reshape((1,-1))

        # Report the initial part of their historical context
        _dec_covariates = dm.train_set._decode_covariates(_covariates)
        print(f"\n\nMedical history of a \n\t" + \
                        f"{_dec_covariates['ETHNICITY'][0].lower()}, " + \
                        f"{'male' if _dec_covariates['SEX'][0] == 'M' else 'female'} patient, " + \
                        f"born in {int(_dec_covariates['birth_year'][0])}, " + \
                        f"with IMD (deprivation) level {int(_dec_covariates['IMD'][0])}. \n\n" 
              )
        table(_tokens, _ages * 1825, _values)

        
        # Predict the future and report
        new_tokens, new_ages, new_values = model.model.generate(_tokens.to(device), _ages.to(device), _values.to(device), _covariates.to(device), max_new_tokens=20, eos_token=stop_token)
        print(f"""\nSurvivEHR then predicts the next events to be:
               """)
        table(new_tokens[:, _tokens.shape[1]:].reshape((1,-1)), 
              new_ages[:, _tokens.shape[1]:].reshape((1,-1)) * 1825,
              new_values[:, _tokens.shape[1]:].reshape((1,-1))
             )

    print('\n----------------------------------------------------------------------------------------')
    print('------------------------------------ document break ------------------------------------')
    print('----------------------------------------------------------------------------------------')

    if idx_sample > 20:
        break
# Out:
# Before type2diabetes is seen in the medical history
#
#
# Medical history of a
# 	black, male patient, born in 1968, with IMD (deprivation) level 5.
#
#
# 	SUBSTANCEMISUSE                                            nan            at age 26 (9605 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	Ex_smoker_84                                               158.05         at age 26 (9605 days)
# 	Ex_smoker_84                                               -10.70         at age 26 (9605 days)
# 	Diastolic_blood_pressure_5                                 71.52          at age 26 (9605 days)
# 	Systolic_blood_pressure_4                                  116.83         at age 26 (9605 days)
# 	Anxiolytics_mumpredict                                     nan            at age 26 (9605 days)
# 	Benzodiazepines                                            nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SABA_PUSHAsthma                                            nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SABA_PUSHAsthma                                            nan            at age 26 (9605 days)
# 	ICS_PUSHAsthma                                             nan            at age 26 (9605 days)
# 	SABA_PUSHAsthma                                            nan            at age 26 (9605 days)
# 	Basophil_count_22                                          0.07           at age 26 (9605 days)
# 	Eosinophil_count_21                                        0.88           at age 26 (9605 days)
# 	Free_T4_level_76                                           20.96          at age 26 (9605 days)
# 	Serum_albumin_51                                           44.24          at age 26 (9605 days)
# 	Serum_creatinine_31                                        78.63          at age 26 (9605 days)
# 	Serum_potassium_26                                         4.13           at age 26 (9605 days)
#
# ------------------------------------ page break ------------------------------------
#
#
# After the diagnosis of type2diabetes is then seen in the medical history
#
#
# Medical history of a
# 	black, male patient, born in 1968, with IMD (deprivation) level 5.
#
#
# 	SUBSTANCEMISUSE                                            nan            at age 26 (9605 days)
#
# SurvivEHR then predicts the next events to be:
#
# 	DEPRESSION                                                 nan            at age 26 (9605 days)
# 	Body_mass_index_3                                          28.63          at age 26 (9605 days)
# 	HbA1c_level__DCCT_aligned__7                               12.65          at age 26 (9605 days)
# 	Diastolic_blood_pressure_5                                 73.71          at age 26 (9605 days)
# 	Never_smoked_tobacco_85                                    0.00           at age 26 (9605 days)
# 	O_E___height_1                                             182.12         at age 26 (9605 days)
# 	O_E___weight_2                                             94.42          at age 26 (9605 days)
# 	Systolic_blood_pressure_4                                  128.69         at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SNRIs_OPTIMAL                                              nan            at age 26 (9605 days)
# 	Ex_smoker_84                                               67.23          at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	Weak_Opioids_Final                                         nan            at age 26 (9605 days)
# 	Anxiolytics_mumpredict                                     nan            at age 26 (9605 days)
# 	Benzodiazepines                                            nan            at age 26 (9605 days)
# 	SSRIs_Optimal                                              nan            at age 26 (9605 days)
# 	NSAIDS_oral_OPTIMAL_final                                  nan            at age 26 (9605 days)
# 	ANXIETY                                                    nan            at age 26 (9605 days)
#
# ----------------------------------------------------------------------------------------
# ------------------------------------ document break ------------------------------------
# ----------------------------------------------------------------------------------------
#
#
# Before type2diabetes is seen in the medical history
#
#
# Medical history of a
# 	white, female patient, born in 1965, with IMD (deprivation) level 5.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [33], line 37
#      33 table(_tokens, _ages * 1825, _values)
#      36 # Predict the future and report
# ---> 37 new_tokens, new_ages, new_values = model.model.generate(_tokens.to(device), _ages.to(device), _values.to(device), _covariates.to(device), max_new_tokens=20, eos_token=stop_token)
#      38 print(f"""\nSurvivEHR then predicts the next events to be:
#      39        """)
#      40 table(new_tokens[:, _tokens.shape[1]:].reshape((1,-1)),
#      41       new_ages[:, _tokens.shape[1]:].reshape((1,-1)) * 1825,
#      42       new_values[:, _tokens.shape[1]:].reshape((1,-1))
#      43      )
#
# File ~/Projects/CPRD/src/models/survival/task_heads/causal.py:170, in SurvStreamGPTForCausalModelling.generate(self, tokens, ages, values, static_covariates, eos_token, max_new_tokens, **kwargs)
#     167 values_window = values[:, -self.block_size:]
#     169 # get the predictions
# --> 170 outputs, _, _ = self(tokens=tokens_window,
#     171                      ages=ages_window,
#     172                      values=values_window,
#     173                      covariates=static_covariates,
#     174                      is_generation=True,
#     175                      return_generation=True,
#     176                      return_loss=False,
#     177                     )
#     179 # sample survival
#     180 surv = outputs["surv"]["surv_CDF"]
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch/2.0.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Projects/CPRD/src/models/survival/task_heads/causal.py:111, in SurvStreamGPTForCausalModelling.forward(self, tokens, ages, values, covariates, attention_mask, is_generation, return_generation, return_loss)
#     104 hidden_states = self.transformer(tokens=tokens,
#     105                                  ages=ages,
#     106                                  values=values,
#     107                                  covariates=covariates,
#     108                                  attention_mask=attention_mask)  # shape: (bsz, seq_len, n_embd)
#     110 # survival time to event head (survival curve until next token)
# --> 111 surv_dict, losses_desurv = self.surv_layer.predict(hidden_states[:,:,:self.n_embd - self.n_embd_private],
#     112                                                    target_tokens=tokens,
#     113                                                    target_ages=ages,
#     114                                                    attention_mask=attention_mask,
#     115                                                    is_generation=is_generation,
#     116                                                    return_loss=return_loss,
#     117                                                    return_cdf=return_generation,
#     118                                                   )
#     120 # regression head (values of next token if applicable)
#     121 values_dist, loss_values = self.value_layer.predict(hidden_states[:,:, self.n_embd_private:],
#     122                                                     target_tokens=tokens,
#     123                                                     target_values=values,
#    (...)
#     127                                                     return_value_dist=return_generation,
#     128                                                     )
#
# File ~/Projects/CPRD/src/modules/head_layers/survival/competing_risk.py:97, in ODESurvCompetingRiskLayer.predict(self, hidden_states, target_tokens, target_ages, attention_mask, is_generation, return_cdf, return_loss)
#      90     surv ={"k": [k],
#      91            "tte_deltas": tte_deltas,
#      92            "surv_CDF": preds,
#      93            "surv_pi": pis}
#      95 else:
#      96     # inference-time mini-optimization: only forward the head on the very last position
# ---> 97     in_hidden_state = hidden_states[:, -1, :]                      # torch.Size([bsz, hid_dim])
#      99     if return_loss:
#     100         # Forward the last state. This will be used for few-shot training a clinical prediction model.
#     101         # Note: Padding doesn't matter as all the padded hidden_state values share the same value as the last observation's hidden state
#     102         assert target_tokens is not None
#
# IndexError: index -1 is out of bounds for dimension 1 with size 0

# %%
# dm.test_set.view_sample(10, max_dynamic_events=None, report_time=True)

# %% [markdown]
# # Appendix: model architectures

# %%
display(model)

# %%
# !jupyter nbconvert --to html --no-input 2_generation_fine_tune.ipynb
