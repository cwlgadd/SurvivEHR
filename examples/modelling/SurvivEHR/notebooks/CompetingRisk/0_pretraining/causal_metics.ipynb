# %% [markdown]
# # Causal evaluation of the pre-trained SurvivEHR foundation model

# %% [markdown]
# In this notebook we evaluate the ability of SurvivEHR to perform next-event prediction after pre-training.

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import wandb
from hydra import compose, initialize
import polars as pl
pl.Config.set_tbl_rows(10000)
# import pandas as pd
# pd.options.display.max_rows = 10000
import logging
logging.basicConfig(level=logging.INFO)
import torch
torch.manual_seed(1337)
torch.set_float32_matmul_precision('medium')

from FastEHR.dataloader.foundational_loader import FoundationalDataModule
from CPRD.examples.modelling.SurvivEHR.run_experiment import run
from CPRD.src.models.survival.task_heads.causal import SurvStreamGPTForCausalModelling

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}.")

 # TODO: define an env variable to fix for a local hpc environment issue, this shouldn't be needed
# %env SLURM_NTASKS_PER_NODE=28
# Out:
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# Using device: cuda.
# env: SLURM_NTASKS_PER_NODE=28

# %% [markdown]
# ## Choosing configurations
# The default configuration is for pre-training. Here we modify as necesssary
#
# Here we choose to load in the configuration for a small **pre-trained** 11.4M parameter model, named "CR_11M". We specfiy the `zero-shot` experiment type, which will lead to running a ```CausalExperiment```.
#
# We tell this experiment that no further training is needed. Additionally, we do choose to perform testing (true by default). As this is a supervised model, this tests the ability to predict the outcomes of interest. In this notebook, this is chosen to be those of the cohort study for predicting Cardiovascular Disease in a Type 2 Diabetes Mellitus population, and we add the folder containing this dataset to the configuration.
#
# ```Note: As this is a supervised dataset, we need to tell the DataModule that the last event observed is a target and must be stripped. This is done by passing a list of targets to the configuration, overriding the null default. This lets the DataModule know that it should process batches as supervised.```
#
# We set the number of workers to be appropriate for the number of CPUs available to reduce bottlenecking, and tell the experiment that we do not want to limit the number of testing batches. In addition, we specify where we want any checkpoints to be saved to avoid bloating the repository.

# %% [markdown]
# # Run small (11M) Competing-Risk model experiment
#
# ```
#
# ```

# %%
# pre_trained_model_ids = ['SurvivEHR-cr-small', 'SurvivEHR-cr-small-v1', 'SurvivEHR-cr', 'SurvivEHR-cr-v1', 'SurvivEHR-cr-v1-v1', 'SurvivEHR-cr-384', 'SurvivEHR-cr-384-v1', 'crPreTrain_small_1337',
                        # 'SurvivEHR-cr-small-192', "SurvivEHR-cr-small-192-v1"]


pre_trained_model, config_name = "SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1", "config_CompetingRisk11M"
# pre_trained_model, config_name = "SurvivEHR-cr-small-debug7_exp1000-v1-v4", "config_CompetingRisk11M"
# pre_trained_model, config_name = "SurvivEHR-cr-big-debug3_2_exp1000-v1", "config_CompetingRiskMOTOR"

print(pre_trained_model)
# Out:
# SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1

# %%
wandb.finish()

# load the configuration file, override any settings 
with initialize(version_base=None, config_path="../../../confs", job_name="causal_metric_testing_notebook"):
    cfg = compose(config_name=config_name, 
                  overrides=[# Experiment setup
                             "experiment.project_name='Evaluating pre-trained models'",
                             f"experiment.run_id='{pre_trained_model}'",
                             "experiment.train=False",
                             "experiment.test=True",
                             "data.batch_size=128",
                             "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                             "data.min_workers=12",
                             "optim.limit_test_batches=0.035",
                            ]
                 )     

model, dm = run(cfg)
print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")

wandb.finish()
# Out:
# INFO:root:Running cr on 72 CPUs and 1 GPUs
# INFO:root:====================================================================================================
# INFO:root:# Loading DataModule for dataset /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/. This will be loaded in causal form.
# INFO:root:====================================================================================================
# INFO:root:Creating unsupervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Set seed to 1337
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=train/ dataset, with 23,613,894 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=test/ dataset, with 1,508,320 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=val/ dataset, with 1,426,714 samples
# INFO:root:is_decoder: true
# data:
#   batch_size: 128
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: Evaluating pre-trained models
#   run_id: SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: false
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
# fine_tuning:
#   fine_tune_outcomes: null
#   custom_outcome_method:
#     _target_: null
#   custom_stratification_method:
#     _target_: null
#   use_callbacks:
#     hidden_embedding:
#       num_batches: 1
#       mask_static: false
#       mask_value: false
#     performance_metrics: true
#     rmst: false
#   head:
#     surv_weight: 1
#     value_weight: 0
#     learning_rate: 0.0005
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: 0.035
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression:
#   - 84
#   - 86
#   - 107
#   - 154
#   - 42
#   - 231
#   - 63
#   - 85
#   - 247
#   - 51
#   - 103
#   - 146
#   - 66
#   - 172
#   - 152
#   - 261
#   - 235
#   - 193
#   - 184
#   - 101
#   - 223
#   - 135
#   - 226
#   - 202
#   - 145
#   - 244
#   - 165
#   - 64
#   - 185
#   - 238
#   - 220
#   - 232
#   - 240
#   - 237
#   - 17
#   - 239
#   - 217
#   - 118
#   - 219
#   - 251
#   - 25
#   - 150
#   - 111
#   - 102
#   - 15
#   - 110
#   - 130
#   - 128
#   - 122
#   - 99
#   - 77
#   - 96
#   - 140
#   - 50
#   - 80
#   - 108
#   - 138
#   - 27
#   - 139
#   - 125
#   - 117
#   - 105
#   - 109
#   - 243
#   - 236
#   - 208
#   - 98
#   - 176
#   - 209
#   - 194
#   - 61
#   - 73
#   - 214
#   - 206
#   - 229
#   - 225
#   - 183
#   - 186
#   - 215
#   - 187
#   - 248
#   - 179
#   - 163
#   - 180
#   - 181
#   - 153
#   - 245
#   - 54
#   - 246
#   - 112
#   - 212
#   - 141
#   - 204
#   - 227
#   - 173
#   - 55
#   - 119
#   - 262
#   - 127
#   - 71
#   - 59
#   - 144
#   - 113
#   - 170
#   - 241
#   - 168
#   - 47
#   - 159
#   value_weight: 0.1
#
# INFO:root:====================================================================================================
# INFO:root:# Pre-training experiment
# INFO:root:====================================================================================================
# INFO:root:Loading a pre-trained model with the checkpoint path /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1.ckpt.
# INFO:torch.distributed.nn.jit.instantiator:Created a temporary directory at /tmp/tmpa0p1vxea
# INFO:torch.distributed.nn.jit.instantiator:Writing /tmp/tmpa0p1vxea/_remote_module_non_scriptable.py
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using a DeSurv Competing-Risk head.
# INFO:root:	With concurrent strategy=add_noise for handling simultaneous events.
# INFO:root:	Evaluating on a time grid between [0.0, 1.0] with 1000 intervals
# INFO:root:Created hidden state embedding callback
# INFO:root:Created PerformanceMetrics callback for causal self-supervised tasks.
# INFO:root:
# INFO:root:Interactive job = True
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:root:Testing model.
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: cwlgadd. Use `wandb login --relogin` to force relogin
# wandb version 0.21.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250715_162435-2qttxkwm</code>
# Syncing run <strong><a href="https://wandb.ai/cwlgadd/Evaluating%20pre-trained%20models/runs/2qttxkwm" target="_blank">SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1</a></strong> to <a href="https://wandb.ai/cwlgadd/Evaluating%20pre-trained%20models" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.trainer.connectors.signal_connector:SLURM auto-requeueing enabled. Setting signal handlers.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                   Test metric                   ┃                  DataLoader 0                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Test:+0_LookAheadMetricsprevalence_no_stratify  │               0.8549209927966827                │
# │    Test:+0_LookAheadMetricssurv_no_stratify     │               0.9867206756214528                │
# │ Test:+10_LookAheadMetricsprevalence_no_stratify │               0.8498032617479898                │
# │    Test:+10_LookAheadMetricssurv_no_stratify    │               0.8195837363045009                │
# │ Test:+13_LookAheadMetricsprevalence_no_stratify │                0.848335813082052                │
# │    Test:+13_LookAheadMetricssurv_no_stratify    │               0.7807488841130765                │
# │ Test:+16_LookAheadMetricsprevalence_no_stratify │               0.8504674233111297                │
# │    Test:+16_LookAheadMetricssurv_no_stratify    │               0.7705623374024421                │
# │ Test:+19_LookAheadMetricsprevalence_no_stratify │               0.8518284716003348                │
# │    Test:+19_LookAheadMetricssurv_no_stratify    │               0.7502532407475381                │
# │ Test:+1_LookAheadMetricsprevalence_no_stratify  │               0.8554057884602225                │
# │    Test:+1_LookAheadMetricssurv_no_stratify     │               0.9235438435297677                │
# │ Test:+2_LookAheadMetricsprevalence_no_stratify  │               0.8562878467821434                │
# │    Test:+2_LookAheadMetricssurv_no_stratify     │               0.9036353028748456                │
# │ Test:+3_LookAheadMetricsprevalence_no_stratify  │                0.856383584919344                │
# │    Test:+3_LookAheadMetricssurv_no_stratify     │               0.8843464116617102                │
# │ Test:+4_LookAheadMetricsprevalence_no_stratify  │               0.8553855002076877                │
# │    Test:+4_LookAheadMetricssurv_no_stratify     │               0.8586765504680968                │
# │ Test:+7_LookAheadMetricsprevalence_no_stratify  │               0.8501297603959204                │
# │    Test:+7_LookAheadMetricssurv_no_stratify     │               0.8083891604804155                │
# │    Test:CausalMetricsprevalence_no_stratify     │               0.8626828301681702                │
# │  Test:CausalMetricsprevalence_stratify_by_100   │                0.376425855513308                │
# │  Test:CausalMetricsprevalence_stratify_by_101   │               0.38022813688212925               │
# │  Test:CausalMetricsprevalence_stratify_by_104   │               0.3916349809885931                │
# │  Test:CausalMetricsprevalence_stratify_by_106   │               0.3992395437262359                │
# │  Test:CausalMetricsprevalence_stratify_by_107   │               0.4030418250950571                │
# │   Test:CausalMetricsprevalence_stratify_by_11   │               0.03802281368821293               │
# │  Test:CausalMetricsprevalence_stratify_by_110   │               0.41444866920152096               │
# │  Test:CausalMetricsprevalence_stratify_by_112   │               0.42205323193916355               │
# │  Test:CausalMetricsprevalence_stratify_by_113   │               0.4258555133079848                │
# │  Test:CausalMetricsprevalence_stratify_by_114   │               0.42965779467680604               │
# │  Test:CausalMetricsprevalence_stratify_by_115   │               0.43346007604562725               │
# │  Test:CausalMetricsprevalence_stratify_by_116   │               0.4372623574144487                │
# │  Test:CausalMetricsprevalence_stratify_by_118   │               0.4448669201520912                │
# │  Test:CausalMetricsprevalence_stratify_by_119   │               0.44866920152091183               │
# │  Test:CausalMetricsprevalence_stratify_by_120   │               0.45247148288973377               │
# │  Test:CausalMetricsprevalence_stratify_by_121   │               0.4562737642585551                │
# │  Test:CausalMetricsprevalence_stratify_by_123   │               0.4638783269961979                │
# │  Test:CausalMetricsprevalence_stratify_by_124   │               0.46768060836501907               │
# │  Test:CausalMetricsprevalence_stratify_by_126   │               0.4752851711026616                │
# │  Test:CausalMetricsprevalence_stratify_by_127   │                0.479087452471483                │
# │  Test:CausalMetricsprevalence_stratify_by_129   │               0.48669201520912553               │
# │  Test:CausalMetricsprevalence_stratify_by_130   │               0.49049429657794685               │
# │  Test:CausalMetricsprevalence_stratify_by_131   │               0.49429657794676896               │
# │  Test:CausalMetricsprevalence_stratify_by_133   │               0.5019011406844106                │
# │  Test:CausalMetricsprevalence_stratify_by_134   │               0.5057034220532319                │
# │  Test:CausalMetricsprevalence_stratify_by_135   │               0.5095057034220533                │
# │  Test:CausalMetricsprevalence_stratify_by_136   │               0.5133079847908741                │
# │  Test:CausalMetricsprevalence_stratify_by_141   │                0.532319391634981                │
# │  Test:CausalMetricsprevalence_stratify_by_142   │                0.536121673003802                │
# │  Test:CausalMetricsprevalence_stratify_by_143   │                0.539923954372624                │
# │  Test:CausalMetricsprevalence_stratify_by_144   │               0.5437262357414447                │
# │  Test:CausalMetricsprevalence_stratify_by_145   │               0.5475285171102662                │
# │  Test:CausalMetricsprevalence_stratify_by_146   │               0.5513307984790876                │
# │  Test:CausalMetricsprevalence_stratify_by_148   │               0.5589353612167296                │
# │  Test:CausalMetricsprevalence_stratify_by_149   │               0.5627376425855521                │
# │  Test:CausalMetricsprevalence_stratify_by_150   │               0.5665399239543727                │
# │  Test:CausalMetricsprevalence_stratify_by_151   │               0.5703422053231935                │
# │  Test:CausalMetricsprevalence_stratify_by_152   │               0.5741444866920152                │
# │  Test:CausalMetricsprevalence_stratify_by_153   │               0.5779467680608357                │
# │  Test:CausalMetricsprevalence_stratify_by_154   │               0.5817490494296573                │
# │  Test:CausalMetricsprevalence_stratify_by_155   │               0.5855513307984791                │
# │  Test:CausalMetricsprevalence_stratify_by_156   │               0.5893536121673008                │
# │  Test:CausalMetricsprevalence_stratify_by_157   │               0.5931558935361212                │
# │  Test:CausalMetricsprevalence_stratify_by_158   │               0.5969581749049425                │
# │  Test:CausalMetricsprevalence_stratify_by_159   │               0.6007604562737643                │
# │  Test:CausalMetricsprevalence_stratify_by_160   │               0.6045627376425854                │
# │  Test:CausalMetricsprevalence_stratify_by_161   │               0.6083650190114078                │
# │  Test:CausalMetricsprevalence_stratify_by_162   │               0.6121673003802284                │
# │  Test:CausalMetricsprevalence_stratify_by_163   │                0.615969581749049                │
# │  Test:CausalMetricsprevalence_stratify_by_164   │               0.6197718631178707                │
# │  Test:CausalMetricsprevalence_stratify_by_165   │               0.6235741444866912                │
# │  Test:CausalMetricsprevalence_stratify_by_166   │               0.6273764258555133                │
# │  Test:CausalMetricsprevalence_stratify_by_167   │               0.6311787072243358                │
# │  Test:CausalMetricsprevalence_stratify_by_168   │               0.6349809885931562                │
# │  Test:CausalMetricsprevalence_stratify_by_169   │               0.6387832699619767                │
# │  Test:CausalMetricsprevalence_stratify_by_170   │                0.642585551330798                │
# │  Test:CausalMetricsprevalence_stratify_by_171   │               0.6463878326996174                │
# │  Test:CausalMetricsprevalence_stratify_by_172   │               0.6501901140684417                │
# │  Test:CausalMetricsprevalence_stratify_by_173   │                0.653992395437262                │
# │  Test:CausalMetricsprevalence_stratify_by_174   │               0.6577946768060839                │
# │  Test:CausalMetricsprevalence_stratify_by_175   │               0.6615969581749045                │
# │  Test:CausalMetricsprevalence_stratify_by_176   │               0.6653992395437258                │
# │  Test:CausalMetricsprevalence_stratify_by_177   │               0.6692015209125464                │
# │  Test:CausalMetricsprevalence_stratify_by_178   │               0.6730038022813708                │
# │  Test:CausalMetricsprevalence_stratify_by_179   │               0.6768060836501868                │
# │  Test:CausalMetricsprevalence_stratify_by_180   │               0.6806083650190117                │
# │  Test:CausalMetricsprevalence_stratify_by_181   │               0.6844106463878322                │
# │  Test:CausalMetricsprevalence_stratify_by_182   │               0.6882129277566531                │
# │  Test:CausalMetricsprevalence_stratify_by_183   │               0.6920152091254733                │
# │  Test:CausalMetricsprevalence_stratify_by_184   │               0.6958174904942973                │
# │  Test:CausalMetricsprevalence_stratify_by_185   │               0.6996197718631177                │
# │  Test:CausalMetricsprevalence_stratify_by_186   │               0.7034220532319374                │
# │  Test:CausalMetricsprevalence_stratify_by_187   │               0.7072243346007637                │
# │  Test:CausalMetricsprevalence_stratify_by_188   │               0.7110266159695826                │
# │  Test:CausalMetricsprevalence_stratify_by_189   │               0.7148288973384025                │
# │  Test:CausalMetricsprevalence_stratify_by_190   │                0.718631178707225                │
# │  Test:CausalMetricsprevalence_stratify_by_191   │               0.7224334600760467                │
# │  Test:CausalMetricsprevalence_stratify_by_192   │               0.7262357414448671                │
# │  Test:CausalMetricsprevalence_stratify_by_193   │               0.7300380228136875                │
# │  Test:CausalMetricsprevalence_stratify_by_194   │               0.7338403041825081                │
# │  Test:CausalMetricsprevalence_stratify_by_195   │               0.7376425855513306                │
# │  Test:CausalMetricsprevalence_stratify_by_196   │               0.7414448669201497                │
# │  Test:CausalMetricsprevalence_stratify_by_197   │               0.7452471482889734                │
# │  Test:CausalMetricsprevalence_stratify_by_198   │               0.7490494296577949                │
# │  Test:CausalMetricsprevalence_stratify_by_199   │               0.7528517110266153                │
# │  Test:CausalMetricsprevalence_stratify_by_200   │               0.7566539923954361                │
# │  Test:CausalMetricsprevalence_stratify_by_201   │               0.7604562737642592                │
# │  Test:CausalMetricsprevalence_stratify_by_202   │                0.764258555133078                │
# │  Test:CausalMetricsprevalence_stratify_by_203   │               0.7680608365019019                │
# │  Test:CausalMetricsprevalence_stratify_by_204   │               0.7718631178707158                │
# │  Test:CausalMetricsprevalence_stratify_by_205   │               0.7756653992395429                │
# │  Test:CausalMetricsprevalence_stratify_by_206   │               0.7794676806083684                │
# │  Test:CausalMetricsprevalence_stratify_by_207   │               0.7832699619771852                │
# │  Test:CausalMetricsprevalence_stratify_by_208   │               0.7870722433460138                │
# │  Test:CausalMetricsprevalence_stratify_by_209   │                0.790874524714831                │
# │  Test:CausalMetricsprevalence_stratify_by_210   │                0.794676806083648                │
# │  Test:CausalMetricsprevalence_stratify_by_211   │               0.7984790874524759                │
# │  Test:CausalMetricsprevalence_stratify_by_212   │               0.8022813688212963                │
# │  Test:CausalMetricsprevalence_stratify_by_213   │               0.8060836501901127                │
# │  Test:CausalMetricsprevalence_stratify_by_214   │               0.8098859315589376                │
# │  Test:CausalMetricsprevalence_stratify_by_215   │               0.8136882129277554                │
# │  Test:CausalMetricsprevalence_stratify_by_216   │                0.817490494296578                │
# │  Test:CausalMetricsprevalence_stratify_by_217   │               0.8212927756654119                │
# │  Test:CausalMetricsprevalence_stratify_by_218   │               0.8250950570342191                │
# │  Test:CausalMetricsprevalence_stratify_by_219   │               0.8288973384030506                │
# │  Test:CausalMetricsprevalence_stratify_by_220   │               0.8326996197718595                │
# │  Test:CausalMetricsprevalence_stratify_by_221   │               0.8365019011406819                │
# │  Test:CausalMetricsprevalence_stratify_by_222   │               0.8403041825095002                │
# │  Test:CausalMetricsprevalence_stratify_by_223   │               0.8441064638783322                │
# │  Test:CausalMetricsprevalence_stratify_by_224   │               0.8479087452471428                │
# │  Test:CausalMetricsprevalence_stratify_by_225   │               0.8517110266159725                │
# │  Test:CausalMetricsprevalence_stratify_by_226   │               0.8555133079847834                │
# │  Test:CausalMetricsprevalence_stratify_by_227   │               0.8593155893536092                │
# │  Test:CausalMetricsprevalence_stratify_by_228   │               0.8631178707224335                │
# │  Test:CausalMetricsprevalence_stratify_by_229   │               0.8669201520912636                │
# │  Test:CausalMetricsprevalence_stratify_by_230   │               0.8707224334600675                │
# │  Test:CausalMetricsprevalence_stratify_by_231   │               0.8745247148289041                │
# │  Test:CausalMetricsprevalence_stratify_by_232   │               0.8783269961977118                │
# │  Test:CausalMetricsprevalence_stratify_by_233   │               0.8821292775665415                │
# │  Test:CausalMetricsprevalence_stratify_by_234   │               0.8859315589353532                │
# │  Test:CausalMetricsprevalence_stratify_by_235   │               0.8897338403041877                │
# │  Test:CausalMetricsprevalence_stratify_by_236   │               0.8935361216729947                │
# │  Test:CausalMetricsprevalence_stratify_by_237   │               0.8973384030418267                │
# │  Test:CausalMetricsprevalence_stratify_by_238   │                0.901140684410634                │
# │  Test:CausalMetricsprevalence_stratify_by_239   │               0.9049429657794688                │
# │  Test:CausalMetricsprevalence_stratify_by_240   │               0.9087452471482781                │
# │  Test:CausalMetricsprevalence_stratify_by_241   │               0.9125475285171163                │
# │  Test:CausalMetricsprevalence_stratify_by_242   │               0.9163498098859406                │
# │  Test:CausalMetricsprevalence_stratify_by_243   │               0.9201520912547497                │
# │  Test:CausalMetricsprevalence_stratify_by_244   │               0.9239543726235859                │
# │  Test:CausalMetricsprevalence_stratify_by_245   │               0.9277566539923905                │
# │  Test:CausalMetricsprevalence_stratify_by_246   │               0.9315589353612244                │
# │  Test:CausalMetricsprevalence_stratify_by_247   │               0.9353612167300316                │
# │  Test:CausalMetricsprevalence_stratify_by_248   │               0.9391634980988669                │
# │  Test:CausalMetricsprevalence_stratify_by_249   │               0.9429657794676789                │
# │   Test:CausalMetricsprevalence_stratify_by_25   │               0.09125475285171103               │
# │  Test:CausalMetricsprevalence_stratify_by_250   │               0.9467680608365009                │
# │  Test:CausalMetricsprevalence_stratify_by_251   │                0.950570342205312                │
# │  Test:CausalMetricsprevalence_stratify_by_252   │               0.9543726235741544                │
# │  Test:CausalMetricsprevalence_stratify_by_253   │               0.9581749049429705                │
# │  Test:CausalMetricsprevalence_stratify_by_254   │                0.961977186311795                │
# │  Test:CausalMetricsprevalence_stratify_by_255   │               0.9657794676806072                │
# │  Test:CausalMetricsprevalence_stratify_by_256   │               0.9695817490494358                │
# │  Test:CausalMetricsprevalence_stratify_by_257   │               0.9733840304182505                │
# │  Test:CausalMetricsprevalence_stratify_by_258   │               0.9771863117870777                │
# │  Test:CausalMetricsprevalence_stratify_by_259   │               0.9809885931558822                │
# │  Test:CausalMetricsprevalence_stratify_by_260   │                0.984790874524719                │
# │  Test:CausalMetricsprevalence_stratify_by_261   │               0.9885931558935528                │
# │  Test:CausalMetricsprevalence_stratify_by_262   │               0.9923954372623227                │
# │  Test:CausalMetricsprevalence_stratify_by_263   │               0.9961977186311591                │
# │  Test:CausalMetricsprevalence_stratify_by_264   │                       1.0                       │
# │   Test:CausalMetricsprevalence_stratify_by_27   │               0.09885931558935361               │
# │   Test:CausalMetricsprevalence_stratify_by_31   │               0.11406844106463879               │
# │   Test:CausalMetricsprevalence_stratify_by_34   │               0.12547528517110265               │
# │   Test:CausalMetricsprevalence_stratify_by_38   │               0.14068441064638784               │
# │   Test:CausalMetricsprevalence_stratify_by_39   │               0.1444866920152091                │
# │   Test:CausalMetricsprevalence_stratify_by_40   │               0.1482889733840304                │
# │   Test:CausalMetricsprevalence_stratify_by_41   │               0.1520912547528517                │
# │   Test:CausalMetricsprevalence_stratify_by_44   │               0.1634980988593156                │
# │   Test:CausalMetricsprevalence_stratify_by_47   │               0.17490494296577946               │
# │   Test:CausalMetricsprevalence_stratify_by_48   │               0.17870722433460076               │
# │   Test:CausalMetricsprevalence_stratify_by_51   │               0.19011406844106463               │
# │   Test:CausalMetricsprevalence_stratify_by_55   │               0.20532319391634982               │
# │   Test:CausalMetricsprevalence_stratify_by_57   │               0.21292775665399238               │
# │   Test:CausalMetricsprevalence_stratify_by_58   │               0.21673003802281368               │
# │   Test:CausalMetricsprevalence_stratify_by_60   │               0.22433460076045628               │
# │   Test:CausalMetricsprevalence_stratify_by_63   │               0.23574144486692014               │
# │   Test:CausalMetricsprevalence_stratify_by_65   │               0.24334600760456274               │
# │   Test:CausalMetricsprevalence_stratify_by_67   │               0.2509505703422053                │
# │   Test:CausalMetricsprevalence_stratify_by_70   │               0.2623574144486692                │
# │   Test:CausalMetricsprevalence_stratify_by_71   │               0.2661596958174905                │
# │   Test:CausalMetricsprevalence_stratify_by_75   │               0.2813688212927757                │
# │   Test:CausalMetricsprevalence_stratify_by_78   │               0.29277566539923955               │
# │   Test:CausalMetricsprevalence_stratify_by_79   │               0.2965779467680608                │
# │   Test:CausalMetricsprevalence_stratify_by_80   │               0.3003802281368821                │
# │   Test:CausalMetricsprevalence_stratify_by_81   │               0.3041825095057034                │
# │   Test:CausalMetricsprevalence_stratify_by_82   │               0.30798479087452474               │
# │   Test:CausalMetricsprevalence_stratify_by_83   │                0.311787072243346                │
# │   Test:CausalMetricsprevalence_stratify_by_84   │               0.3155893536121673                │
# │   Test:CausalMetricsprevalence_stratify_by_85   │               0.3193916349809886                │
# │   Test:CausalMetricsprevalence_stratify_by_89   │               0.33460076045627374               │
# │   Test:CausalMetricsprevalence_stratify_by_91   │               0.34220532319391633               │
# │   Test:CausalMetricsprevalence_stratify_by_93   │                0.349809885931559                │
# │   Test:CausalMetricsprevalence_stratify_by_94   │               0.3536121673003801                │
# │   Test:CausalMetricsprevalence_stratify_by_95   │               0.3574144486692015                │
# │   Test:CausalMetricsprevalence_stratify_by_97   │               0.3650190114068441                │
# │   Test:CausalMetricsprevalence_stratify_by_98   │               0.3688212927756655                │
# │   Test:CausalMetricsprevalence_stratify_by_99   │               0.3726235741444867                │
# │       Test:CausalMetricssurv_no_stratify        │               0.9937437419556212                │
# │     Test:CausalMetricssurv_stratify_by_100      │               0.9328263624841572                │
# │     Test:CausalMetricssurv_stratify_by_101      │               0.8922686945500633                │
# │     Test:CausalMetricssurv_stratify_by_104      │               0.8770595690747781                │
# │     Test:CausalMetricssurv_stratify_by_106      │               0.9211660329531052                │
# │     Test:CausalMetricssurv_stratify_by_107      │               0.8027566539923954                │
# │      Test:CausalMetricssurv_stratify_by_11      │               0.4296577946768061                │
# │     Test:CausalMetricssurv_stratify_by_110      │               0.8678707224334601                │
# │     Test:CausalMetricssurv_stratify_by_112      │               0.9497437592990579                │
# │     Test:CausalMetricssurv_stratify_by_113      │               0.9923954372623573                │
# │     Test:CausalMetricssurv_stratify_by_114      │               0.8929024081115334                │
# │     Test:CausalMetricssurv_stratify_by_115      │               0.9967046894803548                │
# │     Test:CausalMetricssurv_stratify_by_116      │                0.981596958174905                │
# │     Test:CausalMetricssurv_stratify_by_118      │               0.9893243638490786                │
# │     Test:CausalMetricssurv_stratify_by_119      │               0.9849809885931564                │
# │     Test:CausalMetricssurv_stratify_by_120      │               0.8821292775665399                │
# │     Test:CausalMetricssurv_stratify_by_121      │               0.9917617237008872                │
# │     Test:CausalMetricssurv_stratify_by_123      │               0.9677461649403437                │
# │     Test:CausalMetricssurv_stratify_by_124      │               0.9541825095057034                │
# │     Test:CausalMetricssurv_stratify_by_126      │               0.9237733116060111                │
# │     Test:CausalMetricssurv_stratify_by_127      │               0.9852661596958175                │
# │     Test:CausalMetricssurv_stratify_by_129      │               0.9346999504050258                │
# │     Test:CausalMetricssurv_stratify_by_130      │               0.9833650190114068                │
# │     Test:CausalMetricssurv_stratify_by_131      │               0.9921614507165838                │
# │     Test:CausalMetricssurv_stratify_by_133      │               0.9281187760275212                │
# │     Test:CausalMetricssurv_stratify_by_134      │               0.9524714828897338                │
# │     Test:CausalMetricssurv_stratify_by_135      │               0.9653569919729615                │
# │     Test:CausalMetricssurv_stratify_by_136      │               0.9593677775292625                │
# │     Test:CausalMetricssurv_stratify_by_141      │               0.8453738910012675                │
# │     Test:CausalMetricssurv_stratify_by_142      │               0.9854821984099551                │
# │     Test:CausalMetricssurv_stratify_by_143      │               0.9832353957829245                │
# │     Test:CausalMetricssurv_stratify_by_144      │                0.976948669201521                │
# │     Test:CausalMetricssurv_stratify_by_145      │                0.991128010139417                │
# │     Test:CausalMetricssurv_stratify_by_146      │               0.9460942388217742                │
# │     Test:CausalMetricssurv_stratify_by_148      │               0.9855119968532844                │
# │     Test:CausalMetricssurv_stratify_by_149      │               0.9925288506437197                │
# │     Test:CausalMetricssurv_stratify_by_150      │               0.9825095057034222                │
# │     Test:CausalMetricssurv_stratify_by_151      │               0.9995591557833252                │
# │     Test:CausalMetricssurv_stratify_by_152      │               0.9732377888271423                │
# │     Test:CausalMetricssurv_stratify_by_153      │               0.9986487760424853                │
# │     Test:CausalMetricssurv_stratify_by_154      │               0.9511026615969584                │
# │     Test:CausalMetricssurv_stratify_by_155      │               0.9834329168929928                │
# │     Test:CausalMetricssurv_stratify_by_156      │               0.9951166778498471                │
# │     Test:CausalMetricssurv_stratify_by_157      │               0.9821211876061808                │
# │     Test:CausalMetricssurv_stratify_by_158      │               0.9990307910236338                │
# │     Test:CausalMetricssurv_stratify_by_159      │               0.9901140684410645                │
# │     Test:CausalMetricssurv_stratify_by_160      │               0.9768241897519464                │
# │     Test:CausalMetricssurv_stratify_by_161      │                0.999061774727174                │
# │     Test:CausalMetricssurv_stratify_by_162      │                0.997465145754119                │
# │     Test:CausalMetricssurv_stratify_by_163      │               0.9855726520024168                │
# │     Test:CausalMetricssurv_stratify_by_164      │               0.9989993996397838                │
# │     Test:CausalMetricssurv_stratify_by_165      │                0.992980403626792                │
# │     Test:CausalMetricssurv_stratify_by_166      │               0.9961977186311787                │
# │     Test:CausalMetricssurv_stratify_by_167      │               0.9866724158206265                │
# │     Test:CausalMetricssurv_stratify_by_168      │                0.983979721166033                │
# │     Test:CausalMetricssurv_stratify_by_169      │               0.9908903675538657                │
# │     Test:CausalMetricssurv_stratify_by_170      │               0.9983590154092457                │
# │     Test:CausalMetricssurv_stratify_by_171      │               0.9806298873663832                │
# │     Test:CausalMetricssurv_stratify_by_172      │               0.9697261394811577                │
# │     Test:CausalMetricssurv_stratify_by_173      │               0.9975535709022318                │
# │     Test:CausalMetricssurv_stratify_by_174      │               0.9988049972840847                │
# │     Test:CausalMetricssurv_stratify_by_175      │               0.9948246725813266                │
# │     Test:CausalMetricssurv_stratify_by_176      │               0.9802844669764831                │
# │     Test:CausalMetricssurv_stratify_by_177      │               0.9892585551330798                │
# │     Test:CausalMetricssurv_stratify_by_178      │               0.9969420805922712                │
# │     Test:CausalMetricssurv_stratify_by_179      │               0.9899185990467524                │
# │     Test:CausalMetricssurv_stratify_by_180      │               0.9966956364294774                │
# │     Test:CausalMetricssurv_stratify_by_181      │               0.9932900917020803                │
# │     Test:CausalMetricssurv_stratify_by_182      │                0.987832699619772                │
# │     Test:CausalMetricssurv_stratify_by_183      │               0.9981692719335309                │
# │     Test:CausalMetricssurv_stratify_by_184      │                0.973384030418251                │
# │     Test:CausalMetricssurv_stratify_by_185      │               0.8547528517110266                │
# │     Test:CausalMetricssurv_stratify_by_186      │               0.9984132211610435                │
# │     Test:CausalMetricssurv_stratify_by_187      │                0.999461941315733                │
# │     Test:CausalMetricssurv_stratify_by_188      │               0.9964693101575237                │
# │     Test:CausalMetricssurv_stratify_by_189      │               0.9784072278229324                │
# │     Test:CausalMetricssurv_stratify_by_190      │               0.9961470215462611                │
# │     Test:CausalMetricssurv_stratify_by_191      │               0.9759611322348968                │
# │     Test:CausalMetricssurv_stratify_by_192      │               0.9783842908484824                │
# │     Test:CausalMetricssurv_stratify_by_193      │               0.9863661053775132                │
# │     Test:CausalMetricssurv_stratify_by_194      │               0.9970408331955696                │
# │     Test:CausalMetricssurv_stratify_by_195      │               0.9814448669201522                │
# │     Test:CausalMetricssurv_stratify_by_196      │               0.9906599561396593                │
# │     Test:CausalMetricssurv_stratify_by_197      │                0.956958174904943                │
# │     Test:CausalMetricssurv_stratify_by_198      │               0.9577524292353189                │
# │     Test:CausalMetricssurv_stratify_by_199      │               0.9922612390963991                │
# │     Test:CausalMetricssurv_stratify_by_200      │               0.9982245545674513                │
# │     Test:CausalMetricssurv_stratify_by_201      │                0.994858278603526                │
# │     Test:CausalMetricssurv_stratify_by_202      │               0.9913493947897128                │
# │     Test:CausalMetricssurv_stratify_by_203      │               0.9983100971694128                │
# │     Test:CausalMetricssurv_stratify_by_204      │               0.9996029263127497                │
# │     Test:CausalMetricssurv_stratify_by_205      │               0.9648952161994874                │
# │     Test:CausalMetricssurv_stratify_by_206      │               0.9942366995000157                │
# │     Test:CausalMetricssurv_stratify_by_207      │                0.985688635403462                │
# │     Test:CausalMetricssurv_stratify_by_208      │               0.9995291734139922                │
# │     Test:CausalMetricssurv_stratify_by_209      │               0.9923616892028702                │
# │     Test:CausalMetricssurv_stratify_by_210      │               0.9925424868180578                │
# │     Test:CausalMetricssurv_stratify_by_211      │               0.9972368514276264                │
# │     Test:CausalMetricssurv_stratify_by_212      │               0.9991564070274961                │
# │     Test:CausalMetricssurv_stratify_by_213      │               0.9883661540207707                │
# │     Test:CausalMetricssurv_stratify_by_214      │               0.9931270154497746                │
# │     Test:CausalMetricssurv_stratify_by_215      │               0.9970794070645278                │
# │     Test:CausalMetricssurv_stratify_by_216      │               0.9898803865652729                │
# │     Test:CausalMetricssurv_stratify_by_217      │               0.9915064362472099                │
# │     Test:CausalMetricssurv_stratify_by_218      │               0.9930337764702618                │
# │     Test:CausalMetricssurv_stratify_by_219      │               0.9939120372034155                │
# │     Test:CausalMetricssurv_stratify_by_220      │               0.9998353342714282                │
# │     Test:CausalMetricssurv_stratify_by_221      │               0.9956036121673006                │
# │     Test:CausalMetricssurv_stratify_by_222      │               0.9941364818891325                │
# │     Test:CausalMetricssurv_stratify_by_223      │               0.9890766356365515                │
# │     Test:CausalMetricssurv_stratify_by_224      │               0.9969247482555461                │
# │     Test:CausalMetricssurv_stratify_by_225      │               0.9998415716096323                │
# │     Test:CausalMetricssurv_stratify_by_226      │               0.9986880558086908                │
# │     Test:CausalMetricssurv_stratify_by_227      │               0.9993036519586167                │
# │     Test:CausalMetricssurv_stratify_by_228      │               0.9856735469853343                │
# │     Test:CausalMetricssurv_stratify_by_229      │                0.994151542471872                │
# │     Test:CausalMetricssurv_stratify_by_230      │               0.9952802527287474                │
# │     Test:CausalMetricssurv_stratify_by_231      │               0.9901623513790778                │
# │     Test:CausalMetricssurv_stratify_by_232      │               0.9996842173100458                │
# │     Test:CausalMetricssurv_stratify_by_233      │               0.9968424532980662                │
# │     Test:CausalMetricssurv_stratify_by_234      │               0.9921303379637305                │
# │     Test:CausalMetricssurv_stratify_by_235      │               0.9937738474958879                │
# │     Test:CausalMetricssurv_stratify_by_236      │               0.9984130171458924                │
# │     Test:CausalMetricssurv_stratify_by_237      │               0.9999805343957228                │
# │     Test:CausalMetricssurv_stratify_by_238      │               0.9996643147178625                │
# │     Test:CausalMetricssurv_stratify_by_239      │               0.9999036584112628                │
# │     Test:CausalMetricssurv_stratify_by_240      │               0.9929928497196516                │
# │     Test:CausalMetricssurv_stratify_by_241      │               0.9961917775665364                │
# │     Test:CausalMetricssurv_stratify_by_242      │               0.9921878891527023                │
# │     Test:CausalMetricssurv_stratify_by_243      │                0.999422053231939                │
# │     Test:CausalMetricssurv_stratify_by_244      │               0.9944577946768041                │
# │     Test:CausalMetricssurv_stratify_by_245      │               0.9985671549988804                │
# │     Test:CausalMetricssurv_stratify_by_246      │               0.9994715240696763                │
# │     Test:CausalMetricssurv_stratify_by_247      │               0.9899304178051865                │
# │     Test:CausalMetricssurv_stratify_by_248      │                0.998218119063318                │
# │     Test:CausalMetricssurv_stratify_by_249      │               0.9979592275139096                │
# │      Test:CausalMetricssurv_stratify_by_25      │               0.9277566539923955                │
# │     Test:CausalMetricssurv_stratify_by_250      │               0.9965069403087634                │
# │     Test:CausalMetricssurv_stratify_by_251      │               0.9945998985616248                │
# │     Test:CausalMetricssurv_stratify_by_252      │               0.9984328434898773                │
# │     Test:CausalMetricssurv_stratify_by_253      │               0.9988526449202855                │
# │     Test:CausalMetricssurv_stratify_by_254      │               0.9954979639668495                │
# │     Test:CausalMetricssurv_stratify_by_255      │               0.9872026072786521                │
# │     Test:CausalMetricssurv_stratify_by_256      │               0.9927304400261296                │
# │     Test:CausalMetricssurv_stratify_by_257      │                0.996928450229747                │
# │     Test:CausalMetricssurv_stratify_by_258      │               0.9999256883120099                │
# │     Test:CausalMetricssurv_stratify_by_259      │                0.997542205323191                │
# │     Test:CausalMetricssurv_stratify_by_260      │               0.9926642360737733                │
# │     Test:CausalMetricssurv_stratify_by_261      │               0.9962970221995711                │
# │     Test:CausalMetricssurv_stratify_by_262      │               0.9990845886146347                │
# │     Test:CausalMetricssurv_stratify_by_263      │                0.99977917056464                 │
# │     Test:CausalMetricssurv_stratify_by_264      │               0.9980138489597797                │
# │      Test:CausalMetricssurv_stratify_by_27      │               0.8136882129277566                │
# │      Test:CausalMetricssurv_stratify_by_31      │               0.9163498098859315                │
# │      Test:CausalMetricssurv_stratify_by_34      │               0.5703422053231939                │
# │      Test:CausalMetricssurv_stratify_by_38      │               0.4638783269961977                │
# │      Test:CausalMetricssurv_stratify_by_39      │               0.9277566539923955                │
# │      Test:CausalMetricssurv_stratify_by_40      │               0.7629911280101394                │
# │      Test:CausalMetricssurv_stratify_by_41      │                0.532319391634981                │
# │      Test:CausalMetricssurv_stratify_by_44      │               0.8669201520912547                │
# │      Test:CausalMetricssurv_stratify_by_47      │               0.8555133079847909                │
# │      Test:CausalMetricssurv_stratify_by_48      │               0.6806083650190115                │
# │      Test:CausalMetricssurv_stratify_by_51      │               0.8631178707224334                │
# │      Test:CausalMetricssurv_stratify_by_55      │               0.9961977186311787                │
# │      Test:CausalMetricssurv_stratify_by_57      │               0.7243346007604563                │
# │      Test:CausalMetricssurv_stratify_by_58      │               0.9230038022813688                │
# │      Test:CausalMetricssurv_stratify_by_60      │               0.7680608365019012                │
# │      Test:CausalMetricssurv_stratify_by_63      │               0.9759188846641318                │
# │      Test:CausalMetricssurv_stratify_by_65      │               0.7908745247148289                │
# │      Test:CausalMetricssurv_stratify_by_67      │               0.6121673003802282                │
# │      Test:CausalMetricssurv_stratify_by_70      │               0.8111533586818759                │
# │      Test:CausalMetricssurv_stratify_by_71      │                0.155893536121673                │
# │      Test:CausalMetricssurv_stratify_by_75      │               0.8491761723700888                │
# │      Test:CausalMetricssurv_stratify_by_78      │               0.9448669201520913                │
# │      Test:CausalMetricssurv_stratify_by_79      │               0.8574144486692015                │
# │      Test:CausalMetricssurv_stratify_by_80      │               0.9967409016838674                │
# │      Test:CausalMetricssurv_stratify_by_81      │               0.7072243346007605                │
# │      Test:CausalMetricssurv_stratify_by_82      │               0.8307984790874525                │
# │      Test:CausalMetricssurv_stratify_by_83      │               0.8688212927756653                │
# │      Test:CausalMetricssurv_stratify_by_84      │               0.9193916349809882                │
# │      Test:CausalMetricssurv_stratify_by_85      │               0.7167300380228137                │
# │      Test:CausalMetricssurv_stratify_by_89      │               0.7376425855513309                │
# │      Test:CausalMetricssurv_stratify_by_91      │               0.8998732572877058                │
# │      Test:CausalMetricssurv_stratify_by_93      │               0.7934093789607098                │
# │      Test:CausalMetricssurv_stratify_by_94      │               0.8745247148288973                │
# │      Test:CausalMetricssurv_stratify_by_95      │                       1.0                       │
# │      Test:CausalMetricssurv_stratify_by_97      │               0.8468223791417708                │
# │      Test:CausalMetricssurv_stratify_by_98      │               0.9496197718631176                │
# │      Test:CausalMetricssurv_stratify_by_99      │               0.8821292775665399                │
# │                    test_loss                    │               -7.8373284339904785               │
# │                test_loss_desurv                 │                -4.07503080368042                │
# │                test_loss_values                 │               -45.460384368896484               │
# └─────────────────────────────────────────────────┴─────────────────────────────────────────────────┘
# Loaded model with 11.20919 M parameters
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test:+0_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+0_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+10_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+10_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+13_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+13_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+16_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+16_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+19_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+19_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+1_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+1_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+2_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+2_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+3_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+3_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+4_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+4_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:+7_LookAheadMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:+7_LookAheadMetricssurv_no_stratify</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_no_stratify</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_100</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_101</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_104</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_106</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_107</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_11</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_110</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_112</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_113</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_114</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_115</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_116</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_118</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_119</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_120</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_121</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_123</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_124</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_126</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_127</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_129</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_130</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_131</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_133</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_134</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_135</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_136</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_141</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_142</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_143</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_144</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_145</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence_stratify_by_146</td><td>▁</td></tr><tr><td>Test:CausalMetricsprevalence ...
# Synced <strong style="color:#cdcd00">SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1</strong>: <a href="https://wandb.ai/cwlgadd/Evaluating%20pre-trained%20models/runs/2qttxkwm" target="_blank">https://wandb.ai/cwlgadd/Evaluating%20pre-trained%20models/runs/2qttxkwm</a><br/>Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250715_162435-2qttxkwm/logs</code>

# %%
wandb.finish()
print(pre_trained_model)
# Out:
# SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1

# %%
# display(dm.encode(['IHDINCLUDINGMI_OPTIMALV2', 'ISCHAEMICSTROKE_V2', 'MINFARCTION', 'STROKEUNSPECIFIED_V2', 'STROKE_HAEMRGIC']))
# display(dm.encode(['HYPERTENSION']))
# # display(dm.decode([95, 175, 263,249]).split(" "))

# %%
# dm.tokenizer._event_counts["EVENT"][-5:].to_list()

# %%
# valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] > 0]["event"].to_list()
# non_valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] == 0]["event"].to_list()
# diagnoses = dm.meta_information["diagnosis_table"]["event"].to_list()

# # print(valued_events)

# %%
print(pre_trained_model)
os.makedirs(f"figs/metrics/{pre_trained_model}/", exist_ok=True)
# Out:
# SurvivEHR-cr-small-debug7_exp1000-v1-v4-v1

# %%
import matplotlib.pyplot as plt
import numpy as np
import wandb
import polars as pl
wandb.login()

# Load causal_eval results from log
api = wandb.Api()
run = api.run("cwlgadd/Evaluating pre-trained models/2qttxkwm") # 3omvr6q0

# %%
history = run.history(keys=None)
raw_data_from_wandb = {}
for key in history.keys():
    raw_data_from_wandb = {**raw_data_from_wandb, key: history[key].to_numpy()[-1]}
# display(raw_data_from_wandb.sort())

# %% [markdown]
# # Get dataloader so we can extract event names by type

# %%
valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] > 0]["event"].to_list()
non_valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] == 0]["event"].to_list()
diagnoses = dm.meta_information["diagnosis_table"]["event"].to_list()

# %% [markdown]
# # Next event concordance

# %%
Cinter_keys = [_key for _key in raw_data_from_wandb.keys() if "Test:CausalMetricssurv_stratify_by_" in _key ]

decoded_cintra_diagnoses = {}
decoded_cintra_non_valued = {}
decoded_cintra_valued = {}

for _key in Cinter_keys:
    _event = int(_key[len("Test:CausalMetricssurv_stratify_by_"):])                 # token
    _event_name = dm.decode([_event]).split(" ")[0]         # string
    _event_cintra = raw_data_from_wandb[_key]               # concordance

    if _event_name in diagnoses:# .upper() == _event_name:
        decoded_cintra_diagnoses = {**decoded_cintra_diagnoses, _event_name: _event_cintra}
    elif _event_name in non_valued_events:
        decoded_cintra_non_valued = {**decoded_cintra_non_valued, _event_name: _event_cintra}
    elif _event_name in valued_events:
        decoded_cintra_valued = {**decoded_cintra_valued, _event_name: _event_cintra}
    else:
        raise NotImplementedError

# %%
# display(decoded_cintra_diagnoses)
# display(decoded_cintra_other)

# %%
BaseCinter_keys = [_key for _key in raw_data_from_wandb.keys() if "Test:CausalMetricsprevalence_stratify_by_" in _key ]

base_decoded_cintra_diagnoses = {}
base_decoded_cintra_non_valued = {}
base_decoded_cintra_valued = {}

base_prevalence_diagnoses = {}
base_prevalence_non_valued = {}
base_prevalence_valued = {}


for _key in BaseCinter_keys:
    _event = int(_key[len("Test:CausalMetricsprevalence_stratify_by_"):])                 # token
    _event_name = dm.decode([_event]).split(" ")[0]         # string
    _event_cintra = raw_data_from_wandb[_key]               # concordance

    prevalence = dm.tokenizer._event_counts
    prevalence = prevalence.filter(pl.col("EVENT") ==_event_name)["COUNT"][0]

    if _event_name in diagnoses: #.upper() == _event_name:
        base_decoded_cintra_diagnoses = {**base_decoded_cintra_diagnoses, _event_name: _event_cintra}
        base_prevalence_diagnoses = {**base_prevalence_diagnoses, _event_name: prevalence}
        
    elif _event_name in non_valued_events:
        base_decoded_cintra_non_valued = {**base_decoded_cintra_non_valued, _event_name: _event_cintra}
        base_prevalence_non_valued = {**base_prevalence_non_valued, _event_name: prevalence}

    elif _event_name in valued_events:
        base_decoded_cintra_valued = {**base_decoded_cintra_valued, _event_name: _event_cintra}
        base_prevalence_valued = {**base_prevalence_valued, _event_name: prevalence}

    else:
        raise NotImplementedError

# %%
# display(base_decoded_cintra_diagnoses)

# %%
keys_included_diagnoses = list(set(base_decoded_cintra_diagnoses.keys()) & set(decoded_cintra_diagnoses.keys()))
keys_included_non_valued = list(set(base_decoded_cintra_non_valued.keys()) & set(decoded_cintra_non_valued.keys()))
keys_included_valued = list(set(base_decoded_cintra_valued.keys()) & set(decoded_cintra_valued.keys()))

# %%
for dict_name, result_dict, result_dict_base, result_dict_prev, keys_to_include in zip(["diagnoses", "medications", "measurements"],
                                                                     [decoded_cintra_diagnoses, decoded_cintra_non_valued, decoded_cintra_valued], 
                                                                     [base_decoded_cintra_diagnoses, base_decoded_cintra_non_valued, base_decoded_cintra_valued], 
                                                                     [base_prevalence_diagnoses, base_prevalence_non_valued, base_prevalence_valued],
                                                                     [keys_included_diagnoses, keys_included_non_valued, keys_included_valued]
                                                                     ):
    plt.close()
    # plt.figure(figsize=(len(keys_to_include)/5,5))
    fig, ax1 = plt.subplots(figsize=(len(keys_to_include)/4,8))
    ax2 = ax1.twinx()  

    X_axis = np.arange(len(keys_to_include)) 

    Y_base = [result_dict_base[_key] for _key in keys_to_include]
    Y_survivEHR = [result_dict[_key] for _key in keys_to_include]
    Y_log_prevalence = [np.log(result_dict_prev[_key]) for _key in keys_to_include]

    # Sort by prevalence
    arg_sort = np.argsort(Y_log_prevalence)
    Y_base = [Y_base[_i] for _i in arg_sort]
    Y_survivEHR = [Y_survivEHR[_i] for _i in arg_sort]
    Y_log_prevalence = [Y_log_prevalence[_i] for _i in arg_sort]
    keys_to_include = [keys_to_include[_i] for _i in arg_sort]

    width = 0.25
    ax1.bar(X_axis - width, Y_base, width, label = f'Concordance by prevalence (Average over events: {raw_data_from_wandb["Test:CausalMetricsprevalence_no_stratify"]:.3f})', color="mediumblue") 
    ax1.bar(X_axis, Y_survivEHR, width, label = f'Concordance by SurvivEHR (Average over events: {raw_data_from_wandb["Test:CausalMetricssurv_no_stratify"]:.3f})', color="firebrick") 
    ax2.plot(X_axis, Y_log_prevalence, width, label='Log-prevalence', color="darkseagreen", marker=".")  #  + width

    ax1.set_xticks(X_axis, keys_to_include, rotation=90) 
    # ax1.xticks(X_axis, keys_to_include) 
    ax1.set_xlabel("Events") 
    ax1.set_ylabel("Self-supervised Concordance") 
    ax2.set_ylabel("Log Prevalence") 
    ax1.legend(loc="upper left")
    ax2.legend(loc="upper right")
    ax1.set_ylim(0, 1.2)
    ax2.set_ylim(np.min(Y_log_prevalence)*0.95, np.max(Y_log_prevalence)*1.1)
    

    # plt.bar(result_dict.keys(), result_dict.values(), 0.5, color='g')
    # ax1.xticks()

    # ybar = raw_data_from_wandb["Test:Cinter"]
    # ax1.plot([0, len(result_dict)-1], 
    #          [ybar, ybar],
    #          label=f"SurvivEHR marginalised over events",
    #          color="firebrick")

    # ybar = raw_data_from_wandb["Test:base_Cinter"]
    # ax1.plot([0, len(result_dict)-1], 
    #          [ybar, ybar],
    #          label=f"Prevalence marginalised over events",
    #          color="mediumblue")
    
    plt.tight_layout()
    plt.savefig(f"figs/metrics/{pre_trained_model}/inter_causal_eval_{dict_name}.png", bbox_inches="tight")
    plt.close()

# %% [markdown]
# # Future events

# %% [markdown]
# ## SurvivEHR

# %%
Cinter_keys = [_key for _key in raw_data_from_wandb.keys() if "+" in _key and "prevalence" not in _key ]

x_survivEHR, y_survivEHR = [], []
for _key in Cinter_keys:
    x_survivEHR.append(int(_key[6:-33]) + 1 )                # steps ahead
    y_survivEHR.append(raw_data_from_wandb[_key] )           # concordance


arg_sort = np.argsort(x_survivEHR)
x_survivEHR = [x_survivEHR[_i] for _i in arg_sort]
y_survivEHR = [y_survivEHR[_i] for _i in arg_sort]

print(x_survivEHR)
print(y_survivEHR)
# Out:
# [1, 2, 3, 4, 5, 8, 11, 14, 17, 20]
# [0.9867206756214528, 0.9235438435297677, 0.9036353028748456, 0.8843464116617102, 0.8586765504680968, 0.8083891604804155, 0.8195837363045009, 0.7807488841130765, 0.7705623374024421, 0.7502532407475381]

# %%
Cinter_keys = [_key for _key in raw_data_from_wandb.keys() if "+" in _key and "prevalence" in _key ]
# print(Cinter_keys)

x_base, y_base = [], []
for _key in Cinter_keys:
    x_base.append(int(_key[6:-len("_LookAheadMetricsprevalence_no_stratify")]) + 1 )                # steps ahead
    y_base.append(raw_data_from_wandb[_key] )                   # concordance

arg_sort = np.argsort(x_base)
x_base = [x_base[_i] for _i in arg_sort]
y_base = [y_base[_i] for _i in arg_sort]

print(x_base)
print(y_base)
# Out:
# [1, 2, 3, 4, 5, 8, 11, 14, 17, 20]
# [0.8549209927966827, 0.8554057884602225, 0.8562878467821434, 0.856383584919344, 0.8553855002076877, 0.8501297603959204, 0.8498032617479898, 0.848335813082052, 0.8504674233111297, 0.8518284716003348]

# %%
plt.close()

plt.plot(x_survivEHR, y_survivEHR,
         label=f"SurvivEHR",
         color="firebrick")

plt.plot(x_base, y_base,
         label=f"Prevalence",
         color="mediumblue")

plt.xticks(x_survivEHR)
plt.ylabel("Self-supervised multi-step concordance")
plt.xlabel("Number of steps ahead")
plt.legend()
plt.tight_layout()
plt.savefig(f"figs/metrics/{pre_trained_model}/inter_decay.png", bbox_inches="tight")

# %%
# new_dictionary

# %%
import copy
start = time.time()   # starting time
for batch in dm.train_dataloader():
    # print(batch["tokens"][1,:])
    
    c_batch = convert_batch_to_none_causal(batch)
    # print(c_batch["tokens"][1,:])
    # print(c_batch["target_token"][1])

    # print(batch["tokens"][1,:])
    
    break
    
print(f"batch loaded in {time.time()-start} seconds")    
    
# for key in batch.keys():
#     print(f"{key}".ljust(20) + f"{batch[key].shape}")

# tokens = batch["tokens"][0].tolist()    
# sentence = dm.decode(tokens).split(" ")
# for token, value in zip(sentence, batch["values"][0].tolist()):
#     print(f"{token}:".ljust(40) + f"{value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [24], line 2
#       1 import copy
# ----> 2 start = time.time()   # starting time
#       3 for batch in dm.train_dataloader():
#       4     # print(batch["tokens"][1,:])
#       6     c_batch = convert_batch_to_none_causal(batch)
#
# NameError: name 'time' is not defined

# %%
display(batch.keys())
display(c_batch.keys())

print(batch["static_covariates"].shape)

# print(dm.train_set.static_1hot)
# print(dm.train_set.static_1hot["SEX"].categories_)
# print(dm.train_set.static_1hot["IMD"].categories_)
# print(dm.train_set.static_1hot["ETHNICITY"].categories_)

print(batch["tokens"][1,:])
print(c_batch["tokens"][1,:])
print(c_batch["target_token"][1])

# %% [markdown]
# ## View an example sample

# %%
dm.test_set.view_sample(11003, max_dynamic_events=None, report_time=True)

# %% [markdown]
# # Custom wrapper prediction last token
#
# To begin with, I will just loop over samples individually to test the zero-shot capacity of SurvivEHR.

# %%
# Verifying on datamodule 
for _idx, batch in enumerate(dm.test_dataloader()):
    if _idx > 10:
        break
    print(_idx)
    print(torch.stack([batch["tokens"][10,:5], 
                       batch["values"][10,:5],  
                       batch["ages"][10,:5],
                       batch["attention_mask"][10,:5]]))
    batch = replace_last_non_pad_with_pad(batch)
    print(torch.stack([batch["tokens"][10,:5], 
                       batch["values"][10,:5],  
                       batch["ages"][10,:5],
                       batch["attention_mask"][10,:5]]))

# %%
outcome_of_interest = ["COPD", "SUBSTANCEMISUSE"]
outcome_token = dm.encode(outcome_of_interest)[0]
print(outcome_token)
# print(model(batch))

# %%
Hs, labels = [], []
mins,maxes=[],[]
for _idx, batch in enumerate(dm.test_dataloader()):

    batch = replace_last_non_pad_with_pad(batch)
    print(batch["tokens".shape)
    outputs, _, hidden_states = model(batch, is_generation=True)
    print(outputs)
    
    hidden_states = hidden_states.cpu().detach().numpy()                           # (64, 128, 384) 
    Hs.append( hidden_states.reshape(hidden_states.shape[0], -1) )
    labels.append((batch["target_token"] == outcome_token).long().numpy())

    if _idx == 9:
        break

# %% [markdown]
# # Visualise hidden dimension labelled by target

# %%
import umap
from sklearn.preprocessing import StandardScaler

H = np.concatenate(Hs, 0)
lbl = np.concatenate(labels, 0)

H = StandardScaler().fit_transform(H)
reducer = umap.UMAP()
H_proj = reducer.fit_transform(H)

plt.close()
plt.scatter(H_proj[:,0], H_proj[:,1], c=lbl)
plt.savefig(save_path + f"zero_shot/hidden_umap.png")

# %%
print(outputs["surv"]["surv_CDF"][outcome_token].shape)

# The first two tokens in the vocab correspond to the PAD and UNK tokens. There is no CDF corresponding to the PAD token, so the indexing for surv_CDF begins as ["UNK", "ADDISONS_DISEASE", ...]
# print(dm.decode([0,1,2]))

outcomes = ["COPD", "SUBSTANCEMISUSE"]
outcome_tokens = dm.encode(outcomes)

# for outcome in outcomes:
    # observed_outcome_token = dm.encode([outcome])[0]
cdf = np.zeros_like(outputs["surv"]["surv_CDF"][0])
lbls = np.zeros_like(batch["target_token"])

for _outcome_token in outcome_tokens:
    cdf += outputs["surv"]["surv_CDF"][_outcome_token - 1] 
    lbls += (batch["target_token"] == _outcome_token).long().numpy()

plt.close()
cdf_true = cdf[lbls==1,:]
cdf_false = cdf[lbls==0,:]
for i in range(cdf_true.shape[0]):
    plt.plot(np.linspace(1,1826,1826), cdf_true[i,:], c="r", label="outcome occurred next" if i == 0 else None, alpha=1)
for i in range(cdf_false.shape[0]):
    plt.plot(np.linspace(1,1826,1826), cdf_false[i,:], c="k", label="outcome did not occur next" if i == 0 else None, alpha=0.3)

plt.legend(loc=2)
plt.xlabel("days")
plt.ylabel(f"P(t>T) - outcomes={','.join(outcomes)}")
plt.savefig(save_path + f"zero_shot/cdf_outcomes.png")

# %%
print(batch["target_token"].unique())
print(len(outputs["surv"]["surv_CDF"]))

# %%
dm.decode([2])

# %%
outputs["surv"]["surv_CDF"][observed_outcome_token - 1]

# %%
import matplotlib.pyplot as plt
import numpy as np
import wandb
import polars as pl
wandb.login()

# Load causal_eval results from log
api = wandb.Api()
run = api.run("cwlgadd/Evaluating pre-trained models/1felbu63")

history = run.history(keys=None)
raw_data_from_wandb = {}
for key in history.keys():
    raw_data_from_wandb = {**raw_data_from_wandb, key: history[key].to_numpy()[-1]}

# %%
import wandb
import json
import pandas as pd
import io

history = run.history(keys=["Test:NextEventMatrixTruth"])
table_dict = history["Test:NextEventMatrixTruth"].iloc[-1]

print("Available keys in table_dict:", list(table_dict.keys()))
print("table_dict['path'] =", table_dict["path"])

# 2) Download may return either a local filepath (str) or a file‐handle (TextIOWrapper)
file_obj = run.file(table_dict["path"])
downloaded = file_obj.download(replace=True)

# 3) If `downloaded` is a string, that's the path on disk. If it's TextIOWrapper, it’s already open.
if isinstance(downloaded, str):
    # downloaded is the path to the .json file
    with open(downloaded, "r") as f:
        table_json = json.load(f)
elif isinstance(downloaded, io.TextIOBase):
    # downloaded is already an open file‐handle
    table_json = json.load(downloaded)
else:
    raise RuntimeError(f"Unexpected return type from download(): {type(downloaded)}")

# 4) Now rebuild the DataFrame
rows = table_json["data"]
cols = table_json["columns"]
df = pd.DataFrame(rows, columns=cols)

# 5) Extract numeric matrix (drop "Prior event" if it exists)
if "Prior event" in df.columns:
    matrix = df.loc[:, df.columns != "Prior event"].to_numpy()
else:
    matrix = df.to_numpy()

print("Recovered matrix shape:", matrix.shape)
print(matrix)
