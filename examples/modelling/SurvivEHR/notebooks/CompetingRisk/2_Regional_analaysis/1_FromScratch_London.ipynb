# %% [markdown]
# # Notebook: Stability as a benefit from pre-training
#
# ### Evaluation of the fine-tuned and pre-trained SurvivEHR-CR on a stratified cohort of Type 2 Diabetes Mellitus (T2DM) patients.
#
# Cohort study:
# - predicting cardiovascular/hypertension risk upon diagnosis of T2DM.
#
# This notebook quantifies the performance obtained when fine-tuning the pre-trained model
# on a full cohort sub-population and evaluating on two populations within the cohort. For
# example, here we
# - Take the existing full-fine tuned SurvivEHR prognostic hypertension risk prediction
# model trained on the entire cohort of Type 2 Diabetes Mellitus patients
# - And evaluate it on a stratification of the held-out-patients in the same cohort with typically
#   different backgrounds: those from London and those from North East of England.

# %%
# experiment = "cvd" 
experiment = "Hypertension" 
pre_trained_model = None
seed = 1

# %% [markdown]
# ## Results obtained in this notebook
#
# ### Hypertension risk
# ```
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric               ┃       Seed     ┃  London                  ┃  North-East              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsctd    │       1        │ 0.8272256255149841       │ 0.8390284180641174       │
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsibs    │       1        │ 0.07421788083303718      │ 0.0693548212939208       │
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsinbll  │       1        │ 0.2373908019006733       │ 0.22310520884510765      │
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │               test_loss               │       1        │ 0.37776145339012146      │ 0.35308441519737244      │
# └───────────────────────────────────────┴────────────────┴──────────────────────────┴──────────────────────────┘
# ```
#
# ### Cardiovascular disease risk
# ```
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric               ┃       Seed     ┃  London                  ┃  North-East              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsctd    │       1        │                          │                          │
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsibs    │       1        │                          │                          │
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsinbll  │       1        │                          │                          │
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │               test_loss               │       1        │                          │                          │
# └───────────────────────────────────────┴────────────────┴──────────────────────────┴──────────────────────────┘
# ```

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# %load_ext autoreload
# %autoreload 2

print(os.getcwd())
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /rds/homes/g/gaddcz/Projects/CPRD/examples/modelling/SurvivEHR/notebooks/CompetingRisk/2_Regional_analaysis

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import wandb
import pickle
from hydra import compose, initialize
import os
import polars as pl
import logging
import pandas

from FastEHR.dataloader import FoundationalDataModule

from CPRD.examples.modelling.SurvivEHR.run_experiment import run
from CPRD.src.models.survival.task_heads.causal import SurvStreamGPTForCausalModelling


torch.manual_seed(1337)
torch.set_float32_matmul_precision('medium')
pl.Config.set_tbl_rows(10000)
logging.getLogger().setLevel(logging.ERROR)          # Remove deprecation warnings from older dataset format

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}.")

 # TODO: define an env variable to fix for a local hpc environment issue, this shouldn't be needed
# %env SLURM_NTASKS_PER_NODE=28
# Out:
# Using device: cuda.
# env: SLURM_NTASKS_PER_NODE=28

# %% [markdown]
# # Fine-tuning on full dataset
# The default configuration is for pre-training. Here we modify as necesssary
#
# Here we choose to load in the configuration for a small **pre-trained** 11.4M parameter model, named "CR_11M". We specfiy the `fine-tune` experiment type, which will lead to running the ```SupervisedExperiment```.
#
# We tell this experiment that we want to perform training (true by default). Additionally, we do choose to perform testing (true by default). As this is a supervised model, this tests the ability to predict the outcomes of interest. In this notebook, this is chosen to be those of the cohort study for predicting Cardiovascular Disease in a Type 2 Diabetes Mellitus population, and we add the folder containing this dataset to the configuration.
#
# ```Note: As this is a supervised dataset, we need to tell the DataModule that the last event observed is a target and must be stripped. This is done by passing a list of targets to the configuration, overriding the null default. This lets the DataModule know that it should process batches as supervised.```
#
# We set the number of workers to be appropriate for the number of CPUs available to reduce bottlenecking, and tell the experiment that we do not want to limit the number of testing batches. In addition, we specify where we want any checkpoints to be saved to avoid bloating the repository.
#
# We design a new optimisation strategy for fine-tuning. Pre-training was achieved with a warmup and cosine annealing, with rates which are no appropriate for much smaller dataset sizes seen in clinical prediction models (CPMs). We here choose a simpler strategy: of ReduceOnPlateau with no warmup, increasing the number of epochs (default is 1) and reduced validation intervals, and the addition of early stopping. Additionally, as this is not a causal model we can increase the batch size. Finally, as this CPM is not trying to predict the value of any outcomes, we set the value weight to zero allowing the model to focus entirely on optimising survival outcome prediction.

# %%
match experiment.lower():
    case "cvd":
        experiment_type = "fine-tune-cr"
        fine_tune_model_name = f"London{seed}"
    case "hypertension":
        experiment_type = "fine-tune-sr"
        fine_tune_model_name = f"London{seed}"

# %% [markdown]
# ### Train and evaluate on London

# %%
 # load the configuration file, override any settings 
with initialize(version_base=None, config_path="../../../confs", job_name="testing_notebook"):
    cfg = compose(config_name="config_CompetingRisk11M", 
                  overrides=[# Experiment setup
                             f"experiment.type='{experiment_type}'",
                             f"experiment.run_id='{pre_trained_model}'",
                             f"experiment.fine_tune_id='{fine_tune_model_name}'",
                             "experiment.train=True",
                             "experiment.test=Test",
                             f"experiment.seed={seed}",
                             # Optimisation
                             "optim.num_epochs=500",
                             "optim.scheduler=ReduceOnPlateau",
                             "optim.scheduler_warmup=False",
                             "optim.learning_rate=5e-5",
                             "optim.val_check_interval=0.125",
                             "optim.limit_val_batches=null",
                             "optim.limit_test_batches=null",
                             "optim.early_stop=True",
                             "optim.early_stop_patience=5",
                             "optim.accumulate_grad_batches=1",
                             # Dataloader
                             "data.batch_size=128",
                             "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                             "data.min_workers=12",
                             "data.global_diagnoses=True",
                             "data.repeating_events=False",
                             # Model
                             "transformer.block_size=512", 
                            ]
                 )

match experiment.lower():
    case "cvd":
        raise NotImplementedError
        cfg.fine_tuning.fine_tune_outcomes=["IHDINCLUDINGMI_OPTIMALV2", "ISCHAEMICSTROKE_V2", "MINFARCTION", "STROKEUNSPECIFIED_V2", "STROKE_HAEMRGIC"]
    case "hypertension":
        cfg.data.path_to_ds="/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/ByRegion/Hypertension_London/"
        cfg.fine_tuning.fine_tune_outcomes=["HYPERTENSION"]
    
model, dm = run(cfg)
wandb.finish()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: cwlgadd. Use `wandb login --relogin` to force relogin
# wandb version 0.22.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250930_115214-8l6m9va8</code>
# Syncing run <strong><a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/8l6m9va8" target="_blank">None_London1</a></strong> to <a href="https://wandb.ai/cwlgadd/SurvivEHR" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:630: Checkpoint directory /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type                            | Params
# ------------------------------------------------------------------
# 0 | model         | SurvStreamGPTForCausalModelling | 11.2 M
# 1 | reduce_hidden | Sequential                      | 147 K
# 2 | surv_layer    | ODESurvSingleRiskLayer          | 13.5 K
# ------------------------------------------------------------------
# 11.4 M    Trainable params
# 30        Non-trainable params
# 11.4 M    Total params
# 45.482    Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:211: You called `self.log('val_loss_values', ...)` in your `validation_step` but the value needs to be floating point. Converting it to torch.float32.
# Training: |          | 0/? [00:00<?, ?it/s]
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:211: You called `self.log('train_loss_values', ...)` in your `training_step` but the value needs to be floating point. Converting it to torch.float32.
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved. New best score: 0.499
# Epoch 0, global step 118: 'val_loss' reached 0.49853 (best 0.49853), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.048 >= min_delta = 0. New best score: 0.450
# Epoch 0, global step 236: 'val_loss' reached 0.45044 (best 0.45044), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 354: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0. New best score: 0.448
# Epoch 0, global step 472: 'val_loss' reached 0.44848 (best 0.44848), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 590: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.003 >= min_delta = 0. New best score: 0.446
# Epoch 0, global step 708: 'val_loss' reached 0.44563 (best 0.44563), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.003 >= min_delta = 0. New best score: 0.443
# Epoch 0, global step 826: 'val_loss' reached 0.44283 (best 0.44283), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0. New best score: 0.440
# Epoch 0, global step 944: 'val_loss' reached 0.44037 (best 0.44037), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.014 >= min_delta = 0. New best score: 0.427
# Epoch 1, global step 1069: 'val_loss' reached 0.42655 (best 0.42655), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1, global step 1187: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.012 >= min_delta = 0. New best score: 0.414
# Epoch 1, global step 1305: 'val_loss' reached 0.41425 (best 0.41425), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1, global step 1423: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.000 >= min_delta = 0. New best score: 0.414
# Epoch 1, global step 1541: 'val_loss' reached 0.41409 (best 0.41409), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0. New best score: 0.412
# Epoch 1, global step 1659: 'val_loss' reached 0.41178 (best 0.41178), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0. New best score: 0.411
# Epoch 1, global step 1777: 'val_loss' reached 0.41109 (best 0.41109), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0. New best score: 0.410
# Epoch 1, global step 1895: 'val_loss' reached 0.41047 (best 0.41047), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 2020: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.004 >= min_delta = 0. New best score: 0.407
# Epoch 2, global step 2138: 'val_loss' reached 0.40651 (best 0.40651), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0. New best score: 0.405
# Epoch 2, global step 2256: 'val_loss' reached 0.40524 (best 0.40524), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# /rds/homes/g/gaddcz/Projects/CPRD/src/models/base_callback.py:66: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(4, 4), dpi=300)
# Epoch 2, global step 2374: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 2492: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0. New best score: 0.403
# Epoch 2, global step 2610: 'val_loss' reached 0.40280 (best 0.40280), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 2728: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0. New best score: 0.401
# Epoch 2, global step 2846: 'val_loss' reached 0.40120 (best 0.40120), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 2971: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.000 >= min_delta = 0. New best score: 0.401
# Epoch 3, global step 3089: 'val_loss' reached 0.40118 (best 0.40118), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 3207: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0. New best score: 0.400
# Epoch 3, global step 3325: 'val_loss' reached 0.39992 (best 0.39992), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 3443: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0. New best score: 0.399
# Epoch 3, global step 3561: 'val_loss' reached 0.39904 (best 0.39904), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 3679: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0. New best score: 0.398
# Epoch 3, global step 3797: 'val_loss' reached 0.39753 (best 0.39753), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/None_London1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 3922: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 4040: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 4158: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 4276: 'val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Monitored metric val_loss did not improve in the last 5 records. Best score: 0.398. Signaling Trainer to stop.
# Epoch 4, global step 4394: 'val_loss' was not in top 1
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:211: You called `self.log('test_loss_values', ...)` in your `test_step` but the value needs to be floating point. Converting it to torch.float32.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric             ┃            DataLoader 0             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsctd  │         0.8272256255149841          │
# │  Test:OutcomePerformanceMetricsibs  │         0.07421788083303718         │
# │ Test:OutcomePerformanceMetricsinbll │         0.2373908019006733          │
# │              test_loss              │         0.37776145339012146         │
# │          test_loss_desurv           │         0.37776145339012146         │
# │          test_loss_values           │                 0.0                 │
# └─────────────────────────────────────┴─────────────────────────────────────┘
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='6.185 MB of 6.185 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Scheduler/pg1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Scheduler/pg2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Test:OutcomePerformanceMetricsctd</td><td>▁</td></tr><tr><td>Test:OutcomePerformanceMetricsibs</td><td>▁</td></tr><tr><td>Test:OutcomePerformanceMetricsinbll</td><td>▁</td></tr><tr><td>Val:OutcomePerformanceMetricsctd</td><td>▁▃▃▃▃▃▄▅▆▆▇▇▇█▇█▇████████████████████</td></tr><tr><td>Val:OutcomePerformanceMetricsibs</td><td>█▇▇▇█▇▆▆▄▆▂▃▂▂▂▂▃▂▂▂▂▁▂▁▁▁▃▁▂▁▁▁▁▂▁▁▁</td></tr><tr><td>Val:OutcomePerformanceMetricsinbll</td><td>█▆▆▆▆▆▅▅▄▅▂▃▂▂▂▂▂▂▂▂▂▁▂▁▁▁▂▁▁▁▁▁▁▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆█████</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_loss_desurv</td><td>▁</td></tr><tr><td>test_loss_values</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▅▄▄▅▅▅▅▅▄▃▄▅▇▅▃▂▅▂▂▅▆▃▅▃▃▃▄▁▃▃▃▄▂▃▄▆▂▁</td></tr><tr><td>train_loss_desurv</td><td>█▄▅▄▄▅▅▅▅▅▄▃▄▅▇▅▃▂▅▂▂▅▆▃▅▃▃▃▄▁▃▃▃▄▂▃▄▆▂▁</td></tr><tr><td>train_loss_values</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██████</td></tr><tr><td>val_loss</td><td>█▅▅▅▅▄▄▄▃▄▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_desurv</td><td>█▅▅▅▅▄▄▄▃▄▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_values</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Scheduler/pg1</td><td>5e-05</td></tr><tr><td>Scheduler/pg2</td><td>0.0005</td></tr><tr><td>Test:OutcomePerformanceMetricsctd</td><td>0.82723</td></tr><tr><td>Test:OutcomePerformanceMetricsibs</td><td>0.07422</td></tr><tr><td>Test:OutcomePerformanceMetricsinbll</td><td>0.23739</td></tr><tr><td>Val:OutcomePerformanceMetricsctd</td><td>0.82385</td></tr><tr><td>Val:OutcomePerformanceMetricsibs</td><td>0.08021</td></tr><tr><td>Val:OutcomePerformanceMetricsinbll</td><td>0.25277</td></tr><tr><td>epoch</td><td>5</td></tr><tr><td>test_loss</td><td>0.37776</td></tr><tr><td>test_loss_desurv</td><td>0.37776</td></tr><tr><td>test_loss_values</td><td>0.0</td></tr><tr><td>train_loss</td><td>0.35877</td></tr><tr><td>train_loss_desurv</td><td>0.35877</td></tr><tr><td>train_loss_values</td><td>0.0</td></tr><tr><td>trainer/global_step</td><td>4394</td></tr><tr><td>val_loss</td><td>0.39875</td></tr><tr><td>val_loss_desurv</td><td>0.39875</td></tr><tr><td>val_loss_values</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">None_London1</strong>: <a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/8l6m9va8" target="_blank">https://wandb.ai/cwlgadd/SurvivEHR/runs/8l6m9va8</a><br/>Synced 5 W&B file(s), 81 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250930_115214-8l6m9va8/logs</code>

# %% [markdown]
# ### Evaluate on North-East

# %%
# Update config to new evaluation dataset, tell config to not re-train, but to evaluate on the new dataset
cfg.experiment.train = False
cfg.experiment.test = True

match experiment.lower():
    case "cvd":
        raise NotImplementedError
        cfg.fine_tuning.fine_tune_outcomes=["IHDINCLUDINGMI_OPTIMALV2", "ISCHAEMICSTROKE_V2", "MINFARCTION", "STROKEUNSPECIFIED_V2", "STROKE_HAEMRGIC"]
    case "hypertension":
        cfg.data.path_to_ds="/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/ByRegion/Hypertension_North East/"
        cfg.fine_tuning.fine_tune_outcomes=["HYPERTENSION"]

model, dm = run(cfg)
wandb.finish()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# wandb version 0.22.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250930_131327-3c72dqsb</code>
# Syncing run <strong><a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/3c72dqsb" target="_blank">None_London1</a></strong> to <a href="https://wandb.ai/cwlgadd/SurvivEHR" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric             ┃            DataLoader 0             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsctd  │         0.8390284180641174          │
# │  Test:OutcomePerformanceMetricsibs  │         0.0693548212939208          │
# │ Test:OutcomePerformanceMetricsinbll │         0.22310520884510765         │
# │              test_loss              │         0.35308441519737244         │
# │          test_loss_desurv           │         0.35308441519737244         │
# │          test_loss_values           │                 0.0                 │
# └─────────────────────────────────────┴─────────────────────────────────────┘
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.558 MB of 1.616 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.963609…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test:OutcomePerformanceMetricsctd</td><td>▁</td></tr><tr><td>Test:OutcomePerformanceMetricsibs</td><td>▁</td></tr><tr><td>Test:OutcomePerformanceMetricsinbll</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_loss_desurv</td><td>▁</td></tr><tr><td>test_loss_values</td><td>▁</td></tr><tr><td>trainer/global_step</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test:OutcomePerformanceMetricsctd</td><td>0.83903</td></tr><tr><td>Test:OutcomePerformanceMetricsibs</td><td>0.06935</td></tr><tr><td>Test:OutcomePerformanceMetricsinbll</td><td>0.22311</td></tr><tr><td>epoch</td><td>0</td></tr><tr><td>test_loss</td><td>0.35308</td></tr><tr><td>test_loss_desurv</td><td>0.35308</td></tr><tr><td>test_loss_values</td><td>0.0</td></tr><tr><td>trainer/global_step</td><td>0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">None_London1</strong>: <a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/3c72dqsb" target="_blank">https://wandb.ai/cwlgadd/SurvivEHR/runs/3c72dqsb</a><br/>Synced 5 W&B file(s), 15 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250930_131327-3c72dqsb/logs</code>

# %% [markdown]
# # Collate the results

# %%
# Create a dictionary of data
data_hypertension = {
    "Dataset": ["Hypertension" for _ in range(6)],
    "Training sub-population": ["London, P=0" for _ in range(6)],
    "Metric type": ["Ctd", "Ctd",
                    "IBS", "IBS", 
                    "INBLL", "INBLL"],
    "Seed": [1, 1,
             1, 1,
             1, 1],
    "Evaluation sub-population": ["London", "North-East",
                                  "London", "North-East",
                                  "London", "North-East"],
    "Metric value": [0.8272256255149841,  0.8390284180641174,
                     0.07421788083303718, 0.0693548212939208,
                     0.2373908019006733,  0.22310520884510765
                     ]
}

df = pandas.DataFrame(data_hypertension)

with open("1_results.pkl", "wb") as f:
    pickle.dump(df, f)
