# %% [markdown]
# # Demo Notebook:
# ## Time to Event Transformer For Causal Sequence Modelling
#
# Including time (and TODO: values)

# %%
import pytorch_lightning 
import torch
import numpy as np
import matplotlib.pyplot as plt
import random
import sqlite3
from dataclasses import dataclass
import logging
from CPRD.data.foundational_loader import FoundationalDataModule
from CPRD.src.models.TTE.task_heads.causal import TTETransformerForCausalSequenceModelling

# TODO:
# replace experiment boilerplate with pytorch lightning

torch.manual_seed(1337)
logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# device = "cpu"    # if more informative debugging statements are needed
# !pwd
# Out:
# cuda
# /rds/homes/g/gaddcz/Projects/CPRD/examples/modelling

# %% [markdown]
# ## Build configurations

# %%
# Set config to be equivalent architecture of kaparthy benchmark, however they are not comparable tasks.
@dataclass
class DemoConfig:
    block_size: int = 128        # what is the maximum context length for predictions?
    n_layer: int = 6
    n_head: int = 6
    n_embd: int = 384
    bias: bool = True
    attention_type: str = "global"    
    dropout: float = 0.0
    unk_freq_threshold: float = 0.0
    TTELayer = "Exponential"

config = DemoConfig()

@dataclass
class OptConfig:
    batch_size: int = 64
    eval_interval: int = 1
    learning_rate: float = 3e-4
    epochs: int = 50
    
opt = OptConfig()

# %% [markdown]
# ## Create data loader on a reduced cohort

# %%
from CPRD.data.database import queries

# Get a list of patients which fit a reduced set of criterion
PATH_TO_DB = "/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModel/preprocessing/processed/cprd.db"
conn = sqlite3.connect(PATH_TO_DB)
cursor = conn.cursor()
# identifiers1 = queries.query_measurement(["bmi", "diastolic_blood_pressure"], cursor)        
identifiers2 = queries.query_diagnosis(["DEPRESSION", "TYPE1DM", "TYPE2DIABETES"], cursor)    #  "DEPRESSION"  ,  "ANXIETY"
# all_identifiers = list(set(identifiers1).intersection(identifiers2))    # Turn smaller list into the set
all_identifiers = identifiers2

if False:
    # Lets take only the first N for faster run-time
    N = np.min((len(all_identifiers), 10000))
    print(f"Using N={N} random samples, from the available {len(all_identifiers)}")
    identifiers = random.choices(all_identifiers, k=N)
else:
    print(f"Using all available {len(all_identifiers)} samples")
    identifiers = all_identifiers

# Build 
dm = FoundationalDataModule(identifiers=identifiers,
                            tokenizer="tabular",
                            batch_size=opt.batch_size,
                            max_seq_length=config.block_size,
                            unk_freq_threshold=config.unk_freq_threshold,
                            include_measurements=False,
                            include_diagnoses=True,
                           )

vocab_size = dm.train_set.tokenizer.vocab_size

print(f"{len(dm.train_set)} training samples")
print(f"{len(dm.val_set)} validation samples")
print(f"{len(dm.test_set)} test samples")
print(f"{vocab_size} vocab elements")
# print(dm.train_set.tokenizer._itos)
# Out:
# INFO:root:Building polars dataset
# Using all available 129717 samples
# INFO:root:Using diagnoses
# INFO:root:Dropping samples with no dynamic events
# INFO:root:Using tabular tokenizer
# 107680 training samples
# 5983 validation samples
# 5982 test samples
# 74 vocab elements

# %%
import polars as pl
pl.Config.set_tbl_rows(vocab_size + 1)
print(dm.tokenizer._event_counts)
# Out:
# shape: (73, 3)
# ┌───────────────────────────────────┬────────┬──────────┐
# │ EVENT                             ┆ counts ┆ freq     │
# │ ---                               ┆ ---    ┆ ---      │
# │ str                               ┆ u32    ┆ f64      │
# ╞═══════════════════════════════════╪════════╪══════════╡
# │ UNK                               ┆ 0      ┆ 0.0      │
# │ DEPRESSION                        ┆ 86578  ┆ 0.177638 │
# │ ANXIETY                           ┆ 48167  ┆ 0.098828 │
# │ HYPERTENSION                      ┆ 32947  ┆ 0.0676   │
# │ TYPE2DIABETES                     ┆ 27251  ┆ 0.055913 │
# │ ASTHMA_PUSHASTHMA                 ┆ 25362  ┆ 0.052037 │
# │ OSTEOARTHRITIS                    ┆ 25353  ┆ 0.052019 │
# │ ATOPICECZEMA                      ┆ 23152  ┆ 0.047503 │
# │ ALLERGICRHINITISCONJ              ┆ 18500  ┆ 0.037958 │
# │ ANY_DEAFNESS_HEARING_LOSS         ┆ 17188  ┆ 0.035266 │
# │ PREVALENT_IBS                     ┆ 11741  ┆ 0.02409  │
# │ ALLCA_NOBCC_VFINAL                ┆ 11703  ┆ 0.024012 │
# │ IHD_NOMI                          ┆ 11288  ┆ 0.02316  │
# │ ALCOHOLMISUSE                     ┆ 11108  ┆ 0.022791 │
# │ CKDSTAGE3TO5                      ┆ 10438  ┆ 0.021416 │
# │ PERIPHERAL_NEUROPATHY             ┆ 8811   ┆ 0.018078 │
# │ HYPOTHYROIDISM_DRAFT_V1           ┆ 8023   ┆ 0.016461 │
# │ COPD                              ┆ 7727   ┆ 0.015854 │
# │ AF                                ┆ 6198   ┆ 0.012717 │
# │ OSTEOPOROSIS                      ┆ 5756   ┆ 0.01181  │
# │ HF                                ┆ 5724   ┆ 0.011744 │
# │ PSORIASIS                         ┆ 5680   ┆ 0.011654 │
# │ SUBSTANCEMISUSE                   ┆ 5579   ┆ 0.011447 │
# │ GOUT                              ┆ 5304   ┆ 0.010883 │
# │ MINFARCTION                       ┆ 4960   ┆ 0.010177 │
# │ STROKEUNSPECIFIED                 ┆ 4495   ┆ 0.009223 │
# │ ALL_DEMENTIA                      ┆ 4412   ┆ 0.009052 │
# │ VALVULARDISEASES                  ┆ 3222   ┆ 0.006611 │
# │ PAD_STRICT                        ┆ 3213   ┆ 0.006592 │
# │ OTHER_CHRONIC_LIVER_DISEASE_OPTI… ┆ 2936   ┆ 0.006024 │
# │ TYPE1DM                           ┆ 2862   ┆ 0.005872 │
# │ EPILEPSY                          ┆ 2589   ┆ 0.005312 │
# │ OSA                               ┆ 2415   ┆ 0.004955 │
# │ FIBROMYALGIA                      ┆ 2407   ┆ 0.004939 │
# │ POLYCYSTIC_OVARIAN_SYNDROME_PCOS  ┆ 2216   ┆ 0.004547 │
# │ NAFLD                             ┆ 2142   ┆ 0.004395 │
# │ RHEUMATOIDARTHRITIS               ┆ 2044   ┆ 0.004194 │
# │ EATINGDISORDERS                   ┆ 1997   ┆ 0.004097 │
# │ PMRANDGCA                         ┆ 1923   ┆ 0.003946 │
# │ HYPERTHYROIDISM                   ┆ 1904   ┆ 0.003907 │
# │ ENDOMETRIOSIS_ADENOMYOSIS_V2      ┆ 1822   ┆ 0.003738 │
# │ PTSDDIAGNOSIS                     ┆ 1700   ┆ 0.003488 │
# │ ISCHAEMICSTROKE                   ┆ 1486   ┆ 0.003049 │
# │ VISUAL_IMPAIRMENT                 ┆ 1397   ┆ 0.002866 │
# │ BIPOLAR                           ┆ 1378   ┆ 0.002827 │
# │ SCHIZOPHRENIAMM                   ┆ 1339   ┆ 0.002747 │
# │ BRONCHIECTASIS                    ┆ 1069   ┆ 0.002193 │
# │ CHRONIC_LIVER_DISEASE_ALCOHOL     ┆ 911    ┆ 0.001869 │
# │ AORTICANEURYSM                    ┆ 891    ┆ 0.001828 │
# │ CHRONICFATIGUESYNDROMEMM          ┆ 848    ┆ 0.00174  │
# │ ULCERATIVE_COLITIS                ┆ 824    ┆ 0.001691 │
# │ LEARNINGDISABILITY                ┆ 734    ┆ 0.001506 │
# │ PERNICIOUSANAEMIA                 ┆ 715    ┆ 0.001467 │
# │ STROKE_HAEMRGIC                   ┆ 706    ┆ 0.001449 │
# │ PARKINSONS                        ┆ 703    ┆ 0.001442 │
# │ MENIERESDISEASE                   ┆ 698    ┆ 0.001432 │
# │ LYMPHOMA_PREVALENCE               ┆ 596    ┆ 0.001223 │
# │ CROHNS_DISEASE                    ┆ 550    ┆ 0.001128 │
# │ ILD_SH                            ┆ 548    ┆ 0.001124 │
# │ AUTISM                            ┆ 511    ┆ 0.001048 │
# │ PSORIATICARTHRITIS2021            ┆ 484    ┆ 0.000993 │
# │ MS                                ┆ 411    ┆ 0.000843 │
# │ LEUKAEMIA_PREVALENCE              ┆ 397    ┆ 0.000815 │
# │ HIVAIDS                           ┆ 295    ┆ 0.000605 │
# │ SJOGRENSSYNDROME                  ┆ 234    ┆ 0.00048  │
# │ SYSTEMIC_LUPUS_ERYTHEMATOSUS      ┆ 219    ┆ 0.000449 │
# │ HAEMOCHROMATOSIS                  ┆ 197    ┆ 0.000404 │
# │ PLASMACELL_NEOPLASM               ┆ 128    ┆ 0.000263 │
# │ ADDISON_DISEASE                   ┆ 98     ┆ 0.000201 │
# │ SYSTEMIC_SCLEROSIS                ┆ 70     ┆ 0.000144 │
# │ CYSTICFIBROSIS                    ┆ 45     ┆ 0.000092 │
# │ DOWNSSYNDROME                     ┆ 41     ┆ 0.000084 │
# │ SICKLE_CELL_DISEASE               ┆ 24     ┆ 0.000049 │
# └───────────────────────────────────┴────────┴──────────┘

# %% [markdown]
# ## Create models and train

# %%
models, m_names = [], []

# My development model
for tte_layer in ["Exponential", "Geometric"]:
    config = DemoConfig()
    config.TTELayer = tte_layer
    models.append(TTETransformerForCausalSequenceModelling(config, vocab_size).to(device))
    m_names.append(f"TPPTransformerForCausalSequenceModelling: {tte_layer} TTE")
# Out:
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using ExponentialTTELayer. This module predicts the time until next event as an exponential distribution
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using GeometricTTELayer. This module predicts the time until next event as a geometric distribution, supported on the set {0,1,...}

# %%
loss_curves_train = [[] for _ in models]
loss_curves_train_clf = [[] for _ in models]
loss_curves_train_tte = [[] for _ in models]

loss_curves_val = [[] for _ in models]
loss_curves_val_clf = [[] for _ in models]
loss_curves_val_tte = [[] for _ in models]

# %%
for m_idx, (model, m_name) in enumerate(zip(models, m_names)):
    
    print(f"Training model `{m_name}`, with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
    model = model.to(device)

    # create a PyTorch optimizer
    optimizer = torch.optim.AdamW(model.parameters(), lr=opt.learning_rate)

    best_val, epochs_since_best = np.inf, 0
    for epoch in range(opt.epochs):
        epoch_loss, epoch_clf_loss, epoch_tte_loss = 0, 0, 0
        model.train()
        for i, batch in enumerate(dm.train_dataloader()):
            # evaluate the loss
            _, (loss_clf, loss_tte), loss = model(batch['tokens'].to(device), 
                                                  ages=batch['ages'].to(device), 
                                                  attention_mask=batch['attention_mask'].to(device)  
                                                  )
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            # record
            epoch_clf_loss += loss_clf.item()
            epoch_tte_loss += loss_tte.item()
        epoch_loss /= i
        epoch_clf_loss /= i
        epoch_tte_loss /= i
        loss_curves_train[m_idx].append(epoch_loss)
        loss_curves_train_clf[m_idx].append(epoch_clf_loss)
        loss_curves_train_tte[m_idx].append(epoch_tte_loss)

        # evaluate the loss on val set
        with torch.no_grad(): 
            model.eval()
            if epoch % opt.eval_interval == 0 or epoch == opt.epochs - 1:
                val_loss, val_clf_loss, val_tte_loss = 0, 0, 0
                for j, batch in enumerate(dm.val_dataloader()):
                    _, (loss_clf, loss_tte), loss = model(batch['tokens'].to(device), 
                                                          ages=batch['ages'].to(device),
                                                          attention_mask=batch['attention_mask'].to(device) 
                                                          )
                    val_loss += loss.item()
                    # record
                    val_clf_loss += loss_clf.item()
                    val_tte_loss += loss_tte.item()
                val_loss /= j
                val_clf_loss /= j
                val_tte_loss /= j
                loss_curves_val[m_idx].append(val_loss)
                loss_curves_val_clf[m_idx].append(val_clf_loss)
                loss_curves_val_tte[m_idx].append(val_tte_loss)
                print(f"Epoch {epoch}:\tTrain loss {epoch_loss:.2f}  ({epoch_clf_loss:.2f}, {epoch_tte_loss:.2f}). Val loss {val_loss:.2f} ({val_clf_loss:.2f}, {val_tte_loss:.2f})")          
                # TODO: Note not fully accurate as last batch is likely not the same size, will be fixed with lightning
        
            if val_loss >= best_val:
                epochs_since_best += 1
                if epochs_since_best >= 5:
                    break
            else:
                best_val = val_loss
                epochs_since_best = 0

    # Test trained model with a prompt
    # ----------------    
    # set context: diagnosis of depression at 20 years old
    tokens = torch.from_numpy(np.array(dm.encode(["DEPRESSION"])).reshape((1,-1))).to(device)
    ages = torch.tensor([[20*365]], device=device)
    # values = torch.tensor([[torch.nan]], device=device)
    # generate: sample the next 10 tokens
    new_tokens, new_ages = model.generate(tokens, ages, max_new_tokens=10)
    generated = dm.decode(new_tokens[0].tolist())
    # report:
    #    note, Not considering value yet.
    for _cat, _age in zip(generated.split(" "), new_ages[0, :]):
        print(f"\t {_cat} at age {_age/365:.0f} ({_age:.1f} days)")    # with value {_value}
# Out:
# Training model `TPPTransformerForCausalSequenceModelling: Exponential TTE`, with 10.726465 M parameters
# Epoch 0:	Train loss 2.12  (2.81, 1.43). Val loss 2.10 (2.78, 1.42)
# Epoch 1:	Train loss 2.07  (2.74, 1.40). Val loss 2.09 (2.77, 1.41)
# Epoch 2:	Train loss 2.06  (2.72, 1.40). Val loss 2.09 (2.77, 1.41)
# Epoch 3:	Train loss 2.05  (2.71, 1.39). Val loss 2.08 (2.76, 1.41)
# Epoch 4:	Train loss 2.04  (2.69, 1.39). Val loss 2.08 (2.76, 1.41)
# Epoch 5:	Train loss 2.04  (2.69, 1.39). Val loss 2.08 (2.76, 1.41)
# Epoch 6:	Train loss 2.03  (2.68, 1.38). Val loss 2.08 (2.76, 1.41)
# Epoch 7:	Train loss 2.02  (2.67, 1.38). Val loss 2.08 (2.76, 1.41)
# Epoch 8:	Train loss 2.02  (2.66, 1.38). Val loss 2.09 (2.76, 1.41)
# WARNING:root:Using XXX requires value embeddings, but this head ``CURRENTLY`` has no way of sampling value of next event. Setting generated values to nan until this is implemented
# Epoch 9:	Train loss 2.01  (2.65, 1.38). Val loss 2.09 (2.76, 1.41)
# 	 DEPRESSION at age 20 (7300.0 days)
# 	 ANXIETY at age 21 (7610.7 days)
# 	 PREVALENT_IBS at age 24 (8616.8 days)
# 	 ALCOHOLMISUSE at age 30 (10777.6 days)
# 	 OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL at age 37 (13645.4 days)
# 	 EATINGDISORDERS at age 40 (14671.6 days)
# 	 STROKEUNSPECIFIED at age 43 (15716.7 days)
# 	 ENDOMETRIOSIS_ADENOMYOSIS_V2 at age 45 (16415.0 days)
# 	 ALLCA_NOBCC_VFINAL at age 46 (16613.1 days)
# 	 ASTHMA_PUSHASTHMA at age 48 (17660.8 days)
# 	 HAEMOCHROMATOSIS at age 49 (18046.3 days)
# Training model `TPPTransformerForCausalSequenceModelling: Geometric TTE`, with 10.726465 M parameters
# Epoch 0:	Train loss 5.32  (2.83, 7.80). Val loss 5.34 (2.79, 7.89)
# Epoch 1:	Train loss 5.26  (2.75, 7.77). Val loss 5.33 (2.78, 7.88)
# Epoch 2:	Train loss 5.25  (2.73, 7.76). Val loss 5.32 (2.77, 7.86)
# Epoch 3:	Train loss 5.24  (2.72, 7.76). Val loss 5.31 (2.76, 7.87)
# Epoch 4:	Train loss 5.23  (2.71, 7.76). Val loss 5.31 (2.76, 7.86)
# Epoch 5:	Train loss 5.23  (2.70, 7.75). Val loss 5.31 (2.76, 7.86)
# Epoch 6:	Train loss 5.22  (2.69, 7.75). Val loss 5.31 (2.75, 7.87)
# Epoch 7:	Train loss 5.22  (2.68, 7.75). Val loss 5.31 (2.76, 7.86)
# Epoch 8:	Train loss 5.21  (2.68, 7.75). Val loss 5.32 (2.76, 7.87)
# Epoch 9:	Train loss 5.21  (2.67, 7.75). Val loss 5.31 (2.76, 7.86)
# WARNING:root:Using XXX requires value embeddings, but this head ``CURRENTLY`` has no way of sampling value of next event. Setting generated values to nan until this is implemented
# Epoch 10:	Train loss 5.21  (2.67, 7.75). Val loss 5.31 (2.76, 7.86)
# 	 DEPRESSION at age 20 (7300.0 days)
# 	 ANXIETY at age 30 (10860.0 days)
# 	 OSTEOARTHRITIS at age 42 (15439.0 days)
# 	 ASTHMA_PUSHASTHMA at age 43 (15815.0 days)
# 	 COPD at age 46 (16963.0 days)
# 	 SUBSTANCEMISUSE at age 47 (17322.0 days)
# 	 PREVALENT_IBS at age 47 (17323.0 days)
# 	 BRONCHIECTASIS at age 56 (20320.0 days)
# 	 ALLCA_NOBCC_VFINAL at age 56 (20543.0 days)
# 	 STROKEUNSPECIFIED at age 58 (21140.0 days)
# 	 ALCOHOLMISUSE at age 61 (22292.0 days)

# %% [markdown]
# ## Comparing output to real data

# %%
for batch in dm.train_dataloader():
    break
conditions = batch["tokens"].numpy().tolist()
# delta_ages = batch["ages"][:, 1:] - batch["ages"][:, :-1]
for idx, (token, age) in enumerate(zip(conditions[0], batch["ages"][0,:])):
    if token == 0 or idx >= 10:
        break
    print(f"{dm.decode([token])}, at age {age/365:.0f} ({age:.1f} days)")
# Out:
# DEPRESSION, at age 28 (10048.0 days)

# %%
cols = ["k", "r", "b", "y"]

# Plot loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train[m_idx]), len(loss_curves_train[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val[m_idx]), len(loss_curves_val[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/TTE/loss.png")

# Plot classifier loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train_clf[m_idx]), len(loss_curves_train_clf[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train_clf[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val_clf[m_idx]), len(loss_curves_val_clf[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val_clf[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/TTE/loss_clf.png")

# Plot tte loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train_tte[m_idx]), len(loss_curves_train_tte[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train_tte[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val_tte[m_idx]), len(loss_curves_val_tte[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val_tte[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/TTE/loss_tte.png")

# %% [markdown]
# # Prompt testing

# %% [markdown]
# ## Diabetes: How related conditions are impacted by each other
# Probability of type II diabetes before and after a type I diagnosis

# %%
t1_token = dm.tokenizer._stoi["TYPE1DM"]
t2_token = dm.tokenizer._stoi["TYPE2DIABETES"]


base_prompt = ["DEPRESSION"]
ages_in_years = [20]

to_days = lambda a_list: torch.FloatTensor([365 * _a for _a in a_list]).reshape((1,-1)).to(device)

# Create a set of prompts
prompts, ages, values, desc = [], [], [], []
desc.append("Control")
prompts.append(base_prompt)
ages.append(ages_in_years)
desc.append("Type 1")
prompts.append(base_prompt + ["TYPE1DM"])
ages.append(ages_in_years + [21])
desc.append("Type 2")
prompts.append(base_prompt + ["TYPE2DIABETES"])
ages.append(ages_in_years + [21])

for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n--------------------------------------")
    with torch.no_grad(): 
            model.eval()
    
            for p_idx, (prompt, age) in enumerate(zip(prompts, ages)):
                print(f"\n{desc[p_idx]}: \t ({','.join(prompt)}): ")
                encoded_prompt = torch.from_numpy(np.array(dm.encode(prompt)).reshape((1,-1))).to(device)
                (lgts, tte_dist), _, _ = model(encoded_prompt,
                                                       # values=torch.tensor(value).to(device),
                                                       ages=to_days(age),
                                                       is_generation=True)
                probs = torch.nn.functional.softmax(lgts, dim=2)
                print(f"\tprobability of type I diabetes: {100*float(probs[0, 0, t1_token].cpu().detach().numpy()):.4f}%")
                print(f"\tprobability of type II diabetes: {100*float(probs[0, 0, t2_token].cpu().detach().numpy()):.4f}%")

# Note: adding a diagnosis (even if potentially orthogonal) at the beginning of the prompt increases probability of either type
# Out:
# TPPTransformerForCausalSequenceModelling: Exponential TTE
# --------------------------------------
#
# Control: 	 (DEPRESSION):
# 	probability of type I diabetes: 0.1412%
# 	probability of type II diabetes: 0.3065%
#
# Type 1: 	 (DEPRESSION,TYPE1DM):
# 	probability of type I diabetes: 0.0518%
# 	probability of type II diabetes: 3.6401%
#
# Type 2: 	 (DEPRESSION,TYPE2DIABETES):
# 	probability of type I diabetes: 2.1870%
# 	probability of type II diabetes: 0.0495%
#
#
# TPPTransformerForCausalSequenceModelling: Geometric TTE
# --------------------------------------
#
# Control: 	 (DEPRESSION):
# 	probability of type I diabetes: 0.2101%
# 	probability of type II diabetes: 0.2627%
#
# Type 1: 	 (DEPRESSION,TYPE1DM):
# 	probability of type I diabetes: 0.2252%
# 	probability of type II diabetes: 2.2721%
#
# Type 2: 	 (DEPRESSION,TYPE2DIABETES):
# 	probability of type I diabetes: 5.0030%
# 	probability of type II diabetes: 0.0424%

# %% [markdown]
# ## Age: How increasing prompt age affects likelihood of age related diagnoses

# %%
prompt = ["DEPRESSION"]
ages = [[4],[8],[20],[30],[60],[80],[90]]

# target_conditions=["TYPE1DM"]#, "TYPE2DIABETES", "OSTEOARTHRITIS", "ANY_DEAFNESS_HEARING_LOSS"]

for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n--------------------------------------")

    # for condition in target_conditions:
    #     print(f"Probability of {condition}")
    #     target_token = dm.tokenizer._stoi[condition]

    for p_idx, age in enumerate(ages):
        print(f"\nAge {age[-1]}\n======")
        encoded_prompt = torch.from_numpy(np.array(dm.encode(prompt)).reshape((1,-1))).to(device)
        (lgts, tte_dist), _, _ = model(encoded_prompt,
                                       ages=to_days(age),
                                       is_generation=True)
        probs = torch.nn.functional.softmax(lgts, dim=2) * 100

        # top K
        k = 10
        print(f"Top {k}")
        topk_prob, topk_ind = torch.topk(probs[0,0,:], k)
        for i, j in zip(dm.decode(topk_ind.tolist()).split(" "), topk_prob):
            print(f"\t{i}: {j:.2f}%")

        # bottom K
        k = 30
        print(f"Bottom {k}")
        topk_prob, topk_ind = torch.topk(-probs[0,0,:], k)
        for i, j in zip(dm.decode(topk_ind.tolist()).split(" "), topk_prob):
            print(f"\t{i}: {-j:.2f}%")
        
            # print(f"Age: {age[-1]} years old:  {100*float(probs[0, 0, target_token].cpu().detach().numpy()):.4f}%")

# Note: adding a diagnosis (even if potentially orthogonal) at the beginning of the prompt increases probability of either type
# Out:
# TPPTransformerForCausalSequenceModelling: Exponential TTE
# --------------------------------------
#
# Age 4
# ======
# Top 10
# 	ANXIETY: 37.73%
# 	ALLERGICRHINITISCONJ: 10.79%
# 	ASTHMA_PUSHASTHMA: 9.70%
# 	ATOPICECZEMA: 9.27%
# 	AUTISM: 4.22%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.60%
# 	ALCOHOLMISUSE: 3.11%
# 	PREVALENT_IBS: 2.95%
# 	EATINGDISORDERS: 2.50%
# 	EPILEPSY: 2.29%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	ILD_SH: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	PLASMACELL_NEOPLASM: 0.01%
# 	MENIERESDISEASE: 0.01%
# 	PMRANDGCA: 0.01%
# 	PAD_STRICT: 0.01%
# 	PARKINSONS: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	CKDSTAGE3TO5: 0.01%
# 	ALL_DEMENTIA: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	PERNICIOUSANAEMIA: 0.01%
# 	ISCHAEMICSTROKE: 0.01%
# 	MINFARCTION: 0.02%
# 	NAFLD: 0.02%
# 	RHEUMATOIDARTHRITIS: 0.03%
# 	AF: 0.03%
# 	MS: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	LEUKAEMIA_PREVALENCE: 0.04%
#
# Age 8
# ======
# Top 10
# 	ANXIETY: 41.10%
# 	ALLERGICRHINITISCONJ: 9.89%
# 	ATOPICECZEMA: 6.46%
# 	ASTHMA_PUSHASTHMA: 6.02%
# 	PREVALENT_IBS: 4.53%
# 	ALCOHOLMISUSE: 4.12%
# 	SUBSTANCEMISUSE: 3.52%
# 	EATINGDISORDERS: 2.63%
# 	PSORIASIS: 1.98%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.98%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	PLASMACELL_NEOPLASM: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	ILD_SH: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	PARKINSONS: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.03%
# 	PMRANDGCA: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	ISCHAEMICSTROKE: 0.03%
# 	PAD_STRICT: 0.03%
# 	PERNICIOUSANAEMIA: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.04%
# 	MENIERESDISEASE: 0.04%
# 	CKDSTAGE3TO5: 0.04%
# 	NAFLD: 0.04%
# 	HF: 0.05%
# 	BRONCHIECTASIS: 0.06%
# 	STROKE_HAEMRGIC: 0.06%
# 	AF: 0.06%
#
# Age 20
# ======
# Top 10
# 	ANXIETY: 52.56%
# 	ALCOHOLMISUSE: 6.47%
# 	ALLERGICRHINITISCONJ: 5.43%
# 	ATOPICECZEMA: 5.31%
# 	PREVALENT_IBS: 3.93%
# 	ASTHMA_PUSHASTHMA: 2.60%
# 	SUBSTANCEMISUSE: 2.29%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 2.07%
# 	HYPERTENSION: 1.63%
# 	PSORIASIS: 1.61%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	ILD_SH: 0.01%
# 	PARKINSONS: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	BRONCHIECTASIS: 0.03%
# 	PERNICIOUSANAEMIA: 0.03%
# 	PMRANDGCA: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	PAD_STRICT: 0.04%
# 	ISCHAEMICSTROKE: 0.05%
# 	DEPRESSION: 0.05%
# 	HF: 0.05%
# 	AF: 0.06%
# 	STROKE_HAEMRGIC: 0.06%
# 	MS: 0.07%
# 	CKDSTAGE3TO5: 0.08%
#
# Age 30
# ======
# Top 10
# 	ANXIETY: 47.24%
# 	ALLERGICRHINITISCONJ: 6.55%
# 	HYPERTENSION: 4.99%
# 	ALCOHOLMISUSE: 4.31%
# 	ATOPICECZEMA: 4.20%
# 	PREVALENT_IBS: 3.46%
# 	OSTEOARTHRITIS: 3.42%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.41%
# 	ASTHMA_PUSHASTHMA: 2.31%
# 	PSORIASIS: 2.27%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	PLASMACELL_NEOPLASM: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	ILD_SH: 0.02%
# 	HAEMOCHROMATOSIS: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	PARKINSONS: 0.02%
# 	ALL_DEMENTIA: 0.03%
# 	BRONCHIECTASIS: 0.04%
# 	LYMPHOMA_PREVALENCE: 0.04%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.04%
# 	DEPRESSION: 0.04%
# 	AUTISM: 0.05%
# 	PERNICIOUSANAEMIA: 0.05%
# 	PMRANDGCA: 0.06%
# 	LEARNINGDISABILITY: 0.08%
# 	STROKE_HAEMRGIC: 0.08%
# 	VISUAL_IMPAIRMENT: 0.08%
# 	ISCHAEMICSTROKE: 0.09%
# 	PAD_STRICT: 0.09%
# 	MENIERESDISEASE: 0.10%
#
# Age 60
# ======
# Top 10
# 	ANXIETY: 37.74%
# 	HYPERTENSION: 12.73%
# 	OSTEOARTHRITIS: 11.09%
# 	ALLCA_NOBCC_VFINAL: 4.30%
# 	ATOPICECZEMA: 3.68%
# 	ALCOHOLMISUSE: 3.17%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.58%
# 	COPD: 2.35%
# 	HYPOTHYROIDISM_DRAFT_V1: 1.91%
# 	ALLERGICRHINITISCONJ: 1.83%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	HIVAIDS: 0.02%
# 	AUTISM: 0.02%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	PLASMACELL_NEOPLASM: 0.02%
# 	MS: 0.03%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.03%
# 	HAEMOCHROMATOSIS: 0.03%
# 	TYPE1DM: 0.04%
# 	DEPRESSION: 0.04%
# 	CROHNS_DISEASE: 0.05%
# 	LEARNINGDISABILITY: 0.06%
# 	EATINGDISORDERS: 0.06%
# 	LEUKAEMIA_PREVALENCE: 0.06%
# 	CHRONICFATIGUESYNDROMEMM: 0.06%
# 	LYMPHOMA_PREVALENCE: 0.07%
# 	ULCERATIVE_COLITIS: 0.08%
# 	ILD_SH: 0.08%
# 	PERNICIOUSANAEMIA: 0.10%
# 	MENIERESDISEASE: 0.12%
#
# Age 80
# ======
# Top 10
# 	ANXIETY: 22.16%
# 	HYPERTENSION: 14.14%
# 	OSTEOARTHRITIS: 9.57%
# 	ALL_DEMENTIA: 7.88%
# 	ALLCA_NOBCC_VFINAL: 4.72%
# 	OSTEOPOROSIS: 4.56%
# 	ANY_DEAFNESS_HEARING_LOSS: 4.52%
# 	AF: 3.14%
# 	ATOPICECZEMA: 2.07%
# 	CKDSTAGE3TO5: 2.04%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	HIVAIDS: 0.01%
# 	AUTISM: 0.01%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	LEARNINGDISABILITY: 0.01%
# 	MS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	EATINGDISORDERS: 0.02%
# 	OSA: 0.02%
# 	CHRONICFATIGUESYNDROMEMM: 0.03%
# 	PTSDDIAGNOSIS: 0.03%
# 	CROHNS_DISEASE: 0.03%
# 	TYPE1DM: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	FIBROMYALGIA: 0.04%
# 	ULCERATIVE_COLITIS: 0.07%
# 	NAFLD: 0.07%
# 	PLASMACELL_NEOPLASM: 0.07%
# 	DEPRESSION: 0.09%
# 	BRONCHIECTASIS: 0.10%
#
# Age 90
# ======
# Top 10
# 	ANXIETY: 26.30%
# 	ALL_DEMENTIA: 13.79%
# 	HYPERTENSION: 7.48%
# 	OSTEOARTHRITIS: 7.09%
# 	ANY_DEAFNESS_HEARING_LOSS: 5.55%
# 	AF: 4.15%
# 	ALLCA_NOBCC_VFINAL: 3.94%
# 	ATOPICECZEMA: 3.24%
# 	HYPOTHYROIDISM_DRAFT_V1: 3.02%
# 	VISUAL_IMPAIRMENT: 2.85%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	HIVAIDS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	MS: 0.01%
# 	AUTISM: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	TYPE1DM: 0.01%
# 	LEARNINGDISABILITY: 0.02%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.02%
# 	OSA: 0.02%
# 	CROHNS_DISEASE: 0.02%
# 	FIBROMYALGIA: 0.02%
# 	NAFLD: 0.02%
# 	PTSDDIAGNOSIS: 0.03%
# 	ULCERATIVE_COLITIS: 0.04%
# 	DEPRESSION: 0.04%
# 	PLASMACELL_NEOPLASM: 0.04%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.05%
# 	EATINGDISORDERS: 0.05%
#
#
# TPPTransformerForCausalSequenceModelling: Geometric TTE
# --------------------------------------
#
# Age 4
# ======
# Top 10
# 	ANXIETY: 26.55%
# 	ASTHMA_PUSHASTHMA: 22.46%
# 	ALLERGICRHINITISCONJ: 9.77%
# 	ANY_DEAFNESS_HEARING_LOSS: 6.33%
# 	ATOPICECZEMA: 6.24%
# 	EATINGDISORDERS: 4.21%
# 	AUTISM: 3.81%
# 	PREVALENT_IBS: 3.08%
# 	EPILEPSY: 2.02%
# 	ALCOHOLMISUSE: 1.70%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	PERNICIOUSANAEMIA: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	ILD_SH: 0.01%
# 	PARKINSONS: 0.01%
# 	MENIERESDISEASE: 0.01%
# 	PMRANDGCA: 0.01%
# 	MINFARCTION: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	CKDSTAGE3TO5: 0.02%
# 	ADDISON_DISEASE: 0.02%
# 	MS: 0.02%
# 	PAD_STRICT: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	NAFLD: 0.02%
# 	ISCHAEMICSTROKE: 0.03%
# 	AF: 0.03%
# 	RHEUMATOIDARTHRITIS: 0.04%
# 	HF: 0.04%
#
# Age 8
# ======
# Top 10
# 	ANXIETY: 43.22%
# 	ASTHMA_PUSHASTHMA: 11.01%
# 	ALLERGICRHINITISCONJ: 6.64%
# 	ATOPICECZEMA: 5.90%
# 	EATINGDISORDERS: 5.06%
# 	PREVALENT_IBS: 4.18%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.09%
# 	ALCOHOLMISUSE: 2.15%
# 	EPILEPSY: 1.83%
# 	SUBSTANCEMISUSE: 1.78%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	PLASMACELL_NEOPLASM: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	ILD_SH: 0.01%
# 	PERNICIOUSANAEMIA: 0.01%
# 	PARKINSONS: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.02%
# 	ADDISON_DISEASE: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	PMRANDGCA: 0.03%
# 	MENIERESDISEASE: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	NAFLD: 0.03%
# 	PAD_STRICT: 0.04%
# 	MS: 0.04%
# 	HIVAIDS: 0.05%
# 	ISCHAEMICSTROKE: 0.05%
# 	AF: 0.05%
# 	CROHNS_DISEASE: 0.05%
# 	MINFARCTION: 0.05%
# 	DEPRESSION: 0.05%
# 	ALL_DEMENTIA: 0.06%
#
# Age 20
# ======
# Top 10
# 	ANXIETY: 58.08%
# 	ASTHMA_PUSHASTHMA: 5.37%
# 	PREVALENT_IBS: 5.07%
# 	ATOPICECZEMA: 4.45%
# 	ALCOHOLMISUSE: 3.40%
# 	ALLERGICRHINITISCONJ: 3.24%
# 	SUBSTANCEMISUSE: 2.99%
# 	EATINGDISORDERS: 2.28%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 2.18%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.66%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	ILD_SH: 0.00%
# 	PARKINSONS: 0.00%
# 	HAEMOCHROMATOSIS: 0.01%
# 	ALL_DEMENTIA: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	PMRANDGCA: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.02%
# 	BRONCHIECTASIS: 0.02%
# 	PERNICIOUSANAEMIA: 0.02%
# 	ISCHAEMICSTROKE: 0.02%
# 	PSORIATICARTHRITIS2021: 0.02%
# 	PAD_STRICT: 0.02%
# 	AF: 0.02%
# 	MINFARCTION: 0.02%
# 	VISUAL_IMPAIRMENT: 0.02%
# 	HF: 0.02%
# 	MENIERESDISEASE: 0.02%
# 	MS: 0.02%
# 	LYMPHOMA_PREVALENCE: 0.03%
#
# Age 30
# ======
# Top 10
# 	ANXIETY: 56.78%
# 	PREVALENT_IBS: 5.06%
# 	ALLERGICRHINITISCONJ: 4.24%
# 	ASTHMA_PUSHASTHMA: 4.19%
# 	ATOPICECZEMA: 3.42%
# 	ALCOHOLMISUSE: 3.22%
# 	HYPERTENSION: 2.40%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.32%
# 	PERIPHERAL_NEUROPATHY: 2.24%
# 	OSTEOARTHRITIS: 2.14%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	ILD_SH: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	PARKINSONS: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	SJOGRENSSYNDROME: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	BRONCHIECTASIS: 0.03%
# 	PMRANDGCA: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.04%
# 	PERNICIOUSANAEMIA: 0.04%
# 	VISUAL_IMPAIRMENT: 0.04%
# 	DEPRESSION: 0.04%
# 	PAD_STRICT: 0.05%
# 	HF: 0.06%
# 	MS: 0.06%
# 	ISCHAEMICSTROKE: 0.06%
# 	MENIERESDISEASE: 0.06%
# 	AUTISM: 0.06%
#
# Age 60
# ======
# Top 10
# 	ANXIETY: 46.07%
# 	OSTEOARTHRITIS: 8.74%
# 	HYPERTENSION: 8.61%
# 	ATOPICECZEMA: 4.54%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.43%
# 	ALLCA_NOBCC_VFINAL: 2.61%
# 	PREVALENT_IBS: 2.55%
# 	ASTHMA_PUSHASTHMA: 2.39%
# 	ALLERGICRHINITISCONJ: 2.04%
# 	ALCOHOLMISUSE: 2.03%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	ADDISON_DISEASE: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	AUTISM: 0.01%
# 	DEPRESSION: 0.01%
# 	PLASMACELL_NEOPLASM: 0.02%
# 	HAEMOCHROMATOSIS: 0.02%
# 	HIVAIDS: 0.02%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.02%
# 	MS: 0.03%
# 	TYPE1DM: 0.04%
# 	CROHNS_DISEASE: 0.04%
# 	SJOGRENSSYNDROME: 0.04%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.04%
# 	ILD_SH: 0.04%
# 	LEARNINGDISABILITY: 0.05%
# 	ULCERATIVE_COLITIS: 0.05%
# 	LEUKAEMIA_PREVALENCE: 0.06%
# 	LYMPHOMA_PREVALENCE: 0.07%
# 	CHRONICFATIGUESYNDROMEMM: 0.07%
# 	PERNICIOUSANAEMIA: 0.07%
# 	MENIERESDISEASE: 0.08%
# 	AORTICANEURYSM: 0.09%
#
# Age 80
# ======
# Top 10
# 	ANXIETY: 32.98%
# 	ALL_DEMENTIA: 12.57%
# 	HYPERTENSION: 11.39%
# 	ANY_DEAFNESS_HEARING_LOSS: 6.65%
# 	OSTEOARTHRITIS: 6.34%
# 	ALLCA_NOBCC_VFINAL: 2.56%
# 	OSTEOPOROSIS: 2.42%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.07%
# 	CKDSTAGE3TO5: 2.00%
# 	ATOPICECZEMA: 1.88%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.00%
# 	AUTISM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	HAEMOCHROMATOSIS: 0.00%
# 	HIVAIDS: 0.00%
# 	ADDISON_DISEASE: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	MS: 0.01%
# 	LEARNINGDISABILITY: 0.01%
# 	FIBROMYALGIA: 0.01%
# 	CROHNS_DISEASE: 0.01%
# 	TYPE1DM: 0.02%
# 	NAFLD: 0.02%
# 	PTSDDIAGNOSIS: 0.02%
# 	DEPRESSION: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	ULCERATIVE_COLITIS: 0.03%
# 	OSA: 0.03%
# 	EATINGDISORDERS: 0.03%
# 	MENIERESDISEASE: 0.04%
# 	PLASMACELL_NEOPLASM: 0.04%
#
# Age 90
# ======
# Top 10
# 	ANXIETY: 23.03%
# 	ALL_DEMENTIA: 21.70%
# 	OSTEOARTHRITIS: 7.66%
# 	ANY_DEAFNESS_HEARING_LOSS: 7.51%
# 	HYPERTENSION: 7.43%
# 	HYPOTHYROIDISM_DRAFT_V1: 3.31%
# 	ATOPICECZEMA: 2.95%
# 	CKDSTAGE3TO5: 2.76%
# 	ALLCA_NOBCC_VFINAL: 2.58%
# 	VISUAL_IMPAIRMENT: 2.14%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	HIVAIDS: 0.00%
# 	HAEMOCHROMATOSIS: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	MS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	FIBROMYALGIA: 0.01%
# 	AUTISM: 0.01%
# 	NAFLD: 0.02%
# 	CROHNS_DISEASE: 0.02%
# 	PTSDDIAGNOSIS: 0.02%
# 	LEARNINGDISABILITY: 0.02%
# 	ADDISON_DISEASE: 0.02%
# 	OSA: 0.03%
# 	MENIERESDISEASE: 0.03%
# 	TYPE1DM: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	ULCERATIVE_COLITIS: 0.04%
# 	OTHER_CHRONIC_LIVER_DISEASE_OPTIMAL: 0.05%
# 	PLASMACELL_NEOPLASM: 0.05%
# 	ILD_SH: 0.06%

# %% [markdown]
# # Appendix: model architectures

# %%
for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n" + "="*len(m_names[model_idx]))
    print(f"\n\n{model}")
# Out:
# TPPTransformerForCausalSequenceModelling: Exponential TTE
# =========================================================
#
#
# TTETransformerForCausalSequenceModelling(
#   (transformer): TTETransformer(
#     (wpe): TemporalPositionalEncoding()
#     (wte): DataEmbeddingLayer(
#       (token_embed_layer): Embedding(74, 384, padding_idx=0)
#       (value_embed_layer): EmbeddingBag(74, 384, mode=sum, padding_idx=0)
#     )
#     (drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=384, out_features=74, bias=False)
#   (tte_layer): ExponentialTTELayer(
#     (proj): Linear(in_features=384, out_features=1, bias=True)
#   )
# )
#
#
# TPPTransformerForCausalSequenceModelling: Geometric TTE
# =======================================================
#
#
# TTETransformerForCausalSequenceModelling(
#   (transformer): TTETransformer(
#     (wpe): TemporalPositionalEncoding()
#     (wte): DataEmbeddingLayer(
#       (token_embed_layer): Embedding(74, 384, padding_idx=0)
#       (value_embed_layer): EmbeddingBag(74, 384, mode=sum, padding_idx=0)
#     )
#     (drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=384, out_features=74, bias=False)
#   (tte_layer): GeometricTTELayer(
#     (proj): Linear(in_features=384, out_features=1, bias=True)
#   )
# )
