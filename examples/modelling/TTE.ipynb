# %% [markdown]
# # Demo Notebook:
# ## Time to Event Transformer For Causal Sequence Modelling
#
# Including time (and TODO: values)

# %%
import pytorch_lightning 
import torch
import numpy as np
import matplotlib.pyplot as plt
import random
import sqlite3
from dataclasses import dataclass
import logging
from CPRD.data.foundational_loader import FoundationalDataModule
from CPRD.src.models.TTE.task_heads.causal import TTETransformerForCausalSequenceModelling

# TODO:
# replace experiment boilerplate with pytorch lightning

torch.manual_seed(1337)
logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# device = "cpu"    # if more informative debugging statements are needed
# !pwd
# Out:
# cuda
# /rds/homes/g/gaddcz/Projects/CPRD/examples/modelling

# %% [markdown]
# ## Build configurations

# %%
# Set config to be equivalent architecture of kaparthy benchmark, however they are not comparable tasks.
@dataclass
class DemoConfig:
    block_size: int = 256        # what is the maximum context length for predictions?
    n_layer: int = 6
    n_head: int = 6
    n_embd: int = 384
    bias: bool = True
    attention_type: str = "global"    
    dropout: float = 0.0
    unk_freq_threshold: float = 0.0
    TTELayer = "Exponential"

config = DemoConfig()

@dataclass
class OptConfig:
    batch_size: int = 64
    eval_interval: int = 1
    learning_rate: float = 3e-4
    epochs: int = 50
    
opt = OptConfig()

# %% [markdown]
# ## Create data loader on a reduced cohort

# %%
from CPRD.data.database import queries

# Get a list of patients which fit a reduced set of criterion
PATH_TO_DB = "/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModel/preprocessing/processed/cprd.db"
conn = sqlite3.connect(PATH_TO_DB)
cursor = conn.cursor()
# identifiers1 = queries.query_measurement(["bmi", "diastolic_blood_pressure"], cursor)        
identifiers2 = queries.query_diagnosis(["DEPRESSION", "TYPE1DM", "TYPE2DIABETES"], cursor)    #  "DEPRESSION"  ,  "ANXIETY"
# all_identifiers = list(set(identifiers1).intersection(identifiers2))    # Turn smaller list into the set
all_identifiers = identifiers2

if False:
    # Lets take only the first N for faster run-time
    N = np.min((len(all_identifiers), 10000))
    print(f"Using N={N} random samples, from the available {len(all_identifiers)}")
    identifiers = random.choices(all_identifiers, k=N)
else:
    print(f"Using all available {len(all_identifiers)} samples")
    identifiers = all_identifiers

# Build 
dm = FoundationalDataModule(identifiers=identifiers,
                            tokenizer="tabular",    # non-
                            batch_size=opt.batch_size,
                            max_seq_length=config.block_size,
                            unk_freq_threshold=config.unk_freq_threshold,
                            include_measurements=False,
                            include_diagnoses=True
                           )

vocab_size = dm.train_set.tokenizer.vocab_size

print(f"{len(dm.train_set)} training samples")
print(f"{len(dm.val_set)} validation samples")
print(f"{len(dm.test_set)} test samples")
print(f"{vocab_size} vocab elements")
# print(dm.train_set.tokenizer._itos)
# Out:
# INFO:root:Building polars dataset
# Using all available 129717 samples
# INFO:root:Dropping samples with no dynamic events
# INFO:root:Using tabular tokenizer
# 107680 training samples
# 5983 validation samples
# 5982 test samples
# 74 vocab elements

# %%
import polars as pl
pl.Config.set_tbl_rows(vocab_size + 1)
print(dm.tokenizer._event_counts)
# Out:
# shape: (73, 3)
# ┌───────────────────────────────────┬────────┬──────────┐
# │ EVENT                             ┆ counts ┆ freq     │
# │ ---                               ┆ ---    ┆ ---      │
# │ str                               ┆ u32    ┆ f64      │
# ╞═══════════════════════════════════╪════════╪══════════╡
# │ UNK                               ┆ 0      ┆ 0.0      │
# │ DEPRESSION                        ┆ 86549  ┆ 0.177392 │
# │ ANXIETY                           ┆ 48156  ┆ 0.098701 │
# │ HYPERTENSION                      ┆ 32993  ┆ 0.067623 │
# │ TYPE2DIABETES                     ┆ 27348  ┆ 0.056053 │
# │ OSTEOARTHRITIS                    ┆ 25468  ┆ 0.052199 │
# │ ASTHMA_PUSHASTHMA                 ┆ 25278  ┆ 0.05181  │
# │ ATOPICECZEMA                      ┆ 23190  ┆ 0.04753  │
# │ ALLERGICRHINITISCONJ              ┆ 18503  ┆ 0.037924 │
# │ ANY_DEAFNESS_HEARING_LOSS         ┆ 17237  ┆ 0.035329 │
# │ ALLCA_NOBCC_VFINAL                ┆ 11726  ┆ 0.024034 │
# │ PREVALENT_IBS                     ┆ 11722  ┆ 0.024026 │
# │ IHD_NOMI                          ┆ 11287  ┆ 0.023134 │
# │ ALCOHOLMISUSE                     ┆ 11151  ┆ 0.022855 │
# │ CKDSTAGE3TO5                      ┆ 10432  ┆ 0.021382 │
# │ PERIPHERAL_NEUROPATHY             ┆ 8836   ┆ 0.01811  │
# │ HYPOTHYROIDISM_DRAFT_V1           ┆ 7938   ┆ 0.01627  │
# │ COPD                              ┆ 7739   ┆ 0.015862 │
# │ AF                                ┆ 6282   ┆ 0.012876 │
# │ HF                                ┆ 5764   ┆ 0.011814 │
# │ OSTEOPOROSIS                      ┆ 5734   ┆ 0.011752 │
# │ PSORIASIS                         ┆ 5704   ┆ 0.011691 │
# │ SUBSTANCEMISUSE                   ┆ 5545   ┆ 0.011365 │
# │ GOUT                              ┆ 5329   ┆ 0.010922 │
# │ MINFARCTION                       ┆ 4971   ┆ 0.010189 │
# │ STROKEUNSPECIFIED                 ┆ 4517   ┆ 0.009258 │
# │ ALL_DEMENTIA                      ┆ 4425   ┆ 0.00907  │
# │ VALVULARDISEASES                  ┆ 3231   ┆ 0.006622 │
# │ PAD_STRICT                        ┆ 3225   ┆ 0.00661  │
# │ OTHER_CHRONIC_LIVER_DISEASE_OPTI… ┆ 2958   ┆ 0.006063 │
# │ TYPE1DM                           ┆ 2841   ┆ 0.005823 │
# │ EPILEPSY                          ┆ 2569   ┆ 0.005265 │
# │ OSA                               ┆ 2469   ┆ 0.00506  │
# │ FIBROMYALGIA                      ┆ 2410   ┆ 0.00494  │
# │ POLYCYSTIC_OVARIAN_SYNDROME_PCOS  ┆ 2216   ┆ 0.004542 │
# │ NAFLD                             ┆ 2140   ┆ 0.004386 │
# │ RHEUMATOIDARTHRITIS               ┆ 2063   ┆ 0.004228 │
# │ EATINGDISORDERS                   ┆ 2006   ┆ 0.004112 │
# │ PMRANDGCA                         ┆ 1890   ┆ 0.003874 │
# │ HYPERTHYROIDISM                   ┆ 1881   ┆ 0.003855 │
# │ ENDOMETRIOSIS_ADENOMYOSIS_V2      ┆ 1826   ┆ 0.003743 │
# │ PTSDDIAGNOSIS                     ┆ 1686   ┆ 0.003456 │
# │ ISCHAEMICSTROKE                   ┆ 1532   ┆ 0.00314  │
# │ VISUAL_IMPAIRMENT                 ┆ 1420   ┆ 0.00291  │
# │ BIPOLAR                           ┆ 1400   ┆ 0.002869 │
# │ SCHIZOPHRENIAMM                   ┆ 1331   ┆ 0.002728 │
# │ BRONCHIECTASIS                    ┆ 1064   ┆ 0.002181 │
# │ CHRONIC_LIVER_DISEASE_ALCOHOL     ┆ 934    ┆ 0.001914 │
# │ AORTICANEURYSM                    ┆ 884    ┆ 0.001812 │
# │ ULCERATIVE_COLITIS                ┆ 827    ┆ 0.001695 │
# │ CHRONICFATIGUESYNDROMEMM          ┆ 822    ┆ 0.001685 │
# │ LEARNINGDISABILITY                ┆ 740    ┆ 0.001517 │
# │ PARKINSONS                        ┆ 714    ┆ 0.001463 │
# │ MENIERESDISEASE                   ┆ 713    ┆ 0.001461 │
# │ STROKE_HAEMRGIC                   ┆ 705    ┆ 0.001445 │
# │ PERNICIOUSANAEMIA                 ┆ 703    ┆ 0.001441 │
# │ LYMPHOMA_PREVALENCE               ┆ 587    ┆ 0.001203 │
# │ ILD_SH                            ┆ 550    ┆ 0.001127 │
# │ CROHNS_DISEASE                    ┆ 549    ┆ 0.001125 │
# │ AUTISM                            ┆ 512    ┆ 0.001049 │
# │ PSORIATICARTHRITIS2021            ┆ 488    ┆ 0.001    │
# │ MS                                ┆ 432    ┆ 0.000885 │
# │ LEUKAEMIA_PREVALENCE              ┆ 398    ┆ 0.000816 │
# │ HIVAIDS                           ┆ 294    ┆ 0.000603 │
# │ SJOGRENSSYNDROME                  ┆ 247    ┆ 0.000506 │
# │ SYSTEMIC_LUPUS_ERYTHEMATOSUS      ┆ 214    ┆ 0.000439 │
# │ HAEMOCHROMATOSIS                  ┆ 195    ┆ 0.0004   │
# │ PLASMACELL_NEOPLASM               ┆ 124    ┆ 0.000254 │
# │ ADDISON_DISEASE                   ┆ 102    ┆ 0.000209 │
# │ SYSTEMIC_SCLEROSIS                ┆ 71     ┆ 0.000146 │
# │ CYSTICFIBROSIS                    ┆ 45     ┆ 0.000092 │
# │ DOWNSSYNDROME                     ┆ 41     ┆ 0.000084 │
# │ SICKLE_CELL_DISEASE               ┆ 25     ┆ 0.000051 │
# └───────────────────────────────────┴────────┴──────────┘

# %% [markdown]
# ## Create models and train

# %%
models, m_names = [], []

# My development model
for tte_layer in ["Exponential", "Geometric"]:
    config = DemoConfig()
    config.TTELayer = tte_layer
    models.append(TTETransformerForCausalSequenceModelling(config, vocab_size).to(device))
    m_names.append(f"TPPTransformerForCausalSequenceModelling: {tte_layer} TTE")
# Out:
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using ExponentialTTELayer. This module predicts the time until next event as an exponential distribution
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using GeometricTTELayer. This module predicts the time until next event as a geometric distribution, supported on the set {0,1,...}

# %%
loss_curves_train = [[] for _ in models]
loss_curves_train_clf = [[] for _ in models]
loss_curves_train_tte = [[] for _ in models]

loss_curves_val = [[] for _ in models]
loss_curves_val_clf = [[] for _ in models]
loss_curves_val_tte = [[] for _ in models]

# %%
for m_idx, (model, m_name) in enumerate(zip(models, m_names)):
    
    print(f"Training model `{m_name}`, with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
    model = model.to(device)

    # create a PyTorch optimizer
    optimizer = torch.optim.AdamW(model.parameters(), lr=opt.learning_rate)

    best_val, epochs_since_best = np.inf, 0
    for epoch in range(opt.epochs):
        epoch_loss, epoch_clf_loss, epoch_tte_loss = 0, 0, 0
        model.train()
        for i, batch in enumerate(dm.train_dataloader()):
            # evaluate the loss
            _, (loss_clf, loss_tte), loss = model(batch['tokens'].to(device), 
                                                  ages=batch['ages'].to(device), 
                                                  attention_mask=batch['attention_mask'].to(device)  
                                                  )
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            # record
            epoch_clf_loss += loss_clf.item()
            epoch_tte_loss += loss_tte.item()
        epoch_loss /= i
        epoch_clf_loss /= i
        epoch_tte_loss /= i
        loss_curves_train[m_idx].append(epoch_loss)
        loss_curves_train_clf[m_idx].append(epoch_clf_loss)
        loss_curves_train_tte[m_idx].append(epoch_tte_loss)

        # evaluate the loss on val set
        with torch.no_grad(): 
            model.eval()
            if epoch % opt.eval_interval == 0 or epoch == opt.epochs - 1:
                val_loss, val_clf_loss, val_tte_loss = 0, 0, 0
                for j, batch in enumerate(dm.val_dataloader()):
                    _, (loss_clf, loss_tte), loss = model(batch['tokens'].to(device), 
                                                          ages=batch['ages'].to(device),
                                                          attention_mask=batch['attention_mask'].to(device) 
                                                          )
                    val_loss += loss.item()
                    # record
                    val_clf_loss += loss_clf.item()
                    val_tte_loss += loss_tte.item()
                val_loss /= j
                val_clf_loss /= j
                val_tte_loss /= j
                loss_curves_val[m_idx].append(val_loss)
                loss_curves_val_clf[m_idx].append(val_clf_loss)
                loss_curves_val_tte[m_idx].append(val_tte_loss)
                print(f"Epoch {epoch}:\tTrain loss {epoch_loss:.2f}  ({epoch_clf_loss:.2f}, {epoch_tte_loss:.2f}). Val loss {val_loss:.2f} ({val_clf_loss:.2f}, {val_tte_loss:.2f})")          
                # TODO: Note not fully accurate as last batch is likely not the same size, will be fixed with lightning
        
            if val_loss >= best_val:
                epochs_since_best += 1
                if epochs_since_best >= 5:
                    break
            else:
                best_val = val_loss
                epochs_since_best = 0

    # Test trained model with a prompt
    # ----------------    
    # set context: diagnosis of depression at 20 years old
    tokens = torch.from_numpy(np.array(dm.encode(["DEPRESSION"])).reshape((1,-1))).to(device)
    ages = torch.tensor([[20*365]], device=device)
    # values = torch.tensor([[torch.nan]], device=device)
    # generate: sample the next 10 tokens
    new_tokens, new_ages = model.generate(tokens, ages, max_new_tokens=10)
    generated = dm.decode(new_tokens[0].tolist())
    # report:
    #    note, Not considering value yet.
    for _cat, _age in zip(generated.split(" "), new_ages[0, :]):
        print(f"\t {_cat} at age {_age/365:.0f} ({_age:.1f} days)")    # with value {_value}
# Out:
# Training model `TPPTransformerForCausalSequenceModelling: Exponential TTE`, with 10.726465 M parameters
# Epoch 0:	Train loss 2.12  (2.81, 1.43). Val loss 2.10 (2.78, 1.41)
# Epoch 1:	Train loss 2.07  (2.74, 1.40). Val loss 2.08 (2.76, 1.40)
# Epoch 2:	Train loss 2.06  (2.72, 1.40). Val loss 2.08 (2.76, 1.41)
# Epoch 3:	Train loss 2.05  (2.70, 1.39). Val loss 2.08 (2.75, 1.40)
# Epoch 4:	Train loss 2.04  (2.69, 1.39). Val loss 2.08 (2.75, 1.40)
# Epoch 5:	Train loss 2.04  (2.68, 1.39). Val loss 2.07 (2.75, 1.40)
# Epoch 6:	Train loss 2.03  (2.67, 1.38). Val loss 2.08 (2.75, 1.40)
# Epoch 7:	Train loss 2.02  (2.66, 1.38). Val loss 2.08 (2.75, 1.40)
# Epoch 8:	Train loss 2.01  (2.65, 1.38). Val loss 2.09 (2.78, 1.40)
# Epoch 9:	Train loss 2.01  (2.64, 1.38). Val loss 2.09 (2.77, 1.40)
# WARNING:root:Using XXX requires value embeddings, but this head ``CURRENTLY`` has no way of sampling value of next event. Setting generated values to nan until this is implemented
# Epoch 10:	Train loss 2.00  (2.63, 1.38). Val loss 2.09 (2.77, 1.40)
# 	 DEPRESSION at age 20 (7300.0 days)
# 	 ANXIETY at age 20 (7471.2 days)
# 	 ALLERGICRHINITISCONJ at age 24 (8578.7 days)
# 	 ALCOHOLMISUSE at age 30 (10830.3 days)
# 	 SUBSTANCEMISUSE at age 35 (12866.0 days)
# 	 EATINGDISORDERS at age 39 (14194.1 days)
# 	 STROKEUNSPECIFIED at age 42 (15261.3 days)
# 	 ENDOMETRIOSIS_ADENOMYOSIS_V2 at age 44 (16082.8 days)
# 	 PREVALENT_IBS at age 45 (16263.2 days)
# 	 OSTEOARTHRITIS at age 49 (17713.9 days)
# 	 HAEMOCHROMATOSIS at age 50 (18254.2 days)
# Training model `TPPTransformerForCausalSequenceModelling: Geometric TTE`, with 10.726465 M parameters
# Epoch 0:	Train loss 5.32  (2.83, 7.81). Val loss 5.32 (2.80, 7.84)
# Epoch 1:	Train loss 5.26  (2.75, 7.78). Val loss 5.31 (2.77, 7.84)
# Epoch 2:	Train loss 5.25  (2.73, 7.77). Val loss 5.29 (2.76, 7.83)
# Epoch 3:	Train loss 5.24  (2.71, 7.76). Val loss 5.30 (2.76, 7.83)
# Epoch 4:	Train loss 5.23  (2.71, 7.76). Val loss 5.29 (2.75, 7.83)
# Epoch 5:	Train loss 5.23  (2.70, 7.76). Val loss 5.29 (2.75, 7.82)
# Epoch 6:	Train loss 5.22  (2.69, 7.75). Val loss 5.29 (2.75, 7.82)
# Epoch 7:	Train loss 5.22  (2.68, 7.75). Val loss 5.29 (2.76, 7.83)
# Epoch 8:	Train loss 5.21  (2.67, 7.75). Val loss 5.29 (2.76, 7.82)
# Epoch 9:	Train loss 5.21  (2.66, 7.75). Val loss 5.29 (2.76, 7.82)
# WARNING:root:Using XXX requires value embeddings, but this head ``CURRENTLY`` has no way of sampling value of next event. Setting generated values to nan until this is implemented
# Epoch 10:	Train loss 5.20  (2.65, 7.74). Val loss 5.30 (2.77, 7.83)
# 	 DEPRESSION at age 20 (7300.0 days)
# 	 ANXIETY at age 32 (11705.0 days)
# 	 ASTHMA_PUSHASTHMA at age 50 (18083.0 days)
# 	 OSTEOARTHRITIS at age 50 (18366.0 days)
# 	 HYPERTENSION at age 54 (19690.0 days)
# 	 SUBSTANCEMISUSE at age 55 (20039.0 days)
# 	 ALLCA_NOBCC_VFINAL at age 55 (20040.0 days)
# 	 OSTEOPOROSIS at age 62 (22484.0 days)
# 	 COPD at age 62 (22805.0 days)
# 	 ANY_DEAFNESS_HEARING_LOSS at age 65 (23904.0 days)
# 	 ALCOHOLMISUSE at age 70 (25482.0 days)

# %% [markdown]
# ## Comparing output to real data

# %%
for batch in dm.train_dataloader():
    break
conditions = batch["tokens"].numpy().tolist()
# delta_ages = batch["ages"][:, 1:] - batch["ages"][:, :-1]
for idx, (token, age) in enumerate(zip(conditions[0], batch["ages"][0,:])):
    if token == 0 or idx >= 10:
        break
    print(f"{dm.decode([token])}, at age {age/365:.0f} ({age:.1f} days)")
# Out:
# TYPE2DIABETES, at age 44 (16204.0 days)
# ALCOHOLMISUSE, at age 44 (16205.0 days)
# VISUAL_IMPAIRMENT, at age 47 (17310.0 days)

# %%
cols = ["k", "r", "b", "y"]

# Plot loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train[m_idx]), len(loss_curves_train[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val[m_idx]), len(loss_curves_val[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/loss_curves_TPP.png")

# Plot classifier loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train_clf[m_idx]), len(loss_curves_train_clf[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train_clf[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val_clf[m_idx]), len(loss_curves_val_clf[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val_clf[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/loss_clf_curves_TPP.png")

# Plot tte loss
plt.figure()
for m_idx, _ in enumerate(models):
    # Training
    iterations = np.linspace(0, len(loss_curves_train_tte[m_idx]), len(loss_curves_train_tte[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_train_tte[m_idx], label=f"{m_names[m_idx]}-train", c=cols[m_idx], linestyle='dashed')
    # Validation
    iterations = np.linspace(0, len(loss_curves_val_tte[m_idx]), len(loss_curves_val_tte[m_idx])) * opt.eval_interval
    plt.plot(iterations, loss_curves_val_tte[m_idx], label=f"{m_names[m_idx]}-val", c=cols[m_idx])
plt.legend()
plt.savefig(f"figs/loss_tte_curves_TPP.png")

# %% [markdown]
# # Prompt testing

# %% [markdown]
# ## Diabetes: How related conditions are impacted by each other
# Probability of type II diabetes before and after a type I diagnosis

# %%
t1_token = dm.tokenizer._stoi["TYPE1DM"]
t2_token = dm.tokenizer._stoi["TYPE2DIABETES"]


base_prompt = ["DEPRESSION"]
ages_in_years = [20]

to_days = lambda a_list: torch.FloatTensor([365 * _a for _a in a_list]).reshape((1,-1)).to(device)

# Create a set of prompts
prompts, ages, values, desc = [], [], [], []
desc.append("Control")
prompts.append(base_prompt)
ages.append(ages_in_years)
desc.append("Type 1")
prompts.append(base_prompt + ["TYPE1DM"])
ages.append(ages_in_years + [21])
desc.append("Type 2")
prompts.append(base_prompt + ["TYPE2DIABETES"])
ages.append(ages_in_years + [21])

for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n--------------------------------------")
    with torch.no_grad(): 
            model.eval()
    
            for p_idx, (prompt, age) in enumerate(zip(prompts, ages)):
                print(f"\n{desc[p_idx]}: \t ({','.join(prompt)}): ")
                encoded_prompt = torch.from_numpy(np.array(dm.encode(prompt)).reshape((1,-1))).to(device)
                (lgts, tte_dist), _, _ = model(encoded_prompt,
                                                       # values=torch.tensor(value).to(device),
                                                       ages=to_days(age),
                                                       is_generation=True)
                probs = torch.nn.functional.softmax(lgts, dim=2)
                print(f"\tprobability of type I diabetes: {100*float(probs[0, 0, t1_token].cpu().detach().numpy()):.4f}%")
                print(f"\tprobability of type II diabetes: {100*float(probs[0, 0, t2_token].cpu().detach().numpy()):.4f}%")

# Note: adding a diagnosis (even if potentially orthogonal) at the beginning of the prompt increases probability of either type
# Out:
# TPPTransformerForCausalSequenceModelling: Exponential TTE
# --------------------------------------
#
# Control: 	 (DEPRESSION):
# 	probability of type I diabetes: 0.0953%
# 	probability of type II diabetes: 0.2039%
#
# Type 1: 	 (DEPRESSION,TYPE1DM):
# 	probability of type I diabetes: 0.0361%
# 	probability of type II diabetes: 5.1426%
#
# Type 2: 	 (DEPRESSION,TYPE2DIABETES):
# 	probability of type I diabetes: 4.1684%
# 	probability of type II diabetes: 0.0111%
#
#
# TPPTransformerForCausalSequenceModelling: Geometric TTE
# --------------------------------------
#
# Control: 	 (DEPRESSION):
# 	probability of type I diabetes: 0.0873%
# 	probability of type II diabetes: 0.3486%
#
# Type 1: 	 (DEPRESSION,TYPE1DM):
# 	probability of type I diabetes: 0.1112%
# 	probability of type II diabetes: 5.6907%
#
# Type 2: 	 (DEPRESSION,TYPE2DIABETES):
# 	probability of type I diabetes: 2.3168%
# 	probability of type II diabetes: 0.0274%

# %% [markdown]
# ## Age: How increasing prompt age affects likelihood of age related diagnoses

# %%
prompt = ["DEPRESSION"]
ages = [[4],[8],[20],[30],[60],[80],[90]]

# target_conditions=["TYPE1DM"]#, "TYPE2DIABETES", "OSTEOARTHRITIS", "ANY_DEAFNESS_HEARING_LOSS"]

for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n--------------------------------------")

    # for condition in target_conditions:
    #     print(f"Probability of {condition}")
    #     target_token = dm.tokenizer._stoi[condition]

    for p_idx, age in enumerate(ages):
        print(f"\nAge {age[-1]}\n======")
        encoded_prompt = torch.from_numpy(np.array(dm.encode(prompt)).reshape((1,-1))).to(device)
        (lgts, tte_dist), _, _ = model(encoded_prompt,
                                       ages=to_days(age),
                                       is_generation=True)
        probs = torch.nn.functional.softmax(lgts, dim=2) * 100

        # top K
        k = 10
        print(f"Top {k}")
        topk_prob, topk_ind = torch.topk(probs[0,0,:], k)
        for i, j in zip(dm.decode(topk_ind.tolist()).split(" "), topk_prob):
            print(f"\t{i}: {j:.2f}%")

        # bottom K
        k = 30
        print(f"Bottom {k}")
        topk_prob, topk_ind = torch.topk(-probs[0,0,:], k)
        for i, j in zip(dm.decode(topk_ind.tolist()).split(" "), topk_prob):
            print(f"\t{i}: {-j:.2f}%")
        
            # print(f"Age: {age[-1]} years old:  {100*float(probs[0, 0, target_token].cpu().detach().numpy()):.4f}%")

# Note: adding a diagnosis (even if potentially orthogonal) at the beginning of the prompt increases probability of either type
# Out:
# TPPTransformerForCausalSequenceModelling: Exponential TTE
# --------------------------------------
#
# Age 4
# ======
# Top 10
# 	ANXIETY: 41.19%
# 	ALLERGICRHINITISCONJ: 12.48%
# 	ATOPICECZEMA: 9.07%
# 	ASTHMA_PUSHASTHMA: 8.40%
# 	ANY_DEAFNESS_HEARING_LOSS: 6.23%
# 	AUTISM: 3.96%
# 	EATINGDISORDERS: 3.41%
# 	PREVALENT_IBS: 3.02%
# 	SUBSTANCEMISUSE: 1.58%
# 	ALCOHOLMISUSE: 1.31%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	PERNICIOUSANAEMIA: 0.00%
# 	MENIERESDISEASE: 0.00%
# 	HAEMOCHROMATOSIS: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	SJOGRENSSYNDROME: 0.01%
# 	PLASMACELL_NEOPLASM: 0.01%
# 	PMRANDGCA: 0.01%
# 	PAD_STRICT: 0.01%
# 	PARKINSONS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	CKDSTAGE3TO5: 0.01%
# 	ISCHAEMICSTROKE: 0.01%
# 	ILD_SH: 0.01%
# 	MINFARCTION: 0.01%
# 	ALL_DEMENTIA: 0.01%
# 	NAFLD: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	ADDISON_DISEASE: 0.02%
# 	STROKE_HAEMRGIC: 0.02%
# 	RHEUMATOIDARTHRITIS: 0.02%
# 	AF: 0.03%
# 	MS: 0.03%
#
# Age 8
# ======
# Top 10
# 	ANXIETY: 47.96%
# 	ATOPICECZEMA: 9.17%
# 	ALLERGICRHINITISCONJ: 6.09%
# 	ASTHMA_PUSHASTHMA: 6.08%
# 	ANY_DEAFNESS_HEARING_LOSS: 4.40%
# 	EATINGDISORDERS: 4.19%
# 	PREVALENT_IBS: 3.53%
# 	AUTISM: 3.34%
# 	SUBSTANCEMISUSE: 2.20%
# 	ALCOHOLMISUSE: 2.01%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	HAEMOCHROMATOSIS: 0.00%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	ILD_SH: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	MENIERESDISEASE: 0.01%
# 	PAD_STRICT: 0.01%
# 	PERNICIOUSANAEMIA: 0.01%
# 	ISCHAEMICSTROKE: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	PMRANDGCA: 0.01%
# 	PARKINSONS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	ADDISON_DISEASE: 0.02%
# 	STROKE_HAEMRGIC: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	MINFARCTION: 0.02%
# 	CKDSTAGE3TO5: 0.02%
# 	NAFLD: 0.03%
# 	HF: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	AF: 0.04%
#
# Age 20
# ======
# Top 10
# 	ANXIETY: 59.65%
# 	PREVALENT_IBS: 4.99%
# 	ATOPICECZEMA: 4.44%
# 	ALCOHOLMISUSE: 4.44%
# 	ALLERGICRHINITISCONJ: 3.86%
# 	ASTHMA_PUSHASTHMA: 2.72%
# 	SUBSTANCEMISUSE: 2.60%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 1.64%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.63%
# 	EATINGDISORDERS: 1.37%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	ILD_SH: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	PARKINSONS: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	SJOGRENSSYNDROME: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	ISCHAEMICSTROKE: 0.02%
# 	PAD_STRICT: 0.03%
# 	BRONCHIECTASIS: 0.03%
# 	PERNICIOUSANAEMIA: 0.03%
# 	PMRANDGCA: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	AF: 0.04%
# 	VISUAL_IMPAIRMENT: 0.04%
# 	LYMPHOMA_PREVALENCE: 0.04%
# 	STROKE_HAEMRGIC: 0.05%
# 	MINFARCTION: 0.05%
# 	MENIERESDISEASE: 0.05%
# 	DEPRESSION: 0.05%
#
# Age 30
# ======
# Top 10
# 	ANXIETY: 47.30%
# 	ALLERGICRHINITISCONJ: 5.80%
# 	PREVALENT_IBS: 5.17%
# 	OSTEOARTHRITIS: 4.25%
# 	ATOPICECZEMA: 4.15%
# 	ALCOHOLMISUSE: 3.78%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.75%
# 	HYPERTENSION: 3.32%
# 	PERIPHERAL_NEUROPATHY: 2.55%
# 	ASTHMA_PUSHASTHMA: 2.53%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	PARKINSONS: 0.01%
# 	ILD_SH: 0.01%
# 	ALL_DEMENTIA: 0.02%
# 	VISUAL_IMPAIRMENT: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	HAEMOCHROMATOSIS: 0.03%
# 	PSORIATICARTHRITIS2021: 0.03%
# 	LEARNINGDISABILITY: 0.04%
# 	ISCHAEMICSTROKE: 0.04%
# 	AUTISM: 0.04%
# 	BRONCHIECTASIS: 0.05%
# 	LYMPHOMA_PREVALENCE: 0.05%
# 	PERNICIOUSANAEMIA: 0.05%
# 	MENIERESDISEASE: 0.06%
# 	PAD_STRICT: 0.06%
# 	PMRANDGCA: 0.06%
# 	AF: 0.06%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.07%
# 	STROKE_HAEMRGIC: 0.07%
#
# Age 60
# ======
# Top 10
# 	ANXIETY: 47.19%
# 	HYPERTENSION: 9.13%
# 	OSTEOARTHRITIS: 8.40%
# 	ATOPICECZEMA: 3.64%
# 	ALCOHOLMISUSE: 3.51%
# 	ANY_DEAFNESS_HEARING_LOSS: 3.37%
# 	ALLERGICRHINITISCONJ: 2.35%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.34%
# 	ALLCA_NOBCC_VFINAL: 2.15%
# 	COPD: 2.08%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	AUTISM: 0.01%
# 	HIVAIDS: 0.02%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.02%
# 	PLASMACELL_NEOPLASM: 0.02%
# 	TYPE1DM: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	PSORIATICARTHRITIS2021: 0.03%
# 	HAEMOCHROMATOSIS: 0.03%
# 	ILD_SH: 0.03%
# 	LEUKAEMIA_PREVALENCE: 0.04%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.04%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.05%
# 	LEARNINGDISABILITY: 0.05%
# 	ULCERATIVE_COLITIS: 0.06%
# 	LYMPHOMA_PREVALENCE: 0.07%
# 	PERNICIOUSANAEMIA: 0.07%
# 	CROHNS_DISEASE: 0.07%
# 	MS: 0.07%
# 	DEPRESSION: 0.07%
# 	CHRONICFATIGUESYNDROMEMM: 0.07%
# 	SCHIZOPHRENIAMM: 0.08%
# 	MENIERESDISEASE: 0.08%
#
# Age 80
# ======
# Top 10
# 	ANXIETY: 35.50%
# 	HYPERTENSION: 9.98%
# 	ALL_DEMENTIA: 8.82%
# 	ANY_DEAFNESS_HEARING_LOSS: 7.99%
# 	OSTEOARTHRITIS: 5.85%
# 	ALLCA_NOBCC_VFINAL: 3.98%
# 	OSTEOPOROSIS: 2.96%
# 	ATOPICECZEMA: 2.91%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.65%
# 	COPD: 2.50%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	HIVAIDS: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	AUTISM: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	TYPE1DM: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	MS: 0.01%
# 	CHRONICFATIGUESYNDROMEMM: 0.01%
# 	LEARNINGDISABILITY: 0.01%
# 	HAEMOCHROMATOSIS: 0.02%
# 	FIBROMYALGIA: 0.02%
# 	CROHNS_DISEASE: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	OSA: 0.02%
# 	PTSDDIAGNOSIS: 0.03%
# 	NAFLD: 0.05%
# 	ULCERATIVE_COLITIS: 0.05%
# 	MENIERESDISEASE: 0.05%
# 	DEPRESSION: 0.06%
# 	ILD_SH: 0.06%
# 	PLASMACELL_NEOPLASM: 0.08%
#
# Age 90
# ======
# Top 10
# 	ANXIETY: 22.81%
# 	ALL_DEMENTIA: 19.23%
# 	ANY_DEAFNESS_HEARING_LOSS: 14.97%
# 	OSTEOARTHRITIS: 6.11%
# 	HYPERTENSION: 5.70%
# 	ALLCA_NOBCC_VFINAL: 4.15%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.68%
# 	HF: 2.21%
# 	ATOPICECZEMA: 2.01%
# 	AF: 1.95%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	HIVAIDS: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	MS: 0.00%
# 	CHRONICFATIGUESYNDROMEMM: 0.00%
# 	TYPE1DM: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.01%
# 	AUTISM: 0.01%
# 	LEARNINGDISABILITY: 0.01%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	CROHNS_DISEASE: 0.01%
# 	OSA: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	FIBROMYALGIA: 0.02%
# 	PTSDDIAGNOSIS: 0.02%
# 	DEPRESSION: 0.02%
# 	MENIERESDISEASE: 0.03%
# 	SJOGRENSSYNDROME: 0.03%
# 	NAFLD: 0.03%
# 	ULCERATIVE_COLITIS: 0.04%
# 	ADDISON_DISEASE: 0.04%
# 	SCHIZOPHRENIAMM: 0.05%
# 	RHEUMATOIDARTHRITIS: 0.08%
#
#
# TPPTransformerForCausalSequenceModelling: Geometric TTE
# --------------------------------------
#
# Age 4
# ======
# Top 10
# 	ANXIETY: 38.73%
# 	ALLERGICRHINITISCONJ: 11.16%
# 	ATOPICECZEMA: 10.88%
# 	ASTHMA_PUSHASTHMA: 9.12%
# 	ANY_DEAFNESS_HEARING_LOSS: 5.66%
# 	PREVALENT_IBS: 4.30%
# 	ALCOHOLMISUSE: 2.84%
# 	AUTISM: 1.89%
# 	EPILEPSY: 1.73%
# 	PSORIASIS: 1.67%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	AORTICANEURYSM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	PARKINSONS: 0.01%
# 	ILD_SH: 0.01%
# 	DOWNSSYNDROME: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	SJOGRENSSYNDROME: 0.01%
# 	PERNICIOUSANAEMIA: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	PMRANDGCA: 0.02%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.02%
# 	ALL_DEMENTIA: 0.02%
# 	MENIERESDISEASE: 0.02%
# 	ISCHAEMICSTROKE: 0.02%
# 	ADDISON_DISEASE: 0.02%
# 	CKDSTAGE3TO5: 0.03%
# 	NAFLD: 0.03%
# 	MS: 0.03%
# 	STROKE_HAEMRGIC: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	HF: 0.03%
# 	PAD_STRICT: 0.03%
# 	CROHNS_DISEASE: 0.04%
#
# Age 8
# ======
# Top 10
# 	ANXIETY: 53.66%
# 	ALLERGICRHINITISCONJ: 6.20%
# 	ATOPICECZEMA: 5.90%
# 	ASTHMA_PUSHASTHMA: 5.79%
# 	PREVALENT_IBS: 5.08%
# 	ALCOHOLMISUSE: 4.11%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.49%
# 	SUBSTANCEMISUSE: 1.63%
# 	EATINGDISORDERS: 1.35%
# 	PSORIASIS: 1.19%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	DOWNSSYNDROME: 0.01%
# 	ILD_SH: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	PARKINSONS: 0.02%
# 	LEUKAEMIA_PREVALENCE: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	PERNICIOUSANAEMIA: 0.03%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.03%
# 	DEPRESSION: 0.03%
# 	STROKE_HAEMRGIC: 0.03%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	ISCHAEMICSTROKE: 0.04%
# 	MS: 0.04%
# 	CROHNS_DISEASE: 0.04%
# 	NAFLD: 0.04%
# 	PMRANDGCA: 0.04%
# 	MENIERESDISEASE: 0.05%
# 	ALL_DEMENTIA: 0.05%
# 	PAD_STRICT: 0.06%
# 	BRONCHIECTASIS: 0.07%
#
# Age 20
# ======
# Top 10
# 	ANXIETY: 58.46%
# 	PREVALENT_IBS: 5.74%
# 	ALCOHOLMISUSE: 5.30%
# 	ASTHMA_PUSHASTHMA: 4.36%
# 	ATOPICECZEMA: 3.90%
# 	ALLERGICRHINITISCONJ: 2.75%
# 	SUBSTANCEMISUSE: 2.13%
# 	ANY_DEAFNESS_HEARING_LOSS: 1.58%
# 	OSTEOARTHRITIS: 1.38%
# 	HYPERTENSION: 1.28%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	ADDISON_DISEASE: 0.01%
# 	AORTICANEURYSM: 0.01%
# 	ILD_SH: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	PARKINSONS: 0.02%
# 	DEPRESSION: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	LYMPHOMA_PREVALENCE: 0.03%
# 	ALL_DEMENTIA: 0.03%
# 	BRONCHIECTASIS: 0.03%
# 	STROKE_HAEMRGIC: 0.04%
# 	ISCHAEMICSTROKE: 0.04%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.05%
# 	MS: 0.05%
# 	PMRANDGCA: 0.05%
# 	VISUAL_IMPAIRMENT: 0.06%
# 	PAD_STRICT: 0.06%
# 	CROHNS_DISEASE: 0.06%
# 	AF: 0.06%
# 	PERNICIOUSANAEMIA: 0.06%
#
# Age 30
# ======
# Top 10
# 	ANXIETY: 53.64%
# 	PREVALENT_IBS: 5.86%
# 	ALCOHOLMISUSE: 5.33%
# 	ATOPICECZEMA: 3.87%
# 	ALLERGICRHINITISCONJ: 3.83%
# 	ASTHMA_PUSHASTHMA: 3.62%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.45%
# 	HYPERTENSION: 2.19%
# 	PERIPHERAL_NEUROPATHY: 2.10%
# 	OSTEOARTHRITIS: 1.93%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	PLASMACELL_NEOPLASM: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AORTICANEURYSM: 0.01%
# 	ILD_SH: 0.01%
# 	ADDISON_DISEASE: 0.01%
# 	LEUKAEMIA_PREVALENCE: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	PARKINSONS: 0.02%
# 	DEPRESSION: 0.02%
# 	HAEMOCHROMATOSIS: 0.02%
# 	SJOGRENSSYNDROME: 0.03%
# 	ALL_DEMENTIA: 0.03%
# 	BRONCHIECTASIS: 0.04%
# 	LYMPHOMA_PREVALENCE: 0.04%
# 	ISCHAEMICSTROKE: 0.05%
# 	AUTISM: 0.05%
# 	STROKE_HAEMRGIC: 0.06%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.06%
# 	CROHNS_DISEASE: 0.06%
# 	PAD_STRICT: 0.06%
# 	MS: 0.07%
# 	TYPE1DM: 0.07%
# 	PMRANDGCA: 0.07%
# 	VISUAL_IMPAIRMENT: 0.07%
#
# Age 60
# ======
# Top 10
# 	ANXIETY: 38.13%
# 	OSTEOARTHRITIS: 10.59%
# 	HYPERTENSION: 7.60%
# 	ATOPICECZEMA: 4.78%
# 	ALCOHOLMISUSE: 4.27%
# 	ANY_DEAFNESS_HEARING_LOSS: 2.92%
# 	ALLCA_NOBCC_VFINAL: 2.79%
# 	PREVALENT_IBS: 2.76%
# 	COPD: 2.66%
# 	TYPE2DIABETES: 2.38%
# Bottom 30
# 	UNK: 0.00%
# 	PAD: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.01%
# 	PSORIATICARTHRITIS2021: 0.01%
# 	AUTISM: 0.01%
# 	PLASMACELL_NEOPLASM: 0.02%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.02%
# 	DEPRESSION: 0.03%
# 	HAEMOCHROMATOSIS: 0.03%
# 	HIVAIDS: 0.03%
# 	ILD_SH: 0.03%
# 	MS: 0.04%
# 	CROHNS_DISEASE: 0.04%
# 	TYPE1DM: 0.05%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.05%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.05%
# 	SJOGRENSSYNDROME: 0.05%
# 	LEUKAEMIA_PREVALENCE: 0.06%
# 	LYMPHOMA_PREVALENCE: 0.06%
# 	LEARNINGDISABILITY: 0.08%
# 	EATINGDISORDERS: 0.09%
# 	CHRONICFATIGUESYNDROMEMM: 0.09%
# 	AORTICANEURYSM: 0.10%
# 	ULCERATIVE_COLITIS: 0.10%
# 	STROKE_HAEMRGIC: 0.11%
#
# Age 80
# ======
# Top 10
# 	ANXIETY: 21.63%
# 	ALL_DEMENTIA: 17.13%
# 	HYPERTENSION: 8.33%
# 	OSTEOARTHRITIS: 7.77%
# 	ANY_DEAFNESS_HEARING_LOSS: 5.61%
# 	OSTEOPOROSIS: 5.41%
# 	ALLCA_NOBCC_VFINAL: 3.25%
# 	CKDSTAGE3TO5: 2.51%
# 	COPD: 2.48%
# 	HF: 2.36%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	AUTISM: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.00%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.00%
# 	CHRONICFATIGUESYNDROMEMM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	MS: 0.01%
# 	HIVAIDS: 0.01%
# 	HAEMOCHROMATOSIS: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	FIBROMYALGIA: 0.01%
# 	CROHNS_DISEASE: 0.01%
# 	EATINGDISORDERS: 0.02%
# 	LEARNINGDISABILITY: 0.02%
# 	PTSDDIAGNOSIS: 0.02%
# 	SJOGRENSSYNDROME: 0.02%
# 	TYPE1DM: 0.02%
# 	DEPRESSION: 0.03%
# 	OSA: 0.04%
# 	NAFLD: 0.04%
# 	ULCERATIVE_COLITIS: 0.04%
# 	PLASMACELL_NEOPLASM: 0.04%
# 	ILD_SH: 0.05%
#
# Age 90
# ======
# Top 10
# 	ALL_DEMENTIA: 33.35%
# 	ANXIETY: 10.26%
# 	HYPERTENSION: 8.76%
# 	OSTEOARTHRITIS: 7.09%
# 	ANY_DEAFNESS_HEARING_LOSS: 4.75%
# 	ALLCA_NOBCC_VFINAL: 3.61%
# 	CKDSTAGE3TO5: 2.88%
# 	HYPOTHYROIDISM_DRAFT_V1: 2.61%
# 	OSTEOPOROSIS: 2.59%
# 	VISUAL_IMPAIRMENT: 2.55%
# Bottom 30
# 	PAD: 0.00%
# 	UNK: 0.00%
# 	CYSTICFIBROSIS: 0.00%
# 	SICKLE_CELL_DISEASE: 0.00%
# 	PSORIATICARTHRITIS2021: 0.00%
# 	SYSTEMIC_SCLEROSIS: 0.00%
# 	ENDOMETRIOSIS_ADENOMYOSIS_V2: 0.00%
# 	DOWNSSYNDROME: 0.00%
# 	ADDISON_DISEASE: 0.00%
# 	HIVAIDS: 0.00%
# 	HAEMOCHROMATOSIS: 0.00%
# 	CHRONICFATIGUESYNDROMEMM: 0.00%
# 	POLYCYSTIC_OVARIAN_SYNDROME_PCOS: 0.00%
# 	AUTISM: 0.00%
# 	CHRONIC_LIVER_DISEASE_ALCOHOL: 0.01%
# 	SYSTEMIC_LUPUS_ERYTHEMATOSUS: 0.01%
# 	CROHNS_DISEASE: 0.01%
# 	MS: 0.01%
# 	FIBROMYALGIA: 0.01%
# 	PTSDDIAGNOSIS: 0.02%
# 	NAFLD: 0.02%
# 	ULCERATIVE_COLITIS: 0.02%
# 	SJOGRENSSYNDROME: 0.03%
# 	TYPE1DM: 0.03%
# 	EATINGDISORDERS: 0.03%
# 	LEARNINGDISABILITY: 0.03%
# 	LEUKAEMIA_PREVALENCE: 0.04%
# 	ILD_SH: 0.04%
# 	OSA: 0.04%
# 	PLASMACELL_NEOPLASM: 0.05%

# %% [markdown]
# # Appendix: model architectures

# %%
for model_idx, model in enumerate(models):
    print(f"\n\n{m_names[model_idx]}\n" + "="*len(m_names[model_idx]))
    print(f"\n\n{model}")
# Out:
# TPPTransformerForCausalSequenceModelling: Exponential TTE
# =========================================================
#
#
# TTETransformerForCausalSequenceModelling(
#   (transformer): TTETransformer(
#     (wpe): TemporalPositionalEncoding()
#     (wte): DataEmbeddingLayer(
#       (token_embed_layer): Embedding(74, 384, padding_idx=0)
#       (value_embed_layer): EmbeddingBag(74, 384, mode=sum, padding_idx=0)
#     )
#     (drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=384, out_features=74, bias=False)
#   (tte_layer): ExponentialTTELayer(
#     (proj): Linear(in_features=384, out_features=1, bias=True)
#   )
# )
#
#
# TPPTransformerForCausalSequenceModelling: Geometric TTE
# =======================================================
#
#
# TTETransformerForCausalSequenceModelling(
#   (transformer): TTETransformer(
#     (wpe): TemporalPositionalEncoding()
#     (wte): DataEmbeddingLayer(
#       (token_embed_layer): Embedding(74, 384, padding_idx=0)
#       (value_embed_layer): EmbeddingBag(74, 384, mode=sum, padding_idx=0)
#     )
#     (drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadedSelfAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=384, out_features=384, bias=False)
#           (v_proj): Linear(in_features=384, out_features=384, bias=False)
#           (q_proj): Linear(in_features=384, out_features=384, bias=False)
#           (out_proj): Linear(in_features=384, out_features=384, bias=True)
#         )
#         (ln_2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (acti): ReLU()
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=384, out_features=74, bias=False)
#   (tte_layer): GeometricTTELayer(
#     (proj): Linear(in_features=384, out_features=1, bias=True)
#   )
# )
